# %%
# Connect to DB

import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)

mycursor = mydb.cursor()
print('connect')

entity = 'company'
# Out:
# connect

# %%
# insert new job_vacancies 

# set query 1
select = ' company_id, ' + entity 
fromdb = 'jobstreet_raws'
where = ' where company_id is not null '
group = ' group by ' + select
orderby = ' Order By company_id  ASC ' 
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group + orderby )
myresult = mycursor.fetchall()
  
print('Start and Please Wait..')
# loop query 1
for x in myresult:  
    idx = str(x[0])
    word = x[1].replace("'", "\\'") 
    
    print(word)

    query3 = "INSERT INTO companies (nama, raw_id) VALUES ('" + word + "', '" + idx + "')"
    print(query3)
    mycursor.execute(query3)
    mydb.commit()  

    query4 = "UPDATE jobstreet_raws_rc SET "+entity+" = '--extracted--'   " 
    where4 = "  where id = '" + idx + "'"  
    print(query4 + where4)
    mycursor.execute(query4 + where4)
    mydb.commit()  
         
print('Done : ' + str(len(myresult)) + ' row(s)')
# Out:
# Start and Please Wait..
# (Ef) English First For Adults Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('(Ef) English First For Adults Indonesia', '1')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '1'
# (Ef) English First For Adults Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('(Ef) English First For Adults Indonesia', '2')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '2'
# 3.6.9. Group
# INSERT INTO companies (nama, raw_id) VALUES ('3.6.9. Group', '3')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '3'
# 3E Accounting PTe Ltd
# INSERT INTO companies (nama, raw_id) VALUES ('3E Accounting PTe Ltd', '4')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '4'
# A For Effort
# INSERT INTO companies (nama, raw_id) VALUES ('A For Effort', '5')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '5'
# A&W Restaurants Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('A&W Restaurants Indonesia', '6')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '6'
# A2B Outsourcing
# INSERT INTO companies (nama, raw_id) VALUES ('A2B Outsourcing', '7')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '7'
# Aaa Consulting Limited (Jakarta)
# INSERT INTO companies (nama, raw_id) VALUES ('Aaa Consulting Limited (Jakarta)', '8')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '8'
# Abadi Jaya Guangzhou Kosmetik
# INSERT INTO companies (nama, raw_id) VALUES ('Abadi Jaya Guangzhou Kosmetik', '9')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '9'
# Abadi Jaya Guangzhou Kosmetik
# INSERT INTO companies (nama, raw_id) VALUES ('Abadi Jaya Guangzhou Kosmetik', '10')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '10'
# Abadi Jaya Guangzhou Kosmetik
# INSERT INTO companies (nama, raw_id) VALUES ('Abadi Jaya Guangzhou Kosmetik', '11')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '11'
# Abadi Jaya Guangzhou Kosmetik
# INSERT INTO companies (nama, raw_id) VALUES ('Abadi Jaya Guangzhou Kosmetik', '12')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '12'
# Abc Kids Brighton
# INSERT INTO companies (nama, raw_id) VALUES ('Abc Kids Brighton', '13')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '13'
# Abc Kids Brighton
# INSERT INTO companies (nama, raw_id) VALUES ('Abc Kids Brighton', '14')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '14'
# Abeam Consulting Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Abeam Consulting Indonesia', '15')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '15'
# Abeam Consulting Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Abeam Consulting Indonesia', '16')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '16'
# Acefood
# INSERT INTO companies (nama, raw_id) VALUES ('Acefood', '17')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '17'
# Act Foundation
# INSERT INTO companies (nama, raw_id) VALUES ('Act Foundation', '18')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '18'
# Adaro Energy
# INSERT INTO companies (nama, raw_id) VALUES ('Adaro Energy', '19')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '19'
# Adaro Energy
# INSERT INTO companies (nama, raw_id) VALUES ('Adaro Energy', '20')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '20'
# Adaro Foundation
# INSERT INTO companies (nama, raw_id) VALUES ('Adaro Foundation', '21')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '21'
# Adaro Land
# INSERT INTO companies (nama, raw_id) VALUES ('Adaro Land', '22')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '22'
# Adaro Land
# INSERT INTO companies (nama, raw_id) VALUES ('Adaro Land', '23')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '23'
# Adco Property Group
# INSERT INTO companies (nama, raw_id) VALUES ('Adco Property Group', '24')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '24'
# Add Property Prima
# INSERT INTO companies (nama, raw_id) VALUES ('Add Property Prima', '25')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '25'
# Addon Systems PTe Ltd
# INSERT INTO companies (nama, raw_id) VALUES ('Addon Systems PTe Ltd', '26')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '26'
# Aden Services - Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aden Services - Indonesia', '27')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '27'
# Aden Services - Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aden Services - Indonesia', '28')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '28'
# Aden Services - Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aden Services - Indonesia', '29')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '29'
# Adi Jaya Utama
# INSERT INTO companies (nama, raw_id) VALUES ('Adi Jaya Utama', '30')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '30'
# Adicita Prayoga
# INSERT INTO companies (nama, raw_id) VALUES ('Adicita Prayoga', '31')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '31'
# Adicita Prayoga
# INSERT INTO companies (nama, raw_id) VALUES ('Adicita Prayoga', '32')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '32'
# Adin Putra Group
# INSERT INTO companies (nama, raw_id) VALUES ('Adin Putra Group', '33')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '33'
# Aditya Birla Yarn
# INSERT INTO companies (nama, raw_id) VALUES ('Aditya Birla Yarn', '34')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '34'
# Adoralezat
# INSERT INTO companies (nama, raw_id) VALUES ('Adoralezat', '35')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '35'
# Adr Group Of Companies (PT Selamat Sempurna Tbk.)
# INSERT INTO companies (nama, raw_id) VALUES ('Adr Group Of Companies (PT Selamat Sempurna Tbk.)', '36')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '36'
# Adr Group Of Companies (PT Selamat Sempurna Tbk.)
# INSERT INTO companies (nama, raw_id) VALUES ('Adr Group Of Companies (PT Selamat Sempurna Tbk.)', '37')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '37'
# Adr Group Of Companies (PT Selamat Sempurna Tbk.)
# INSERT INTO companies (nama, raw_id) VALUES ('Adr Group Of Companies (PT Selamat Sempurna Tbk.)', '38')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '38'
# Adr Group Of Companies (PT Selamat Sempurna Tbk.)
# INSERT INTO companies (nama, raw_id) VALUES ('Adr Group Of Companies (PT Selamat Sempurna Tbk.)', '39')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '39'
# Adventus Singapore
# INSERT INTO companies (nama, raw_id) VALUES ('Adventus Singapore', '40')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '40'
# Advertnative
# INSERT INTO companies (nama, raw_id) VALUES ('Advertnative', '41')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '41'
# Aeco Pacific Services Singapore PTe. Ltd
# INSERT INTO companies (nama, raw_id) VALUES ('Aeco Pacific Services Singapore PTe. Ltd', '42')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '42'
# Aedea Jakarta
# INSERT INTO companies (nama, raw_id) VALUES ('Aedea Jakarta', '43')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '43'
# Aedea Jakarta
# INSERT INTO companies (nama, raw_id) VALUES ('Aedea Jakarta', '44')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '44'
# Aeon Credit Service Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aeon Credit Service Indonesia', '45')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '45'
# Aeon Credit Service Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aeon Credit Service Indonesia', '46')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '46'
# Aeon Credit Service Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aeon Credit Service Indonesia', '47')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '47'
# Aeon Credit Service Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aeon Credit Service Indonesia', '48')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '48'
# Aeon Delight Indonesia (PT Sinar Jernih Sarana)
# INSERT INTO companies (nama, raw_id) VALUES ('Aeon Delight Indonesia (PT Sinar Jernih Sarana)', '49')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '49'
# Aeon Delight Indonesia (PT Sinar Jernih Sarana)
# INSERT INTO companies (nama, raw_id) VALUES ('Aeon Delight Indonesia (PT Sinar Jernih Sarana)', '50')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '50'
# Aeon Delight Indonesia (PT Sinar Jernih Sarana)
# INSERT INTO companies (nama, raw_id) VALUES ('Aeon Delight Indonesia (PT Sinar Jernih Sarana)', '51')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '51'
# Agensi Pekerjaan Js Staffing Services Sdn Bhd (Pg)
# INSERT INTO companies (nama, raw_id) VALUES ('Agensi Pekerjaan Js Staffing Services Sdn Bhd (Pg)', '52')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '52'
# Ages Systems Gelderfarenit PTe Ltd
# INSERT INTO companies (nama, raw_id) VALUES ('Ages Systems Gelderfarenit PTe Ltd', '53')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '53'
# Agk Recruitment
# INSERT INTO companies (nama, raw_id) VALUES ('Agk Recruitment', '54')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '54'
# Agneya Restaurant
# INSERT INTO companies (nama, raw_id) VALUES ('Agneya Restaurant', '55')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '55'
# Agneya Restaurant
# INSERT INTO companies (nama, raw_id) VALUES ('Agneya Restaurant', '56')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '56'
# Agrinos ( Prima Group )
# INSERT INTO companies (nama, raw_id) VALUES ('Agrinos ( Prima Group )', '57')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '57'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '58')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '58'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '59')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '59'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '60')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '60'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '61')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '61'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '62')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '62'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '63')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '63'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '64')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '64'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '65')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '65'
# Agro Boga Utama Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agro Boga Utama Group', '66')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '66'
# Agung Logistics
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Logistics', '67')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '67'
# Agung Sanjaya
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sanjaya', '68')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '68'
# Agung Sedayu Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sedayu Group', '69')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '69'
# Agung Sedayu Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sedayu Group', '70')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '70'
# Agung Sedayu Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sedayu Group', '71')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '71'
# Agung Sedayu Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sedayu Group', '72')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '72'
# Agung Sedayu Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sedayu Group', '73')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '73'
# Agung Sedayu Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sedayu Group', '74')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '74'
# Agung Sedayu Group
# INSERT INTO companies (nama, raw_id) VALUES ('Agung Sedayu Group', '75')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '75'
# Aia Financial
# INSERT INTO companies (nama, raw_id) VALUES ('Aia Financial', '76')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '76'
# Aisyah Morioka Industries
# INSERT INTO companies (nama, raw_id) VALUES ('Aisyah Morioka Industries', '77')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '77'
# Aj Bakery & Cake
# INSERT INTO companies (nama, raw_id) VALUES ('Aj Bakery & Cake', '78')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '78'
# Aj Bakery & Cake
# INSERT INTO companies (nama, raw_id) VALUES ('Aj Bakery & Cake', '79')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '79'
# Akzonobel
# INSERT INTO companies (nama, raw_id) VALUES ('Akzonobel', '80')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '80'
# Alametric.Com
# INSERT INTO companies (nama, raw_id) VALUES ('Alametric.Com', '81')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '81'
# Alcott Semarang
# INSERT INTO companies (nama, raw_id) VALUES ('Alcott Semarang', '82')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '82'
# Alex Villa Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Alex Villa Indonesia', '83')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '83'
# Alkausar Boarding School
# INSERT INTO companies (nama, raw_id) VALUES ('Alkausar Boarding School', '84')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '84'
# Almindo Pratama Group Cv
# INSERT INTO companies (nama, raw_id) VALUES ('Almindo Pratama Group Cv', '85')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '85'
# Almindo Pratama Group Cv
# INSERT INTO companies (nama, raw_id) VALUES ('Almindo Pratama Group Cv', '86')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '86'
# Alodokter
# INSERT INTO companies (nama, raw_id) VALUES ('Alodokter', '87')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '87'
# Alphavet Klinik Hewan
# INSERT INTO companies (nama, raw_id) VALUES ('Alphavet Klinik Hewan', '88')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '88'
# Am Badar & Partners
# INSERT INTO companies (nama, raw_id) VALUES ('Am Badar & Partners', '89')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '89'
# Amazon Pet Indo
# INSERT INTO companies (nama, raw_id) VALUES ('Amazon Pet Indo', '90')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '90'
# Amb Consulting
# INSERT INTO companies (nama, raw_id) VALUES ('Amb Consulting', '91')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '91'
# Amd Media
# INSERT INTO companies (nama, raw_id) VALUES ('Amd Media', '92')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '92'
# Ame Art & Education Club
# INSERT INTO companies (nama, raw_id) VALUES ('Ame Art & Education Club', '93')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '93'
# American Embassy Commissary Recreation Association (Aecra)
# INSERT INTO companies (nama, raw_id) VALUES ('American Embassy Commissary Recreation Association (Aecra)', '94')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '94'
# Aming Coffee
# INSERT INTO companies (nama, raw_id) VALUES ('Aming Coffee', '95')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '95'
# Amr Original
# INSERT INTO companies (nama, raw_id) VALUES ('Amr Original', '96')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '96'
# Amr Partnership
# INSERT INTO companies (nama, raw_id) VALUES ('Amr Partnership', '97')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '97'
# Amsai Playgroup & Bimbel
# INSERT INTO companies (nama, raw_id) VALUES ('Amsai Playgroup & Bimbel', '98')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '98'
# Amsky Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Amsky Indonesia', '99')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '99'
# Amway Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Amway Indonesia', '100')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '100'
# Amway Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Amway Indonesia', '101')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '101'
# Aneka Baja Pekayon
# INSERT INTO companies (nama, raw_id) VALUES ('Aneka Baja Pekayon', '102')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '102'
# Ann\'S Bakehouse
# INSERT INTO companies (nama, raw_id) VALUES ('Ann\'S Bakehouse', '103')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '103'
# Anugerah Group
# INSERT INTO companies (nama, raw_id) VALUES ('Anugerah Group', '104')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '104'
# Anugerah Group
# INSERT INTO companies (nama, raw_id) VALUES ('Anugerah Group', '105')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '105'
# Anugerah Perdana
# INSERT INTO companies (nama, raw_id) VALUES ('Anugerah Perdana', '106')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '106'
# Anugrah Original Bionatura Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Anugrah Original Bionatura Indonesia', '107')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '107'
# Apical Group
# INSERT INTO companies (nama, raw_id) VALUES ('Apical Group', '108')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '108'
# Apical Group
# INSERT INTO companies (nama, raw_id) VALUES ('Apical Group', '109')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '109'
# Apical Group
# INSERT INTO companies (nama, raw_id) VALUES ('Apical Group', '110')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '110'
# Apm (Avantech Prestige Motor)
# INSERT INTO companies (nama, raw_id) VALUES ('Apm (Avantech Prestige Motor)', '111')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '111'
# Apotek Alvin Farma
# INSERT INTO companies (nama, raw_id) VALUES ('Apotek Alvin Farma', '112')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '112'
# Apotek Klinik Mutiara Medicare
# INSERT INTO companies (nama, raw_id) VALUES ('Apotek Klinik Mutiara Medicare', '113')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '113'
# Apotek Sarika
# INSERT INTO companies (nama, raw_id) VALUES ('Apotek Sarika', '114')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '114'
# Apple Tree Pre-School Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Apple Tree Pre-School Indonesia', '115')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '115'
# Apple Watch Stuff
# INSERT INTO companies (nama, raw_id) VALUES ('Apple Watch Stuff', '116')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '116'
# Aptiv
# INSERT INTO companies (nama, raw_id) VALUES ('Aptiv', '117')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '117'
# Archid Design & Build
# INSERT INTO companies (nama, raw_id) VALUES ('Archid Design & Build', '118')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '118'
# Area Designs
# INSERT INTO companies (nama, raw_id) VALUES ('Area Designs', '119')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '119'
# Arion Paramita Group
# INSERT INTO companies (nama, raw_id) VALUES ('Arion Paramita Group', '120')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '120'
# Arista Group
# INSERT INTO companies (nama, raw_id) VALUES ('Arista Group', '121')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '121'
# Arista Group
# INSERT INTO companies (nama, raw_id) VALUES ('Arista Group', '122')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '122'
# Arkademi
# INSERT INTO companies (nama, raw_id) VALUES ('Arkademi', '123')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '123'
# Arkora Group
# INSERT INTO companies (nama, raw_id) VALUES ('Arkora Group', '124')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '124'
# Armatasoft
# INSERT INTO companies (nama, raw_id) VALUES ('Armatasoft', '125')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '125'
# Arofah Mina Travel & Tour
# INSERT INTO companies (nama, raw_id) VALUES ('Arofah Mina Travel & Tour', '126')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '126'
# Arsa Technology
# INSERT INTO companies (nama, raw_id) VALUES ('Arsa Technology', '127')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '127'
# Artalenta Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Artalenta Indonesia', '128')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '128'
# Arya Mandiri Trans Logistik
# INSERT INTO companies (nama, raw_id) VALUES ('Arya Mandiri Trans Logistik', '129')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '129'
# As Foods, PT
# INSERT INTO companies (nama, raw_id) VALUES ('As Foods, PT', '130')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '130'
# Asaba Group
# INSERT INTO companies (nama, raw_id) VALUES ('Asaba Group', '131')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '131'
# Ascertain Technologies Sdn Bhd
# INSERT INTO companies (nama, raw_id) VALUES ('Ascertain Technologies Sdn Bhd', '132')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '132'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '133')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '133'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '134')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '134'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '135')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '135'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '136')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '136'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '137')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '137'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '138')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '138'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '139')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '139'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '140')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '140'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '141')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '141'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '142')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '142'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '143')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '143'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '144')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '144'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '145')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '145'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '146')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '146'
# Asia Pulp And Paper
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Pulp And Paper', '147')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '147'
# Asia Top
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Top', '148')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '148'
# Asia Top
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Top', '149')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '149'
# Asia Top
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Top', '150')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '150'
# Asia Top
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Top', '151')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '151'
# Asia Top
# INSERT INTO companies (nama, raw_id) VALUES ('Asia Top', '152')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '152'
# Askfast
# INSERT INTO companies (nama, raw_id) VALUES ('Askfast', '153')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '153'
# Asosiasi Penyelenggara Jasa Internet Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Asosiasi Penyelenggara Jasa Internet Indonesia', '154')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '154'
# Aspire Lifestyles Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Aspire Lifestyles Indonesia', '155')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '155'
# Asri (A Subsidiary Of Agung Sedayu Group)
# INSERT INTO companies (nama, raw_id) VALUES ('Asri (A Subsidiary Of Agung Sedayu Group)', '156')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '156'
# Asri (A Subsidiary Of Agung Sedayu Group)
# INSERT INTO companies (nama, raw_id) VALUES ('Asri (A Subsidiary Of Agung Sedayu Group)', '157')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '157'
# Asri (A Subsidiary Of Agung Sedayu Group)
# INSERT INTO companies (nama, raw_id) VALUES ('Asri (A Subsidiary Of Agung Sedayu Group)', '158')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '158'
# Asri (A Subsidiary Of Agung Sedayu Group)
# INSERT INTO companies (nama, raw_id) VALUES ('Asri (A Subsidiary Of Agung Sedayu Group)', '159')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '159'
# Asri Raya Plastik
# INSERT INTO companies (nama, raw_id) VALUES ('Asri Raya Plastik', '160')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '160'
# Astel Group
# INSERT INTO companies (nama, raw_id) VALUES ('Astel Group', '161')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '161'
# Asuransi Astra
# INSERT INTO companies (nama, raw_id) VALUES ('Asuransi Astra', '162')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '162'
# Asuransi Astra
# INSERT INTO companies (nama, raw_id) VALUES ('Asuransi Astra', '163')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '163'
# Asuransi Astra
# INSERT INTO companies (nama, raw_id) VALUES ('Asuransi Astra', '164')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '164'
# Atelli Furniture Interior
# INSERT INTO companies (nama, raw_id) VALUES ('Atelli Furniture Interior', '165')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '165'
# Atelli Furniture Interior
# INSERT INTO companies (nama, raw_id) VALUES ('Atelli Furniture Interior', '166')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '166'
# Ati Business Group
# INSERT INTO companies (nama, raw_id) VALUES ('Ati Business Group', '167')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '167'
# Atop Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Atop Indonesia', '168')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '168'
# Aura Esports
# INSERT INTO companies (nama, raw_id) VALUES ('Aura Esports', '169')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '169'
# Aura Partners (Singapore) PTe. Ltd.
# INSERT INTO companies (nama, raw_id) VALUES ('Aura Partners (Singapore) PTe. Ltd.', '170')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '170'
# Australian Sacred Heart International School
# INSERT INTO companies (nama, raw_id) VALUES ('Australian Sacred Heart International School', '171')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '171'
# Avian Group
# INSERT INTO companies (nama, raw_id) VALUES ('Avian Group', '172')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '172'
# Avian Group
# INSERT INTO companies (nama, raw_id) VALUES ('Avian Group', '173')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '173'
# Avond Studio
# INSERT INTO companies (nama, raw_id) VALUES ('Avond Studio', '174')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '174'
# Ayam Dan Bebek Goreng Mbah Joy
# INSERT INTO companies (nama, raw_id) VALUES ('Ayam Dan Bebek Goreng Mbah Joy', '175')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '175'
# Azwar Hadisupani Rum & Partners - Counsellors At Law
# INSERT INTO companies (nama, raw_id) VALUES ('Azwar Hadisupani Rum & Partners - Counsellors At Law', '176')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '176'
# B Erl Cosmetics
# INSERT INTO companies (nama, raw_id) VALUES ('B Erl Cosmetics', '177')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '177'
# B Erl Cosmetics
# INSERT INTO companies (nama, raw_id) VALUES ('B Erl Cosmetics', '178')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '178'
# Bababoo Home
# INSERT INTO companies (nama, raw_id) VALUES ('Bababoo Home', '179')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '179'
# Baby Harper Shop
# INSERT INTO companies (nama, raw_id) VALUES ('Baby Harper Shop', '180')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '180'
# Bae Educator
# INSERT INTO companies (nama, raw_id) VALUES ('Bae Educator', '181')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '181'
# Bali Implant Aesthetic (Bia) Dental Center
# INSERT INTO companies (nama, raw_id) VALUES ('Bali Implant Aesthetic (Bia) Dental Center', '182')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '182'
# Bali Treasure Properties
# INSERT INTO companies (nama, raw_id) VALUES ('Bali Treasure Properties', '183')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '183'
# Bank Of China (Hong Kong) Limited Jakarta Branch
# INSERT INTO companies (nama, raw_id) VALUES ('Bank Of China (Hong Kong) Limited Jakarta Branch', '184')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '184'
# Bank Of China (Hong Kong) Limited Jakarta Branch
# INSERT INTO companies (nama, raw_id) VALUES ('Bank Of China (Hong Kong) Limited Jakarta Branch', '185')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '185'
# Bank Sahabat Sampoerna
# INSERT INTO companies (nama, raw_id) VALUES ('Bank Sahabat Sampoerna', '186')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '186'
# Bank Sahabat Sampoerna
# INSERT INTO companies (nama, raw_id) VALUES ('Bank Sahabat Sampoerna', '187')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '187'
# Bank Tabungan Pensiunan Nasional Tbk (Btpn)
# INSERT INTO companies (nama, raw_id) VALUES ('Bank Tabungan Pensiunan Nasional Tbk (Btpn)', '188')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '188'
# Barantum
# INSERT INTO companies (nama, raw_id) VALUES ('Barantum', '189')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '189'
# Barokah Perkasa Group
# INSERT INTO companies (nama, raw_id) VALUES ('Barokah Perkasa Group', '190')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '190'
# Basf Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Basf Indonesia', '191')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '191'
# Basf Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Basf Indonesia', '192')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '192'
# Batang Industrial Corporation
# INSERT INTO companies (nama, raw_id) VALUES ('Batang Industrial Corporation', '193')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '193'
# Batang Industrial Corporation
# INSERT INTO companies (nama, raw_id) VALUES ('Batang Industrial Corporation', '194')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '194'
# Batik Roebini
# INSERT INTO companies (nama, raw_id) VALUES ('Batik Roebini', '195')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '195'
# Batik Trusmi
# INSERT INTO companies (nama, raw_id) VALUES ('Batik Trusmi', '196')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '196'
# Batik Trusmi
# INSERT INTO companies (nama, raw_id) VALUES ('Batik Trusmi', '197')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '197'
# Batin Estetika Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Batin Estetika Indonesia', '198')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '198'
# Batin Estetika Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Batin Estetika Indonesia', '199')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '199'
# Bayoran Teknik
# INSERT INTO companies (nama, raw_id) VALUES ('Bayoran Teknik', '200')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '200'
# Bayoran Teknik
# INSERT INTO companies (nama, raw_id) VALUES ('Bayoran Teknik', '201')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '201'
# Beart
# INSERT INTO companies (nama, raw_id) VALUES ('Beart', '202')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '202'
# Behn Meyer Chemicals
# INSERT INTO companies (nama, raw_id) VALUES ('Behn Meyer Chemicals', '203')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '203'
# Bellissimore
# INSERT INTO companies (nama, raw_id) VALUES ('Bellissimore', '204')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '204'
# Benny Gunawan & Rekan
# INSERT INTO companies (nama, raw_id) VALUES ('Benny Gunawan & Rekan', '205')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '205'
# Bentuk Management
# INSERT INTO companies (nama, raw_id) VALUES ('Bentuk Management', '206')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '206'
# Beryls Private Tutoring
# INSERT INTO companies (nama, raw_id) VALUES ('Beryls Private Tutoring', '207')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '207'
# Besha Analitika, PT
# INSERT INTO companies (nama, raw_id) VALUES ('Besha Analitika, PT', '208')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '208'
# Best Hostels Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Best Hostels Indonesia', '209')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '209'
# Best Hostels Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Best Hostels Indonesia', '210')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '210'
# Biensi Fesyenindo (3Second, Greenlight & The Parlor)
# INSERT INTO companies (nama, raw_id) VALUES ('Biensi Fesyenindo (3Second, Greenlight & The Parlor)', '211')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '211'
# Bihels Interior
# INSERT INTO companies (nama, raw_id) VALUES ('Bihels Interior', '212')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '212'
# Bika Group
# INSERT INTO companies (nama, raw_id) VALUES ('Bika Group', '213')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '213'
# Bika Group
# INSERT INTO companies (nama, raw_id) VALUES ('Bika Group', '214')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '214'
# Bika Group
# INSERT INTO companies (nama, raw_id) VALUES ('Bika Group', '215')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '215'
# Bika Group
# INSERT INTO companies (nama, raw_id) VALUES ('Bika Group', '216')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '216'
# Bimbel One Learning Center
# INSERT INTO companies (nama, raw_id) VALUES ('Bimbel One Learning Center', '217')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '217'
# Bimbel One Learning Center
# INSERT INTO companies (nama, raw_id) VALUES ('Bimbel One Learning Center', '218')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '218'
# Bimbingan Belajar Genesis
# INSERT INTO companies (nama, raw_id) VALUES ('Bimbingan Belajar Genesis', '219')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '219'
# Bimbingan Belajar Sg
# INSERT INTO companies (nama, raw_id) VALUES ('Bimbingan Belajar Sg', '220')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '220'
# Bina Bahasa Mandarin
# INSERT INTO companies (nama, raw_id) VALUES ('Bina Bahasa Mandarin', '221')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '221'
# Bintang Inti Talenta
# INSERT INTO companies (nama, raw_id) VALUES ('Bintang Inti Talenta', '222')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '222'
# Bintang Jaya
# INSERT INTO companies (nama, raw_id) VALUES ('Bintang Jaya', '223')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '223'
# Bintangguna Sempurna Foodindo
# INSERT INTO companies (nama, raw_id) VALUES ('Bintangguna Sempurna Foodindo', '224')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '224'
# Binus Center
# INSERT INTO companies (nama, raw_id) VALUES ('Binus Center', '225')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '225'
# Binus Center Bandung
# INSERT INTO companies (nama, raw_id) VALUES ('Binus Center Bandung', '226')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '226'
# Bio Industries
# INSERT INTO companies (nama, raw_id) VALUES ('Bio Industries', '227')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '227'
# Bioskop Mie & Kopi
# INSERT INTO companies (nama, raw_id) VALUES ('Bioskop Mie & Kopi', '228')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '228'
# Bisnis Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Bisnis Indonesia', '229')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '229'
# Bisnis Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Bisnis Indonesia', '230')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '230'
# Bisnishack
# INSERT INTO companies (nama, raw_id) VALUES ('Bisnishack', '231')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '231'
# Blitz Car Seat
# INSERT INTO companies (nama, raw_id) VALUES ('Blitz Car Seat', '232')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '232'
# Blossom School
# INSERT INTO companies (nama, raw_id) VALUES ('Blossom School', '233')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '233'
# Blue Dolphin Playskool
# INSERT INTO companies (nama, raw_id) VALUES ('Blue Dolphin Playskool', '234')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '234'
# Bms Hardware
# INSERT INTO companies (nama, raw_id) VALUES ('Bms Hardware', '235')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '235'
# Boaz Homer & Rekan
# INSERT INTO companies (nama, raw_id) VALUES ('Boaz Homer & Rekan', '236')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '236'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '237')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '237'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '238')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '238'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '239')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '239'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '240')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '240'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '241')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '241'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '242')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '242'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '243')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '243'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '244')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '244'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '245')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '245'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '246')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '246'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '247')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '247'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '248')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '248'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '249')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '249'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '250')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '250'
# Boga Group
# INSERT INTO companies (nama, raw_id) VALUES ('Boga Group', '251')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '251'
# Bogajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Bogajaya Group', '252')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '252'
# Bongkar Muat Karya Tehnik
# INSERT INTO companies (nama, raw_id) VALUES ('Bongkar Muat Karya Tehnik', '253')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '253'
# Bos Sayur Buah
# INSERT INTO companies (nama, raw_id) VALUES ('Bos Sayur Buah', '254')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '254'
# Bosch Group
# INSERT INTO companies (nama, raw_id) VALUES ('Bosch Group', '255')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '255'
# Bosch Group
# INSERT INTO companies (nama, raw_id) VALUES ('Bosch Group', '256')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '256'
# Bose Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Bose Indonesia', '257')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '257'
# Bose Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Bose Indonesia', '258')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '258'
# Bpk Penabur Jakarta (Spk)
# INSERT INTO companies (nama, raw_id) VALUES ('Bpk Penabur Jakarta (Spk)', '259')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '259'
# Bpr Fianka Rezalina Fatma
# INSERT INTO companies (nama, raw_id) VALUES ('Bpr Fianka Rezalina Fatma', '260')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '260'
# Bpr Lestari Jabar
# INSERT INTO companies (nama, raw_id) VALUES ('Bpr Lestari Jabar', '261')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '261'
# Brainfit ( Gading Serpong)
# INSERT INTO companies (nama, raw_id) VALUES ('Brainfit ( Gading Serpong)', '262')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '262'
# Brata Jaya Store
# INSERT INTO companies (nama, raw_id) VALUES ('Brata Jaya Store', '263')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '263'
# Bravo Motor
# INSERT INTO companies (nama, raw_id) VALUES ('Bravo Motor', '264')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '264'
# Bravonomics
# INSERT INTO companies (nama, raw_id) VALUES ('Bravonomics', '265')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '265'
# Bread N\' Beyond
# INSERT INTO companies (nama, raw_id) VALUES ('Bread N\' Beyond', '266')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '266'
# Brepublic
# INSERT INTO companies (nama, raw_id) VALUES ('Brepublic', '267')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '267'
# Bridge Note Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Bridge Note Indonesia', '268')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '268'
# Bridge Note Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Bridge Note Indonesia', '269')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '269'
# Brillyindonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Brillyindonesia', '270')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '270'
# Bro Kitchen
# INSERT INTO companies (nama, raw_id) VALUES ('Bro Kitchen', '271')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '271'
# Brood En Boter
# INSERT INTO companies (nama, raw_id) VALUES ('Brood En Boter', '272')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '272'
# Broom.Id
# INSERT INTO companies (nama, raw_id) VALUES ('Broom.Id', '273')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '273'
# Brouhaha Design Studio
# INSERT INTO companies (nama, raw_id) VALUES ('Brouhaha Design Studio', '274')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '274'
# Bruule.Id
# INSERT INTO companies (nama, raw_id) VALUES ('Bruule.Id', '275')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '275'
# Bry-Air ( Malaysia) Sdn. Bhd. Indonesia Rep Office
# INSERT INTO companies (nama, raw_id) VALUES ('Bry-Air ( Malaysia) Sdn. Bhd. Indonesia Rep Office', '276')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '276'
# Bsd Dental Centre
# INSERT INTO companies (nama, raw_id) VALUES ('Bsd Dental Centre', '277')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '277'
# Btb School Pluit
# INSERT INTO companies (nama, raw_id) VALUES ('Btb School Pluit', '278')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '278'
# Bti Indo Tekno
# INSERT INTO companies (nama, raw_id) VALUES ('Bti Indo Tekno', '279')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '279'
# Bubur Cap Tiger
# INSERT INTO companies (nama, raw_id) VALUES ('Bubur Cap Tiger', '280')
# ...
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '744')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '744'
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '745')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '745'
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '746')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '746'
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '747')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '747'
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '748')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '748'
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '749')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '749'
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '750')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '750'
# Erajaya Group
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Group', '751')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '751'
# Erajaya Swasembada Tbk
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Swasembada Tbk', '752')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '752'
# Erajaya Swasembada Tbk
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Swasembada Tbk', '753')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '753'
# Erajaya Swasembada Tbk
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Swasembada Tbk', '754')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '754'
# Erajaya Swasembada Tbk
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Swasembada Tbk', '755')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '755'
# Erajaya Swasembada Tbk
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Swasembada Tbk', '756')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '756'
# Erajaya Swasembada Tbk
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Swasembada Tbk', '757')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '757'
# Erajaya Swasembada Tbk
# INSERT INTO companies (nama, raw_id) VALUES ('Erajaya Swasembada Tbk', '758')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '758'
# Eroti Tempatnya Chiffon
# INSERT INTO companies (nama, raw_id) VALUES ('Eroti Tempatnya Chiffon', '759')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '759'
# Esmod Jakarta
# INSERT INTO companies (nama, raw_id) VALUES ('Esmod Jakarta', '760')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '760'
# Esq Group
# INSERT INTO companies (nama, raw_id) VALUES ('Esq Group', '761')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '761'
# Esuohouse
# INSERT INTO companies (nama, raw_id) VALUES ('Esuohouse', '762')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '762'
# Eth Cargo
# INSERT INTO companies (nama, raw_id) VALUES ('Eth Cargo', '763')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '763'
# Eurokars Group
# INSERT INTO companies (nama, raw_id) VALUES ('Eurokars Group', '764')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '764'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '765')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '765'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '766')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '766'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '767')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '767'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '768')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '768'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '769')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '769'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '770')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '770'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '771')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '771'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '772')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '772'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '773')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '773'
# Euromedica Group
# INSERT INTO companies (nama, raw_id) VALUES ('Euromedica Group', '774')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '774'
# Evangeline & Partners
# INSERT INTO companies (nama, raw_id) VALUES ('Evangeline & Partners', '775')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '775'
# Everlash
# INSERT INTO companies (nama, raw_id) VALUES ('Everlash', '776')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '776'
# Everlash
# INSERT INTO companies (nama, raw_id) VALUES ('Everlash', '777')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '777'
# Everlash
# INSERT INTO companies (nama, raw_id) VALUES ('Everlash', '778')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '778'
# Evyna Food
# INSERT INTO companies (nama, raw_id) VALUES ('Evyna Food', '779')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '779'
# Excellent Stars
# INSERT INTO companies (nama, raw_id) VALUES ('Excellent Stars', '780')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '780'
# Excelpoint Systems (PTe) Ltd
# INSERT INTO companies (nama, raw_id) VALUES ('Excelpoint Systems (PTe) Ltd', '781')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '781'
# Exito Course
# INSERT INTO companies (nama, raw_id) VALUES ('Exito Course', '782')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '782'
# F45 Kemang
# INSERT INTO companies (nama, raw_id) VALUES ('F45 Kemang', '783')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '783'
# Fa Merak
# INSERT INTO companies (nama, raw_id) VALUES ('Fa Merak', '784')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '784'
# Fa. Wiyono Partnership
# INSERT INTO companies (nama, raw_id) VALUES ('Fa. Wiyono Partnership', '785')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '785'
# Fabrico
# INSERT INTO companies (nama, raw_id) VALUES ('Fabrico', '786')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '786'
# Fakultas Ilmu Komputer Universitas Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Fakultas Ilmu Komputer Universitas Indonesia', '787')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '787'
# Family Computer
# INSERT INTO companies (nama, raw_id) VALUES ('Family Computer', '788')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '788'
# Familymart Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Familymart Indonesia', '789')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '789'
# Familymart Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Familymart Indonesia', '790')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '790'
# Fap Agri Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fap Agri Group', '791')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '791'
# Fap Agri Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fap Agri Group', '792')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '792'
# Fap Agri Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fap Agri Group', '793')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '793'
# Fast Print Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Fast Print Indonesia', '794')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '794'
# Fat Bubble Dessert House And Cafe
# INSERT INTO companies (nama, raw_id) VALUES ('Fat Bubble Dessert House And Cafe', '795')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '795'
# Favorite Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Favorite Indonesia', '796')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '796'
# Favorite Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Favorite Indonesia', '797')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '797'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '798')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '798'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '799')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '799'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '800')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '800'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '801')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '801'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '802')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '802'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '803')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '803'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '804')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '804'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '805')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '805'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '806')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '806'
# Fiberstar (PT Mega Akses Persada)
# INSERT INTO companies (nama, raw_id) VALUES ('Fiberstar (PT Mega Akses Persada)', '807')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '807'
# Fifgroup
# INSERT INTO companies (nama, raw_id) VALUES ('Fifgroup', '808')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '808'
# Fifgroup
# INSERT INTO companies (nama, raw_id) VALUES ('Fifgroup', '809')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '809'
# Fifgroup
# INSERT INTO companies (nama, raw_id) VALUES ('Fifgroup', '810')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '810'
# Fifgroup
# INSERT INTO companies (nama, raw_id) VALUES ('Fifgroup', '811')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '811'
# Fifgroup
# INSERT INTO companies (nama, raw_id) VALUES ('Fifgroup', '812')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '812'
# Firstasia Consultant (PT Asia Utama Konsultan)
# INSERT INTO companies (nama, raw_id) VALUES ('Firstasia Consultant (PT Asia Utama Konsultan)', '813')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '813'
# Firstasia Consultant (PT Asia Utama Konsultan)
# INSERT INTO companies (nama, raw_id) VALUES ('Firstasia Consultant (PT Asia Utama Konsultan)', '814')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '814'
# Fitrah Islamic World Academy
# INSERT INTO companies (nama, raw_id) VALUES ('Fitrah Islamic World Academy', '815')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '815'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '816')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '816'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '817')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '817'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '818')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '818'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '819')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '819'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '820')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '820'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '821')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '821'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '822')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '822'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '823')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '823'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '824')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '824'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '825')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '825'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '826')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '826'
# Fks Group
# INSERT INTO companies (nama, raw_id) VALUES ('Fks Group', '827')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '827'
# Focus Data Consulting
# INSERT INTO companies (nama, raw_id) VALUES ('Focus Data Consulting', '828')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '828'
# Food Retail Indonesia (Jakarta)
# INSERT INTO companies (nama, raw_id) VALUES ('Food Retail Indonesia (Jakarta)', '829')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '829'
# Food Retail Indonesia (Jakarta)
# INSERT INTO companies (nama, raw_id) VALUES ('Food Retail Indonesia (Jakarta)', '830')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '830'
# Formi.Id
# INSERT INTO companies (nama, raw_id) VALUES ('Formi.Id', '831')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '831'
# Formi.Id
# INSERT INTO companies (nama, raw_id) VALUES ('Formi.Id', '832')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '832'
# Fortklass
# INSERT INTO companies (nama, raw_id) VALUES ('Fortklass', '833')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '833'
# Fotile Indonesia
# INSERT INTO companies (nama, raw_id) VALUES ('Fotile Indonesia', '834')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '834'
# Fotofoto
# INSERT INTO companies (nama, raw_id) VALUES ('Fotofoto', '835')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '835'
# Foxquinn
# INSERT INTO companies (nama, raw_id) VALUES ('Foxquinn', '836')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '836'
# Fpone Agency Jakarta
# INSERT INTO companies (nama, raw_id) VALUES ('Fpone Agency Jakarta', '837')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '837'
# Frank Amachi Group
# INSERT INTO companies (nama, raw_id) VALUES ('Frank Amachi Group', '838')
# UPDATE jobstreet_raws_rc SET company = '--extracted--'     where id = '838'
# Done : 838 row(s)
