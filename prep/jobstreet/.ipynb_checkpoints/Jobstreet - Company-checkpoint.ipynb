# %%
# Connect DB

import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)

# %%
# max id

select = ' max(company_id) '
fromdb = 'jobstreet_raws' 
 
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` "    )
myresult = mycursor.fetchall()

counter = 1

for x in myresult:  
    words = x[0]   
    print(words)
      
    
    
counter = words + 1
print('done : ' + str(len(myresult)) + ' row(s)')
print(counter)
# Out:
# 838
# done : 1 row(s)
# 839

# %%
# make Company _id

select = ' company, city '
fromdb = 'jobstreet_raws'
where = ' where company_id is null '
group = ' GROUP by' + select
 
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group  )
myresult = mycursor.fetchall()

for x in myresult:  
    company = x[0]  
    city = x[1]  
    print(' ')
    print(company)
    
    company_rep = company.replace("'", "\\'")
    city_rep = city.replace("'", "\\'")
    
    query = "UPDATE jobstreet_raws SET company_id = '" + str(counter)+"'   " 
    where = "  where company LIKE '" + company_rep + "'" 
    andwhere = "  and city LIKE '" + city_rep + "'" 
    
    print(query + where + andwhere)
    
    mycursor.execute(query + where + andwhere)
    mydb.commit()  
    
    counter += 1
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
#
# Fresto Post
# UPDATE jobstreet_raws SET company_id = '839'     where company LIKE 'Fresto Post'  and city LIKE 'Jakarta Barat'
#
# FSK Consulting
# UPDATE jobstreet_raws SET company_id = '840'     where company LIKE 'FSK Consulting'  and city LIKE 'Jakarta Pusat'
#
# FujiShop Id
# UPDATE jobstreet_raws SET company_id = '841'     where company LIKE 'FujiShop Id'  and city LIKE 'Jakarta Pusat'
#
# Fulfilindo
# UPDATE jobstreet_raws SET company_id = '842'     where company LIKE 'Fulfilindo'  and city LIKE 'Tangerang'
#
# G4S Indonesia
# UPDATE jobstreet_raws SET company_id = '843'     where company LIKE 'G4S Indonesia'  and city LIKE 'Papua'
#
# Gadkey
# UPDATE jobstreet_raws SET company_id = '844'     where company LIKE 'Gadkey'  and city LIKE 'Jakarta Barat'
#
# Galaxy Property
# UPDATE jobstreet_raws SET company_id = '845'     where company LIKE 'Galaxy Property'  and city LIKE 'Jakarta Barat'
#
# Gamaland Group
# UPDATE jobstreet_raws SET company_id = '846'     where company LIKE 'Gamaland Group'  and city LIKE 'Jakarta Raya'
#
# Gamevil Com2us Southeast Asia PTE LTD
# UPDATE jobstreet_raws SET company_id = '847'     where company LIKE 'Gamevil Com2us Southeast Asia PTE LTD'  and city LIKE 'Jakarta Barat'
#
# Garuda Perkasa Putra Angkasa
# UPDATE jobstreet_raws SET company_id = '848'     where company LIKE 'Garuda Perkasa Putra Angkasa'  and city LIKE 'Jakarta Barat'
#
# Gatra Ineffa Indonesia
# UPDATE jobstreet_raws SET company_id = '849'     where company LIKE 'Gatra Ineffa Indonesia'  and city LIKE 'Jakarta Raya'
#
# GCK Consulting
# UPDATE jobstreet_raws SET company_id = '850'     where company LIKE 'GCK Consulting'  and city LIKE 'Tangerang'
#
# Geek Portal
# UPDATE jobstreet_raws SET company_id = '851'     where company LIKE 'Geek Portal'  and city LIKE 'Bandung'
#
# Geek Portal
# UPDATE jobstreet_raws SET company_id = '852'     where company LIKE 'Geek Portal'  and city LIKE 'Jakarta Raya'
#
# Geekhunter
# UPDATE jobstreet_raws SET company_id = '853'     where company LIKE 'Geekhunter'  and city LIKE 'Jakarta Raya'
#
# Geekhunter
# UPDATE jobstreet_raws SET company_id = '854'     where company LIKE 'Geekhunter'  and city LIKE 'Jawa Timur'
#
# Geekseat
# UPDATE jobstreet_raws SET company_id = '855'     where company LIKE 'Geekseat'  and city LIKE 'Bali'
#
# Geekseat
# UPDATE jobstreet_raws SET company_id = '856'     where company LIKE 'Geekseat'  and city LIKE 'Denpasar'
#
# Gelora Perkasa
# UPDATE jobstreet_raws SET company_id = '857'     where company LIKE 'Gelora Perkasa'  and city LIKE 'Denpasar'
#
# Gema-Astrindo
# UPDATE jobstreet_raws SET company_id = '858'     where company LIKE 'Gema-Astrindo'  and city LIKE 'Tangerang'
#
# Geniebook
# UPDATE jobstreet_raws SET company_id = '859'     where company LIKE 'Geniebook'  and city LIKE 'Surabaya'
#
# Gitrys
# UPDATE jobstreet_raws SET company_id = '860'     where company LIKE 'Gitrys'  and city LIKE 'Yogyakarta'
#
# Giyanti Coffee Roastery
# UPDATE jobstreet_raws SET company_id = '861'     where company LIKE 'Giyanti Coffee Roastery'  and city LIKE 'Jakarta Raya'
#
# GKA LAND
# UPDATE jobstreet_raws SET company_id = '862'     where company LIKE 'GKA LAND'  and city LIKE 'Jakarta Selatan'
#
# Global Energi Lestari
# UPDATE jobstreet_raws SET company_id = '863'     where company LIKE 'Global Energi Lestari'  and city LIKE 'Jakarta Raya'
#
# Global Estetik
# UPDATE jobstreet_raws SET company_id = '864'     where company LIKE 'Global Estetik'  and city LIKE 'Bogor'
#
# Global Leadership Center (GLC)
# UPDATE jobstreet_raws SET company_id = '865'     where company LIKE 'Global Leadership Center (GLC)'  and city LIKE 'Jakarta Pusat'
#
# Global Leadership Center (GLC)
# UPDATE jobstreet_raws SET company_id = '866'     where company LIKE 'Global Leadership Center (GLC)'  and city LIKE 'Jakarta Raya'
#
# Global Lingua Course
# UPDATE jobstreet_raws SET company_id = '867'     where company LIKE 'Global Lingua Course'  and city LIKE 'Tegal'
#
# Global Trans Energy Internasional
# UPDATE jobstreet_raws SET company_id = '868'     where company LIKE 'Global Trans Energy Internasional'  and city LIKE 'Banjarmasin'
#
# Global Trans Energy Internasional
# UPDATE jobstreet_raws SET company_id = '869'     where company LIKE 'Global Trans Energy Internasional'  and city LIKE 'Jakarta Raya'
#
# GML Performance Consulting
# UPDATE jobstreet_raws SET company_id = '870'     where company LIKE 'GML Performance Consulting'  and city LIKE 'Jakarta Raya'
#
# GML Performance Consulting
# UPDATE jobstreet_raws SET company_id = '871'     where company LIKE 'GML Performance Consulting'  and city LIKE 'Jakarta Utara'
#
# GML Performance Consulting
# UPDATE jobstreet_raws SET company_id = '872'     where company LIKE 'GML Performance Consulting'  and city LIKE 'Makassar'
#
# Gokomodo
# UPDATE jobstreet_raws SET company_id = '873'     where company LIKE 'Gokomodo'  and city LIKE 'Jakarta Raya'
#
# Gold's Gym (PT Fit and Health Indonesia)
# UPDATE jobstreet_raws SET company_id = '874'     where company LIKE 'Gold\'s Gym (PT Fit and Health Indonesia)'  and city LIKE 'Banten'
#
# Gold's Gym (PT Fit and Health Indonesia)
# UPDATE jobstreet_raws SET company_id = '875'     where company LIKE 'Gold\'s Gym (PT Fit and Health Indonesia)'  and city LIKE 'Jakarta Utara'
#
# Gold's Gym (PT Fit and Health Indonesia)
# UPDATE jobstreet_raws SET company_id = '876'     where company LIKE 'Gold\'s Gym (PT Fit and Health Indonesia)'  and city LIKE 'Tangerang'
#
# Goldland Group
# UPDATE jobstreet_raws SET company_id = '877'     where company LIKE 'Goldland Group'  and city LIKE 'Tangerang'
#
# Golf Graha Famili
# UPDATE jobstreet_raws SET company_id = '878'     where company LIKE 'Golf Graha Famili'  and city LIKE 'Jawa Timur'
#
# Good Reason Advertising Agency
# UPDATE jobstreet_raws SET company_id = '879'     where company LIKE 'Good Reason Advertising Agency'  and city LIKE 'Jakarta Pusat'
#
# GP Outsourcing Asia Sdn Bhd.
# UPDATE jobstreet_raws SET company_id = '880'     where company LIKE 'GP Outsourcing Asia Sdn Bhd.'  and city LIKE 'Batam'
#
# Graha dr. Yanti Surabaya
# UPDATE jobstreet_raws SET company_id = '881'     where company LIKE 'Graha dr. Yanti Surabaya'  and city LIKE 'Surabaya'
#
# GRATYO Group
# UPDATE jobstreet_raws SET company_id = '882'     where company LIKE 'GRATYO Group'  and city LIKE 'Denpasar'
#
# GRATYO Group
# UPDATE jobstreet_raws SET company_id = '883'     where company LIKE 'GRATYO Group'  and city LIKE 'Jakarta Raya'
#
# GRATYO Group
# UPDATE jobstreet_raws SET company_id = '884'     where company LIKE 'GRATYO Group'  and city LIKE 'Jakarta Utara'
#
# GRATYO Group
# UPDATE jobstreet_raws SET company_id = '885'     where company LIKE 'GRATYO Group'  and city LIKE 'Makassar'
#
# GRATYO Group
# UPDATE jobstreet_raws SET company_id = '886'     where company LIKE 'GRATYO Group'  and city LIKE 'Medan'
#
# Green Park Group
# UPDATE jobstreet_raws SET company_id = '887'     where company LIKE 'Green Park Group'  and city LIKE 'Depok'
#
# Green School Bali
# UPDATE jobstreet_raws SET company_id = '888'     where company LIKE 'Green School Bali'  and city LIKE 'Bali'
#
# Grinnliving Indonesia
# UPDATE jobstreet_raws SET company_id = '889'     where company LIKE 'Grinnliving Indonesia'  and city LIKE 'Tangerang'
#
# GrosirOne
# UPDATE jobstreet_raws SET company_id = '890'     where company LIKE 'GrosirOne'  and city LIKE 'Bekasi'
#
# GrosirOne
# UPDATE jobstreet_raws SET company_id = '891'     where company LIKE 'GrosirOne'  and city LIKE 'Tangerang'
#
# Growing Tree Prep - School
# UPDATE jobstreet_raws SET company_id = '892'     where company LIKE 'Growing Tree Prep - School'  and city LIKE 'Jakarta Utara'
#
# Gsmart IT Solutions
# UPDATE jobstreet_raws SET company_id = '893'     where company LIKE 'Gsmart IT Solutions'  and city LIKE 'Surabaya'
#
# Guang Ming Mart
# UPDATE jobstreet_raws SET company_id = '894'     where company LIKE 'Guang Ming Mart'  and city LIKE 'Jakarta Barat'
#
# Gudi Bake Bread
# UPDATE jobstreet_raws SET company_id = '895'     where company LIKE 'Gudi Bake Bread'  and city LIKE 'Jakarta Raya'
#
# Gunasland Group
# UPDATE jobstreet_raws SET company_id = '896'     where company LIKE 'Gunasland Group'  and city LIKE 'Jakarta Selatan'
#
# HADS PARTNERSHIP
# UPDATE jobstreet_raws SET company_id = '897'     where company LIKE 'HADS PARTNERSHIP'  and city LIKE 'Jakarta Selatan'
#
# Hago Kreatif Indonesia (JOYY)
# UPDATE jobstreet_raws SET company_id = '898'     where company LIKE 'Hago Kreatif Indonesia (JOYY)'  and city LIKE 'Jakarta Pusat'
#
# Hair4all Indonesia
# UPDATE jobstreet_raws SET company_id = '899'     where company LIKE 'Hair4all Indonesia'  and city LIKE 'Surabaya'
#
# Halodoc
# UPDATE jobstreet_raws SET company_id = '900'     where company LIKE 'Halodoc'  and city LIKE 'Bandung'
#
# Halodoc
# UPDATE jobstreet_raws SET company_id = '901'     where company LIKE 'Halodoc'  and city LIKE 'Jakarta Raya'
#
# Halodoc
# UPDATE jobstreet_raws SET company_id = '902'     where company LIKE 'Halodoc'  and city LIKE 'Jakarta Selatan'
#
# Halodoc
# UPDATE jobstreet_raws SET company_id = '903'     where company LIKE 'Halodoc'  and city LIKE 'Semarang'
#
# Halodoc
# UPDATE jobstreet_raws SET company_id = '904'     where company LIKE 'Halodoc'  and city LIKE 'Tangerang'
#
# Hand Global Solutions Pte. Ltd.
# UPDATE jobstreet_raws SET company_id = '905'     where company LIKE 'Hand Global Solutions Pte. Ltd.'  and city LIKE 'Jakarta Pusat'
#
# Happy SP Sihombing, Budihardjo Hardisurjo & Associates
# UPDATE jobstreet_raws SET company_id = '906'     where company LIKE 'Happy SP Sihombing, Budihardjo Hardisurjo & Associates'  and city LIKE 'Jakarta Barat'
#
# HappyFresh
# UPDATE jobstreet_raws SET company_id = '907'     where company LIKE 'HappyFresh'  and city LIKE 'Surabaya'
#
# Harian Bisnis Indonesia
# UPDATE jobstreet_raws SET company_id = '908'     where company LIKE 'Harian Bisnis Indonesia'  and city LIKE 'Jakarta Pusat'
#
# Harvest Agency Surabaya
# UPDATE jobstreet_raws SET company_id = '909'     where company LIKE 'Harvest Agency Surabaya'  and city LIKE 'Jawa Timur'
#
# Haura Mom & Baby Spa
# UPDATE jobstreet_raws SET company_id = '910'     where company LIKE 'Haura Mom & Baby Spa'  and city LIKE 'Sleman'
#
# HD Car Care Indonesia
# UPDATE jobstreet_raws SET company_id = '911'     where company LIKE 'HD Car Care Indonesia'  and city LIKE 'Jakarta Raya'
#
# Heha Sky View Yogyakarta
# UPDATE jobstreet_raws SET company_id = '912'     where company LIKE 'Heha Sky View Yogyakarta'  and city LIKE 'Gunung Kidul'
#
# HEKA PROPERTI GROUP
# UPDATE jobstreet_raws SET company_id = '913'     where company LIKE 'HEKA PROPERTI GROUP'  and city LIKE 'Bekasi'
#
# Heritage School
# UPDATE jobstreet_raws SET company_id = '914'     where company LIKE 'Heritage School'  and city LIKE 'Jakarta Selatan'
#
# Hero Jaya
# UPDATE jobstreet_raws SET company_id = '915'     where company LIKE 'Hero Jaya'  and city LIKE 'Jakarta Barat'
#
# HHR Lawyers
# UPDATE jobstreet_raws SET company_id = '916'     where company LIKE 'HHR Lawyers'  and city LIKE 'Jakarta Selatan'
#
# HIGH SPEED RAILWAY CONTRACTOR CONSORTIUM 13
# UPDATE jobstreet_raws SET company_id = '917'     where company LIKE 'HIGH SPEED RAILWAY CONTRACTOR CONSORTIUM 13'  and city LIKE 'Bandung'
#
# Highpoint Group
# UPDATE jobstreet_raws SET company_id = '918'     where company LIKE 'Highpoint Group'  and city LIKE 'Jakarta Barat'
#
# Himeji Express Sukoharjo
# UPDATE jobstreet_raws SET company_id = '919'     where company LIKE 'Himeji Express Sukoharjo'  and city LIKE 'Bandung'
#
# Hippie Fashion Bandung
# UPDATE jobstreet_raws SET company_id = '920'     where company LIKE 'Hippie Fashion Bandung'  and city LIKE 'Bandung'
#
# Hirsch Bedner Associates
# UPDATE jobstreet_raws SET company_id = '921'     where company LIKE 'Hirsch Bedner Associates'  and city LIKE 'Badung'
#
# HJR Konsultan
# UPDATE jobstreet_raws SET company_id = '922'     where company LIKE 'HJR Konsultan'  and city LIKE 'Jakarta Barat'
#
# HLS GROUP
# UPDATE jobstreet_raws SET company_id = '923'     where company LIKE 'HLS GROUP'  and city LIKE 'Jakarta Selatan'
#
# Holan Medik Solusindo
# UPDATE jobstreet_raws SET company_id = '924'     where company LIKE 'Holan Medik Solusindo'  and city LIKE 'Jawa Tengah'
#
# HOLI GROUP
# UPDATE jobstreet_raws SET company_id = '925'     where company LIKE 'HOLI GROUP'  and city LIKE 'Semarang'
#
# Honda Kencana Kranji (PT Kencana Dharma Abadi)
# UPDATE jobstreet_raws SET company_id = '926'     where company LIKE 'Honda Kencana Kranji (PT Kencana Dharma Abadi)'  and city LIKE 'Bekasi'
#
# Hotel Grand Menteng
# UPDATE jobstreet_raws SET company_id = '927'     where company LIKE 'Hotel Grand Menteng'  and city LIKE 'Jakarta Raya'
#
# Hotel Mega Matra
# UPDATE jobstreet_raws SET company_id = '928'     where company LIKE 'Hotel Mega Matra'  and city LIKE 'Jakarta Raya'
#
# Hotel Pyrenees Jogja
# UPDATE jobstreet_raws SET company_id = '929'     where company LIKE 'Hotel Pyrenees Jogja'  and city LIKE 'Yogyakarta'
#
# Hotel Sinar I
# UPDATE jobstreet_raws SET company_id = '930'     where company LIKE 'Hotel Sinar I'  and city LIKE 'Surabaya'
#
# Hova Studio
# UPDATE jobstreet_raws SET company_id = '931'     where company LIKE 'Hova Studio'  and city LIKE 'Jakarta Barat'
#
# HPI-Agro
# UPDATE jobstreet_raws SET company_id = '932'     where company LIKE 'HPI-Agro'  and city LIKE 'Jakarta Barat'
#
# HPI-Agro
# UPDATE jobstreet_raws SET company_id = '933'     where company LIKE 'HPI-Agro'  and city LIKE 'Jakarta Raya'
#
# HPI-Agro
# UPDATE jobstreet_raws SET company_id = '934'     where company LIKE 'HPI-Agro'  and city LIKE 'Kalimantan Barat'
#
# HPI-Agro
# UPDATE jobstreet_raws SET company_id = '935'     where company LIKE 'HPI-Agro'  and city LIKE 'Makassar'
#
# HSW GROUP
# UPDATE jobstreet_raws SET company_id = '936'     where company LIKE 'HSW GROUP'  and city LIKE 'Jakarta Pusat'
#
# HSW GROUP
# UPDATE jobstreet_raws SET company_id = '937'     where company LIKE 'HSW GROUP'  and city LIKE 'Jakarta Raya'
#
# HSW GROUP
# UPDATE jobstreet_raws SET company_id = '938'     where company LIKE 'HSW GROUP'  and city LIKE 'Jakarta Utara'
#
# Huayou International Mining (Hongkong) Ltd.
# UPDATE jobstreet_raws SET company_id = '939'     where company LIKE 'Huayou International Mining (Hongkong) Ltd.'  and city LIKE 'Halmahera'
#
# Human Plus Institute
# UPDATE jobstreet_raws SET company_id = '940'     where company LIKE 'Human Plus Institute'  and city LIKE 'Jakarta Raya'
#
# Hurricane XCS
# UPDATE jobstreet_raws SET company_id = '941'     where company LIKE 'Hurricane XCS'  and city LIKE 'Jakarta Utara'
#
# Hurricane XCS
# UPDATE jobstreet_raws SET company_id = '942'     where company LIKE 'Hurricane XCS'  and city LIKE 'Sumatera Selatan'
#
# hys beauty brand
# UPDATE jobstreet_raws SET company_id = '943'     where company LIKE 'hys beauty brand'  and city LIKE 'Jakarta Raya'
#
# I CAN READ
# UPDATE jobstreet_raws SET company_id = '944'     where company LIKE 'I CAN READ'  and city LIKE 'Batam'
#
# I CAN READ
# UPDATE jobstreet_raws SET company_id = '945'     where company LIKE 'I CAN READ'  and city LIKE 'Bogor'
#
# I CAN READ
# UPDATE jobstreet_raws SET company_id = '946'     where company LIKE 'I CAN READ'  and city LIKE 'Cikarang'
#
# I CAN READ
# UPDATE jobstreet_raws SET company_id = '947'     where company LIKE 'I CAN READ'  and city LIKE 'Jakarta Barat'
#
# I CAN READ
# UPDATE jobstreet_raws SET company_id = '948'     where company LIKE 'I CAN READ'  and city LIKE 'Jakarta Raya'
#
# I CAN READ (SOLO)
# UPDATE jobstreet_raws SET company_id = '949'     where company LIKE 'I CAN READ (SOLO)'  and city LIKE 'Surakarta'
#
# Ida Jaya Crystal
# UPDATE jobstreet_raws SET company_id = '950'     where company LIKE 'Ida Jaya Crystal'  and city LIKE 'Jakarta Utara'
#
# IDEKU.ID
# UPDATE jobstreet_raws SET company_id = '951'     where company LIKE 'IDEKU.ID'  and city LIKE 'Tangerang'
#
# IKA GROUP
# UPDATE jobstreet_raws SET company_id = '952'     where company LIKE 'IKA GROUP'  and city LIKE 'Jakarta Pusat'
#
# IKA GROUP
# UPDATE jobstreet_raws SET company_id = '953'     where company LIKE 'IKA GROUP'  and city LIKE 'Jakarta Raya'
#
# IKEA Indonesia
# UPDATE jobstreet_raws SET company_id = '954'     where company LIKE 'IKEA Indonesia'  and city LIKE 'Banten'
#
# IND.PARFUME
# UPDATE jobstreet_raws SET company_id = '955'     where company LIKE 'IND.PARFUME'  and city LIKE 'Tegal'
#
# INDAH GROUP
# UPDATE jobstreet_raws SET company_id = '956'     where company LIKE 'INDAH GROUP'  and city LIKE 'Jakarta Timur'
#
# Indah Plastic
# UPDATE jobstreet_raws SET company_id = '957'     where company LIKE 'Indah Plastic'  and city LIKE 'Jawa Timur'
#
# Indium Corporation of America
# UPDATE jobstreet_raws SET company_id = '958'     where company LIKE 'Indium Corporation of America'  and city LIKE 'Cikarang'
#
# Indo Medika nusantara
# UPDATE jobstreet_raws SET company_id = '959'     where company LIKE 'Indo Medika nusantara'  and city LIKE 'Jakarta Selatan'
#
# Indo Trans Konstruksi
# UPDATE jobstreet_raws SET company_id = '960'     where company LIKE 'Indo Trans Konstruksi'  and city LIKE 'Bekasi'
#
# INDOASIA INTERIOR
# UPDATE jobstreet_raws SET company_id = '961'     where company LIKE 'INDOASIA INTERIOR'  and city LIKE 'Bali'
#
# Indodana - PT Artha Dana Teknologi
# UPDATE jobstreet_raws SET company_id = '962'     where company LIKE 'Indodana - PT Artha Dana Teknologi'  and city LIKE 'Jakarta Barat'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '963'     where company LIKE 'Indofood Group'  and city LIKE 'Cikarang'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '964'     where company LIKE 'Indofood Group'  and city LIKE 'Jakarta Pusat'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '965'     where company LIKE 'Indofood Group'  and city LIKE 'Jakarta Raya'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '966'     where company LIKE 'Indofood Group'  and city LIKE 'Jakarta Selatan'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '967'     where company LIKE 'Indofood Group'  and city LIKE 'Jakarta Utara'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '968'     where company LIKE 'Indofood Group'  and city LIKE 'Karawang'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '969'     where company LIKE 'Indofood Group'  and city LIKE 'Semarang'
#
# Indofood Group
# UPDATE jobstreet_raws SET company_id = '970'     where company LIKE 'Indofood Group'  and city LIKE 'Sidoarjo'
#
# INDOFUN GAMES
# UPDATE jobstreet_raws SET company_id = '971'     where company LIKE 'INDOFUN GAMES'  and city LIKE 'Jakarta Pusat'
#
# INDOFUN GAMES
# UPDATE jobstreet_raws SET company_id = '972'     where company LIKE 'INDOFUN GAMES'  and city LIKE 'Jakarta Raya'
#
# INDOFUN GAMES
# UPDATE jobstreet_raws SET company_id = '973'     where company LIKE 'INDOFUN GAMES'  and city LIKE 'Yogyakarta'
#
# Indojastari
# UPDATE jobstreet_raws SET company_id = '974'     where company LIKE 'Indojastari'  and city LIKE 'Jakarta Barat'
#
# Indonesia Bakery Family
# UPDATE jobstreet_raws SET company_id = '975'     where company LIKE 'Indonesia Bakery Family'  and city LIKE 'Bandung'
#
# Indonesia Equipment Centre
# UPDATE jobstreet_raws SET company_id = '976'     where company LIKE 'Indonesia Equipment Centre'  and city LIKE 'Jakarta Raya'
#
# Indonesia Equipment Centre
# UPDATE jobstreet_raws SET company_id = '977'     where company LIKE 'Indonesia Equipment Centre'  and city LIKE 'Maluku Utara'
#
# Indonesia Equipment Centre
# UPDATE jobstreet_raws SET company_id = '978'     where company LIKE 'Indonesia Equipment Centre'  and city LIKE 'Sulawesi Tenggara'
#
# Indonesia International Institute for Life Sciences
# UPDATE jobstreet_raws SET company_id = '979'     where company LIKE 'Indonesia International Institute for Life Sciences'  and city LIKE 'Jakarta Raya'
#
# Indonesia International Institute for Life Sciences
# UPDATE jobstreet_raws SET company_id = '980'     where company LIKE 'Indonesia International Institute for Life Sciences'  and city LIKE 'Jakarta Timur'
#
# Indoprima Group
# UPDATE jobstreet_raws SET company_id = '981'     where company LIKE 'Indoprima Group'  and city LIKE 'Gresik'
#
# Indoprima Group
# UPDATE jobstreet_raws SET company_id = '982'     where company LIKE 'Indoprima Group'  and city LIKE 'Jawa Timur'
#
# Indoprima Group
# UPDATE jobstreet_raws SET company_id = '983'     where company LIKE 'Indoprima Group'  and city LIKE 'Pasuruan'
#
# Indoprima Group
# UPDATE jobstreet_raws SET company_id = '984'     where company LIKE 'Indoprima Group'  and city LIKE 'Surabaya'
#
# Indosat Ooredoo
# UPDATE jobstreet_raws SET company_id = '985'     where company LIKE 'Indosat Ooredoo'  and city LIKE 'Jakarta Raya'
#
# Indosat Ooredoo
# UPDATE jobstreet_raws SET company_id = '986'     where company LIKE 'Indosat Ooredoo'  and city LIKE 'Surabaya'
#
# IndoSoft
# UPDATE jobstreet_raws SET company_id = '987'     where company LIKE 'IndoSoft'  and city LIKE 'Malang'
#
# Indotim (Jakarta)
# UPDATE jobstreet_raws SET company_id = '988'     where company LIKE 'Indotim (Jakarta)'  and city LIKE 'Tangerang'
#
# INDRACO GROUP
# UPDATE jobstreet_raws SET company_id = '989'     where company LIKE 'INDRACO GROUP'  and city LIKE 'Gresik'
#
# INDRACO GROUP
# UPDATE jobstreet_raws SET company_id = '990'     where company LIKE 'INDRACO GROUP'  and city LIKE 'Pekalongan'
#
# INDRACO GROUP
# UPDATE jobstreet_raws SET company_id = '991'     where company LIKE 'INDRACO GROUP'  and city LIKE 'Surabaya'
#
# Industri pembuatan logam dasar bukan besi
# UPDATE jobstreet_raws SET company_id = '992'     where company LIKE 'Industri pembuatan logam dasar bukan besi'  and city LIKE 'Sulawesi Tengah'
#
# INFIGYGROUP
# UPDATE jobstreet_raws SET company_id = '993'     where company LIKE 'INFIGYGROUP'  and city LIKE 'Bali'
#
# InkubatorX
# UPDATE jobstreet_raws SET company_id = '994'     where company LIKE 'InkubatorX'  and city LIKE 'Jakarta Timur'
#
# Innovasi Dapur Indonesia
# UPDATE jobstreet_raws SET company_id = '995'     where company LIKE 'Innovasi Dapur Indonesia'  and city LIKE 'Banten'
#
# Innovasi Dapur Indonesia
# UPDATE jobstreet_raws SET company_id = '996'     where company LIKE 'Innovasi Dapur Indonesia'  and city LIKE 'Tangerang'
#
# Innovative Learning Center
# UPDATE jobstreet_raws SET company_id = '997'     where company LIKE 'Innovative Learning Center'  and city LIKE 'Surabaya'
#
# Innovatz solutions Jakarta
# UPDATE jobstreet_raws SET company_id = '998'     where company LIKE 'Innovatz solutions Jakarta'  and city LIKE 'Jakarta Pusat'
#
# Insan Cendekia Madani
# UPDATE jobstreet_raws SET company_id = '999'     where company LIKE 'Insan Cendekia Madani'  and city LIKE 'Tangerang'
#
# Inspira Digital
# UPDATE jobstreet_raws SET company_id = '1000'     where company LIKE 'Inspira Digital'  and city LIKE 'Jakarta Raya'
#
# Inspirasi Media Kreatif
# UPDATE jobstreet_raws SET company_id = '1001'     where company LIKE 'Inspirasi Media Kreatif'  and city LIKE 'Denpasar'
#
# Inspire
# UPDATE jobstreet_raws SET company_id = '1002'     where company LIKE 'Inspire'  and city LIKE 'Sidoarjo'
#
# Institut Bisnis Dan Informatika Kwik Kian Gie
# UPDATE jobstreet_raws SET company_id = '1003'     where company LIKE 'Institut Bisnis Dan Informatika Kwik Kian Gie'  and city LIKE 'Jakarta Raya'
#
# Institut Bisnis Dan Informatika Kwik Kian Gie
# UPDATE jobstreet_raws SET company_id = '1004'     where company LIKE 'Institut Bisnis Dan Informatika Kwik Kian Gie'  and city LIKE 'Jakarta Utara'
#
# Instpower
# UPDATE jobstreet_raws SET company_id = '1005'     where company LIKE 'Instpower'  and city LIKE 'Jakarta Barat'
#
# Integrasi Megakanal Agensi
# UPDATE jobstreet_raws SET company_id = '1006'     where company LIKE 'Integrasi Megakanal Agensi'  and city LIKE 'Jakarta Raya'
#
# INTEGRITY TAX AND MANAGEMENT CONSULTANT
# UPDATE jobstreet_raws SET company_id = '1007'     where company LIKE 'INTEGRITY TAX AND MANAGEMENT CONSULTANT'  and city LIKE 'Surabaya'
#
# Integro Technologies Sdn Bhd
# UPDATE jobstreet_raws SET company_id = '1008'     where company LIKE 'Integro Technologies Sdn Bhd'  and city LIKE 'Jakarta Pusat'
#
# IQI Holdings Sdn Bhd
# UPDATE jobstreet_raws SET company_id = '1009'     where company LIKE 'IQI Holdings Sdn Bhd'  and city LIKE 'Petaling Jaya'
#
# Iron Bird Logistic (Bluebirdgroup)
# UPDATE jobstreet_raws SET company_id = '1010'     where company LIKE 'Iron Bird Logistic (Bluebirdgroup)'  and city LIKE 'Jakarta Utara'
#
# ISMAYA GROUP
# UPDATE jobstreet_raws SET company_id = '1011'     where company LIKE 'ISMAYA GROUP'  and city LIKE 'Bali'
#
# ISMAYA GROUP
# UPDATE jobstreet_raws SET company_id = '1012'     where company LIKE 'ISMAYA GROUP'  and city LIKE 'Jakarta Raya'
#
# ISMAYA GROUP
# UPDATE jobstreet_raws SET company_id = '1013'     where company LIKE 'ISMAYA GROUP'  and city LIKE 'Jakarta Selatan'
#
# ISMAYA GROUP
# UPDATE jobstreet_raws SET company_id = '1014'     where company LIKE 'ISMAYA GROUP'  and city LIKE 'Jawa Timur'
#
# ISMAYA GROUP
# UPDATE jobstreet_raws SET company_id = '1015'     where company LIKE 'ISMAYA GROUP'  and city LIKE 'Surabaya'
#
# Iswari Interior
# UPDATE jobstreet_raws SET company_id = '1016'     where company LIKE 'Iswari Interior'  and city LIKE 'Ungaran'
#
# ITC Auto Multi Finance
# UPDATE jobstreet_raws SET company_id = '1017'     where company LIKE 'ITC Auto Multi Finance'  and city LIKE 'Jakarta Raya'
#
# ITPI  Technology
# UPDATE jobstreet_raws SET company_id = '1018'     where company LIKE 'ITPI  Technology'  and city LIKE 'Jawa Timur'
#
# Jaddi Pastrisindo Gemilang
# UPDATE jobstreet_raws SET company_id = '1019'     where company LIKE 'Jaddi Pastrisindo Gemilang'  and city LIKE 'Jakarta Utara'
#
# Jakarta Academics
# UPDATE jobstreet_raws SET company_id = '1020'     where company LIKE 'Jakarta Academics'  and city LIKE 'Jakarta Selatan'
#
# Jakarta Derma Clinic
# UPDATE jobstreet_raws SET company_id = '1021'     where company LIKE 'Jakarta Derma Clinic'  and city LIKE 'Jakarta Raya'
#
# Jakarta FnB
# UPDATE jobstreet_raws SET company_id = '1022'     where company LIKE 'Jakarta FnB'  and city LIKE 'Jakarta Barat'
#
# Jakarta FnB
# UPDATE jobstreet_raws SET company_id = '1023'     where company LIKE 'Jakarta FnB'  and city LIKE 'Jakarta Utara'
#
# Jakarta International College
# UPDATE jobstreet_raws SET company_id = '1024'     where company LIKE 'Jakarta International College'  and city LIKE 'Jakarta Raya'
#
# Jakarta Japanese School
# UPDATE jobstreet_raws SET company_id = '1025'     where company LIKE 'Jakarta Japanese School'  and city LIKE 'Tangerang'
#
# JAKARTA NANYANG SCHOOL
# UPDATE jobstreet_raws SET company_id = '1026'     where company LIKE 'JAKARTA NANYANG SCHOOL'  and city LIKE 'Tangerang'
#
# Januar Jahja and Partners
# UPDATE jobstreet_raws SET company_id = '1027'     where company LIKE 'Januar Jahja and Partners'  and city LIKE 'Jakarta Raya'
#
# JawaMetalAksesoris
# UPDATE jobstreet_raws SET company_id = '1028'     where company LIKE 'JawaMetalAksesoris'  and city LIKE 'Surakarta'
#
# Jaya Mandiri Plastik
# UPDATE jobstreet_raws SET company_id = '1029'     where company LIKE 'Jaya Mandiri Plastik'  and city LIKE 'Bandung'
#
# Jaya Mandiri Plastik
# UPDATE jobstreet_raws SET company_id = '1030'     where company LIKE 'Jaya Mandiri Plastik'  and city LIKE 'Jawa Barat'
#
# JD .ID (PT Ritel Bersama Nasional)
# UPDATE jobstreet_raws SET company_id = '1031'     where company LIKE 'JD .ID (PT Ritel Bersama Nasional)'  and city LIKE 'Jakarta Raya'
#
# JD .ID (PT Ritel Bersama Nasional)
# UPDATE jobstreet_raws SET company_id = '1032'     where company LIKE 'JD .ID (PT Ritel Bersama Nasional)'  and city LIKE 'Jakarta Selatan'
#
# JD .ID (PT Ritel Bersama Nasional)
# UPDATE jobstreet_raws SET company_id = '1033'     where company LIKE 'JD .ID (PT Ritel Bersama Nasional)'  and city LIKE 'Palembang'
#
# Jec and Jen Digital House
# UPDATE jobstreet_raws SET company_id = '1034'     where company LIKE 'Jec and Jen Digital House'  and city LIKE 'Jakarta Barat'
#
# Jegstudio
# UPDATE jobstreet_raws SET company_id = '1035'     where company LIKE 'Jegstudio'  and city LIKE 'Denpasar'
#
# Jendela360
# UPDATE jobstreet_raws SET company_id = '1036'     where company LIKE 'Jendela360'  and city LIKE 'Jakarta Barat'
#
# Jendela360
# UPDATE jobstreet_raws SET company_id = '1037'     where company LIKE 'Jendela360'  and city LIKE 'Jakarta Raya'
#
# Jimac Group
# UPDATE jobstreet_raws SET company_id = '1038'     where company LIKE 'Jimac Group'  and city LIKE 'Jakarta Barat'
#
# JJ Creative Technology
# UPDATE jobstreet_raws SET company_id = '1039'     where company LIKE 'JJ Creative Technology'  and city LIKE 'Tangerang'
#
# JJ PROMOTION
# UPDATE jobstreet_raws SET company_id = '1040'     where company LIKE 'JJ PROMOTION'  and city LIKE 'Surabaya'
#
# JJ-Lapp Cable Indonesia
# UPDATE jobstreet_raws SET company_id = '1041'     where company LIKE 'JJ-Lapp Cable Indonesia'  and city LIKE 'Jakarta Selatan'
#
# JJ-Lapp Cable Indonesia
# UPDATE jobstreet_raws SET company_id = '1042'     where company LIKE 'JJ-Lapp Cable Indonesia'  and city LIKE 'Tangerang'
#
# JM Top Optical
# UPDATE jobstreet_raws SET company_id = '1043'     where company LIKE 'JM Top Optical'  and city LIKE 'Surabaya'
#
# JO.Shimizu-Adhikarya (MRT Project)
# UPDATE jobstreet_raws SET company_id = '1044'     where company LIKE 'JO.Shimizu-Adhikarya (MRT Project)'  and city LIKE 'Jakarta Pusat'
#
# JO.Shimizu-Adhikarya (MRT Project)
# UPDATE jobstreet_raws SET company_id = '1045'     where company LIKE 'JO.Shimizu-Adhikarya (MRT Project)'  and city LIKE 'Jakarta Raya'
#
# JSI Group
# UPDATE jobstreet_raws SET company_id = '1046'     where company LIKE 'JSI Group'  and city LIKE 'Jakarta Selatan'
#
# JU HUI FOOTWEAR CO.LTD
# UPDATE jobstreet_raws SET company_id = '1047'     where company LIKE 'JU HUI FOOTWEAR CO.LTD'  and city LIKE 'Cambodia'
#
# Justech Digital Sdn Bhd
# UPDATE jobstreet_raws SET company_id = '1048'     where company LIKE 'Justech Digital Sdn Bhd'  and city LIKE 'Jakarta Utara'
#
# JUWONO,WIDYAPRATHAMA & REKAN
# UPDATE jobstreet_raws SET company_id = '1049'     where company LIKE 'JUWONO,WIDYAPRATHAMA & REKAN'  and city LIKE 'Jakarta Raya'
#
# Kabobs Premium Kebab
# UPDATE jobstreet_raws SET company_id = '1050'     where company LIKE 'Kabobs Premium Kebab'  and city LIKE 'Bandung'
#
# Kaftan Collection Jakarta
# UPDATE jobstreet_raws SET company_id = '1051'     where company LIKE 'Kaftan Collection Jakarta'  and city LIKE 'Jakarta Pusat'
#
# KAJA Group
# UPDATE jobstreet_raws SET company_id = '1052'     where company LIKE 'KAJA Group'  and city LIKE 'Bali'
#
# KAJA Group
# UPDATE jobstreet_raws SET company_id = '1053'     where company LIKE 'KAJA Group'  and city LIKE 'Jakarta Selatan'
#
# Kalbe Consumer Health (PT Saka Farma Laboratories)
# UPDATE jobstreet_raws SET company_id = '1054'     where company LIKE 'Kalbe Consumer Health (PT Saka Farma Laboratories)'  and city LIKE 'Cikarang'
#
# Kalbe Consumer Health (PT Saka Farma Laboratories)
# UPDATE jobstreet_raws SET company_id = '1055'     where company LIKE 'Kalbe Consumer Health (PT Saka Farma Laboratories)'  and city LIKE 'Jakarta Raya'
#
# Kalbe Consumer Health (PT Saka Farma Laboratories)
# UPDATE jobstreet_raws SET company_id = '1056'     where company LIKE 'Kalbe Consumer Health (PT Saka Farma Laboratories)'  and city LIKE 'Jakarta Utara'
#
# KALBE NUTRITIONALS
# UPDATE jobstreet_raws SET company_id = '1057'     where company LIKE 'KALBE NUTRITIONALS'  and city LIKE 'Jakarta Raya'
#
# KALBE NUTRITIONALS
# UPDATE jobstreet_raws SET company_id = '1058'     where company LIKE 'KALBE NUTRITIONALS'  and city LIKE 'Jakarta Timur'
#
# KALBE NUTRITIONALS
# UPDATE jobstreet_raws SET company_id = '1059'     where company LIKE 'KALBE NUTRITIONALS'  and city LIKE 'Jakarta Utara'
#
# KALBE NUTRITIONALS
# UPDATE jobstreet_raws SET company_id = '1060'     where company LIKE 'KALBE NUTRITIONALS'  and city LIKE 'Jambi'
#
# Kalbe Nutritionals (PT. Chakra Radha Mustika)
# UPDATE jobstreet_raws SET company_id = '1061'     where company LIKE 'Kalbe Nutritionals (PT. Chakra Radha Mustika)'  and city LIKE 'Jakarta Timur'
#
# Kalbe Nutritionals (PT. Chakra Radha Mustika)
# UPDATE jobstreet_raws SET company_id = '1062'     where company LIKE 'Kalbe Nutritionals (PT. Chakra Radha Mustika)'  and city LIKE 'Yogyakarta'
#
# KALBIS Institute
# UPDATE jobstreet_raws SET company_id = '1063'     where company LIKE 'KALBIS Institute'  and city LIKE 'Jakarta Raya'
#
# KALBIS Institute
# UPDATE jobstreet_raws SET company_id = '1064'     where company LIKE 'KALBIS Institute'  and city LIKE 'Jakarta Timur'
#
# KALINDO LAND
# UPDATE jobstreet_raws SET company_id = '1065'     where company LIKE 'KALINDO LAND'  and city LIKE 'Jakarta Raya'
#
# KALINDO LAND
# UPDATE jobstreet_raws SET company_id = '1066'     where company LIKE 'KALINDO LAND'  and city LIKE 'Tangerang'
#
# Kaloka Realty
# UPDATE jobstreet_raws SET company_id = '1067'     where company LIKE 'Kaloka Realty'  and city LIKE 'Bandung'
#
# Kanmo Group
# UPDATE jobstreet_raws SET company_id = '1068'     where company LIKE 'Kanmo Group'  and city LIKE 'Bali'
#
# Kanmo Group
# UPDATE jobstreet_raws SET company_id = '1069'     where company LIKE 'Kanmo Group'  and city LIKE 'Bogor'
#
# Kanmo Group
# UPDATE jobstreet_raws SET company_id = '1070'     where company LIKE 'Kanmo Group'  and city LIKE 'Jakarta Pusat'
#
# Kanmo Group
# UPDATE jobstreet_raws SET company_id = '1071'     where company LIKE 'Kanmo Group'  and city LIKE 'Jakarta Raya'
#
# Kanmo Group
# UPDATE jobstreet_raws SET company_id = '1072'     where company LIKE 'Kanmo Group'  and city LIKE 'Makassar'
#
# Kanmo Group
# UPDATE jobstreet_raws SET company_id = '1073'     where company LIKE 'Kanmo Group'  and city LIKE 'Surabaya'
#
# Kantor Akuntan Publik Agus, Indra, Jerri, & Rekan
# UPDATE jobstreet_raws SET company_id = '1074'     where company LIKE 'Kantor Akuntan Publik Agus, Indra, Jerri, & Rekan'  and city LIKE 'Jakarta Raya'
#
# Kantor Akuntan Publik Charles & Nurlena
# UPDATE jobstreet_raws SET company_id = '1075'     where company LIKE 'Kantor Akuntan Publik Charles & Nurlena'  and city LIKE 'Jakarta Raya'
#
# Kantor Akuntan Publik Jamaludin, Ardi, Sukimto & Rekan
# UPDATE jobstreet_raws SET company_id = '1076'     where company LIKE 'Kantor Akuntan Publik Jamaludin, Ardi, Sukimto & Rekan'  and city LIKE 'Jakarta Selatan'
#
# Kantor Akuntan Publik Jimy Abadi
# UPDATE jobstreet_raws SET company_id = '1077'     where company LIKE 'Kantor Akuntan Publik Jimy Abadi'  and city LIKE 'Jakarta Raya'
#
# Kantor Akuntan Publik Jimy Abadi
# UPDATE jobstreet_raws SET company_id = '1078'     where company LIKE 'Kantor Akuntan Publik Jimy Abadi'  and city LIKE 'Surabaya'
#
# Kantor Konsultan Pajak Hirwan
# UPDATE jobstreet_raws SET company_id = '1079'     where company LIKE 'Kantor Konsultan Pajak Hirwan'  and city LIKE 'Jakarta Raya'
#
# Kantor Notaris Irvin
# UPDATE jobstreet_raws SET company_id = '1080'     where company LIKE 'Kantor Notaris Irvin'  and city LIKE 'Jakarta Raya'
#
# Kaos Polos Mania
# UPDATE jobstreet_raws SET company_id = '1081'     where company LIKE 'Kaos Polos Mania'  and city LIKE 'Jakarta Barat'
#
# KAP Anwar & Rekan
# UPDATE jobstreet_raws SET company_id = '1082'     where company LIKE 'KAP Anwar & Rekan'  and city LIKE 'Jakarta Raya'
#
# KAP Anwar & Rekan
# UPDATE jobstreet_raws SET company_id = '1083'     where company LIKE 'KAP Anwar & Rekan'  and city LIKE 'Jakarta Selatan'
#
# KAP Heliantono & Rekan
# UPDATE jobstreet_raws SET company_id = '1084'     where company LIKE 'KAP Heliantono & Rekan'  and city LIKE 'Tangerang'
#
# KAP Hendrawinata Hanny Erwin & Sumargo
# UPDATE jobstreet_raws SET company_id = '1085'     where company LIKE 'KAP Hendrawinata Hanny Erwin & Sumargo'  and city LIKE 'Jakarta Raya'
#
# KAP Johannes Juara & Rekan
# UPDATE jobstreet_raws SET company_id = '1086'     where company LIKE 'KAP Johannes Juara & Rekan'  and city LIKE 'Jakarta Selatan'
#
# KAP Kanel & Partners
# UPDATE jobstreet_raws SET company_id = '1087'     where company LIKE 'KAP Kanel & Partners'  and city LIKE 'Jakarta Pusat'
#
# KAP Mennix & Rekan
# UPDATE jobstreet_raws SET company_id = '1088'     where company LIKE 'KAP Mennix & Rekan'  and city LIKE 'Jakarta Pusat'
#
# KAP Morhan dan Rekan
# UPDATE jobstreet_raws SET company_id = '1089'     where company LIKE 'KAP Morhan dan Rekan'  and city LIKE 'Jakarta Raya'
#
# KAP Morhan dan Rekan
# UPDATE jobstreet_raws SET company_id = '1090'     where company LIKE 'KAP Morhan dan Rekan'  and city LIKE 'Jakarta Selatan'
#
# KAP PAUL HADIWINATA, HIDAJAT, ARSONO, RETNO, PALILINGAN & REKAN
# UPDATE jobstreet_raws SET company_id = '1091'     where company LIKE 'KAP PAUL HADIWINATA, HIDAJAT, ARSONO, RETNO, PALILINGAN & REKAN'  and city LIKE 'Jakarta Pusat'
#
# KAP SENDY CAHYADI & ERRY FEBRIANTO SAPUTRA
# UPDATE jobstreet_raws SET company_id = '1092'     where company LIKE 'KAP SENDY CAHYADI & ERRY FEBRIANTO SAPUTRA'  and city LIKE 'Bekasi'
#
# KAP Tjahjadi & Tamara
# UPDATE jobstreet_raws SET company_id = '1093'     where company LIKE 'KAP Tjahjadi & Tamara'  and city LIKE 'Jakarta Pusat'
#
# Karma Group
# UPDATE jobstreet_raws SET company_id = '1094'     where company LIKE 'Karma Group'  and city LIKE 'Badung'
#
# Karma Group
# UPDATE jobstreet_raws SET company_id = '1095'     where company LIKE 'Karma Group'  and city LIKE 'Denpasar'
#
# Karma Group
# UPDATE jobstreet_raws SET company_id = '1096'     where company LIKE 'Karma Group'  and city LIKE 'Jakarta Raya'
#
# Karma Group
# UPDATE jobstreet_raws SET company_id = '1097'     where company LIKE 'Karma Group'  and city LIKE 'Yogyakarta'
#
# Kartiko Heritage Restaurant
# UPDATE jobstreet_raws SET company_id = '1098'     where company LIKE 'Kartiko Heritage Restaurant'  and city LIKE 'Jawa Timur'
#
# Karunia Prima Nastari (KPN CORP.)
# UPDATE jobstreet_raws SET company_id = '1099'     where company LIKE 'Karunia Prima Nastari (KPN CORP.)'  and city LIKE 'Jakarta Raya'
#
# Karunia Prima Nastari (KPN CORP.)
# UPDATE jobstreet_raws SET company_id = '1100'     where company LIKE 'Karunia Prima Nastari (KPN CORP.)'  and city LIKE 'Jakarta Selatan'
#
# Karunia Prima Nastari (KPN CORP.)
# UPDATE jobstreet_raws SET company_id = '1101'     where company LIKE 'Karunia Prima Nastari (KPN CORP.)'  and city LIKE 'Jambi'
#
# Karyamas Plantation
# UPDATE jobstreet_raws SET company_id = '1102'     where company LIKE 'Karyamas Plantation'  and city LIKE 'Jakarta Raya'
#
# Karyamas Plantation
# UPDATE jobstreet_raws SET company_id = '1103'     where company LIKE 'Karyamas Plantation'  and city LIKE 'Kutai Barat'
#
# Kawan Lama Group
# UPDATE jobstreet_raws SET company_id = '1104'     where company LIKE 'Kawan Lama Group'  and city LIKE 'Jakarta Barat'
#
# Kay Collection
# UPDATE jobstreet_raws SET company_id = '1105'     where company LIKE 'Kay Collection'  and city LIKE 'Jakarta Barat'
#
# KDS
# UPDATE jobstreet_raws SET company_id = '1106'     where company LIKE 'KDS'  and city LIKE 'Bima'
#
# KDS
# UPDATE jobstreet_raws SET company_id = '1107'     where company LIKE 'KDS'  and city LIKE 'Gorontalo'
#
# KDS
# UPDATE jobstreet_raws SET company_id = '1108'     where company LIKE 'KDS'  and city LIKE 'Jawa Barat'
#
# KDS
# UPDATE jobstreet_raws SET company_id = '1109'     where company LIKE 'KDS'  and city LIKE 'Jawa Tengah'
#
# KDS
# UPDATE jobstreet_raws SET company_id = '1110'     where company LIKE 'KDS'  and city LIKE 'Sulawesi Selatan'
#
# Keira Skin Care
# UPDATE jobstreet_raws SET company_id = '1111'     where company LIKE 'Keira Skin Care'  and city LIKE 'Cianjur'
#
# Keira Skin Care
# UPDATE jobstreet_raws SET company_id = '1112'     where company LIKE 'Keira Skin Care'  and city LIKE 'Purwakarta'
#
# Kelontongunik
# UPDATE jobstreet_raws SET company_id = '1113'     where company LIKE 'Kelontongunik'  and city LIKE 'Jakarta Raya'
#
# Kelontongunik
# UPDATE jobstreet_raws SET company_id = '1114'     where company LIKE 'Kelontongunik'  and city LIKE 'Jakarta Utara'
#
# KENCANA ABADI
# UPDATE jobstreet_raws SET company_id = '1115'     where company LIKE 'KENCANA ABADI'  and city LIKE 'Jawa Timur'
#
# Kencana Agri Ltd
# UPDATE jobstreet_raws SET company_id = '1116'     where company LIKE 'Kencana Agri Ltd'  and city LIKE 'Kalimantan Timur'
#
# Kencana Agri Ltd
# UPDATE jobstreet_raws SET company_id = '1117'     where company LIKE 'Kencana Agri Ltd'  and city LIKE 'Kutai Kartanegara'
#
# Kencana Agri Ltd
# UPDATE jobstreet_raws SET company_id = '1118'     where company LIKE 'Kencana Agri Ltd'  and city LIKE 'Sulawesi Tengah'
#
# Kencana Group ( Medan )
# UPDATE jobstreet_raws SET company_id = '1119'     where company LIKE 'Kencana Group ( Medan )'  and city LIKE 'Medan'
#
# Kencana Group ( Medan )
# UPDATE jobstreet_raws SET company_id = '1120'     where company LIKE 'Kencana Group ( Medan )'  and city LIKE 'Riau'
#
# Kencana Group ( Medan )
# UPDATE jobstreet_raws SET company_id = '1121'     where company LIKE 'Kencana Group ( Medan )'  and city LIKE 'Sumatera Utara'
#
# Keppel Land
# UPDATE jobstreet_raws SET company_id = '1122'     where company LIKE 'Keppel Land'  and city LIKE 'Jakarta Selatan'
#
# Keppel Land
# UPDATE jobstreet_raws SET company_id = '1123'     where company LIKE 'Keppel Land'  and city LIKE 'Jakarta Timur'
#
# Kerajinan Anyaman Yogya
# UPDATE jobstreet_raws SET company_id = '1124'     where company LIKE 'Kerajinan Anyaman Yogya'  and city LIKE 'Bantul'
#
# Kereta Laju Grup
# UPDATE jobstreet_raws SET company_id = '1125'     where company LIKE 'Kereta Laju Grup'  and city LIKE 'Tangerang'
#
# KESAN Digital Nusantara
# UPDATE jobstreet_raws SET company_id = '1126'     where company LIKE 'KESAN Digital Nusantara'  and city LIKE 'Jakarta Raya'
#
# KEYWORDS INTERNATIONAL PTE LTD.
# UPDATE jobstreet_raws SET company_id = '1127'     where company LIKE 'KEYWORDS INTERNATIONAL PTE LTD.'  and city LIKE 'Yogyakarta'
#
# Kiat Ananda Group
# UPDATE jobstreet_raws SET company_id = '1128'     where company LIKE 'Kiat Ananda Group'  and city LIKE 'Bekasi'
#
# Kiat Ananda Group
# UPDATE jobstreet_raws SET company_id = '1129'     where company LIKE 'Kiat Ananda Group'  and city LIKE 'Bogor'
#
# Kiddles (Kids Learning Chinese)
# UPDATE jobstreet_raws SET company_id = '1130'     where company LIKE 'Kiddles (Kids Learning Chinese)'  and city LIKE 'Bogor'
#
# Kinderfield School
# UPDATE jobstreet_raws SET company_id = '1131'     where company LIKE 'Kinderfield School'  and city LIKE 'Bandung'
#
# Kinderworld Montessori
# UPDATE jobstreet_raws SET company_id = '1132'     where company LIKE 'Kinderworld Montessori'  and city LIKE 'Tangerang'
#
# KINGMAO INTERNATIONAL (S) PTE LTD
# UPDATE jobstreet_raws SET company_id = '1133'     where company LIKE 'KINGMAO INTERNATIONAL (S) PTE LTD'  and city LIKE 'Jakarta Raya'
#
# Kisel (Koperasi Telekomunikasi Selular)
# UPDATE jobstreet_raws SET company_id = '1134'     where company LIKE 'Kisel (Koperasi Telekomunikasi Selular)'  and city LIKE 'Jakarta Selatan'
#
# Kitchenware Indonesia
# UPDATE jobstreet_raws SET company_id = '1135'     where company LIKE 'Kitchenware Indonesia'  and city LIKE 'Jawa Timur'
#
# Kitchenware Indonesia
# UPDATE jobstreet_raws SET company_id = '1136'     where company LIKE 'Kitchenware Indonesia'  and city LIKE 'Surabaya'
#
# KJA SK&CO
# UPDATE jobstreet_raws SET company_id = '1137'     where company LIKE 'KJA SK&CO'  and city LIKE 'Jakarta Utara'
#
# KJPP Ruky Safrudin & Rekan
# UPDATE jobstreet_raws SET company_id = '1138'     where company LIKE 'KJPP Ruky Safrudin & Rekan'  and city LIKE 'Jakarta Raya'
#
# KJPP Sugeng, Irwan, Gunawan dan Rekan
# UPDATE jobstreet_raws SET company_id = '1139'     where company LIKE 'KJPP Sugeng, Irwan, Gunawan dan Rekan'  and city LIKE 'Tangerang'
#
# KKBC (HK) LIMITED
# UPDATE jobstreet_raws SET company_id = '1140'     where company LIKE 'KKBC (HK) LIMITED'  and city LIKE 'Jakarta Raya'
#
# KKP Benny Gunawan
# UPDATE jobstreet_raws SET company_id = '1141'     where company LIKE 'KKP Benny Gunawan'  and city LIKE 'Surabaya'
#
# KKP EC Consulting
# UPDATE jobstreet_raws SET company_id = '1142'     where company LIKE 'KKP EC Consulting'  and city LIKE 'Tangerang'
#
# KKP Karjoyono
# UPDATE jobstreet_raws SET company_id = '1143'     where company LIKE 'KKP Karjoyono'  and city LIKE 'Surabaya'
#
# Klik Dental Sejahtera
# UPDATE jobstreet_raws SET company_id = '1144'     where company LIKE 'Klik Dental Sejahtera'  and city LIKE 'Jakarta Utara'
#
# kliktimes.com
# UPDATE jobstreet_raws SET company_id = '1145'     where company LIKE 'kliktimes.com'  and city LIKE 'Malang'
#
# Klinik Afiah
# UPDATE jobstreet_raws SET company_id = '1146'     where company LIKE 'Klinik Afiah'  and city LIKE 'Bogor'
#
# Klinik Asri
# UPDATE jobstreet_raws SET company_id = '1147'     where company LIKE 'Klinik Asri'  and city LIKE 'Medan'
#
# KLINIK MEMOCI
# UPDATE jobstreet_raws SET company_id = '1148'     where company LIKE 'KLINIK MEMOCI'  and city LIKE 'Pekanbaru'
#
# Klinik Pratama Daarussyifa
# UPDATE jobstreet_raws SET company_id = '1149'     where company LIKE 'Klinik Pratama Daarussyifa'  and city LIKE 'Cilacap'
#
# Klinik Raisha
# UPDATE jobstreet_raws SET company_id = '1150'     where company LIKE 'Klinik Raisha'  and city LIKE 'Sleman'
#
# Klinik Sahabat Medika (Surabaya)
# UPDATE jobstreet_raws SET company_id = '1151'     where company LIKE 'Klinik Sahabat Medika (Surabaya)'  and city LIKE 'Jakarta Raya'
#
# Klinik Sakti Medika
# UPDATE jobstreet_raws SET company_id = '1152'     where company LIKE 'Klinik Sakti Medika'  and city LIKE 'Jakarta Selatan'
#
# Klinik Utama Mutiara Cikutra
# UPDATE jobstreet_raws SET company_id = '1153'     where company LIKE 'Klinik Utama Mutiara Cikutra'  and city LIKE 'Bandung'
#
# Klinik Wisma Husada
# UPDATE jobstreet_raws SET company_id = '1154'     where company LIKE 'Klinik Wisma Husada'  and city LIKE 'Jawa Timur'
#
# KNIGHT FRANK
# UPDATE jobstreet_raws SET company_id = '1155'     where company LIKE 'KNIGHT FRANK'  and city LIKE 'Jakarta Raya'
#
# KNIGHT FRANK
# UPDATE jobstreet_raws SET company_id = '1156'     where company LIKE 'KNIGHT FRANK'  and city LIKE 'Jakarta Selatan'
#
# Kocopaper Indonesia
# UPDATE jobstreet_raws SET company_id = '1157'     where company LIKE 'Kocopaper Indonesia'  and city LIKE 'Jakarta Raya'
#
# Koding Next
# UPDATE jobstreet_raws SET company_id = '1158'     where company LIKE 'Koding Next'  and city LIKE 'Bekasi'
#
# Koding Next
# UPDATE jobstreet_raws SET company_id = '1159'     where company LIKE 'Koding Next'  and city LIKE 'Jakarta Utara'
#
# Koffiesoft Group
# UPDATE jobstreet_raws SET company_id = '1160'     where company LIKE 'Koffiesoft Group'  and city LIKE 'Surabaya'
#
# Koji Space and Coffee
# UPDATE jobstreet_raws SET company_id = '1161'     where company LIKE 'Koji Space and Coffee'  and city LIKE 'Surakarta'
#
# Kolabora Group
# UPDATE jobstreet_raws SET company_id = '1162'     where company LIKE 'Kolabora Group'  and city LIKE 'Tangerang'
#
# KOMA JUNKYARD
# UPDATE jobstreet_raws SET company_id = '1163'     where company LIKE 'KOMA JUNKYARD'  and city LIKE 'Bekasi'
#
# Kompas Gramedia - KG Media
# UPDATE jobstreet_raws SET company_id = '1164'     where company LIKE 'Kompas Gramedia - KG Media'  and city LIKE 'Jakarta Barat'
#
# Kompas Gramedia - KG Media
# UPDATE jobstreet_raws SET company_id = '1165'     where company LIKE 'Kompas Gramedia - KG Media'  and city LIKE 'Jakarta Pusat'
#
# Kompas Gramedia - KG Media
# UPDATE jobstreet_raws SET company_id = '1166'     where company LIKE 'Kompas Gramedia - KG Media'  and city LIKE 'Jakarta Raya'
#
# Kompas Gramedia - KG Media
# UPDATE jobstreet_raws SET company_id = '1167'     where company LIKE 'Kompas Gramedia - KG Media'  and city LIKE 'Jakarta Selatan'
#
# Kompas Gramedia - KG Media
# UPDATE jobstreet_raws SET company_id = '1168'     where company LIKE 'Kompas Gramedia - KG Media'  and city LIKE 'Surakarta'
#
# Kompas Gramedia Group of Manufacture
# UPDATE jobstreet_raws SET company_id = '1169'     where company LIKE 'Kompas Gramedia Group of Manufacture'  and city LIKE 'Cikarang'
#
# Kompas Gramedia Group of Manufacture
# UPDATE jobstreet_raws SET company_id = '1170'     where company LIKE 'Kompas Gramedia Group of Manufacture'  and city LIKE 'Jakarta Pusat'
#
# Kompas Gramedia Group of Manufacture
# UPDATE jobstreet_raws SET company_id = '1171'     where company LIKE 'Kompas Gramedia Group of Manufacture'  and city LIKE 'Purwakarta'
#
# Konsultan pajak sony
# UPDATE jobstreet_raws SET company_id = '1172'     where company LIKE 'Konsultan pajak sony'  and city LIKE 'Surabaya'
#
# Kop Sehati Makmur Abadi
# UPDATE jobstreet_raws SET company_id = '1173'     where company LIKE 'Kop Sehati Makmur Abadi'  and city LIKE 'Bekasi'
#
# Koperasi Astra International
# UPDATE jobstreet_raws SET company_id = '1174'     where company LIKE 'Koperasi Astra International'  and city LIKE 'Jakarta Pusat'
#
# Koperasi Jasa Gramindo Berkah Madani
# UPDATE jobstreet_raws SET company_id = '1175'     where company LIKE 'Koperasi Jasa Gramindo Berkah Madani'  and city LIKE 'Yogyakarta'
#
# Koperasi Karyawan PT Tigaraksa Satria (Kopkara)
# ...
#
# PT Vanadia Utama
# UPDATE jobstreet_raws SET company_id = '8441'     where company LIKE 'PT Vanadia Utama'  and city LIKE 'Jakarta Raya'
#
# PT Vanz Inovatif Teknologi
# UPDATE jobstreet_raws SET company_id = '8442'     where company LIKE 'PT Vanz Inovatif Teknologi'  and city LIKE 'Jakarta Raya'
#
# PT Varley Indonesia
# UPDATE jobstreet_raws SET company_id = '8443'     where company LIKE 'PT Varley Indonesia'  and city LIKE 'Tangerang'
#
# PT Varnion Technology Semesta
# UPDATE jobstreet_raws SET company_id = '8444'     where company LIKE 'PT Varnion Technology Semesta'  and city LIKE 'Jakarta Selatan'
#
# PT VARP International Integrasi
# UPDATE jobstreet_raws SET company_id = '8445'     where company LIKE 'PT VARP International Integrasi'  and city LIKE 'Jakarta Utara'
#
# PT Vassa Sukses Mandiri
# UPDATE jobstreet_raws SET company_id = '8446'     where company LIKE 'PT Vassa Sukses Mandiri'  and city LIKE 'Surabaya'
#
# PT Vector InfoTechnologies Indonesia
# UPDATE jobstreet_raws SET company_id = '8447'     where company LIKE 'PT Vector InfoTechnologies Indonesia'  and city LIKE 'Jakarta Raya'
#
# PT Vega Technology Indonesia
# UPDATE jobstreet_raws SET company_id = '8448'     where company LIKE 'PT Vega Technology Indonesia'  and city LIKE 'Bali'
#
# PT Vega Technology Indonesia
# UPDATE jobstreet_raws SET company_id = '8449'     where company LIKE 'PT Vega Technology Indonesia'  and city LIKE 'Jakarta Raya'
#
# PT Vega Technology Indonesia
# UPDATE jobstreet_raws SET company_id = '8450'     where company LIKE 'PT Vega Technology Indonesia'  and city LIKE 'Jakarta Selatan'
#
# PT Venindo Jaya Abadi
# UPDATE jobstreet_raws SET company_id = '8451'     where company LIKE 'PT Venindo Jaya Abadi'  and city LIKE 'Jakarta Raya'
#
# PT Venturindo Jaya Batam
# UPDATE jobstreet_raws SET company_id = '8452'     where company LIKE 'PT Venturindo Jaya Batam'  and city LIKE 'Batam'
#
# PT Verena Multi Finance Tbk
# UPDATE jobstreet_raws SET company_id = '8453'     where company LIKE 'PT Verena Multi Finance Tbk'  and city LIKE 'Jakarta Raya'
#
# PT Verentia Inti Cipta Alami
# UPDATE jobstreet_raws SET company_id = '8454'     where company LIKE 'PT Verentia Inti Cipta Alami'  and city LIKE 'Jakarta Barat'
#
# PT Veron Indonesia
# UPDATE jobstreet_raws SET company_id = '8455'     where company LIKE 'PT Veron Indonesia'  and city LIKE 'Sidoarjo'
#
# PT VERTEX Global Indonesia
# UPDATE jobstreet_raws SET company_id = '8456'     where company LIKE 'PT VERTEX Global Indonesia'  and city LIKE 'Jakarta Utara'
#
# PT Vertika Technologies Nusantara
# UPDATE jobstreet_raws SET company_id = '8457'     where company LIKE 'PT Vertika Technologies Nusantara'  and city LIKE 'Bekasi'
#
# PT Vertika Technologies Nusantara
# UPDATE jobstreet_raws SET company_id = '8458'     where company LIKE 'PT Vertika Technologies Nusantara'  and city LIKE 'Jakarta Raya'
#
# PT Victoria Care Indonesia
# UPDATE jobstreet_raws SET company_id = '8459'     where company LIKE 'PT Victoria Care Indonesia'  and city LIKE 'Jakarta Barat'
#
# PT Victoria Care Indonesia
# UPDATE jobstreet_raws SET company_id = '8460'     where company LIKE 'PT Victoria Care Indonesia'  and city LIKE 'Semarang'
#
# PT Victory Chingluh Indonesia
# UPDATE jobstreet_raws SET company_id = '8461'     where company LIKE 'PT Victory Chingluh Indonesia'  and city LIKE 'Tangerang'
#
# PT Victory Pan Multitex
# UPDATE jobstreet_raws SET company_id = '8462'     where company LIKE 'PT Victory Pan Multitex'  and city LIKE 'Bandung'
#
# PT Vim Emineo Indonesia
# UPDATE jobstreet_raws SET company_id = '8463'     where company LIKE 'PT Vim Emineo Indonesia'  and city LIKE 'Jakarta Selatan'
#
# PT Virby Virbiza Ubo
# UPDATE jobstreet_raws SET company_id = '8464'     where company LIKE 'PT Virby Virbiza Ubo'  and city LIKE 'Jakarta Pusat'
#
# PT Virby Virbiza Ubo
# UPDATE jobstreet_raws SET company_id = '8465'     where company LIKE 'PT Virby Virbiza Ubo'  and city LIKE 'Jakarta Raya'
#
# PT Virgo Ramayana Music & Entertainment
# UPDATE jobstreet_raws SET company_id = '8466'     where company LIKE 'PT Virgo Ramayana Music & Entertainment'  and city LIKE 'Jakarta Raya'
#
# PT Virtue Power Technica
# UPDATE jobstreet_raws SET company_id = '8467'     where company LIKE 'PT Virtue Power Technica'  and city LIKE 'Jakarta Raya'
#
# PT Virtus Venturama
# UPDATE jobstreet_raws SET company_id = '8468'     where company LIKE 'PT Virtus Venturama'  and city LIKE 'Tangerang'
#
# PT Visa Enam Dua Prima
# UPDATE jobstreet_raws SET company_id = '8469'     where company LIKE 'PT Visa Enam Dua Prima'  and city LIKE 'Jakarta Utara'
#
# PT Visi Care Indonesia
# UPDATE jobstreet_raws SET company_id = '8470'     where company LIKE 'PT Visi Care Indonesia'  and city LIKE 'Jakarta Raya'
#
# PT Visi Fokus Sindotama Perkasa
# UPDATE jobstreet_raws SET company_id = '8471'     where company LIKE 'PT Visi Fokus Sindotama Perkasa'  and city LIKE 'Jawa Timur'
#
# PT Visi Multimedia Aditama
# UPDATE jobstreet_raws SET company_id = '8472'     where company LIKE 'PT Visi Multimedia Aditama'  and city LIKE 'Jawa Tengah'
#
# PT Visi Multimedia Aditama
# UPDATE jobstreet_raws SET company_id = '8473'     where company LIKE 'PT Visi Multimedia Aditama'  and city LIKE 'Malang'
#
# PT Visi Teliti Saksama (Jakarta)
# UPDATE jobstreet_raws SET company_id = '8474'     where company LIKE 'PT Visi Teliti Saksama (Jakarta)'  and city LIKE 'Jakarta Raya'
#
# PT Vision Teknik
# UPDATE jobstreet_raws SET company_id = '8475'     where company LIKE 'PT Vision Teknik'  and city LIKE 'Jakarta Barat'
#
# PT Visionet Data Internasional
# UPDATE jobstreet_raws SET company_id = '8476'     where company LIKE 'PT Visionet Data Internasional'  and city LIKE 'Banten'
#
# PT Visionet Data Internasional
# UPDATE jobstreet_raws SET company_id = '8477'     where company LIKE 'PT Visionet Data Internasional'  and city LIKE 'Jakarta Pusat'
#
# PT Visionet Data Internasional
# UPDATE jobstreet_raws SET company_id = '8478'     where company LIKE 'PT Visionet Data Internasional'  and city LIKE 'Jakarta Selatan'
#
# PT Visionet Data Internasional
# UPDATE jobstreet_raws SET company_id = '8479'     where company LIKE 'PT Visionet Data Internasional'  and city LIKE 'Tangerang'
#
# PT Vista Indonesia
# UPDATE jobstreet_raws SET company_id = '8480'     where company LIKE 'PT Vista Indonesia'  and city LIKE 'Jakarta Raya'
#
# PT Vista Mandiri Gemilang
# UPDATE jobstreet_raws SET company_id = '8481'     where company LIKE 'PT Vista Mandiri Gemilang'  and city LIKE 'Jakarta Raya'
#
# PT Vistra International Expansion Indonesia
# UPDATE jobstreet_raws SET company_id = '8482'     where company LIKE 'PT Vistra International Expansion Indonesia'  and city LIKE 'Jakarta Selatan'
#
# PT Vita Shopindo
# UPDATE jobstreet_raws SET company_id = '8483'     where company LIKE 'PT Vita Shopindo'  and city LIKE 'Jakarta Barat'
#
# PT Vita Shopindo
# UPDATE jobstreet_raws SET company_id = '8484'     where company LIKE 'PT Vita Shopindo'  and city LIKE 'Jakarta Raya'
#
# PT Viva Tehnik Mandiri
# UPDATE jobstreet_raws SET company_id = '8485'     where company LIKE 'PT Viva Tehnik Mandiri'  and city LIKE 'Jakarta Raya'
#
# PT Vivamas Adipratama
# UPDATE jobstreet_raws SET company_id = '8486'     where company LIKE 'PT Vivamas Adipratama'  and city LIKE 'Jakarta Pusat'
#
# PT Vivo Mobile Indonesia
# UPDATE jobstreet_raws SET company_id = '8487'     where company LIKE 'PT Vivo Mobile Indonesia'  and city LIKE 'Cikupa'
#
# PT Vivo Mobile Indonesia
# UPDATE jobstreet_raws SET company_id = '8488'     where company LIKE 'PT Vivo Mobile Indonesia'  and city LIKE 'Jakarta Utara'
#
# PT Viwi Surya Agung (Bali)
# UPDATE jobstreet_raws SET company_id = '8489'     where company LIKE 'PT Viwi Surya Agung (Bali)'  and city LIKE 'Gianyar'
#
# PT Vkool Indo Lestari
# UPDATE jobstreet_raws SET company_id = '8490'     where company LIKE 'PT Vkool Indo Lestari'  and city LIKE 'Jakarta Raya'
#
# PT Voksel Electric, Tbk.
# UPDATE jobstreet_raws SET company_id = '8491'     where company LIKE 'PT Voksel Electric, Tbk.'  and city LIKE 'Bogor'
#
# PT Voksel Electric, Tbk.
# UPDATE jobstreet_raws SET company_id = '8492'     where company LIKE 'PT Voksel Electric, Tbk.'  and city LIKE 'Cileungsi'
#
# PT Voksel Electric, Tbk.
# UPDATE jobstreet_raws SET company_id = '8493'     where company LIKE 'PT Voksel Electric, Tbk.'  and city LIKE 'Jawa Barat'
#
# PT Volcom Indonesia
# UPDATE jobstreet_raws SET company_id = '8494'     where company LIKE 'PT Volcom Indonesia'  and city LIKE 'Kuta'
#
# PT Waagner Biro Indonesia
# UPDATE jobstreet_raws SET company_id = '8495'     where company LIKE 'PT Waagner Biro Indonesia'  and city LIKE 'Serang'
#
# PT WADAH MAKMUR KENCANA
# UPDATE jobstreet_raws SET company_id = '8496'     where company LIKE 'PT WADAH MAKMUR KENCANA'  and city LIKE 'Bekasi'
#
# PT Wagginton Arthatech Global
# UPDATE jobstreet_raws SET company_id = '8497'     where company LIKE 'PT Wagginton Arthatech Global'  and city LIKE 'Jakarta Pusat'
#
# PT Wagginton Arthatech Global
# UPDATE jobstreet_raws SET company_id = '8498'     where company LIKE 'PT Wagginton Arthatech Global'  and city LIKE 'Jakarta Selatan'
#
# PT Wahana Cipta Sinatria
# UPDATE jobstreet_raws SET company_id = '8499'     where company LIKE 'PT Wahana Cipta Sinatria'  and city LIKE 'Jakarta Pusat'
#
# PT Wahana Citra Nabati
# UPDATE jobstreet_raws SET company_id = '8500'     where company LIKE 'PT Wahana Citra Nabati'  and city LIKE 'Jakarta Timur'
#
# PT Wahana Duta Jaya Rucika
# UPDATE jobstreet_raws SET company_id = '8501'     where company LIKE 'PT Wahana Duta Jaya Rucika'  and city LIKE 'Bekasi'
#
# PT Wahana Duta Jaya Rucika
# UPDATE jobstreet_raws SET company_id = '8502'     where company LIKE 'PT Wahana Duta Jaya Rucika'  and city LIKE 'Jakarta Pusat'
#
# PT Wahana Duta Jaya Rucika
# UPDATE jobstreet_raws SET company_id = '8503'     where company LIKE 'PT Wahana Duta Jaya Rucika'  and city LIKE 'Jakarta Raya'
#
# PT Wahana Internet Nusantara
# UPDATE jobstreet_raws SET company_id = '8504'     where company LIKE 'PT Wahana Internet Nusantara'  and city LIKE 'Karawang'
#
# PT Wahana Inti Makmur Tbk
# UPDATE jobstreet_raws SET company_id = '8505'     where company LIKE 'PT Wahana Inti Makmur Tbk'  and city LIKE 'Jakarta Raya'
#
# PT Wahana Inti Makmur Tbk
# UPDATE jobstreet_raws SET company_id = '8506'     where company LIKE 'PT Wahana Inti Makmur Tbk'  and city LIKE 'Jakarta Utara'
#
# PT Wahana Makmur Sejati (Wahanaartha Group)
# UPDATE jobstreet_raws SET company_id = '8507'     where company LIKE 'PT Wahana Makmur Sejati (Wahanaartha Group)'  and city LIKE 'Jakarta Raya'
#
# PT Wahana Makmur Sejati (Wahanaartha Group)
# UPDATE jobstreet_raws SET company_id = '8508'     where company LIKE 'PT Wahana Makmur Sejati (Wahanaartha Group)'  and city LIKE 'Tangerang'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8509'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Bali'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8510'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Dumai'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8511'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Jakarta Raya'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8512'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Jakarta Utara'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8513'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Jawa Barat'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8514'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Jawa Tengah'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8515'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Jawa Timur'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8516'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Kalimantan Barat'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8517'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Medan'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8518'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Pekanbaru'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8519'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Riau'
#
# PT Wahana Ottomitra Multiartha (WOM Finance), Tbk
# UPDATE jobstreet_raws SET company_id = '8520'     where company LIKE 'PT Wahana Ottomitra Multiartha (WOM Finance), Tbk'  and city LIKE 'Tanjung Pinang'
#
# PT Wahana Satria Abadi
# UPDATE jobstreet_raws SET company_id = '8521'     where company LIKE 'PT Wahana Satria Abadi'  and city LIKE 'Tangerang'
#
# PT Wahana Sentra Niaga
# UPDATE jobstreet_raws SET company_id = '8522'     where company LIKE 'PT Wahana Sentra Niaga'  and city LIKE 'Jawa Timur'
#
# PT Wahana Sentra Niaga
# UPDATE jobstreet_raws SET company_id = '8523'     where company LIKE 'PT Wahana Sentra Niaga'  and city LIKE 'Surabaya'
#
# PT Wahana Supra Sinergi
# UPDATE jobstreet_raws SET company_id = '8524'     where company LIKE 'PT Wahana Supra Sinergi'  and city LIKE 'Surabaya'
#
# PT Wahana Tata Mandiri
# UPDATE jobstreet_raws SET company_id = '8525'     where company LIKE 'PT Wahana Tata Mandiri'  and city LIKE 'Jakarta Raya'
#
# PT Wahana Tirta Milenia
# UPDATE jobstreet_raws SET company_id = '8526'     where company LIKE 'PT Wahana Tirta Milenia'  and city LIKE 'Batam'
#
# PT Wahyu Abadi
# UPDATE jobstreet_raws SET company_id = '8527'     where company LIKE 'PT Wahyu Abadi'  and city LIKE 'Cikarang'
#
# PT Wajah Rejuvenasi Perempuan Indonesia
# UPDATE jobstreet_raws SET company_id = '8528'     where company LIKE 'PT Wajah Rejuvenasi Perempuan Indonesia'  and city LIKE 'Bogor'
#
# PT Wajah Rejuvenasi Perempuan Indonesia
# UPDATE jobstreet_raws SET company_id = '8529'     where company LIKE 'PT Wajah Rejuvenasi Perempuan Indonesia'  and city LIKE 'Jakarta Selatan'
#
# PT Walden Global Services
# UPDATE jobstreet_raws SET company_id = '8530'     where company LIKE 'PT Walden Global Services'  and city LIKE 'Jawa Barat'
#
# PT Walk Brains Indonesia
# UPDATE jobstreet_raws SET company_id = '8531'     where company LIKE 'PT Walk Brains Indonesia'  and city LIKE 'Jakarta Pusat'
#
# PT Wanapotensi Guna (Palembang)
# UPDATE jobstreet_raws SET company_id = '8532'     where company LIKE 'PT Wanapotensi Guna (Palembang)'  and city LIKE 'Sumatera Selatan'
#
# PT Wanata Jaya Cipta (Nanny's Pavillon)
# UPDATE jobstreet_raws SET company_id = '8533'     where company LIKE 'PT Wanata Jaya Cipta (Nanny\'s Pavillon)'  and city LIKE 'Bogor'
#
# PT Wanatiara Persada
# UPDATE jobstreet_raws SET company_id = '8534'     where company LIKE 'PT Wanatiara Persada'  and city LIKE 'Jakarta Utara'
#
# PT Wangta Agung (Ardiles)
# UPDATE jobstreet_raws SET company_id = '8535'     where company LIKE 'PT Wangta Agung (Ardiles)'  and city LIKE 'Surabaya'
#
# PT Wanindo Prima (INDOPRIMA DESIGN)
# UPDATE jobstreet_raws SET company_id = '8536'     where company LIKE 'PT Wanindo Prima (INDOPRIMA DESIGN)'  and city LIKE 'Jakarta Barat'
#
# PT Wanindo Prima (INDOPRIMA DESIGN)
# UPDATE jobstreet_raws SET company_id = '8537'     where company LIKE 'PT Wanindo Prima (INDOPRIMA DESIGN)'  and city LIKE 'Jakarta Raya'
#
# PT Want Want Indonesia
# UPDATE jobstreet_raws SET company_id = '8538'     where company LIKE 'PT Want Want Indonesia'  and city LIKE 'Jakarta Raya'
#
# PT Wanxiang Nickel Indonesia
# UPDATE jobstreet_raws SET company_id = '8539'     where company LIKE 'PT Wanxiang Nickel Indonesia'  and city LIKE 'Jakarta Selatan'
