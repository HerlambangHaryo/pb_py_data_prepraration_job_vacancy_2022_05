# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')

entity = 'domain'

# set query 1
select = ' id, created_at, ' + entity
fromdb = 'jobstreet_raws_v2'
where = ' '
group = ' '
# Out:
# connect

# %%
# check distinct 
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where  )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0])
    created_at = x[1]  
    word_1 = x[2].replace("1", "")
    word_2 = word_1.replace("2", "")
    word_3 = word_2.replace("3", "")
    word_4 = word_3.replace("4", "")
    word_5 = word_4.replace("5", "")
    word_6 = word_5.replace("6", "")
    word_7 = word_6.replace("7", "")
    word_8 = word_7.replace("8", "")
    word_9 = word_8.replace("9", "")
    word_10 = word_9.replace("0", "")
    
    word = word_10
#     print(word) 
    
    queryx = "UPDATE jobstreet_raws_v2 SET "+entity+" = '" + word + "'   " 
    wherex = "  where id = '" + idx + "'"  
#     print(queryx + wherex)
    mycursor.execute(queryx + wherex)
    mydb.commit()   

    
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + entity + " FROM `" + fromdb + "` " + where + ' group by ' + entity )
myresult = mycursor.fetchall()

# loop query 1
for x in myresult:  
    word = x[0]  
    print(word) 


print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# Akuntansi / Keuangan, Akuntansi Umum / Pembiayaan
# Akuntansi / Keuangan, Audit & Pajak
# Akuntansi / Keuangan, Keuangan / Investasi Perusahaan
# Akuntansi / Keuangan, Perbankan / Jasa Finansial
# Bangunan / Konstruksi, Arsitek / Desain Interior
# Bangunan / Konstruksi, Properti / Real Estate
# Bangunan / Konstruksi, Survei Kuantitas
# Bangunan / Konstruksi, Teknik Sipil / Konstruksi Bangunan
# Hotel / Restoran,  Hotel / Pariwisata
# Hotel / Restoran, Makanan / Minuman / Pelayanan Restoran
# Komputer / Teknologi Informasi, IT-Admin Jaringan / Sistem / Database
# Komputer / Teknologi Informasi, IT-Perangkat Keras
# Komputer / Teknologi Informasi, IT-Perangkat Lunak
# Komputer / Teknologi Informasi, IT-Perangkat Lunak, IT-Admin Jaringan / Sistem / Database
# Lainnya,  Jurnalis / Editor
# Lainnya,  Penerbitan
# Lainnya, Lainnya / Kategori tidak tersedia
# Lainnya, Pekerjaan Umum
# Layanan Kesehatan,  Diagnosa / Lainnya
# ...
