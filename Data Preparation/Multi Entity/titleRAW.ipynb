# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')


# set query 1
select = ' * '
fromdb = 'titles_raws'
where = ' '
group = ' '
# Out:
# connect

# %%
# repairing tittle

where = '  '
orderby = ' order by nama ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    word = x[1] 
    
    word = word.replace("abaper", "ABAPER")
    word = word.replace("Spv", "Supervisor")
    word = word.replace("Acc ", "Accounting ")
    word = word.replace("Payble", "Payable")
    word = word.replace("  /  ", " / ")
    word = word.replace(" /  ", " / ")
    word = word.replace("Pajak", "Tax")
    word = word.replace("Dan", "&")
    word = word.replace("Dept", "Departement")
    word = word.replace("Dept.", "Departement")
    word = word.replace("Sr.", "Senior")
    word = word.replace(" – ", " ")
    word = word.replace("Adm ", "Admin ")
    word = word.replace("Adm.", "Admin")
    word = word.replace("  ", " ")
    word = word.replace("Hr", "HR")
    word = word.replace("Hrd", "HRD")
    word = word.replace("Ga", "GA")
    word = word.replace("Admin. ", "Admin ")
    word = word.replace("Ads.", "Advertisement")
    word = word.replace("Jr", "Junior")
    word = word.replace("Assist. ", "Assisstant ")
    word = word.replace("E Commerce", "Ecommerce")
    word = word.replace("Asst.", "Assisstant")
    word = word.replace("Backend", "Back End")
    word = word.replace("Frontend", "Front End")
    word = word.replace("Business Analys", "Business Analyst")
    word = word.replace("Asst.Manager", "Assistant Manager")
    word = word.replace("Catholicc", "Catholic")
    word = word.replace("Copy Writer", "Copywriter")
    word = word.replace("Data Analis", "Data Analyst")
    word = word.replace("Doctor", "Dokter")
    word = word.replace("Doc.", "Document")
    word = word.replace("Dpa", "Dokumen Pelaksanaan Anggaran")
    word = word.replace("Dsigner", "Designer")
    word = word.replace("Eng&Maintenance", "Engineer & Maintenance")
    word = word.replace("Manager.", "Manager")
    word = word.replace("Exim", "Export Import")
    word = word.replace(", &", "&")
    word = word.replace("Snr.", "Senior")
    word = word.replace(" , ", ", ")
    word = word.replace("Hr&Ga", "Hr & Ga")
    word = word.replace("Kabag", "Kepala Bagian")
    word = word.replace("Lead,", "Lead")
    word = word.replace("Engineer:", "Engineer")
    word = word.replace("Akunting", "Accounting")
    word = word.replace("Manajer,", "Manager")
    word = word.replace("Managing", "Manager")
    word = word.replace("Marcomm", "Marketing Communication")
    word = word.replace("In House", "")
    word = word.replace("Inhouse", "")
    word = word.replace("Marketing Properti", "Marketing Property")
    word = word.replace("Marketing,", "Marketing")
    word = word.replace("Math", "Mathematic")
    word = word.replace("Mekanik", "Mechanic")
    word = word.replace("Net", ".Net")
    word = word.replace("Nodejs", "Node Js")
    word = word.replace("Officegirl", "Office Girl")
    word = word.replace("Pharma", "Pharmacy")
    word = word.replace("Programmer.", "Programmer")
    word = word.replace("Proyek Manager", "Project Manager")
    word = word.replace(" _ ", " ")
    word = word.replace("R & D", "R&D")
    word = word.replace("Reactjs", "React js")
    word = word.replace("Jakarta", "")
    word = word.replace("Excutive", "Executive")
    word = word.replace("Remote", "")
    word = word.replace("Jabodetabek", "")
    word = word.replace("Bandung", "")
    word = word.replace("Rnd", "R&D")
    word = word.replace("Developers", "Developer")
    word = word.replace("Sales,", "Sales")
    word = word.replace("Cirebon", "")
    word = word.replace("QC", "Quality Control")
    word = word.replace("qc", "Quality Control") 
    word = word.replace("QA", "Quality Control")
    word = word.replace("qa", "Quality Assurance") 
    word = word.replace("Bogor", "") 
    word = word.replace("Surabaya", "") 
    word = word.replace("Qa&Qc", "Qa & Qc") 
    word = word.replace("R N D", "R&D") 
    word = word.replace("Banjarmasin", "Banjarmasin") 
    word = word.replace(" + ", " ") 
    word = word.replace("F & B", "F&B") 
    word = word.replace("Semarang", "") 
    word = word.replace("Karawang", "") 
    word = word.replace("Supervisor Logistik", "Supervisor Logistic")
    word = word.replace("Tech.", "") 
    word = word.replace("Tik Tok", "Tiktok") 
    word = word.replace("Waitres", "Waitress") 
    word = word.replace("Waiter", "Waitress") 
    word = word.replace("Waitress,", "Waitress") 
    word = word.replace("Waitress & Kasir,", "Waitress & Kasir") 
    word = word.replace("Supervisor&Logistics", "Supervisor & Logistics")  
    
    print(word)   
    
    
#     queryx = "UPDATE titles_raws SET nama = '" + word + "'   " 
#     wherex = "  where id = '" + idx + "'"  
# #     print(queryx + wherex)
#     mycursor.execute(queryx + wherex)
#     mydb.commit()   
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# ..Net Core Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Developer
# ..Net Programmer
# 10.	Photographer / Videographer & Design Grafis
# 2D / 3D Designer
# 3D Artist
# 3D Artist
# 3D Artist / Modeling For GAme
# 3D Artist Staff
# 3D Designer
# 3D Designer Interior
# 3D Designer Interior
# 3D Modeller Arsitektur
# 3D Visualizer
# 3D Visualizer
# A Level / Igcse Chemistry Teacher / Tutor
# Abaper
# Academic Specialist Matematika & Fisika
# Academics Coordinator
# Accounting & Finance Supervisor
# Access Point Engineering & Development
# Accident & Health Flow Underwriter
# Account / Sales Leader
# Account Assistant
# Account Director
# ...

# %%
# repairing tittle

where = '  '
orderby = ' order by nama ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    word = x[1] 
     
    
    print(word)   
    
    
#     queryx = "UPDATE titles_raws SET nama = '" + word + "'   " 
#     wherex = "  where id = '" + idx + "'"  
# #     print(queryx + wherex)
#     mycursor.execute(queryx + wherex)
#     mydb.commit()   
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
#  Python Programmer Mentor
#  Service Engineer Medical Device
# ..Net Core Developer
# ..Net Developer
# ..Net Programmer
# .Net Developer
# .Net Engineer
# .Net Revenue Management Analyst
# 2D / 3D Designer
# 3D Artist
# 3D Artist / Modeling For GAme
# 3D Artist Staff
# 3D Designer
# 3D Designer Interior
# 3D Modeller Arsitektur
# 3D Visualizer
# A Level / Igcse Chemistry Teacher / Tutor
# Abaper
# Academic Specialist Matematika & Fisika
# Academics Coordinator
# Access Point Engineering & Development
# Accident & Health Flow Underwriter
# Account / Sales Leader
# Account Assistant
# Account Director
# Account Executive
# Account Executive Associate
# Account Executive Audio Visual
# Account Executive Corporate Banking
# Account Executive Creative Agency GAram
# Account Executive Enterprise
# Account Executive Erp
# Account Executive For Interior Design
# Account Executive For Pharmacy Ingredients Business
# Account Executive Marketing
# ...
