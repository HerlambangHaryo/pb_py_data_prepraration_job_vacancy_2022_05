# %%
# Connect to DB
import datetime
datenow = datetime.datetime.now()

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
print(datenow)
# Out:
# connect
# 2022-06-11 19:35:42.426144

# %%
# set query 1
select = ' id, nama '
fromdb = 'working_hours' 
where = '  '
orderby = '  order by nama ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_working_hours  = str(x[0]) 
    nama = x[1]   
    
    print(nama)    
    
    queryy = "Select id, benefit From jobstreet_raws_v2 Where benefit like '%"+nama+"%'  "
    print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()

    for y in myresultc:   
        job_vacancy_id = str(y[0]) 
        word = y[1]   

        queryy = "UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'"+nama+"', '-idwh-' ),  	working_hours  = '"+id_working_hours+"'  where id = '"+job_vacancy_id+"' "
        print(queryy)
        mycursor.execute(queryy)
        mydb.commit()   
        
         
    
print('done : ' + str(len(myresult)) + ' row(s)')
print('done : ' + str(len(myresultc)) + ' row(s)')
# Out:
# SELECT  id, nama  FROM `working_hours`     order by nama ASC
# We start and please wait ...
# Monday - Friday : 08.00 - 16.00 ; Saturday : 08.00 - 13.00
# Select id, benefit From jobstreet_raws_v2 Where benefit like '%Monday - Friday : 08.00 - 16.00 ; Saturday : 08.00 - 13.00%'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Monday - Friday : 08.00 - 16.00 ; Saturday : 08.00 - 13.00', '-idwh-' ),  	working_hours  = '1'  where id = '13495'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Monday - Friday : 08.00 - 16.00 ; Saturday : 08.00 - 13.00', '-idwh-' ),  	working_hours  = '1'  where id = '14044'
# Waktu regular, Senin - Jumat
# Select id, benefit From jobstreet_raws_v2 Where benefit like '%Waktu regular, Senin - Jumat%'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '2'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '3'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '5'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '6'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '7'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '9'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '10'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '11'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '12'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '13'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '15'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '16'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '18'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '19'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '20'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '22'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '23'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '24'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '27'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '28'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '30'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '31'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '34'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '35'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '36'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '37'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '40'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '43'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '44'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '45'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '47'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '48'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '49'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '50'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '51'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '54'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '55'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '56'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '58'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '59'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '61'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '62'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '64'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '66'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '68'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '70'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '71'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '72'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '74'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '77'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '78'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '80'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '81'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '83'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '84'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '85'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '86'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '87'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '89'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '90'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '91'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '92'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '93'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '94'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '97'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '98'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '100'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '101'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '102'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '103'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '105'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '106'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '108'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '109'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '110'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '113'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '114'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '115'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '117'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '119'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '120'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '121'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '122'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '123'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '124'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '126'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '127'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '128'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '129'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '131'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '133'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '134'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '135'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '136'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '137'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '138'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '139'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '140'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '142'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '144'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '145'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '148'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '149'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '150'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '151'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '152'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '153'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '155'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '156'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '158'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '159'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '160'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '161'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '162'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '163'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '165'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '166'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '167'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '168'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '170'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '171'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '173'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id = '174'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Waktu regular, Senin - Jumat', '-idwh-' ),  	working_hours  = '4'  where id =