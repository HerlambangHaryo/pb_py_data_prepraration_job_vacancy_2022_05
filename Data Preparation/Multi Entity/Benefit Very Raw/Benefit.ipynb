# %%
# Connect to DB
import datetime
datenow = datetime.datetime.now()

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
print(datenow)
# Out:
# connect
# 2022-06-11 20:47:24.040843

# %%
# set query 1
select = ' id, benefit '
fromdb = 'jobstreet_raws_v2' 
where = ' where benefit is not null '
orderby = '  '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    nama = x[1]   
    
    print(nama)    
     
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# Monday-Friday
# Sesuai PKB
# BPJS Kesehatan,
# Uniform
# outside normal business hours
# BPJS
# ,, ,  Uniform
# Monday-Friday
# Sesuai PKB
# BPJS Kesehatan,
# Uniform
# outside normal business hours
# BPJS
# Mondays - Saturdays 07.00 - 16.15
# Mondays - Saturdays
# Senin-Sabtu
# Monday - Saturday
# Monday - Saturday
# Uniform Mondays-Saturday
# Jamsostek 08.00 – 17.00
# Mondays - Friday 0800 -1730 Saturdays 0800-1400
# BPJS
# Senin - Sabtu (bisa Lembur setiap saat diperlukan dan tidak sedang Kuliah)
# Senin - Jumat jam 08:00-16:30 , Sabtu Jam 08:15 - 15:00
# Formal (Mon-Thu), Casual (Everyday for IT Division and Friday only for others ) Monday-Friday (Head Office), Monday-Saturday (Branch)
# Tunjangan kehadiran, Tunjangan Transportasi dan lain-lain Monday - Saturday
# Uniform
# senin - selasa (Formil) Rabu-kamis (Kaos Berkerah) Jumat (Batik)
# Monday-Saturday
# Senin-Jumat, Sabtu (Setengah hari)
# , BPJS Kesehatan Mondays - Saturday
# ...

# %%
# set query 1
select = ' id, nama '
fromdb = 'benefits' 
where = '  '
orderby = '  order by nama ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)    
    
    queryy = "Select id, benefit From jobstreet_raws_v2 Where benefit like '%"+nama+"%'  "
    print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()

    for y in myresultc:   
        job_vacancy_id = str(y[0]) 
        word = y[1]   

        queryy = "UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'"+nama+"', '-idben-' )  where id = '"+job_vacancy_id+"' "
        print(queryy)
        mycursor.execute(queryy)
        mydb.commit()   
        
        
        queryz = "INSERT INTO job_vacancy_benefits (job_vacancy_id, benefit_id) VALUES ('"+job_vacancy_id+"', '"+id_benefit+"' )"
        print(queryz)
        mycursor.execute(queryz)
        mydb.commit()   
    
print('done : ' + str(len(myresult)) + ' row(s)')
print('done : ' + str(len(myresultc)) + ' row(s)')
# Out:
# SELECT  id, nama  FROM `benefits`     order by nama ASC
# We start and please wait ...
# Annual leave
# Select id, benefit From jobstreet_raws_v2 Where benefit like '%Annual leave%'
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Annual leave', '-idben-' )  where id = '409'
# INSERT INTO job_vacancy_benefits (job_vacancy_id, benefit_id) VALUES ('409', '32' )
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Annual leave', '-idben-' )  where id = '1103'
# INSERT INTO job_vacancy_benefits (job_vacancy_id, benefit_id) VALUES ('1103', '32' )
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Annual leave', '-idben-' )  where id = '2191'
# INSERT INTO job_vacancy_benefits (job_vacancy_id, benefit_id) VALUES ('2191', '32' )
# UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'Annual leave', '-idben-' )  where id = '2363'
# INSERT INTO job_vacancy_benefits (job_vacancy_id, benefit_id) VALUES ('2363', '32' )
# ...

# %%
# set query 1
select = ' id, benefit '
fromdb = 'jobstreet_raws_v2' 
where = '  '
orderby = '  order by benefit ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    nama = x[1]   
    
    print(nama)    
     
    queryy = "UPDATE jobstreet_raws_v2 SET benefit = REPLACE(benefit,'-idben-', '' )  where id = '"+idx+"' "

    mycursor.execute(queryy)
    mydb.commit()   
        
         
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# SELECT  id, benefit  FROM `jobstreet_raws_v2`     order by benefit ASC
# We start and please wait ...
# -","-","-
# -","-","-
# -","-","-
# -","-","Monday - Friday : 08.00 - 16.00 ; Saturday : 08.00 - 13.00
# -","-","Monday - Friday : 08.00 - 16.00 ; Saturday : 08.00 - 13.00
# -","-","Senin - Sabtu
# -","casual and formal","regular hours, mondays-saturdays
# -","Plant Uniform","5 days work
# -","Plant Uniform","5 days work
# -","Plant Uniform","5 days work
# -","Seragam sesuai Standart RS","3 Shift
# -","Seragam sesuai Standart RS","3 Shift
# -","Seragam sesuai Standart RS","3 Shift
# -","Seragam sesuai Standart RS","3 Shift
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben-
# -idben- & BPJS Kesehatan","Formal","8.00 – 17.00 (Senin – Jumat)
# -idben- & Kesehatan","Formal (Kemeja)","Senin - Sabtu
# -idben- & Kesehatan","Formal (Kemeja)","Senin - Sabtu
# ...
