# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')

entity = 'domain'

# set query 1
select = ' id, created_at, ' + entity
fromdb = 'jobstreet_raws_v2'
where = ' '
group = ' '
# Out:
# connect

# %%
# check distinct 
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where  )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0])
    created_at = x[1]  
    word_1 = x[2].replace(" ,", ",")
    word_2 = word_1.replace("130 ", "")
    word_3 = word_2.replace("146 ", "")
    word_4 = word_3.replace("509 ", "")
    word_5 = word_4.replace("185 ", "")
    word_6 = word_5.replace("138 ", "")
    word_7 = word_6.replace("132 ", "")
    word_8 = word_7.replace("112 ", "")
    word_9 = word_8.replace("202 ", "")
    word_10 = word_9.replace("506 ", "")
    
    word = word_10
#     print(word) 
    
    queryx = "UPDATE jobstreet_raws_v2 SET "+entity+" = '" + word + "'   " 
    wherex = "  where id = '" + idx + "'"  
#     print(queryx + wherex)
    mycursor.execute(queryx + wherex)
    mydb.commit()   
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# Akuntansi / Keuangan, Akuntansi Umum / Pembiayaan
# Penjualan / Pemasaran, Digital Marketing
# Sumber Daya Manusia / Personalia, Sumber Daya Manusia / HR
# Komputer / Teknologi Informasi, IT-Admin Jaringan / Sistem / Database
# Lainnya, Pekerjaan Umum
# Manufaktur, Pembelian / Manajemen Material
# Pelayanan, Layanan Pelanggan
# Akuntansi / Keuangan, Akuntansi Umum / Pembiayaan
# Seni / Media / Komunikasi, Seni / Desain Kreatif
# Sumber Daya Manusia / Personalia, Sumber Daya Manusia / HR
# Sains, Pertanian
# Akuntansi / Keuangan, Akuntansi Umum / Pembiayaan
# Manufaktur, 194 Manufaktur
# Akuntansi / Keuangan, Akuntansi Umum / Pembiayaan
# Penjualan / Pemasaran, Digital Marketing
# Sumber Daya Manusia / Personalia, Sumber Daya Manusia / HR
# Komputer / Teknologi Informasi, IT-Admin Jaringan / Sistem / Database
# Lainnya, Pekerjaan Umum
# Manufaktur, Pembelian / Manajemen Material
# Pelayanan, Layanan Pelanggan
# ...
