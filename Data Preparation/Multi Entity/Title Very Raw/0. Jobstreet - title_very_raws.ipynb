# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
# Out:
# connect

# %%
# set query 1
select = ' id, title, domain_id '
fromdb = 'jobstreet_raws_v2' 
where = '  '
orderby = '  order by title ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    word = x[1]  
    word = word.replace("'", "\'") 
    word = word.replace("'", "") 
    domain_id = str(x[2])
    
#     print(word)   
    
    queryx = "INSERT INTO title_very_raws (nama, domain_id) VALUES ('"+word+"', '"+domain_id+"' )"
    print(queryx)
    mycursor.execute(queryx)
    mydb.commit()   
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET - Angular Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET CORE Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Developer C# (Karawaci)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.NET Developers', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('.Net Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(Doctor) Medical Advisor', '19' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2107008) Account Officer - Sales - Makassar', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2108004) Account Officer - Sales - Direct & Leasing', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2108004) Account Officer - Sales - Direct & Leasing', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2108005) Account Officer - Sales - Manado', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2110009) Account Officer - Sales - Medan', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2112007) Account Officer  Sales - Lampung', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2203001) Account Officer - Direct Sales jakarta', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2203003) Account Officer - Sales - Jember', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2204003) Account Officer - Sales - Malang', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2204003) Account Officer - Sales - Malang', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2204004) MV Claim Controller', '63' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2205001) Account Officer - Sales - Surabaya', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2205002) Account Officer - Sales - Denpasar', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2205005) Account Officer - Sales - Pontianak', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2205008) Underwriter Marine Hull', '4' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2205009) Surveyor - Semarang', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2205010) Treasury Staff- Jakarta (Temporary)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(JV2205012) Account Officer - Sales - Bandung', '38' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('(Programmable Logic Controller) PLC Engineer \u002F Specialist', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('[ Project-Based ] Senior Recruiter', '64' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('[BMW ASTRA Used Car] Sales Consultant Used Car - Malang', '46' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('[FREELANCE] Talent Acquisition Specialist', '64' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('[MOOIMOM] SPG', '46' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('[MOOIMOM] SPG', '46' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('[SALES] DAIHATSU', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('[Ubud] Resident Medical Officer (RMO) - Dokter Jaga', '19' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('10.	Photographer /  Videographer & Design Grafis', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('2D / 3D Designer', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('2nd Level Engineer (Data Center)', '31' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Artist', '5' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Artist', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D artist  /  modeling for game', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Artist Staff', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Designer', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Designer (Architect \u002F Interior Background)', '5' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Designer Interior', '5' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Designer Interior', '5' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Modeling Animation Designer- Yogyakarta,Malang & Bandung', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D Modeller Architecture', '5' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D VISUALIZER', '5' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3D VISUALIZER', '5' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('3PL Management Head - Shopee Express', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('6-Month Intern', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('A Level  /  IGCSE Chemistry Teacher  /  Tutor', '36' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ABAPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Academic Specialist Matematika & Fisika', '36' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Academics Coordinator', '36' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACC & Finance SPV', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Acc Tax Stafff (Manufaktur Tas di Jombang Jawa Timur)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Acccounting Staff (AR)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Access & Community Relation (Site Acquisition\u002FSitac) - JABODETABEK', '6' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Access Point Engineering & Development', '67' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accident & Health Flow Underwriter', '17' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accont Manager (Batam Based)', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accont Manager (Batam Based)', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account / Sales Leader', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Assistant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Director', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Director', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '45' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '43' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNT EXECUTIVE', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '46' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '41' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '41' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '45' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNT EXECUTIVE', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNT EXECUTIVE', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '41' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '4' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNT EXECUTIVE', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '46' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '45' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '41' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive', '45' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive  Aceh, Pekanbaru, Padang, Lampung', '20' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive - BSA', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive - Marketspace Kompas Digital Media', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Executive -
'1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNT RECEIVABLE ADMIN', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Admin (Outsourced Contract)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNT RECEIVABLE CONTROL', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Head (Purwokerto,Cilacap,Banyumas)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Officer (Sulawesi, Papua, Maluku)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Section Head', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Specialist - Indonesia', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Specialist - PT Lippo Malls Indonesia', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Staff (Bandung)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Receivable Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Representative (Area Jakarta)', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Representative (Area Jakarta)', '39' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Support (ID: 549621)', '32' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account Verificator - Branch Balikpapan', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Account(Sales) Manager', '41' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTANT', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTANT', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant  /  Human Resources Development', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant - Sports Retailer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant \u002F Account Executive (Client Facing Outsourcing) - Work in Jakarta', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant \u002F Account Executive (Client Facing Outsourcing) - Work in Jakarta', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant Executive', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTANT FOR CONSTRUCTION BUSINESS', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountant, Account officer, Tax Consultant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accountantu002FBookkeeper Staff (Night Shift)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting  Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting - Karawaci', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting - Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting (Account receivable)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting (English Speaker-Retail Experience)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting (group)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting /  Finance Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting / Perpajakan', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & finance', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & finance', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Head', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & FINANCE MANAGER', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & FINANCE OFFICER', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Staff (Mandarin Speaker)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Finance Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & General Admin', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Pajak', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & PAJAK SPV', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Regulatory Reporting Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Reporting Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax – Senior Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX ASISTANT MANAGER', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Assistant Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Consultant Staff', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Leader', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX MANAGER', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Officer (Medan)', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Specialist Bali', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax staf', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX STAFF', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX STAFF', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX STAFF', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX STAFF', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Staff - Jakarta', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX SUPERVISOR', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING & TAX SUPERVISOR', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting & Tax Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Account Receivable Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Admin', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING ADMIN', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Admin', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Administator', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Analyst', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Analyst', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Administration Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Budget Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Finance Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Finance Supervisor\u002FCoordinator', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Reconciliation Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Tax Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING AND TAX STAFF', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Tax Supervisor', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING AND TAX SUPERVISOR', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting and Tax Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING AND TAX SUPERVISOR (Work From Home)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Ass Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Asset and Tax Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING ASSISTANT', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Assistant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Assistant Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Assistant Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Assistant Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Assistant Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING AUDIT SUPERVISOR', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Budgeting Manager Mandarin', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Claim', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Consultant', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING DAN FINANCE', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting dan Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Executive', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Executive Mandarin Speaking', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING FINANCE', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance and Tax Department Head', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance Officer', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance Site', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING FINANCE STAFF', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance Staff', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING FINANCE STAFF', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance Staff', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('ACCOUNTING FINANCE STAFF', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Finance Supervisor', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting General Ledger Staff (DKI Jakarta)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Head', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Intern (3 months)', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Inventory', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Junior Manager', '1' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Accounting Junior Manager', '1' )
# ...
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Stafff (Mandarin Speaking ONLY)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE SUPERVISOR', '21' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE SUPERVISOR', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE SUPERVISOR', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor - MANDARIN Speaking', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor (Denpasar)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor (Penempatan Makassar)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor (Semarang)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE SUPERVISOR (SPV)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE SUPERVISOR (SPV)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor (Surabaya Area)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor Cabang Gresik (DWSG)', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor Cabang Gresik (DWSG)', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE SUPERVISOR POWER DISTRIBUTION AND RENEWABLE ENERGY', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor&Logistics', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Supervisor&Logistics', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Team Leader (Cold Storage)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Team Leader (Cold Storage)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Team Leader (Pontianak Branch)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Technician', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Warehouse Training Supervisor', '35' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE WEIGHT CHECKER', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WAREHOUSE-WETAR, MALUKU', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wartawan Harian Kompas', '15' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WASTE WATER TREATMENT PLANT MANAGER', '72' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WASTE WATER TREATMENT PLANT MANAGER', '72' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Water Sports / Lifeguard', '27' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Water Treatment Manager', '72' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Water Treatment Plant Manager (WTP)', '6' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Water Treatment Sales Engineer - Jakarta', '41' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wealth Management Program (WMP)', '4' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web / Mobile Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web / Mobile Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB & API PROGRAMMER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web & Mobile Development Specialist', '31' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web & Mobile Development Specialist', '31' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB Administrator / ADMIN ONLINE', '43' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB Administrator / ADMIN ONLINE', '43' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Administrator \u002F Admin Online', '63' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web and Android Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Designer', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer (C#)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer (C#)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer (Code: DEV)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER (FULLTIME ONSITE JAKARTA)', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB DEVELOPER (SOFTWARE ENGINEER)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer & Designer (Shopify)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer & SEO Specialist', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Developer Intern', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Development Specialist', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Engineer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Front End Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Progammer (Visual Basic)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB PROGRAMMER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB PROGRAMMER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer (Full Stack)', '56' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer (Software Developer)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer (Software Developer) Solo', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer (Ximpay)', '31' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer Specialist', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Programmer Specialist', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEB PROGRAMMER VUE JS (BALI)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Web Quality Assurance', '25' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WebApp Developer Intern', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Webmaster', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Webmaster', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Webmethods Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Webmethods Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Website Commercial Operation Supervisor', '43' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEBSITE DESIGN & ADMINISTRATOR', '44' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Website Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WEBSITE FRONTEND DEVELOPER', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Website Technical Consultant', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Website Technical Consultant', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Website Technical Consultant', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Webtoon Korean Translator', '15' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Webtoon Line Artist', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Webtoon Typesetter', '60' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wedding Sales', '46' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WELDER', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Welder', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Welder', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Welder', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WELDER CPVC / PVC', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Welder Operator (Mandarin Speaker Preferred)', '67' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Welder-Setter', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Welding Inspector', '25' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Well Integrity  /  Valve Maintenance Engineer', '66' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Well Integrity  /  Valve Maintenance Engineer', '66' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wellness Business Development Staff', '45' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wellness Programmer', '58' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WFH - Junior Programmer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WFH Data Analyst', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Whatsapp Operator', '4' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WINE SOMMELIER', '10' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wireless O&M Engineer', '69' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wood Handling Plant Expert', '56' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WordPress Developer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Wordpress Engineer', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Work Force Management (WFM) Analys Supervisor', '32' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Workforce Management (WFM) - Semarang', '32' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Working Permit Specialist', '63' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WORKSHOP HEAD', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Workshop Manager', '45' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Workshop Manager \u002F Kepala Bengkel', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WORKSHOP PRODUCTION MANAGER', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Workshop Staff (CNC Machinist) Surabaya', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Workshop Staff (CNC Machinist) Surabaya', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Workshop Supervisor', '23' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WORKSHOPHEAD', '65' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WWTP (Waste Water Treatment Plant) Staff', '73' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WWTP (Wastewater Treatment Plant) Staff', '70' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WWTP SUPERVISOR', '72' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WWTP Technician (SJA SMG)', '72' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WWTP Technician (SJA SMG)', '72' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('WWTP Technician (SJA SMG)', '72' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Yogyakarta City Coordinator', '33' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Youth Leadership Program (ACSI-YLP)', '3' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Youth Leadership Program (ACSI-YLP)', '3' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Youtube & Tiktok Content Writer & Idea Maker', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('Youtube Channel Specialist', '17' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('YOUTUBE Content Creator', '59' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('业务助理 Business Operation Assistant (Location: Jakarta)', '45' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('文员（会中文）', '17' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('片区网管 (IT Specialist)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('片区网管 (IT Specialist)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('片区网管 (IT Specialist)', '13' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('现场翻译（ Site Mandarin Translator )', '15' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('电工片区 Electrician Staff (Regional Jakarta)', '67' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('财务行政', '2' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('采购专员 Purchasing Staff (Location Gandaria 8 Office Tower)', '26' )
# INSERT INTO title_very_raws (nama, domain_id) VALUES ('门店文员 (Outlet Administrator: Pakuwon Mall Surabaya)', '10' )
# done : 20611 row(s)
