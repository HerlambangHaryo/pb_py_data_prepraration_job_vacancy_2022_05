# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
# Out:
# connect

# %%
check_word = 'marketing'
change_word = 'Marketing Officer'   

# set query 1
select = ' id, nama '
fromdb = 'title_very_raws' 
where = " where nama like '%"+check_word+"%'   "
orderby = '  order by nama ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    
    idx = str(x[0]) 
    word = x[1].replace(check_word, change_word)   
      
    word = word.replace(check_word, change_word)
    word = word.strip()
    queryx = "UPDATE title_very_raws  SET nama = '"+word+"'   where id = '"+idx+"'    " 
    print(queryx)
        #         mycursor.execute(queryx)
#         mydb.commit()   
         
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# UPDATE title_very_raws  SET nama = 'account executive (Marketing Officer bidang outsourcing)'   where id = '87'
# UPDATE title_very_raws  SET nama = 'account executive Marketing Officer'   where id = '103'
# UPDATE title_very_raws  SET nama = 'account manager (Marketing Officer)'   where id = '130'
# UPDATE title_very_raws  SET nama = 'acount executive sales Marketing Officer mini market & corporate retailer'   where id = '376'
# UPDATE title_very_raws  SET nama = 'admin brand Marketing Officer'   where id = '419'
# UPDATE title_very_raws  SET nama = 'admin internal Marketing Officer'   where id = '483'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer'   where id = '507'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer'   where id = '508'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer'   where id = '509'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer (magang)'   where id = '510'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer (surabaya)'   where id = '511'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer online marketplace'   where id = '512'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer sales (palembang)'   where id = '513'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer sales (yogyakarta)'   where id = '514'
# UPDATE title_very_raws  SET nama = 'admin Marketing Officer support'   where id = '515'
# UPDATE title_very_raws  SET nama = 'admin project & Marketing Officer project'   where id = '564'
# UPDATE title_very_raws  SET nama = 'admin sales & Marketing Officer'   where id = '585'
# UPDATE title_very_raws  SET nama = 'admin sales Marketing Officer'   where id = '590'
# UPDATE title_very_raws  SET nama = 'admin support Marketing Officer'   where id = '620'
# UPDATE title_very_raws  SET nama = 'admin teleMarketing Officer'   where id = '626'
# UPDATE title_very_raws  SET nama = 'administrasi Marketing Officer'   where id = '676'
# UPDATE title_very_raws  SET nama = 'administrasi support Marketing Officer (led)'   where id = '694'
# UPDATE title_very_raws  SET nama = 'administration of Marketing Officer'   where id = '713'
# UPDATE title_very_raws  SET nama = 'admissions & Marketing Officer'   where id = '751'
# UPDATE title_very_raws  SET nama = 'ads specialist digital Marketing Officer'   where id = '752'
# UPDATE title_very_raws  SET nama = 'advertiser (digital Marketing Officer)'   where id = '753'
# UPDATE title_very_raws  SET nama = 'agency Marketing Officer support manager'   where id = '785'
# UPDATE title_very_raws  SET nama = 'area Marketing Officer manager - kalimantan'   where id = '951'
# UPDATE title_very_raws  SET nama = 'area Marketing Officer manager multiproduct area semarang'   where id = '952'
# UPDATE title_very_raws  SET nama = 'area Marketing Officer manager multiproduct area surabaya'   where id = '953'
# UPDATE title_very_raws  SET nama = 'area Marketing Officer support (ams) wilayah jawa tengah'   where id = '954'
# UPDATE title_very_raws  SET nama = 'assistant manager Marketing Officer'   where id = '1183'
# UPDATE title_very_raws  SET nama = 'assistant manager Marketing Officer logistik trucking'   where id = '1184'
# UPDATE title_very_raws  SET nama = 'assistant Marketing Officer manager'   where id = '1202'
# UPDATE title_very_raws  SET nama = 'associate & senior associate Marketing Officer'   where id = '1270'
# UPDATE title_very_raws  SET nama = 'asst. manager Marketing Officer (banten area)'   where id = '1286'
# UPDATE title_very_raws  SET nama = 'b2b senior Marketing Officer executive'   where id = '1328'
# UPDATE title_very_raws  SET nama = 'bancassurance Marketing Officer (area jakarta)'   where id = '1406'
# UPDATE title_very_raws  SET nama = 'bancassurance Marketing Officer (area semarang dan surabaya)'   where id = '1407'
# UPDATE title_very_raws  SET nama = 'beauty consultant (teleMarketing Officer)'   where id = '1490'
# UPDATE title_very_raws  SET nama = 'brand & Marketing Officer manager'   where id = '1612'
# UPDATE title_very_raws  SET nama = 'brand & Marketing Officer manager'   where id = '1613'
# UPDATE title_very_raws  SET nama = 'brand Marketing Officer'   where id = '1630'
# UPDATE title_very_raws  SET nama = 'brand Marketing Officer analyst'   where id = '1631'
# UPDATE title_very_raws  SET nama = 'brand Marketing Officer and retail support lead -sea'   where id = '1632'
# UPDATE title_very_raws  SET nama = 'brand Marketing Officer executive'   where id = '1633'
# UPDATE title_very_raws  SET nama = 'brand Marketing Officer manager'   where id = '1634'
# UPDATE title_very_raws  SET nama = 'brand Marketing Officer strategist lead'   where id = '1635'
# UPDATE title_very_raws  SET nama = 'brand, content  & Marketing Officer digital'   where id = '1639'
# UPDATE title_very_raws  SET nama = 'broker (Marketing Officer asuransi)'   where id = '1647'
# UPDATE title_very_raws  SET nama = 'business development executive (Marketing Officer)'   where id = '1759'
# UPDATE title_very_raws  SET nama = 'business director (Marketing Officer platform and medical communication)'   where id = '1816'
# UPDATE title_very_raws  SET nama = 'buy & selling staff  (Marketing Officer & sales)'   where id = '1893'
# UPDATE title_very_raws  SET nama = 'category manager (trade Marketing Officer)'   where id = '1979'
# UPDATE title_very_raws  SET nama = 'channel Marketing Officer specialist'   where id = '2008'
# UPDATE title_very_raws  SET nama = 'chief Marketing Officer officer pematangsiantar'   where id = '2066'
# UPDATE title_very_raws  SET nama = 'cmo car (credit Marketing Officer officer) area denpasar'   where id = '2165'
# UPDATE title_very_raws  SET nama = 'cmo car (credit Marketing Officer officer) area palembang'   where id = '2166'
# UPDATE title_very_raws  SET nama = 'content creator /  social media Marketing Officer'   where id = '2339'
# UPDATE title_very_raws  SET nama = 'content creator and online Marketing Officer'   where id = '2329'
# UPDATE title_very_raws  SET nama = 'content Marketing Officer specialist'   where id = '2345'
# UPDATE title_very_raws  SET nama = 'corporate digital Marketing Officer manager'   where id = '2434'
# UPDATE title_very_raws  SET nama = 'corporate Marketing Officer'   where id = '2451'
# UPDATE title_very_raws  SET nama = 'corporate Marketing Officer (area bandung)'   where id = '2452'
# UPDATE title_very_raws  SET nama = 'corporate Marketing Officer (area palembang)'   where id = '2453'
# UPDATE title_very_raws  SET nama = 'corporate Marketing Officer executive - jasa konsultan'   where id = '2454'
# UPDATE title_very_raws  SET nama = 'corporate Marketing Officer supervisor (general insurance)'   where id = '2455'
# UPDATE title_very_raws  SET nama = 'counter staff_ admin_Marketing Officer komunikasi'   where id = '2509'
# UPDATE title_very_raws  SET nama = 'credi Marketing Officer officer - yogyakarta'   where id = '2549'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer  motor ujungberung'   where id = '2576'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer elektronik cro sumedang'   where id = '2577'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer elektronik cro tasikmalaya'   where id = '2578'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer mobil bandung'   where id = '2579'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer mobil cimahi'   where id = '2580'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer mobil cirebon'   where id = '2581'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer mobil solo'   where id = '2582'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer mobil sukabumi'   where id = '2583'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer mobil tasikmalaya'   where id = '2584'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer motor bandung'   where id = '2585'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer motor cimahi'   where id = '2586'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer motor sukabumi'   where id = '2587'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer motor tasikmalaya'   where id = '2588'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer'   where id = '2589'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer'   where id = '2590'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - bandar lampung'   where id = '2591'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - bandung'   where id = '2592'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - bandung & cimahi'   where id = '2593'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - banjarmasin'   where id = '2594'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - barabai'   where id = '2595'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - batam'   where id = '2596'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - bekasi'   where id = '2597'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - bengkulu'   where id = '2598'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - bogor'   where id = '2599'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - cirebon'   where id = '2600'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - denpasar'   where id = '2601'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - depok'   where id = '2602'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - gorontalo'   where id = '2603'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - gresik'   where id = '2604'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - jambi'   where id = '2605'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - karawang'   where id = '2606'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - karawang & purwakarta'   where id = '2607'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - kediri'   where id = '2608'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - kedoya'   where id = '2609'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - kendari'   where id = '2610'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - kudus'   where id = '2611'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - kupang'   where id = '2612'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - makassar'   where id = '2613'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - malang'   where id = '2614'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - manado'   where id = '2615'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - mataram'   where id = '2616'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - medan'   where id = '2617'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - padang'   where id = '2618'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - palangkaraya'   where id = '2619'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - palembang'   where id = '2620'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - palu'   where id = '2621'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - pangkal pinang'   where id = '2622'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - pare pare'   where id = '2623'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - pekanbaru'   where id = '2624'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - pontianak'   where id = '2625'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - samarinda'   where id = '2626'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - sampit'   where id = '2627'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - semarang'   where id = '2628'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - serang'   where id = '2629'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - solo'   where id = '2630'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - sumedang & cirebon'   where id = '2631'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - sunter'   where id = '2632'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - surabaya'   where id = '2633'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - tangerang'   where id = '2634'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - tasikmalaya'   where id = '2635'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - tegal'   where id = '2636'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer - ternate'   where id = '2637'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (area aceh - urgent)'   where id = '2638'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (area jambi - urgent)'   where id = '2639'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (area lampung - urgent)'   where id = '2640'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (area riau daratan - urgent)'   where id = '2641'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (bengkulu sumsel - urgent)'   where id = '2642'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo-used car only)'   where id = '2643'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo)'   where id = '2644'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) bandung'   where id = '2645'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) bekasi'   where id = '2646'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) cibubur'   where id = '2647'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) cilegon'   where id = '2648'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) jakarta'   where id = '2649'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) jambi, lampung dan metro lampung'   where id = '2650'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) lampung'   where id = '2651'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) malang'   where id = '2652'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) mobil - motor'   where id = '2653'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) samarinda'   where id = '2654'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) sobat dan carfin'   where id = '2655'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) sobat dan carfin kediri'   where id = '2656'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) surabaya'   where id = '2657'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) tangerang'   where id = '2658'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (cmo) tangerang'   where id = '2659'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (kalimantan selatan - urgent)'   where id = '2660'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (kalimantan tengah)'   where id = '2661'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (kalimantan timur - urgent)'   where id = '2662'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (motor) - dki jakarta'   where id = '2663'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (nusa tenggara barat - urgent)'   where id = '2664'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (sulawesi barat - urgent)'   where id = '2665'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (sulawesi selatan - urgent)'   where id = '2666'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (sumatera utara - urgent)'   where id = '2667'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (surabaya)'   where id = '2668'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer (wilayah cirebon & bogor)'   where id = '2669'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer bandung'   where id = '2670'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer karawang'   where id = '2671'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - balikpapan'   where id = '2672'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - bandung'   where id = '2673'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - banjarmasin'   where id = '2674'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - batam'   where id = '2675'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - bengkulu'   where id = '2676'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - cilegon'   where id = '2677'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - cirebon'   where id = '2678'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - denpasar'   where id = '2679'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - jabotabek'   where id = '2680'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - jambi'   where id = '2681'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - karawang'   where id = '2682'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - kediri'   where id = '2683'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - lampung'   where id = '2684'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - malang'   where id = '2685'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - palembang'   where id = '2686'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - pekanbaru'   where id = '2687'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - pontianak'   where id = '2688'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - samarinda'   where id = '2689'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - semarang'   where id = '2690'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - sukabumi'   where id = '2691'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - surabaya'   where id = '2692'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil - yogyakarta'   where id = '2693'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer mobil (kmob) pontianak'   where id = '2694'
# UPDATE title_very_raws  SET nama = 'credit Marketing Officer officer used car (jakarta utara & bogor)'   where id = '2695'
# UPDATE title_very_raws  SET nama = 'credit operational teleMarketing Officer'   where id = '2697'
# UPDATE title_very_raws  SET nama = 'csr outbound (teleMarketing Officer)'   where id = '2736'
# UPDATE title_very_raws  SET nama = 'customer relation Marketing Officer media (crm)'   where id = '2780'
# UPDATE title_very_raws  SET nama = 'customer service & teleMarketing Officer jr. spv (mandarin speaking)'   where id = '2825'
# UPDATE title_very_raws  SET nama = 'customer service/ sales Marketing Officer'   where id = '2863'
# UPDATE title_very_raws  SET nama = 'customer servicing & Marketing Officer support'   where id = '2865'
# UPDATE title_very_raws  SET nama = 'dermatology Marketing Officer/  operation'   where id = '3009'
# UPDATE title_very_raws  SET nama = 'design Marketing Officer promosi'   where id = '3036'
# UPDATE title_very_raws  SET nama = 'digital & operation Marketing Officer specialist'   where id = '3092'
# UPDATE title_very_raws  SET nama = 'digital & operational Marketing Officer'   where id = '3093'
# UPDATE title_very_raws  SET nama = 'digital & performance Marketing Officer manager'   where id = '3094'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer'   where id = '3121'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer'   where id = '3122'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer  /  social media officer'   where id = '3123'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer - freight forwarding'   where id = '3124'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer - marketplace'   where id = '3125'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer - social media Marketing Officer'   where id = '3126'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer (apprenticeship)'   where id = '3127'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer (depok)'   where id = '3128'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer (google ads & manajemen leads)'   where id = '3129'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer & branding specialist spv'   where id = '3130'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer & design'   where id = '3131'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer & design (marcomm) manager'   where id = '3132'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer & event specialist'   where id = '3133'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer & graphic design'   where id = '3134'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer & promotion'   where id = '3135'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer & sales executive'   where id = '3136'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer administrator'   where id = '3137'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer advertising (retargeting)'   where id = '3138'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer analyst manager'   where id = '3139'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer assistant manager'   where id = '3140'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer associate'   where id = '3141'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer communication'   where id = '3142'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer communication supervisor'   where id = '3143'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer executive'   where id = '3144'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer executive'   where id = '3145'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer executive'   where id = '3146'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer head'   where id = '3147'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer intern'   where id = '3148'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer intership'   where id = '3149'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer leader'   where id = '3150'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer manager'   where id = '3151'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer manager (getplus.id)'   where id = '3152'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer officer'   where id = '3153'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer oficer'   where id = '3154'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer osram automotive (dmoa)'   where id = '3155'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer senior specialist'   where id = '3156'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer specialist'   where id = '3157'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer specialist'   where id = '3158'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer staff'   where id = '3159'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer staff (2)'   where id = '3160'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer staff for fb / ig / tiktok ads'   where id = '3161'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer strategist'   where id = '3162'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer supervisor'   where id = '3163'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer supervisor - cs2'   where id = '3164'
# UPDATE title_very_raws  SET nama = 'digital Marketing Officer, host live stream, e-commerce specialist, promotor toko'   where id = '3165'
# UPDATE title_very_raws  SET nama = 'digital sales & Marketing Officer'   where id = '3178'
# UPDATE title_very_raws  SET nama = 'director of sales & Marketing Officer (perhotelan)'   where id = '3195'
# UPDATE title_very_raws  SET nama = 'e-commerce /  online Marketing Officer /  Marketing Officer'   where id = '3393'
# UPDATE title_very_raws  SET nama = 'e-commerce & social media Marketing Officer'   where id = '3375'
# UPDATE title_very_raws  SET nama = 'e-commerce Marketing Officer analyst'   where id = '3381'
# UPDATE title_very_raws  SET nama = 'e-commerce sales & Marketing Officer manager'   where id = '3384'
# UPDATE title_very_raws  SET nama = 'e-commerce specialist /  online Marketing Officer /  Marketing Officer'   where id = '3387'
# UPDATE title_very_raws  SET nama = 'electronic imaging - digital Marketing Officer staff'   where id = '3468'
# UPDATE title_very_raws  SET nama = 'email Marketing Officer officer'   where id = '3478'
# UPDATE title_very_raws  SET nama = 'email Marketing Officer specialist'   where id = '3479'
# UPDATE title_very_raws  SET nama = 'erp sales Marketing Officer  /  presales senior'   where id = '3642'
# UPDATE title_very_raws  SET nama = 'event Marketing Officer staff'   where id = '3684'
# UPDATE title_very_raws  SET nama = 'export Marketing Officer vice president'   where id = '3749'
# UPDATE title_very_raws  SET nama = 'faculty member - global business Marketing Officer program'   where id = '3795'
# UPDATE title_very_raws  SET nama = 'feed technical Marketing Officer (east java - surabaya)'   where id = '3819'
# UPDATE title_very_raws  SET nama = 'field Marketing Officer'   where id = '4001'
# UPDATE title_very_raws  SET nama = 'field Marketing Officer officer'   where id = '4002'
# UPDATE title_very_raws  SET nama = 'fleet credit Marketing Officer officer - lampung'   where id = '4356'
# UPDATE title_very_raws  SET nama = 'fleet credit Marketing Officer officer - medan area'   where id = '4357'
# UPDATE title_very_raws  SET nama = 'freight forwarding Marketing Officer'   where id = '4415'
# UPDATE title_very_raws  SET nama = 'fresh graduate Marketing Officer progam'   where id = '4425'
# UPDATE title_very_raws  SET nama = 'funding Marketing Officer'   where id = '4514'
# UPDATE title_very_raws  SET nama = 'funding Marketing Officer pekanbaru'   where id = '4515'
# UPDATE title_very_raws  SET nama = 'furniture sales Marketing Officer'   where id = '4524'
# UPDATE title_very_raws  SET nama = 'general manager Marketing Officer & sales (industrial estate)'   where id = '4630'
# UPDATE title_very_raws  SET nama = 'general manager sales & Marketing Officer'   where id = '4634'
# UPDATE title_very_raws  SET nama = 'general manager sales and Marketing Officer'   where id = '4635'
# UPDATE title_very_raws  SET nama = 'gm of digital Marketing Officer (for retail)'   where id = '4658'
# UPDATE title_very_raws  SET nama = 'graphic designer /  Marketing Officer person'   where id = '4712'
# UPDATE title_very_raws  SET nama = 'graphic designer & digital Marketing Officer'   where id = '4701'
# UPDATE title_very_raws  SET nama = 'graphic designer & Marketing Officer communication'   where id = '4703'
# UPDATE title_very_raws  SET nama = 'growth Marketing Officer'   where id = '4728'
# UPDATE title_very_raws  SET nama = 'growth Marketing Officer manager'   where id = '4729'
# UPDATE title_very_raws  SET nama = 'growth Marketing Officer manager (getplus.id)'   where id = '4730'
# UPDATE title_very_raws  SET nama = 'growth Marketing Officer specialist'   where id = '4731'
# UPDATE title_very_raws  SET nama = 'head digital Marketing Officer'   where id = '4827'
# UPDATE title_very_raws  SET nama = 'head finance accounting asisten direktur head Marketing Officer'   where id = '4831'
# UPDATE title_very_raws  SET nama = 'head Marketing Officer'   where id = '4833'
# UPDATE title_very_raws  SET nama = 'head of Marketing Officer'   where id = '4881'
# UPDATE title_very_raws  SET nama = 'head of Marketing Officer and business development'   where id = '4882'
# UPDATE title_very_raws  SET nama = 'head of Marketing Officer communication'   where id = '4883'
# UPDATE title_very_raws  SET nama = 'head of Marketing Officer communication'   where id = '4884'
# UPDATE title_very_raws  SET nama = 'head of Marketing Officer communication & partnership'   where id = '4885'
# UPDATE title_very_raws  SET nama = 'head of Marketing Officer marine and cargo'   where id = '4886'
# UPDATE title_very_raws  SET nama = 'head of Marketing Officer strategist (digital and customer relation management)'   where id = '4887'
# UPDATE title_very_raws  SET nama = 'house artist and Marketing Officer communication'   where id = '4992'
# UPDATE title_very_raws  SET nama = 'hunter  /  Marketing Officer'   where id = '5346'
# UPDATE title_very_raws  SET nama = 'intern program (Marketing Officer-agricultural solutions division)'   where id = '5522'
# UPDATE title_very_raws  SET nama = 'internal Marketing Officer devevelopment bpm officer'   where id = '5567'
# UPDATE title_very_raws  SET nama = 'internet Marketing Officer manager (e-commerce)'   where id = '5582'
# UPDATE title_very_raws  SET nama = 'it web & digital Marketing Officer'   where id = '5940'
# UPDATE title_very_raws  SET nama = 'junior Marketing Officer staff'   where id = '6053'
# UPDATE title_very_raws  SET nama = 'kepala divisi Marketing Officer rumah sakit'   where id = '6169'
# UPDATE title_very_raws  SET nama = 'kepala Marketing Officer era jack'   where id = '6187'
# UPDATE title_very_raws  SET nama = 'koordinator Marketing Officer'   where id = '6309'
# UPDATE title_very_raws  SET nama = 'laboratory information service (Marketing Officer) - jawa timur, nusa tenggara'   where id = '6349'
# UPDATE title_very_raws  SET nama = 'live stream Marketing Officer executive'   where id = '6542'
# UPDATE title_very_raws  SET nama = 'livestream performance Marketing Officer deputy manager (mandarin)'   where id = '6546'
# UPDATE title_very_raws  SET nama = 'livestream performance Marketing Officer specialist (mandarin)'   where id = '6547'
# UPDATE title_very_raws  SET nama = 'local store Marketing Officer supervisor'   where id = '6555'
# UPDATE title_very_raws  SET nama = 'management development program (mdp) - Marketing Officer'   where id = '6661'
# UPDATE title_very_raws  SET nama = 'management trainee (mt) - sales Marketing Officer'   where id = '6697'
# UPDATE title_very_raws  SET nama = 'manager branding Marketing Officer'   where id = '6728'
# UPDATE title_very_raws  SET nama = 'manager digital Marketing Officer'   where id = '6741'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer'   where id = '6771'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer'   where id = '6772'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer'   where id = '6773'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer'   where id = '6774'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer'   where id = '6775'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer b2b'   where id = '6776'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer online'   where id = '6777'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer pintu baja (mandarin)'   where id = '6778'
# UPDATE title_very_raws  SET nama = 'manager Marketing Officer trucking company'   where id = '6779'
# UPDATE title_very_raws  SET nama = 'manager sales & Marketing Officer'   where id = '6813'
# UPDATE title_very_raws  SET nama = 'Marketing Officer'   where id = '6912'
# UPDATE title_very_raws  SET nama = 'Marketing Officer'   where id = '6913'
# UPDATE title_very_raws  SET nama = 'Marketing Officer'   where id = '6914'
# UPDATE title_very_raws  SET nama = 'Marketing Officer'   where id = '6915'
# UPDATE title_very_raws  SET nama = 'Marketing Officer'   where id = '6916'
# UPDATE title_very_raws  SET nama = 'Marketing Officer  /  branding manager'   where id = '6917'
# UPDATE title_very_raws  SET nama = 'Marketing Officer  /  event & promotion specialist  /  brand activation staff'   where id = '6918'
# UPDATE title_very_raws  SET nama = 'Marketing Officer  administration staff'   where id = '6919'
# UPDATE title_very_raws  SET nama = 'Marketing Officer - copywriter'   where id = '6920'
# UPDATE title_very_raws  SET nama = 'Marketing Officer - jakarta'   where id = '6921'
# UPDATE title_very_raws  SET nama = 'Marketing Officer - kawasan industri'   where id = '6922'
# UPDATE title_very_raws  SET nama = 'Marketing Officer - surabaya'   where id = '6923'
# UPDATE title_very_raws  SET nama = 'Marketing Officer ( heavy equipment dan trucking )'   where id = '6924'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (bogor, depok, cikarang, bekasi)'   where id = '6925'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (business development)'   where id = '6926'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (cimahi, sukabumi, tasikmalaya)'   where id = '6927'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (cirebon, kuningan, indramayu)'   where id = '6928'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (experience)'   where id = '6929'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (kupang, lombok, bima)'   where id = '6930'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (staff development program)'   where id = '6931'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (yogyakarta, semarang, solo/ surakarta)'   where id = '6932'
# UPDATE title_very_raws  SET nama = 'Marketing Officer (yogyakarta)'   where id = '6933'
# UPDATE title_very_raws  SET nama = 'Marketing Officer /  business development (b to b)'   where id = '7352'
# UPDATE title_very_raws  SET nama = 'Marketing Officer /  business development education'   where id = '7353'
# UPDATE title_very_raws  SET nama = 'Marketing Officer /  sales'   where id = '7354'
# UPDATE title_very_raws  SET nama = 'Marketing Officer / business development'   where id = '6934'
# UPDATE title_very_raws  SET nama = 'Marketing Officer / lobbyist / project manajer'   where id = '6935'
# UPDATE title_very_raws  SET nama = 'Marketing Officer / sales'   where id = '6936'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & branding manager'   where id = '6937'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & branding support staff (pontianak)'   where id = '6938'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & business development (brand teh 63)'   where id = '6939'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & business development manager'   where id = '6940'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & communication executive'   where id = '6941'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & customer relation'   where id = '6942'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & customer relation'   where id = '6943'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & digital advertiser'   where id = '6944'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & growth senior officer'   where id = '6945'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & management supervisor'   where id = '6946'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & pr'   where id = '6947'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & promotion specialist (paramount lifestyle)'   where id = '6948'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & public relation'   where id = '6949'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & public relation officer'   where id = '6950'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & sales'   where id = '6951'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & sales executive'   where id = '6952'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & sales export import'   where id = '6953'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & sales officer'   where id = '6954'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & sales specialist'   where id = '6955'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & sales support manager (e-commerce)'   where id = '6956'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & user acquisition manager'   where id = '6957'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) - banjarnegara'   where id = '6958'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) balaraja'   where id = '6959'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) bangkinang'   where id = '6960'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) banjar'   where id = '6961'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) banjarmasin'   where id = '6962'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) batam'   where id = '6963'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) bekasi'   where id = '6964'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) bengkulu'   where id = '6965'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) binjai'   where id = '6966'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) bogor'   where id = '6967'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) bojonegoro'   where id = '6968'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) cianjur'   where id = '6969'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) cibubur'   where id = '6970'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) cikampek'   where id = '6971'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) cikupa'   where id = '6972'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) ciledug'   where id = '6973'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) cilegon'   where id = '6974'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) deli serdang'   where id = '6975'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) depok'   where id = '6976'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) fatmawati'   where id = '6977'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) garut'   where id = '6978'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) jakarta utara'   where id = '6979'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) jatibarang, indramayu'   where id = '6980'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) kalimalang'   where id = '6981'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) karawang'   where id = '6982'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) kebumen'   where id = '6983'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) kedoya'   where id = '6984'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) kelapa gading'   where id = '6985'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) ketanggungan'   where id = '6986'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) lampung'   where id = '6987'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) luwuk'   where id = '6988'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) magelang'   where id = '6989'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) majalengka'   where id = '6990'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) medan'   where id = '6991'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) muara bungo'   where id = '6992'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) muara enim'   where id = '6993'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) nganjuk'   where id = '6994'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) padang'   where id = '6995'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) palembang'   where id = '6996'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) pangkajene dan kepulauan'   where id = '6997'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) pangkalan kerinci'   where id = '6998'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) pasar minggu'   where id = '6999'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) paser'   where id = '7000'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) pecenongan'   where id = '7001'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) pekanbaru'   where id = '7002'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) perawang'   where id = '7003'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) polewali mandar'   where id = '7004'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) polman sulawesi barat'   where id = '7005'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) pondok gede'   where id = '7006'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) pondok indah'   where id = '7007'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) praya'   where id = '7008'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) probolinggo'   where id = '7009'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) purbalingga'   where id = '7010'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) purwakarta'   where id = '7011'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) purwokerto'   where id = '7012'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) rantau prapat'   where id = '7013'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) sambas'   where id = '7014'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) semarang'   where id = '7015'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) serang'   where id = '7016'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) sumedang'   where id = '7017'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) tangerang'   where id = '7018'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js - mvo) tangerang selatan'   where id = '7019'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js- mvo) cirebon'   where id = '7020'
# UPDATE title_very_raws  SET nama = 'Marketing Officer & verification officer (js- mvo) kuningan, jawa barat'   where id = '7021'
# UPDATE title_very_raws  SET nama = 'Marketing Officer activation'   where id = '7022'
# UPDATE title_very_raws  SET nama = 'Marketing Officer admin'   where id = '7023'
# UPDATE title_very_raws  SET nama = 'Marketing Officer admin staff'   where id = '7024'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency - branch balikpapan'   where id = '7025'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (car and motor product) - jakarta dan bekasi'   where id = '7026'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (car and motor product) bogor, cileungsi, citeureup, bekasi, depok'   where id = '7027'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (cirebon,kuningan,indramayu,karawang,cikampek,purwakarta dan subang)'   where id = '7028'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (gresik & lamongan)'   where id = '7029'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (jawa tengah & yogyakarta)'   where id = '7030'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (kediri, blitar dan tulungagung)'   where id = '7031'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (penempatan branch makassar dan gowa)'   where id = '7032'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency (sidoarjo)'   where id = '7033'
# UPDATE title_very_raws  SET nama = 'Marketing Officer agency bpkb mobil - branch bintaro'   where id = '7034'
# ...
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer officer'   where id = '10327'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer officer'   where id = '10328'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer online'   where id = '10329'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer perbankan'   where id = '10330'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer program mt (management trainee)'   where id = '10331'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer realty'   where id = '10332'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer rental otomotif'   where id = '10333'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer retail'   where id = '10334'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer staff'   where id = '10335'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer staff'   where id = '10336'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer staff'   where id = '10337'
# UPDATE title_very_raws  SET nama = 'sales Marketing Officer supervisor'   where id = '10338'
# UPDATE title_very_raws  SET nama = 'sales staff Marketing Officer'   where id = '10542'
# UPDATE title_very_raws  SET nama = 'sales, Marketing Officer'   where id = '10666'
# UPDATE title_very_raws  SET nama = 'sales/ Marketing Officer'   where id = '10695'
# UPDATE title_very_raws  SET nama = 'sales/ Marketing Officer'   where id = '10696'
# UPDATE title_very_raws  SET nama = 'salesman-Marketing Officer'   where id = '10694'
# UPDATE title_very_raws  SET nama = 'sdp Marketing Officer area'   where id = '10756'
# UPDATE title_very_raws  SET nama = 'secured loan direct sales (Marketing Officer kpr) - jabodetabek'   where id = '10802'
# UPDATE title_very_raws  SET nama = 'senior admin Marketing Officer lokal'   where id = '10883'
# UPDATE title_very_raws  SET nama = 'senior digital Marketing Officer'   where id = '10951'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer'   where id = '11026'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer'   where id = '11027'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer'   where id = '11028'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer executive (b2b)'   where id = '11029'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer manager'   where id = '11030'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer manager'   where id = '11031'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer manager'   where id = '11032'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer officer'   where id = '11033'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer staff for heavy equipment & machinery leasing -jakarta-'   where id = '11034'
# UPDATE title_very_raws  SET nama = 'senior Marketing Officer syariah'   where id = '11035'
# UPDATE title_very_raws  SET nama = 'senior sales Marketing Officer (wilayah timur jateng)'   where id = '11116'
# UPDATE title_very_raws  SET nama = 'senior staff digital Marketing Officer - cikarang'   where id = '11136'
# UPDATE title_very_raws  SET nama = 'senior teleMarketing Officer'   where id = '11171'
# UPDATE title_very_raws  SET nama = 'seo specialist (digital Marketing Officer officer)'   where id = '11200'
# UPDATE title_very_raws  SET nama = 'sharia Marketing Officer head development program'   where id = '11248'
# UPDATE title_very_raws  SET nama = 'shipping agency Marketing Officer & operation'   where id = '11268'
# UPDATE title_very_raws  SET nama = 'social media  - digital Marketing Officer specialist'   where id = '11357'
# UPDATE title_very_raws  SET nama = 'social media and content Marketing Officer specialist'   where id = '11366'
# UPDATE title_very_raws  SET nama = 'social media Marketing Officer'   where id = '11379'
# UPDATE title_very_raws  SET nama = 'social media Marketing Officer'   where id = '11380'
# UPDATE title_very_raws  SET nama = 'social media Marketing Officer deputy manager (mandarin)'   where id = '11381'
# UPDATE title_very_raws  SET nama = 'social media Marketing Officer manager'   where id = '11382'
# UPDATE title_very_raws  SET nama = 'social media Marketing Officer specialist'   where id = '11383'
# UPDATE title_very_raws  SET nama = 'social media specialist & Marketing Officer support'   where id = '11400'
# UPDATE title_very_raws  SET nama = 'solution dan digital Marketing Officer'   where id = '11467'
# UPDATE title_very_raws  SET nama = 'sosmed Marketing Officer manager'   where id = '11486'
# UPDATE title_very_raws  SET nama = 'spv digital Marketing Officer'   where id = '11540'
# UPDATE title_very_raws  SET nama = 'spv product Marketing Officer development'   where id = '11561'
# UPDATE title_very_raws  SET nama = 'spv sales dan Marketing Officer'   where id = '11574'
# UPDATE title_very_raws  SET nama = 'sr. Marketing Officer manager (tanifund)'   where id = '11608'
# UPDATE title_very_raws  SET nama = 'staff admin Marketing Officer'   where id = '11673'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer'   where id = '11877'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer'   where id = '11878'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer ( malang )'   where id = '11879'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer ( medan )'   where id = '11880'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer ( surabaya )'   where id = '11881'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer ( tulungagung - kediri - blitar )'   where id = '11882'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer (psr) area dki jakarta dan surabaya'   where id = '11883'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer (solo - surakarta - sukoharjo - wonogiri)'   where id = '11884'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer (sukabumi & depok)'   where id = '11885'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer & administration'   where id = '11886'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer & business development area surabaya'   where id = '11887'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer & sales_jakarta'   where id = '11888'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer & social media'   where id = '11889'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer communication'   where id = '11890'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer dan advertising'   where id = '11891'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer executive emkl/ logistik dan exim'   where id = '11892'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer frozen food (jakarta dan kab bandung)'   where id = '11893'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer jambi'   where id = '11894'
# UPDATE title_very_raws  SET nama = 'staff Marketing Officer services'   where id = '11895'
# UPDATE title_very_raws  SET nama = 'staff nurse Marketing Officer bandung'   where id = '11902'
# UPDATE title_very_raws  SET nama = 'staff sales&Marketing Officer'   where id = '11986'
# UPDATE title_very_raws  SET nama = 'stafff analis riset perencana Marketing Officer dan perencana business plan'   where id = '12035'
# UPDATE title_very_raws  SET nama = 'stafff Marketing Officer'   where id = '12059'
# UPDATE title_very_raws  SET nama = 'stafff Marketing Officer'   where id = '12060'
# UPDATE title_very_raws  SET nama = 'stafff Marketing Officer (penempatan jombang , sidoarjo , malang , surabaya timur , suarabaya barat , jember)'   where id = '12061'
# UPDATE title_very_raws  SET nama = 'stafff Marketing Officer (penempatan medan)'   where id = '12062'
# UPDATE title_very_raws  SET nama = 'stafff Marketing Officer (penempatan pontianak , banjarmasin , ketapang , balikpapan, martapura , singkawang)'   where id = '12063'
# UPDATE title_very_raws  SET nama = 'stafff Marketing Officer & trading - admin'   where id = '12064'
# UPDATE title_very_raws  SET nama = 'stafff sales Marketing Officer'   where id = '12081'
# UPDATE title_very_raws  SET nama = 'strategic digital Marketing Officer'   where id = '12183'
# UPDATE title_very_raws  SET nama = 'strategic field Marketing Officer - karawaci'   where id = '12184'
# UPDATE title_very_raws  SET nama = 'strategic Marketing Officer planner'   where id = '12188'
# UPDATE title_very_raws  SET nama = 'strategic Marketing Officer planner'   where id = '12189'
# UPDATE title_very_raws  SET nama = 'supervisor development (Marketing Officer, survey, piutang)'   where id = '12266'
# UPDATE title_very_raws  SET nama = 'supervisor digital Marketing Officer'   where id = '12268'
# UPDATE title_very_raws  SET nama = 'supervisor digital Marketing Officer'   where id = '12269'
# UPDATE title_very_raws  SET nama = 'supervisor humas & Marketing Officer'   where id = '12312'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer'   where id = '12330'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer'   where id = '12331'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer'   where id = '12332'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer'   where id = '12333'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer'   where id = '12334'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer ( spv motor pembiayaan )'   where id = '12335'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer (indoor)'   where id = '12336'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer (jakarta)'   where id = '12337'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer elektronik (banjarbaru)'   where id = '12338'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer elektronik (banjarmasin)'   where id = '12339'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer elektronik (bro) garut'   where id = '12340'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer elektronik (bro) samarinda'   where id = '12341'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer elektronik (pontianak)'   where id = '12342'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer elektronik serang'   where id = '12343'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer elektronik wilayah solo'   where id = '12344'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer farmasi (madiun & jember)'   where id = '12345'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer for trucking & bus leasing -jakarta-'   where id = '12346'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer kain'   where id = '12347'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer mobil area cirebon'   where id = '12348'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer mobil area jakarta timur'   where id = '12349'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer mobil area jakarta utara'   where id = '12350'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer mobil tangerang'   where id = '12351'
# UPDATE title_very_raws  SET nama = 'supervisor Marketing Officer motor jakarta'   where id = '12352'
# UPDATE title_very_raws  SET nama = 'supervisor sales & Marketing Officer (area jawa tengah)'   where id = '12411'
# UPDATE title_very_raws  SET nama = 'supervisor sales Marketing Officer'   where id = '12420'
# UPDATE title_very_raws  SET nama = 'supervisor sales Marketing Officer  (area timur jawa tengah)'   where id = '12421'
# UPDATE title_very_raws  SET nama = 'supervisor sales Marketing Officer taking order (tegal)'   where id = '12422'
# UPDATE title_very_raws  SET nama = 'supervisor teleMarketing Officer properti - yogyakarta'   where id = '12453'
# UPDATE title_very_raws  SET nama = 'team leader digital Marketing Officer'   where id = '12673'
# UPDATE title_very_raws  SET nama = 'team leader teleMarketing Officer'   where id = '12679'
# UPDATE title_very_raws  SET nama = 'technical Marketing Officer staff'   where id = '12725'
# UPDATE title_very_raws  SET nama = 'teknik mesin (Marketing Officer staff) (001-c)'   where id = '12817'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer'   where id = '12959'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer'   where id = '12960'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer (e-commerce)'   where id = '12961'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer (jakarta)'   where id = '12962'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer / customer service Marketing Officer property'   where id = '12963'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer executive'   where id = '12964'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer jogja'   where id = '12965'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer officer'   where id = '12966'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer officer  - alam sutera, tangerang selatan'   where id = '12967'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer part-time'   where id = '12968'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer specialist'   where id = '12969'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer specialist'   where id = '12970'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer staff'   where id = '12971'
# UPDATE title_very_raws  SET nama = 'teleMarketing Officer/ telesales'   where id = '12972'
# UPDATE title_very_raws  SET nama = 'telesales  /  teleMarketing Officer'   where id = '12975'
# UPDATE title_very_raws  SET nama = 'telesales /  teleMarketing Officer (jakarta)'   where id = '12987'
# UPDATE title_very_raws  SET nama = 'telesales/ teleMarketing Officer - branch pekanbaru - palembang - bandar lampung'   where id = '12988'
# UPDATE title_very_raws  SET nama = 'tenant leasing & Marketing Officer specialist'   where id = '13003'
# UPDATE title_very_raws  SET nama = 'tire Marketing Officer manager'   where id = '13047'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer (mandarin speaker)'   where id = '13061'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer analyst'   where id = '13062'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer executive - pt kalbe blackmores nutrition'   where id = '13063'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer manager'   where id = '13064'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer manager [food product]'   where id = '13065'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer specialist'   where id = '13066'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer supervisor - kalimantan'   where id = '13067'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer supervisor mt'   where id = '13068'
# UPDATE title_very_raws  SET nama = 'trade Marketing Officer/ promotion assistant manager (guardian)'   where id = '13069'
# UPDATE title_very_raws  SET nama = 'trade promotion Marketing Officer'   where id = '13070'
# UPDATE title_very_raws  SET nama = 'ui/ ux designer - Marketing Officer'   where id = '13190'
# UPDATE title_very_raws  SET nama = 'urgently needed : Marketing Officer manager'   where id = '13204'
# UPDATE title_very_raws  SET nama = 'vp Marketing Officer and customer experience'   where id = '13294'
# done : 1105 row(s)
