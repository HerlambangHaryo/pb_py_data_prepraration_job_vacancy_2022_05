# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
# Out:
# connect

# %%
# set query 1
select = ' id, nama '
fromdb = 'title_very_raws' 
where = '  '
orderby = '    '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    word = x[1]
     
    queryx = "UPDATE title_very_raws  SET nama  = TRIM('"+word+"')  where id = '"+idx+"'    " 
    print(queryx)
    mycursor.execute(queryx)
    mydb.commit()   
    
    
    
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# UPDATE title_very_raws  SET nama  = TRIM('.NET ')  where id = '1'
# UPDATE title_very_raws  SET nama  = TRIM('.net core developer')  where id = '2'
# UPDATE title_very_raws  SET nama  = TRIM('.net developer')  where id = '3'
# UPDATE title_very_raws  SET nama  = TRIM('.net developer c# ')  where id = '4'
# UPDATE title_very_raws  SET nama  = TRIM('.net developers')  where id = '5'
# UPDATE title_very_raws  SET nama  = TRIM('.net programmer')  where id = '6'
# UPDATE title_very_raws  SET nama  = TRIM('(doctor) medical advisor')  where id = '7'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2107008) account officer ')  where id = '8'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2108004) account officer ')  where id = '9'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2108005) account officer ')  where id = '10'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2110009) account officer ')  where id = '11'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2112007) account officer  sales ')  where id = '12'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2203001) account officer ')  where id = '13'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2203003) account officer ')  where id = '14'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2204003) account officer ')  where id = '15'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2204004) mv claim controller')  where id = '16'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2205001) account officer ')  where id = '17'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2205002) account officer ')  where id = '18'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2205005) account officer ')  where id = '19'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2205008) underwriter marine hull')  where id = '20'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2205009) surveyor ')  where id = '21'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2205010) treasury staff')  where id = '22'
# UPDATE title_very_raws  SET nama  = TRIM('(jv2205012) account officer ')  where id = '23'
# UPDATE title_very_raws  SET nama  = TRIM('(programmable logic controller) plc engineer /  specialist')  where id = '24'
# UPDATE title_very_raws  SET nama  = TRIM('[ project')  where id = '25'
# UPDATE title_very_raws  SET nama  = TRIM('[bmw astra used car] sales consultant used car ')  where id = '26'
# UPDATE title_very_raws  SET nama  = TRIM('[freelance] talent acquisition specialist')  where id = '27'
# UPDATE title_very_raws  SET nama  = TRIM('[mooimom] spg')  where id = '28'
# UPDATE title_very_raws  SET nama  = TRIM('[sales] daihatsu')  where id = '29'
# UPDATE title_very_raws  SET nama  = TRIM('[ubud] resident medical officer ')  where id = '30'
# UPDATE title_very_raws  SET nama  = TRIM('10.	photographer /  videographer & design grafis')  where id = '31'
# UPDATE title_very_raws  SET nama  = TRIM('2d / 3d designer')  where id = '32'
# UPDATE title_very_raws  SET nama  = TRIM('2nd level engineer ')  where id = '33'
# UPDATE title_very_raws  SET nama  = TRIM('3d artist')  where id = '34'
# UPDATE title_very_raws  SET nama  = TRIM('3d artist')  where id = '35'
# UPDATE title_very_raws  SET nama  = TRIM('3d artist  /  modeling for game')  where id = '36'
# UPDATE title_very_raws  SET nama  = TRIM('3d artist staff')  where id = '37'
# UPDATE title_very_raws  SET nama  = TRIM('3d designer')  where id = '38'
# UPDATE title_very_raws  SET nama  = TRIM('3d designer ')  where id = '39'
# UPDATE title_very_raws  SET nama  = TRIM('3d designer interior')  where id = '40'
# UPDATE title_very_raws  SET nama  = TRIM('3d modeling animation designer')  where id = '41'
# UPDATE title_very_raws  SET nama  = TRIM('3d modeller architecture')  where id = '42'
# UPDATE title_very_raws  SET nama  = TRIM('3d visualizer')  where id = '43'
# UPDATE title_very_raws  SET nama  = TRIM('3pl management head ')  where id = '44'
# UPDATE title_very_raws  SET nama  = TRIM('6')  where id = '45'
# UPDATE title_very_raws  SET nama  = TRIM('a level  /  igcse chemistry teacher  /  tutor')  where id = '46'
# UPDATE title_very_raws  SET nama  = TRIM('abaper')  where id = '47'
# UPDATE title_very_raws  SET nama  = TRIM('academic specialist matematika & fisika')  where id = '48'
# UPDATE title_very_raws  SET nama  = TRIM('academics coordinator')  where id = '49'
# UPDATE title_very_raws  SET nama  = TRIM('acc & finance spv')  where id = '50'
# UPDATE title_very_raws  SET nama  = TRIM('acc tax stafff ')  where id = '51'
# UPDATE title_very_raws  SET nama  = TRIM('acccounting staff ')  where id = '52'
# UPDATE title_very_raws  SET nama  = TRIM('access & community relation ')  where id = '53'
# UPDATE title_very_raws  SET nama  = TRIM('access point engineering & development')  where id = '54'
# UPDATE title_very_raws  SET nama  = TRIM('accident & health flow underwriter')  where id = '55'
# UPDATE title_very_raws  SET nama  = TRIM('accont manager ')  where id = '56'
# UPDATE title_very_raws  SET nama  = TRIM('account / sales leader')  where id = '57'
# UPDATE title_very_raws  SET nama  = TRIM('account assistant')  where id = '58'
# UPDATE title_very_raws  SET nama  = TRIM('account director')  where id = '59'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '60'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '61'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '62'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '63'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '64'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '65'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '66'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '67'
# UPDATE title_very_raws  SET nama  = TRIM('account executive  aceh, pekanbaru, padang, lampung')  where id = '68'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '69'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '70'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '71'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '72'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '73'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '74'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '75'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '76'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '77'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '78'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '79'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '80'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '81'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '82'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '83'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '84'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '85'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '86'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '87'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '88'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '89'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '90'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '91'
# UPDATE title_very_raws  SET nama  = TRIM('account executive ')  where id = '92'
# UPDATE title_very_raws  SET nama  = TRIM('account executive associate')  where id = '93'
# UPDATE title_very_raws  SET nama  = TRIM('account executive audio visual')  where id = '94'
# UPDATE title_very_raws  SET nama  = TRIM('account executive corporate banking')  where id = '95'
# UPDATE title_very_raws  SET nama  = TRIM('account executive creative agency garam')  where id = '96'
# UPDATE title_very_raws  SET nama  = TRIM('account executive e')  where id = '97'
# UPDATE title_very_raws  SET nama  = TRIM('account executive enterprise')  where id = '98'
# UPDATE title_very_raws  SET nama  = TRIM('account executive erp')  where id = '99'
# UPDATE title_very_raws  SET nama  = TRIM('account executive for interior design')  where id = '100'
# UPDATE title_very_raws  SET nama  = TRIM('account executive for pharma ingredients business')  where id = '101'
# UPDATE title_very_raws  SET nama  = TRIM('account executive internet service provider ')  where id = '102'
# UPDATE title_very_raws  SET nama  = TRIM('account executive marketing')  where id = '103'
# UPDATE title_very_raws  SET nama  = TRIM('account executive payment switching')  where id = '104'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '105'
# UPDATE title_very_raws  SET nama  = TRIM('account executive')  where id = '106'
# UPDATE title_very_raws  SET nama  = TRIM('account finance manager ')  where id = '107'
# UPDATE title_very_raws  SET nama  = TRIM('account manager')  where id = '108'
# UPDATE title_very_raws  SET nama  = TRIM('account manager')  where id = '109'
# UPDATE title_very_raws  SET nama  = TRIM('account manager')  where id = '110'
# UPDATE title_very_raws  SET nama  = TRIM('account manager')  where id = '111'
# UPDATE title_very_raws  SET nama  = TRIM('account manager')  where id = '112'
# UPDATE title_very_raws  SET nama  = TRIM('account manager  ')  where id = '113'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '114'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '115'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '116'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '117'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '118'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '119'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '120'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '121'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '122'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '123'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '124'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '125'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '126'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '127'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '128'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '129'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '130'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '131'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '132'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '133'
# UPDATE title_very_raws  SET nama  = TRIM('account manager ')  where id = '134'
# UPDATE title_very_raws  SET nama  = TRIM('account manager & sales manager')  where id = '135'
# UPDATE title_very_raws  SET nama  = TRIM('account manager cbn cloud')  where id = '136'
# UPDATE title_very_raws  SET nama  = TRIM('account manager corporate')  where id = '137'
# UPDATE title_very_raws  SET nama  = TRIM('account manager corporate pekanbaru')  where id = '138'
# UPDATE title_very_raws  SET nama  = TRIM('account manager for fsi')  where id = '139'
# UPDATE title_very_raws  SET nama  = TRIM('account manager for software solution division ')  where id = '140'
# UPDATE title_very_raws  SET nama  = TRIM('account manager garut')  where id = '141'
# UPDATE title_very_raws  SET nama  = TRIM('account manager padang sidempuan')  where id = '142'
# UPDATE title_very_raws  SET nama  = TRIM('account manager surabaya')  where id = '143'
# UPDATE title_very_raws  SET nama  = TRIM('account manger ')  where id = '144'
# UPDATE title_very_raws  SET nama  = TRIM('account officer')  where id = '145'
# UPDATE title_very_raws  SET nama  = TRIM('account officer')  where id = '146'
# UPDATE title_very_raws  SET nama  = TRIM('account officer')  where id = '147'
# UPDATE title_very_raws  SET nama  = TRIM('account officer')  where id = '148'
# UPDATE title_very_raws  SET nama  = TRIM('account officer  ')  where id = '149'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '150'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '151'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '152'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '153'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '154'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '155'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '156'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '157'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '158'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '159'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '160'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '161'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '162'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '163'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '164'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '165'
# UPDATE title_very_raws  SET nama  = TRIM('account officer ')  where id = '166'
# UPDATE title_very_raws  SET nama  = TRIM('account officer mikro ')  where id = '167'
# UPDATE title_very_raws  SET nama  = TRIM('account officer mikro ')  where id = '168'
# UPDATE title_very_raws  SET nama  = TRIM('account officer yogyakarta malang surabaya')  where id = '169'
# UPDATE title_very_raws  SET nama  = TRIM('account officer, remedial dan analis kredit perbankan')  where id = '170'
# UPDATE title_very_raws  SET nama  = TRIM('account payable')  where id = '171'
# UPDATE title_very_raws  SET nama  = TRIM('account payable ')  where id = '172'
# UPDATE title_very_raws  SET nama  = TRIM('account payable ')  where id = '173'
# UPDATE title_very_raws  SET nama  = TRIM('account payable & account receivable staff')  where id = '174'
# UPDATE title_very_raws  SET nama  = TRIM('account payable analyst')  where id = '175'
# UPDATE title_very_raws  SET nama  = TRIM('account payable associate')  where id = '176'
# UPDATE title_very_raws  SET nama  = TRIM('account payable officer')  where id = '177'
# UPDATE title_very_raws  SET nama  = TRIM('account payable officer ')  where id = '178'
# UPDATE title_very_raws  SET nama  = TRIM('account payable specialist')  where id = '179'
# UPDATE title_very_raws  SET nama  = TRIM('account payable staff')  where id = '180'
# UPDATE title_very_raws  SET nama  = TRIM('account payable supervisor')  where id = '181'
# UPDATE title_very_raws  SET nama  = TRIM('account payable supervisor ')  where id = '182'
# UPDATE title_very_raws  SET nama  = TRIM('account payable/ receivable supervisor ')  where id = '183'
# UPDATE title_very_raws  SET nama  = TRIM('account payble ')  where id = '184'
# UPDATE title_very_raws  SET nama  = TRIM('account payble group leader')  where id = '185'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable')  where id = '186'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable ')  where id = '187'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable ')  where id = '188'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable ')  where id = '189'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable ')  where id = '190'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable ')  where id = '191'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable & billing analyst')  where id = '192'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable admin')  where id = '193'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable admin ')  where id = '194'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable control')  where id = '195'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable head ')  where id = '196'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable officer')  where id = '197'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable officer ')  where id = '198'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable section head')  where id = '199'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable specialist ')  where id = '200'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable specialist ')  where id = '201'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable staff')  where id = '202'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable staff ')  where id = '203'
# UPDATE title_very_raws  SET nama  = TRIM('account receivable supervisor')  where id = '204'
# UPDATE title_very_raws  SET nama  = TRIM('account representative ')  where id = '205'
# UPDATE title_very_raws  SET nama  = TRIM('account support ')  where id = '206'
# UPDATE title_very_raws  SET nama  = TRIM('account verificator ')  where id = '207'
# UPDATE title_very_raws  SET nama  = TRIM('account')  where id = '208'
# UPDATE title_very_raws  SET nama  = TRIM('accountant')  where id = '209'
# UPDATE title_very_raws  SET nama  = TRIM('accountant  /  human resources development')  where id = '210'
# UPDATE title_very_raws  SET nama  = TRIM('accountant ')  where id = '211'
# UPDATE title_very_raws  SET nama  = TRIM('accountant executive')  where id = '212'
# UPDATE title_very_raws  SET nama  = TRIM('accountant for construction business')  where id = '213'
# UPDATE title_very_raws  SET nama  = TRIM('accountant supervisor')  where id = '214'
# UPDATE title_very_raws  SET nama  = TRIM('accountant /  account executive ')  where id = '215'
# UPDATE title_very_raws  SET nama  = TRIM('accountant, account officer, tax consultant')  where id = '216'
# UPDATE title_very_raws  SET nama  = TRIM('accountant/ bookkeeper staff ')  where id = '217'
# UPDATE title_very_raws  SET nama  = TRIM('accounting')  where id = '218'
# UPDATE title_very_raws  SET nama  = TRIM('accounting')  where id = '219'
# UPDATE title_very_raws  SET nama  = TRIM('accounting  staff')  where id = '220'
# UPDATE title_very_raws  SET nama  = TRIM('accounting ')  where id = '221'
# UPDATE title_very_raws  SET nama  = TRIM('accounting ')  where id = '222'
# UPDATE title_very_raws  SET nama  = TRIM('accounting ')  where id = '223'
# UPDATE title_very_raws  SET nama  = TRIM('accounting ')  where id = '224'
# UPDATE title_very_raws  SET nama  = TRIM('accounting ')  where id = '225'
# UPDATE title_very_raws  SET nama  = TRIM('accounting /  finance supervisor')  where id = '226'
# UPDATE title_very_raws  SET nama  = TRIM('accounting / perpajakan')  where id = '227'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & finance')  where id = '228'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & finance head')  where id = '229'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & finance manager')  where id = '230'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & finance officer')  where id = '231'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & finance staff')  where id = '232'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & finance staff ')  where id = '233'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & finance supervisor')  where id = '234'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & general admin')  where id = '235'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & pajak')  where id = '236'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & pajak spv')  where id = '237'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & regulatory reporting officer')  where id = '238'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & reporting manager')  where id = '239'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax')  where id = '240'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax')  where id = '241'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax – senior staff')  where id = '242'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax asistant manager')  where id = '243'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax assistant manager')  where id = '244'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax consultant staff')  where id = '245'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax leader')  where id = '246'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax manager')  where id = '247'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax officer')  where id = '248'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax officer ')  where id = '249'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax specialist bali')  where id = '250'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax staf')  where id = '251'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax staff')  where id = '252'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax staff')  where id = '253'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax staff ')  where id = '254'
# UPDATE title_very_raws  SET nama  = TRIM('accounting & tax supervisor')  where id = '255'
# UPDATE title_very_raws  SET nama  = TRIM('accounting account receivable supervisor')  where id = '256'
# UPDATE title_very_raws  SET nama  = TRIM('accounting admin')  where id = '257'
# UPDATE title_very_raws  SET nama  = TRIM('accounting administator')  where id = '258'
# UPDATE title_very_raws  SET nama  = TRIM('accounting analyst')  where id = '259'
# UPDATE title_very_raws  SET nama  = TRIM('accounting analyst')  where id = '260'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and administration staff')  where id = '261'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and budget staff')  where id = '262'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and finance manager')  where id = '263'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and finance supervisor/ coordinator')  where id = '264'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and reconciliation staff')  where id = '265'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and tax staff')  where id = '266'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and tax supervisor')  where id = '267'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and tax supervisor')  where id = '268'
# UPDATE title_very_raws  SET nama  = TRIM('accounting and tax supervisor ')  where id = '269'
# UPDATE title_very_raws  SET nama  = TRIM('accounting ass manager')  where id = '270'
# UPDATE title_very_raws  SET nama  = TRIM('accounting asset and tax officer')  where id = '271'
# UPDATE title_very_raws  SET nama  = TRIM('accounting assistant')  where id = '272'
# UPDATE title_very_raws  SET nama  = TRIM('accounting assistant manager')  where id = '273'
# UPDATE title_very_raws  SET nama  = TRIM('accounting audit supervisor')  where id = '274'
# UPDATE title_very_raws  SET nama  = TRIM('accounting budgeting manager mandarin')  where id = '275'
# UPDATE title_very_raws  SET nama  = TRIM('accounting claim')  where id = '276'
# UPDATE title_very_raws  SET nama  = TRIM('accounting consultant')  where id = '277'
# UPDATE title_very_raws  SET nama  = TRIM('accounting dan finance')  where id = '278'
# UPDATE title_very_raws  SET nama  = TRIM('accounting dan finance staff')  where id = '279'
# UPDATE title_very_raws  SET nama  = TRIM('accounting executive')  where id = '280'
# UPDATE title_very_raws  SET nama  = TRIM('accounting executive mandarin speaking')  where id = '281'
# UPDATE title_very_raws  SET nama  = TRIM('accounting finance')  where id = '282'
# UPDATE title_very_raws  SET nama  = TRIM('accounting finance and tax department head')  where id = '283'
# UPDATE title_very_raws  SET nama  = TRIM('accounting finance officer')  where id = '284'
# UPDATE title_very_raws  SET nama  = TRIM('accounting finance site')  where id = '285'
# UPDATE title_very_raws  SET nama  = TRIM('accounting finance staff')  where id = '286'
# UPDATE title_very_raws  SET nama  = TRIM('accounting finance staff')  where id = '287'
# UPDATE title_very_raws  SET nama  = TRIM('accounting finance supervisor')  where id = '288'
# UPDATE title_very_raws  SET nama  = TRIM('accounting general ledger staff ')  where id = '289'
# UPDATE title_very_raws  SET nama  = TRIM('accounting head')  where id = '290'
# UPDATE title_very_raws  SET nama  = TRIM('accounting intern ')  where id = '291'
# UPDATE title_very_raws  SET nama  = TRIM('accounting inventory')  where id = '292'
# UPDATE title_very_raws  SET nama  = TRIM('accounting junior manager')  where id = '293'
# UPDATE title_very_raws  SET nama  = TRIM('accounting junior staff')  where id = '294'
# UPDATE title_very_raws  SET nama  = TRIM('accounting manager')  where id = '295'
# UPDATE title_very_raws  SET nama  = TRIM('accounting manager')  where id = '296'
# UPDATE title_very_raws  SET nama  = TRIM('accounting manager ')  where id = '297'
# UPDATE title_very_raws  SET nama  = TRIM('accounting manager ')  where id = '298'
# UPDATE title_very_raws  SET nama  = TRIM('accounting manager freight forwarding')  where id = '299'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer')  where id = '300'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer')  where id = '301'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer ')  where id = '302'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer ')  where id = '303'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer ')  where id = '304'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer ')  where id = '305'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer leader')  where id = '306'
# UPDATE title_very_raws  SET nama  = TRIM('accounting officer trucking company')  where id = '307'
# UPDATE title_very_raws  SET nama  = TRIM('accounting pajak')  where id = '308'
# UPDATE title_very_raws  SET nama  = TRIM('accounting project')  where id = '309'
# UPDATE title_very_raws  SET nama  = TRIM('accounting reporting assistant manager ')  where id = '310'
# UPDATE title_very_raws  SET nama  = TRIM('accounting reporting supervisor')  where id = '311'
# UPDATE title_very_raws  SET nama  = TRIM('accounting representative ')  where id = '312'
# UPDATE title_very_raws  SET nama  = TRIM('accounting revenue & refund flight staff')  where id = '313'
# UPDATE title_very_raws  SET nama  = TRIM('accounting section head')  where id = '314'
# UPDATE title_very_raws  SET nama  = TRIM('accounting senior associate')  where id = '315'
# UPDATE title_very_raws  SET nama  = TRIM('accounting senior manager')  where id = '316'
# UPDATE title_very_raws  SET nama  = TRIM('accounting senior staff ')  where id = '317'
# UPDATE title_very_raws  SET nama  = TRIM('accounting specialist')  where id = '318'
# UPDATE title_very_raws  SET nama  = TRIM('accounting specialist ')  where id = '319'
# UPDATE title_very_raws  SET nama  = TRIM('accounting sr. supervisor')  where id = '320'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff')  where id = '321'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff')  where id = '322'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff')  where id = '323'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff  "tour and travel"')  where id = '324'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '325'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '326'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '327'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '328'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '329'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '330'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '331'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '332'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '333'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '334'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '335'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '336'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '337'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '338'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '339'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff ')  where id = '340'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff coal mining')  where id = '341'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff dan tax staff')  where id = '342'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff fresh graduate')  where id = '343'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff full time wfo')  where id = '344'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff sbu makasar')  where id = '345'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff semarang bawen')  where id = '346'
# UPDATE title_very_raws  SET nama  = TRIM('accounting staff tangerang')  where id = '347'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor')  where id = '348'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor')  where id = '349'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor ')  where id = '350'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor ')  where id = '351'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor ')  where id = '352'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor ')  where id = '353'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor ')  where id = '354'
# UPDATE title_very_raws  SET nama  = TRIM('accounting supervisor medan')  where id = '355'
# UPDATE title_very_raws  SET nama  = TRIM('accounting support ')  where id = '356'
# UPDATE title_very_raws  SET nama  = TRIM('accounting tax')  where id = '357'
# UPDATE title_very_raws  SET nama  = TRIM('accounting tax')  where id = '358'
# UPDATE title_very_raws  SET nama  = TRIM('accounting tax manager')  where id = '359'
# UPDATE title_very_raws  SET nama  = TRIM('accounting tax senior')  where id = '360'
# UPDATE title_very_raws  SET nama  = TRIM('accounting tax senior staff')  where id = '361'
# UPDATE title_very_raws  SET nama  = TRIM('accounting tax staff')  where id = '362'
# UPDATE title_very_raws  SET nama  = TRIM('accounting tax supervisor')  where id = '363'
# UPDATE title_very_raws  SET nama  = TRIM('accounting, admin kredit, dan account officer')  where id = '364'
# UPDATE title_very_raws  SET nama  = TRIM('accounting, costing & inventory')  where id = '365'
# UPDATE title_very_raws  SET nama  = TRIM('accounting, finance & tax staff')  where id = '366'
# UPDATE title_very_raws  SET nama  = TRIM('accounting, tax & finance supervisor')  where id = '367'
# UPDATE title_very_raws  SET nama  = TRIM('accounting&finance supervisor/  财务主管')  where id = '368'
# UPDATE title_very_raws  SET nama  = TRIM('accounts & tax executive')  where id = '369'
# UPDATE title_very_raws  SET nama  = TRIM('accounts admin')  where id = '370'
# UPDATE title_very_raws  SET nama  = TRIM('accounts assistant')  where id = '371'
# UPDATE title_very_raws  SET nama  = TRIM('accounts executive')  where id = '372'
# UPDATE title_very_raws  SET nama  = TRIM('accounts officer')  where id = '373'
# UPDATE title_very_raws  SET nama  = TRIM('accouting & tax staff')  where id = '374'
# UPDATE title_very_raws  SET nama  = TRIM('accreditation staff')  where id = '375'
# UPDATE title_very_raws  SET nama  = TRIM('acount executive sales marketing mini market & corporate retailer')  where id = '376'
# UPDATE title_very_raws  SET nama  = TRIM('acquiring operation engineer')  where id = '377'
# UPDATE title_very_raws  SET nama  = TRIM('acquisition supervisor')  where id = '378'
# UPDATE title_very_raws  SET nama  = TRIM('activation supervisor')  where id = '379'
# UPDATE title_very_raws  SET nama  = TRIM('actuarial intern')  where id = '380'
# UPDATE title_very_raws  SET nama  = TRIM('actuary assistant manager')  where id = '381'
# UPDATE title_very_raws  SET nama  = TRIM('actuary staff')  where id = '382'
# UPDATE title_very_raws  SET nama  = TRIM('ad ops vcbl')  where id = '383'
# UPDATE title_very_raws  SET nama  = TRIM('adm accounting')  where id = '384'
# UPDATE title_very_raws  SET nama  = TRIM('adm. logistik')  where id = '385'
# UPDATE title_very_raws  SET nama  = TRIM('admin')  where id = '386'
# UPDATE title_very_raws  SET nama  = TRIM('admin')  where id = '387'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '388'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '389'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '390'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '391'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '392'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '393'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '394'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '395'
# UPDATE title_very_raws  SET nama  = TRIM('admin ')  where id = '396'
# UPDATE title_very_raws  SET nama  = TRIM('admin & accounting')  where id = '397'
# UPDATE title_very_raws  SET nama  = TRIM('admin & accounting staff')  where id = '398'
# UPDATE title_very_raws  SET nama  = TRIM('admin & cashier')  where id = '399'
# UPDATE title_very_raws  SET nama  = TRIM('admin & finance')  where id = '400'
# UPDATE title_very_raws  SET nama  = TRIM('admin & sales counter kudus')  where id = '401'
# UPDATE title_very_raws  SET nama  = TRIM('admin & sekretaris')  where id = '402'
# UPDATE title_very_raws  SET nama  = TRIM('admin account')  where id = '403'
# UPDATE title_very_raws  SET nama  = TRIM('admin account  auction staff')  where id = '404'
# UPDATE title_very_raws  SET nama  = TRIM('admin account receivable')  where id = '405'
# UPDATE title_very_raws  SET nama  = TRIM('admin account receivable officer')  where id = '406'
# UPDATE title_very_raws  SET nama  = TRIM('admin accountant ')  where id = '407'
# UPDATE title_very_raws  SET nama  = TRIM('admin accounting')  where id = '408'
# UPDATE title_very_raws  SET nama  = TRIM('admin accounting ')  where id = '409'
# UPDATE title_very_raws  SET nama  = TRIM('admin accounting ')  where id = '410'
# UPDATE title_very_raws  SET nama  = TRIM('admin analyst')  where id = '411'
# UPDATE title_very_raws  SET nama  = TRIM('admin ar ')  where id = '412'
# UPDATE title_very_raws  SET nama  = TRIM('admin area ')  where id = '413'
# UPDATE title_very_raws  SET nama  = TRIM('admin area medan')  where id = '414'
# UPDATE title_very_raws  SET nama  = TRIM('admin assistant')  where id = '415'
# UPDATE title_very_raws  SET nama  = TRIM('admin auditor')  where id = '416'
# UPDATE title_very_raws  SET nama  = TRIM('admin bahasa mandarin')  where id = '417'
# UPDATE title_very_raws  SET nama  = TRIM('admin bekasi')  where id = '418'
# UPDATE title_very_raws  SET nama  = TRIM('admin brand marketing')  where id = '419'
# UPDATE title_very_raws  SET nama  = TRIM('admin cathlab')  where id = '420'
# UPDATE title_very_raws  SET nama  = TRIM('admin cdgr')  where id = '421'
# UPDATE title_very_raws  SET nama  = TRIM('admin collection')  where id = '422'
# UPDATE title_very_raws  SET nama  = TRIM('admin coordinator ')  where id = '423'
# UPDATE title_very_raws  SET nama  = TRIM('admin cum kasir')  where id = '424'
# UPDATE title_very_raws  SET nama  = TRIM('admin cum receptionist')  where id = '425'
# UPDATE title_very_raws  SET nama  = TRIM('admin customer service –  sea freight export')  where id = '426'
# UPDATE title_very_raws  SET nama  = TRIM('admin customer service ')  where id = '427'
# UPDATE title_very_raws  SET nama  = TRIM('admin customer service import/ export staff surabaya ')  where id = '428'
# UPDATE title_very_raws  SET nama  = TRIM('admin dan checker gudang ')  where id = '429'
# UPDATE title_very_raws  SET nama  = TRIM('admin dan customer service executive')  where id = '430'
# UPDATE title_very_raws  SET nama  = TRIM('admin data')  where id = '431'
# UPDATE title_very_raws  SET nama  = TRIM('admin data analis')  where id = '432'
# UPDATE title_very_raws  SET nama  = TRIM('admin data analyst')  where id = '433'
# UPDATE title_very_raws  SET nama  = TRIM('admin data entry')  where id = '434'
# UPDATE title_very_raws  SET nama  = TRIM('admin dispatch')  where id = '435'
# UPDATE title_very_raws  SET nama  = TRIM('admin distribusi ')  where id = '436'
# UPDATE title_very_raws  SET nama  = TRIM('admin divisi market')  where id = '437'
# UPDATE title_very_raws  SET nama  = TRIM('admin ecommerce')  where id = '438'
# UPDATE title_very_raws  SET nama  = TRIM('admin e')  where id = '439'
# UPDATE title_very_raws  SET nama  = TRIM('admin e')  where id = '440'
# UPDATE title_very_raws  SET nama  = TRIM('admin e')  where id = '441'
# UPDATE title_very_raws  SET nama  = TRIM('admin e')  where id = '442'
# UPDATE title_very_raws  SET nama  = TRIM('admin ecommerce  /  ecommerce manager')  where id = '443'
# UPDATE title_very_raws  SET nama  = TRIM('admin executive anodizing department')  where id = '444'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance')  where id = '445'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance')  where id = '446'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance ')  where id = '447'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance ')  where id = '448'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance ')  where id = '449'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance & accounting')  where id = '450'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance & accounting ')  where id = '451'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance & after sales ')  where id = '452'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance accounting')  where id = '453'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance and accounting')  where id = '454'
# UPDATE title_very_raws  SET nama  = TRIM('admin finance, accounting dan pajak')  where id = '455'
# UPDATE title_very_raws  SET nama  = TRIM('admin finish goods and delivery')  where id = '456'
# UPDATE title_very_raws  SET nama  = TRIM('admin freelance')  where id = '457'
# UPDATE title_very_raws  SET nama  = TRIM('admin general affair data center ')  where id = '458'
# UPDATE title_very_raws  SET nama  = TRIM('admin general affairs ')  where id = '459'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang')  where id = '460'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang')  where id = '461'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang')  where id = '462'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang')  where id = '463'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang ')  where id = '464'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang ')  where id = '465'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang ')  where id = '466'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang ')  where id = '467'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang ')  where id = '468'
# UPDATE title_very_raws  SET nama  = TRIM('admin gudang farmasi')  where id = '469'
# UPDATE title_very_raws  SET nama  = TRIM('admin head ')  where id = '470'
# UPDATE title_very_raws  SET nama  = TRIM('admin head accounting')  where id = '471'
# UPDATE title_very_raws  SET nama  = TRIM('admin human resources')  where id = '472'
# UPDATE title_very_raws  SET nama  = TRIM('admin human resources ')  where id = '473'
# UPDATE title_very_raws  SET nama  = TRIM('admin human resources development')  where id = '474'
# UPDATE title_very_raws  SET nama  = TRIM('admin human resources development')  where id = '475'
# UPDATE title_very_raws  SET nama  = TRIM('admin human resources development & general affairs bogor')  where id = '476'
# UPDATE title_very_raws  SET nama  = TRIM('admin human resources development ga')  where id = '477'
# UPDATE title_very_raws  SET nama  = TRIM('admin human resources generalist')  where id = '478'
# UPDATE title_very_raws  SET nama  = TRIM('admin import')  where id = '479'
# UPDATE title_very_raws  SET nama  = TRIM('admin import ')  where id = '480'
# UPDATE title_very_raws  SET nama  = TRIM('admin import staff')  where id = '481'
# UPDATE title_very_raws  SET nama  = TRIM('admin intern')  where id = '482'
# UPDATE title_very_raws  SET nama  = TRIM('admin internal marketing')  where id = '483'
# UPDATE title_very_raws  SET nama  = TRIM('admin inventory')  where id = '484'
# UPDATE title_very_raws  SET nama  = TRIM('admin inventory control')  where id = '485'
# UPDATE title_very_raws  SET nama  = TRIM('admin invoice')  where id = '486'
# UPDATE title_very_raws  SET nama  = TRIM('admin invoice ')  where id = '487'
# UPDATE title_very_raws  SET nama  = TRIM('admin invoice staff')  where id = '488'
# UPDATE title_very_raws  SET nama  = TRIM('admin invoicing')  where id = '489'
# UPDATE title_very_raws  SET nama  = TRIM('admin kantor')  where id = '490'
# UPDATE title_very_raws  SET nama  = TRIM('admin kantor / online / gudang')  where id = '491'
# UPDATE title_very_raws  SET nama  = TRIM('admin kasir')  where id = '492'
# UPDATE title_very_raws  SET nama  = TRIM('admin kepabeanan')  where id = '493'
# UPDATE title_very_raws  SET nama  = TRIM('admin keuangan')  where id = '494'
# UPDATE title_very_raws  SET nama  = TRIM('admin lab')  where id = '495'
# UPDATE title_very_raws  SET nama  = TRIM('admin last mile / linehaul')  where id = '496'
# UPDATE title_very_raws  SET nama  = TRIM('admin leasing ')  where id = '497'
# UPDATE title_very_raws  SET nama  = TRIM('admin legal ')  where id = '498'
# UPDATE title_very_raws  SET nama  = TRIM('admin live streaming')  where id = '499'
# UPDATE title_very_raws  SET nama  = TRIM('admin logistik')  where id = '500'
# UPDATE title_very_raws  SET nama  = TRIM('admin logistik')  where id = '501'
# UPDATE title_very_raws  SET nama  = TRIM('admin logistik')  where id = '502'
# UPDATE title_very_raws  SET nama  = TRIM('admin lpse ')  where id = '503'
# UPDATE title_very_raws  SET nama  = TRIM('admin mandarin')  where id = '504'
# UPDATE title_very_raws  SET nama  = TRIM('admin mandarin staff')  where id = '505'
# UPDATE title_very_raws  SET nama  = TRIM('admin marine')  where id = '506'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing')  where id = '507'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing')  where id = '508'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing')  where id = '509'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing ')  where id = '510'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing ')  where id = '511'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing online marketplace')  where id = '512'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing sales ')  where id = '513'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing sales ')  where id = '514'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketing support')  where id = '515'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketplace')  where id = '516'
# UPDATE title_very_raws  SET nama  = TRIM('admin marketplace')  where id = '517'
# UPDATE title_very_raws  SET nama  = TRIM('admin material control ftth')  where id = '518'
# UPDATE title_very_raws  SET nama  = TRIM('admin md grocery')  where id = '519'
# UPDATE title_very_raws  SET nama  = TRIM('admin media online')  where id = '520'
# UPDATE title_very_raws  SET nama  = TRIM('admin media sosial dan online promotion')  where id = '521'
# UPDATE title_very_raws  SET nama  = TRIM('admin merchandiser')  where id = '522'
# UPDATE title_very_raws  SET nama  = TRIM('admin mine engineer')  where id = '523'
# UPDATE title_very_raws  SET nama  = TRIM('admin officer ')  where id = '524'
# UPDATE title_very_raws  SET nama  = TRIM('admin online')  where id = '525'
# UPDATE title_very_raws  SET nama  = TRIM('admin online')  where id = '526'
# UPDATE title_very_raws  SET nama  = TRIM('admin online')  where id = '527'
# UPDATE title_very_raws  SET nama  = TRIM('admin online & retail')  where id = '528'
# UPDATE title_very_raws  SET nama  = TRIM('admin online & staff toko')  where id = '529'
# UPDATE title_very_raws  SET nama  = TRIM('admin online marketplace')  where id = '530'
# UPDATE title_very_raws  SET nama  = TRIM('admin online shop')  where id = '531'
# UPDATE title_very_raws  SET nama  = TRIM('admin online shop ')  where id = '532'
# UPDATE title_very_raws  SET nama  = TRIM('admin online shop ')  where id = '533'
# UPDATE title_very_raws  SET nama  = TRIM('admin online shop ')  where id = '534'
# UPDATE title_very_raws  SET nama  = TRIM('admin online shop ')  where id = '535'
# UPDATE title_very_raws  SET nama  = TRIM('admin online shop dan live streaming')  where id = '536'
# UPDATE title_very_raws  SET nama  = TRIM('admin online store')  where id = '537'
# UPDATE title_very_raws  SET nama  = TRIM('admin operasional')  where id = '538'
# UPDATE title_very_raws  SET nama  = TRIM('admin operasional manado')  where id = '539'
# UPDATE title_very_raws  SET nama  = TRIM('admin operation ')  where id = '540'
# UPDATE title_very_raws  SET nama  = TRIM('admin operation ')  where id = '541'
# UPDATE title_very_raws  SET nama  = TRIM('admin operation staff')  where id = '542'
# UPDATE title_very_raws  SET nama  = TRIM('admin operation staff ')  where id = '543'
# ...
# UPDATE title_very_raws  SET nama  = TRIM('wakil kepala gudang ')  where id = '13314'
# UPDATE title_very_raws  SET nama  = TRIM('wakil kepala teknik')  where id = '13315'
# UPDATE title_very_raws  SET nama  = TRIM('wakil koordinator pdi ')  where id = '13316'
# UPDATE title_very_raws  SET nama  = TRIM('wakil ktt ')  where id = '13317'
# UPDATE title_very_raws  SET nama  = TRIM('wakil penjaminan emisi efek dan wakil perantara pedagang efek ojk')  where id = '13318'
# UPDATE title_very_raws  SET nama  = TRIM('wakil team leader reminder')  where id = '13319'
# UPDATE title_very_raws  SET nama  = TRIM('wali asrama / pembina asrama')  where id = '13320'
# UPDATE title_very_raws  SET nama  = TRIM('walk in interview medical representative jakarta')  where id = '13321'
# UPDATE title_very_raws  SET nama  = TRIM('walk in interview medical representative semarang')  where id = '13322'
# UPDATE title_very_raws  SET nama  = TRIM('walk in interview medical representative yogyakarta')  where id = '13323'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse')  where id = '13324'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse ')  where id = '13325'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse ')  where id = '13326'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse & delivery supervisor')  where id = '13327'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse & distribution')  where id = '13328'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse & fulfillment operations ')  where id = '13329'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse & logistic manager')  where id = '13330'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse & logistic manager ')  where id = '13331'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse & logistic supervisor')  where id = '13332'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse & transportation supervisor')  where id = '13333'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse admin')  where id = '13334'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse admin')  where id = '13335'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse admin ')  where id = '13336'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse admin ')  where id = '13337'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse admin karawang ')  where id = '13338'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse admin staff')  where id = '13339'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse administration staff ')  where id = '13340'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse administrator ')  where id = '13341'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse analyst')  where id = '13342'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse and fulfillment ops')  where id = '13343'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse assistant manager ')  where id = '13344'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse associate manager')  where id = '13345'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse associate /  staff gudang')  where id = '13346'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse checker')  where id = '13347'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse coordinator ')  where id = '13348'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse crew')  where id = '13349'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse dan inventory controller')  where id = '13350'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse executive')  where id = '13351'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse foreman')  where id = '13352'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse foreman')  where id = '13353'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse head')  where id = '13354'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse indoor staff')  where id = '13355'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse inventory control')  where id = '13356'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse leader')  where id = '13357'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse leader ')  where id = '13358'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse logistics staff')  where id = '13359'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse maintenance staff ')  where id = '13360'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse manager')  where id = '13361'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse manager')  where id = '13362'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse manager ')  where id = '13363'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse manager ')  where id = '13364'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse material auditor')  where id = '13365'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse officer')  where id = '13366'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse officer cum translator')  where id = '13367'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse officer /  petugas gudang')  where id = '13368'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse operator')  where id = '13369'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse operator')  where id = '13370'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse production planning & inventory control')  where id = '13371'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse section head ')  where id = '13372'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse spv')  where id = '13373'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse staff')  where id = '13374'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse staff for heavy equipment & material handling companys')  where id = '13375'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse staff medan')  where id = '13376'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse stafff')  where id = '13377'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse stafff ')  where id = '13378'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse stafff ')  where id = '13379'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse stafff ')  where id = '13380'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor')  where id = '13381'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor')  where id = '13382'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor')  where id = '13383'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor ')  where id = '13384'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor ')  where id = '13385'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor ')  where id = '13386'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor ')  where id = '13387'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor ')  where id = '13388'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor ')  where id = '13389'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor cabang gresik ')  where id = '13390'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor power distribution and renewable energy')  where id = '13391'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse supervisor&logistics')  where id = '13392'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse team leader ')  where id = '13393'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse team leader ')  where id = '13394'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse technician')  where id = '13395'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse training supervisor')  where id = '13396'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse weight checker')  where id = '13397'
# UPDATE title_very_raws  SET nama  = TRIM('warehouse')  where id = '13398'
# UPDATE title_very_raws  SET nama  = TRIM('wartawan harian kompas')  where id = '13399'
# UPDATE title_very_raws  SET nama  = TRIM('waste water treatment plant manager')  where id = '13400'
# UPDATE title_very_raws  SET nama  = TRIM('water sports / lifeguard')  where id = '13401'
# UPDATE title_very_raws  SET nama  = TRIM('water treatment manager')  where id = '13402'
# UPDATE title_very_raws  SET nama  = TRIM('water treatment plant manager ')  where id = '13403'
# UPDATE title_very_raws  SET nama  = TRIM('water treatment sales engineer ')  where id = '13404'
# UPDATE title_very_raws  SET nama  = TRIM('wealth management program ')  where id = '13405'
# UPDATE title_very_raws  SET nama  = TRIM('web / mobile developer')  where id = '13406'
# UPDATE title_very_raws  SET nama  = TRIM('web & api programmer')  where id = '13407'
# UPDATE title_very_raws  SET nama  = TRIM('web & mobile development specialist')  where id = '13408'
# UPDATE title_very_raws  SET nama  = TRIM('web administrator / admin online')  where id = '13409'
# UPDATE title_very_raws  SET nama  = TRIM('web administrator /  admin online')  where id = '13410'
# UPDATE title_very_raws  SET nama  = TRIM('web and android developer')  where id = '13411'
# UPDATE title_very_raws  SET nama  = TRIM('web designer')  where id = '13412'
# UPDATE title_very_raws  SET nama  = TRIM('web developer')  where id = '13413'
# UPDATE title_very_raws  SET nama  = TRIM('web developer ')  where id = '13414'
# UPDATE title_very_raws  SET nama  = TRIM('web developer ')  where id = '13415'
# UPDATE title_very_raws  SET nama  = TRIM('web developer ')  where id = '13416'
# UPDATE title_very_raws  SET nama  = TRIM('web developer ')  where id = '13417'
# UPDATE title_very_raws  SET nama  = TRIM('web developer & designer ')  where id = '13418'
# UPDATE title_very_raws  SET nama  = TRIM('web developer & seo specialist')  where id = '13419'
# UPDATE title_very_raws  SET nama  = TRIM('web developer intern')  where id = '13420'
# UPDATE title_very_raws  SET nama  = TRIM('web development specialist')  where id = '13421'
# UPDATE title_very_raws  SET nama  = TRIM('web engineer')  where id = '13422'
# UPDATE title_very_raws  SET nama  = TRIM('web front end developer')  where id = '13423'
# UPDATE title_very_raws  SET nama  = TRIM('web progammer ')  where id = '13424'
# UPDATE title_very_raws  SET nama  = TRIM('web programmer')  where id = '13425'
# UPDATE title_very_raws  SET nama  = TRIM('web programmer ')  where id = '13426'
# UPDATE title_very_raws  SET nama  = TRIM('web programmer ')  where id = '13427'
# UPDATE title_very_raws  SET nama  = TRIM('web programmer ')  where id = '13428'
# UPDATE title_very_raws  SET nama  = TRIM('web programmer ')  where id = '13429'
# UPDATE title_very_raws  SET nama  = TRIM('web programmer specialist')  where id = '13430'
# UPDATE title_very_raws  SET nama  = TRIM('web programmer vue js ')  where id = '13431'
# UPDATE title_very_raws  SET nama  = TRIM('web quality assurance')  where id = '13432'
# UPDATE title_very_raws  SET nama  = TRIM('webapp developer intern')  where id = '13433'
# UPDATE title_very_raws  SET nama  = TRIM('webmaster')  where id = '13434'
# UPDATE title_very_raws  SET nama  = TRIM('webmethods developer')  where id = '13435'
# UPDATE title_very_raws  SET nama  = TRIM('website commercial operation supervisor')  where id = '13436'
# UPDATE title_very_raws  SET nama  = TRIM('website design & administrator')  where id = '13437'
# UPDATE title_very_raws  SET nama  = TRIM('website developer')  where id = '13438'
# UPDATE title_very_raws  SET nama  = TRIM('website frontend developer')  where id = '13439'
# UPDATE title_very_raws  SET nama  = TRIM('website technical consultant')  where id = '13440'
# UPDATE title_very_raws  SET nama  = TRIM('webtoon korean translator')  where id = '13441'
# UPDATE title_very_raws  SET nama  = TRIM('webtoon line artist')  where id = '13442'
# UPDATE title_very_raws  SET nama  = TRIM('webtoon typesetter')  where id = '13443'
# UPDATE title_very_raws  SET nama  = TRIM('wedding sales')  where id = '13444'
# UPDATE title_very_raws  SET nama  = TRIM('welder')  where id = '13445'
# UPDATE title_very_raws  SET nama  = TRIM('welder cpvc / pvc')  where id = '13446'
# UPDATE title_very_raws  SET nama  = TRIM('welder operator ')  where id = '13447'
# UPDATE title_very_raws  SET nama  = TRIM('welder')  where id = '13448'
# UPDATE title_very_raws  SET nama  = TRIM('welding inspector')  where id = '13449'
# UPDATE title_very_raws  SET nama  = TRIM('well integrity  /  valve maintenance engineer')  where id = '13450'
# UPDATE title_very_raws  SET nama  = TRIM('wellness business development staff')  where id = '13451'
# UPDATE title_very_raws  SET nama  = TRIM('wellness programmer')  where id = '13452'
# UPDATE title_very_raws  SET nama  = TRIM('wfh ')  where id = '13453'
# UPDATE title_very_raws  SET nama  = TRIM('wfh data analyst')  where id = '13454'
# UPDATE title_very_raws  SET nama  = TRIM('whatsapp operator')  where id = '13455'
# UPDATE title_very_raws  SET nama  = TRIM('wine sommelier')  where id = '13456'
# UPDATE title_very_raws  SET nama  = TRIM('wireless o&m engineer')  where id = '13457'
# UPDATE title_very_raws  SET nama  = TRIM('wood handling plant expert')  where id = '13458'
# UPDATE title_very_raws  SET nama  = TRIM('wordpress developer')  where id = '13459'
# UPDATE title_very_raws  SET nama  = TRIM('wordpress engineer')  where id = '13460'
# UPDATE title_very_raws  SET nama  = TRIM('work force management ')  where id = '13461'
# UPDATE title_very_raws  SET nama  = TRIM('workforce management ')  where id = '13462'
# UPDATE title_very_raws  SET nama  = TRIM('working permit specialist')  where id = '13463'
# UPDATE title_very_raws  SET nama  = TRIM('workshop head')  where id = '13464'
# UPDATE title_very_raws  SET nama  = TRIM('workshop manager')  where id = '13465'
# UPDATE title_very_raws  SET nama  = TRIM('workshop manager /  kepala bengkel')  where id = '13466'
# UPDATE title_very_raws  SET nama  = TRIM('workshop production manager')  where id = '13467'
# UPDATE title_very_raws  SET nama  = TRIM('workshop staff ')  where id = '13468'
# UPDATE title_very_raws  SET nama  = TRIM('workshop supervisor')  where id = '13469'
# UPDATE title_very_raws  SET nama  = TRIM('workshophead')  where id = '13470'
# UPDATE title_very_raws  SET nama  = TRIM('wwtp ')  where id = '13471'
# UPDATE title_very_raws  SET nama  = TRIM('wwtp ')  where id = '13472'
# UPDATE title_very_raws  SET nama  = TRIM('wwtp supervisor')  where id = '13473'
# UPDATE title_very_raws  SET nama  = TRIM('wwtp technician ')  where id = '13474'
# UPDATE title_very_raws  SET nama  = TRIM('yogyakarta city coordinator')  where id = '13475'
# UPDATE title_very_raws  SET nama  = TRIM('youth leadership program ')  where id = '13476'
# UPDATE title_very_raws  SET nama  = TRIM('youtube & tiktok content writer & idea maker')  where id = '13477'
# UPDATE title_very_raws  SET nama  = TRIM('youtube channel specialist')  where id = '13478'
# UPDATE title_very_raws  SET nama  = TRIM('youtube content creator')  where id = '13479'
# UPDATE title_very_raws  SET nama  = TRIM('业务助理 business operation assistant ')  where id = '13480'
# UPDATE title_very_raws  SET nama  = TRIM('文员（会中文）')  where id = '13481'
# UPDATE title_very_raws  SET nama  = TRIM('片区网管 ')  where id = '13482'
# UPDATE title_very_raws  SET nama  = TRIM('现场翻译（ site mandarin translator )')  where id = '13483'
# UPDATE title_very_raws  SET nama  = TRIM('电工片区 electrician staff ')  where id = '13484'
# UPDATE title_very_raws  SET nama  = TRIM('财务行政')  where id = '13485'
# UPDATE title_very_raws  SET nama  = TRIM('采购专员 purchasing staff ')  where id = '13486'
# UPDATE title_very_raws  SET nama  = TRIM('门店文员 ')  where id = '13487'
# done : 13487 row(s)
