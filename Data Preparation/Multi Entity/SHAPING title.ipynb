# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')


# set query 1
select = ' * '
fromdb = 'titles_raws'
where = ' '
group = ' '
# Out:
# connect

# %%
# repairing tittle

where = '  '
orderby = '   '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    word = x[1]  
    
    print(word)   
    
    
    queryx = "UPDATE "+fromdb+" SET first = '" + word[:1] + "',   	nama_length = '" + str(len(word)) + "'   " 
    wherex = "  where id = " + idx + ""  
    print(queryx + wherex)
    mycursor.execute(queryx + wherex)
    mydb.commit()   
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# .Net Core Developer
# UPDATE titles_raws SET first = '.',   	nama_length = '19'     where id = 1
# .Net Developer
# UPDATE titles_raws SET first = '.',   	nama_length = '14'     where id = 2
# .Net Engineer
# UPDATE titles_raws SET first = '.',   	nama_length = '13'     where id = 3
# .Net Programmer
# UPDATE titles_raws SET first = '.',   	nama_length = '15'     where id = 4
# .Net Revenue Management Analyst
# UPDATE titles_raws SET first = '.',   	nama_length = '31'     where id = 5
# 2D / 3D Designer
# UPDATE titles_raws SET first = '2',   	nama_length = '16'     where id = 6
# 3D Artist
# UPDATE titles_raws SET first = '3',   	nama_length = '9'     where id = 7
# 3D Artist / Modeling For GAme
# UPDATE titles_raws SET first = '3',   	nama_length = '29'     where id = 8
# 3D Artist Staff
# UPDATE titles_raws SET first = '3',   	nama_length = '15'     where id = 9
# 3D Designer
# UPDATE titles_raws SET first = '3',   	nama_length = '11'     where id = 10
# 3D Designer Interior
# UPDATE titles_raws SET first = '3',   	nama_length = '20'     where id = 11
# 3D Modeller Architecture
# UPDATE titles_raws SET first = '3',   	nama_length = '24'     where id = 12
# 3D Visualizer
# UPDATE titles_raws SET first = '3',   	nama_length = '13'     where id = 13
# ABAPER
# UPDATE titles_raws SET first = 'A',   	nama_length = '6'     where id = 14
# Academic Specialist Matematika & Fisika
# UPDATE titles_raws SET first = 'A',   	nama_length = '39'     where id = 15
# Academics Coordinator
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 16
# Access Point Engineering & Development
# UPDATE titles_raws SET first = 'A',   	nama_length = '38'     where id = 17
# Accident & Health Flow Underwriter
# UPDATE titles_raws SET first = 'A',   	nama_length = '34'     where id = 18
# Account / Sales Leader
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 19
# Account Assistant
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 20
# Account Director
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 21
# Account Executive
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 22
# Account Executive Associate
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 23
# Account Executive Audio Visual
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 24
# Account Executive Corporate Banking
# UPDATE titles_raws SET first = 'A',   	nama_length = '35'     where id = 25
# Account Executive Creative Agency
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 26
# Account Executive Enterprise
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 27
# Account Executive ERP
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 28
# Account Executive For Interior Design
# UPDATE titles_raws SET first = 'A',   	nama_length = '37'     where id = 29
# Account Executive For Pharmacy Ingredients Business
# UPDATE titles_raws SET first = 'A',   	nama_length = '51'     where id = 30
# Account Executive Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 31
# Account Executive Payment Switching
# UPDATE titles_raws SET first = 'A',   	nama_length = '35'     where id = 32
# Account Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 33
# Account Manager & Sales Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 34
# Account Manager Cbn Cloud
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 35
# Account Manager Corporate
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 36
# Account Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 38
# Account Officer, Remedial & Analis Kredit Perbankan
# UPDATE titles_raws SET first = 'A',   	nama_length = '51'     where id = 39
# Account Payable
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 40
# Account Payable & Account Receivable Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '42'     where id = 41
# Account Payable Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 42
# Account Payable Associate
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 43
# Account Payable Group Leader
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 44
# Account Payable Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 45
# Account Payable Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 46
# Account Payable Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 47
# Account Payable Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 48
# Account Receivable
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 49
# Account Receivable & Billing Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '36'     where id = 50
# Account Receivable Admin
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 51
# Account Receivable Control
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 52
# Account Receivable Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 53
# Account Receivable Section Head
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 54
# Account Receivable Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 55
# Account Receivable Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '29'     where id = 56
# Accountant
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 57
# Accountant Executive
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 59
# Accountant For Construction Business
# UPDATE titles_raws SET first = 'A',   	nama_length = '36'     where id = 60
# Accountant Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 61
# Accountant, Account Officer, Tax Consultant
# UPDATE titles_raws SET first = 'A',   	nama_length = '43'     where id = 62
# Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 63
# Accounting / Finance Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 64
# Accounting / Perpajakan
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 65
# Accounting & Administration Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 66
# Accounting & Budget Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 67
# Accounting & Finance
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 68
# Accounting & Finance Head
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 69
# Accounting & Finance Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 70
# Accounting & Finance Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 71
# Accounting & Finance Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 72
# Accounting & Finance Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 73
# Accounting & General Admin
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 75
# Accounting & Reconciliation Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 76
# Accounting & Regulatory Reporting Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '41'     where id = 77
# Accounting & Reporting Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 78
# Accounting & Tax
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 79
# Accounting & Tax Assistant Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '34'     where id = 81
# Accounting & Tax Consultant Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 82
# Accounting & Tax Leader
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 83
# Accounting & Tax Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 84
# Accounting & Tax Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 85
# Accounting & Tax Senior Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '29'     where id = 86
# Accounting & Tax Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 88
# Accounting & Tax Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 89
# Accounting Account Receivable Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '40'     where id = 90
# Accounting Admin
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 91
# Accounting Administator
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 92
# Accounting Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 93
# Accounting Asset & Tax Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 95
# Accounting Assistant
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 96
# Accounting Assistant Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 97
# Accounting Audit Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 98
# Accounting Budgeting Manager Mandarin
# UPDATE titles_raws SET first = 'A',   	nama_length = '37'     where id = 99
# Accounting Claim
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 100
# Accounting Consultant
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 101
# Accounting Executive
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 102
# Accounting Finance
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 104
# Accounting Finance & Tax Department Head
# UPDATE titles_raws SET first = 'A',   	nama_length = '40'     where id = 105
# Accounting Finance Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 106
# Accounting Finance Site
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 107
# Accounting Finance Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 108
# Accounting Finance Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '29'     where id = 109
# Accounting Head
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 110
# Accounting Inventory
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 111
# Accounting Junior Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 112
# Accounting Junior Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 113
# Accounting Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 114
# Accounting Manager Freight Forwarding
# UPDATE titles_raws SET first = 'A',   	nama_length = '37'     where id = 115
# Accounting Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 116
# Accounting Officer Leader
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 117
# Accounting Officer Trucking Company
# UPDATE titles_raws SET first = 'A',   	nama_length = '35'     where id = 118
# Accounting Project
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 119
# Accounting Reporting Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 120
# Accounting Revenue & Refund Flight Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '40'     where id = 121
# Accounting Section Head
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 122
# Accounting Senior Associate
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 123
# Accounting Senior Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 124
# Accounting Senior Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 125
# Accounting Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 126
# Accounting Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 127
# Accounting Staff & Tax Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 128
# Accounting Staff Fresh Graduate
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 129
# Accounting Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 130
# Accounting Tax
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 131
# Accounting Tax Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 132
# Accounting Tax Senior
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 133
# Accounting Tax Senior Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 134
# Accounting Tax Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 135
# Accounting Tax Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 136
# Accounting, Admin Kredit & Account Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '42'     where id = 137
# Accounting, Costing & Inventory
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 138
# Accounting, Finance & Tax Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 139
# Accounting, Tax & Finance Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '36'     where id = 140
# Accounts & Tax Executive
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 141
# Accounts Admin
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 142
# Accounts Assistant
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 143
# Accounts Executive
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 144
# Accounts Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 145
# Accouting & Tax Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 146
# Accreditation Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 147
# Acount Executive Sales Marketing Mini Market & Corporate Retailer
# UPDATE titles_raws SET first = 'A',   	nama_length = '65'     where id = 148
# Acquiring Operation Engineer
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 149
# Acquisition Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 150
# Activation Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 151
# Actuarial Intern
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 152
# Actuary Assistant Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 153
# Actuary Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 154
# Ad Ops Vcbl
# UPDATE titles_raws SET first = 'A',   	nama_length = '11'     where id = 155
# Admin
# UPDATE titles_raws SET first = 'A',   	nama_length = '5'     where id = 156
# Admin & Accounting Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 157
# Admin & Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 158
# Admin & Cashier
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 159
# Admin & Customer Service Executive
# UPDATE titles_raws SET first = 'A',   	nama_length = '34'     where id = 160
# Admin & Finance
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 161
# Admin & Sales Counter Kudus
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 162
# Admin & Sekretaris
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 163
# Admin Account
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 164
# Admin Account Auction Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 165
# Admin Account Receivable
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 166
# Admin Account Receivable Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '32'     where id = 167
# Admin Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 168
# Admin Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 169
# Admin Assistant
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 170
# Admin Auditor
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 171
# Admin Bahasa Mandarin
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 172
# Admin Brand Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 173
# Admin Cathlab
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 174
# Admin Cdgr
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 175
# Admin Collection
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 176
# Admin Cum Kasir
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 177
# Admin Cum Receptionist
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 178
# Admin Customer Service Sea Freight Export
# UPDATE titles_raws SET first = 'A',   	nama_length = '41'     where id = 179
# Admin Data
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 180
# Admin Data Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 181
# Admin Data Entry
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 182
# Admin Dispatch
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 183
# Admin Divisi Market
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 184
# Admin Ecommerce
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 185
# Ecommerce Manager
# UPDATE titles_raws SET first = 'E',   	nama_length = '17'     where id = 186
# Admin Executive Anodizing Department
# UPDATE titles_raws SET first = 'A',   	nama_length = '36'     where id = 187
# Admin Finance
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 188
# Admin Finance & Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 189
# Admin Finance Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 190
# Admin Finance, Accounting & Tax
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 191
# Admin Finish Goods & Delivery
# UPDATE titles_raws SET first = 'A',   	nama_length = '29'     where id = 192
# Admin Freelance
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 193
# Admin Gudang
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 194
# Admin Gudang Farmasi
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 195
# Admin Head Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 196
# Admin Human Resources
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 197
# Admin Human Resources Generalist
# UPDATE titles_raws SET first = 'A',   	nama_length = '32'     where id = 198
# Admin Human Resources Development
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 199
# Admin Human Resources Development General Affairs
# UPDATE titles_raws SET first = 'A',   	nama_length = '49'     where id = 200
# Admin Import
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 201
# Admin Import Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 202
# Admin Internal Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 203
# Admin Intern
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 204
# Admin Inventory
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 205
# Admin Inventory Control
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 206
# Admin Invoice
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 207
# Admin Invoice Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 208
# Admin Invoicing
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 209
# Admin Kantor
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 210
# Admin Kasir
# UPDATE titles_raws SET first = 'A',   	nama_length = '11'     where id = 212
# Admin Kepabeanan
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 213
# Admin Keuangan
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 214
# Admin Lab
# UPDATE titles_raws SET first = 'A',   	nama_length = '9'     where id = 215
# Admin Live Streaming
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 217
# Admin Logistik
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 218
# Admin Mandarin
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 219
# Admin Mandarin Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 220
# Admin Marine
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 221
# Admin Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 222
# Admin Marketing Online Marketplace
# UPDATE titles_raws SET first = 'A',   	nama_length = '34'     where id = 223
# Admin Marketing Support
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 224
# Admin Marketplace
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 225
# Admin Material Control FTTH
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 226
# Admin Media Online
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 227
# Admin Media Sosial & Online Promotion
# UPDATE titles_raws SET first = 'A',   	nama_length = '37'     where id = 228
# Admin Merchandiser
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 229
# Admin Mine Engineer
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 230
# Admin Online
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 231
# Admin Online & Retail
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 232
# Admin Online & Staff Toko
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 233
# Admin Online Marketplace
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 234
# Admin Online Shop
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 235
# Admin Online Shop & Live Streaming
# UPDATE titles_raws SET first = 'A',   	nama_length = '34'     where id = 236
# Admin Online Store
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 237
# Admin Operasional
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 238
# Admin Operation Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 239
# Admin Operational Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 240
# Admin Outlet
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 241
# Admin Pabrik
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 242
# Admin Pembelian
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 243
# Admin Penjualan
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 245
# Admin Penjualan & Pembelian Export Import
# UPDATE titles_raws SET first = 'A',   	nama_length = '41'     where id = 247
# Admin Perusahaan
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 248
# Admin Piutang
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 249
# Admin Production Planning & Inventory Control
# UPDATE titles_raws SET first = 'A',   	nama_length = '45'     where id = 250
# Admin Procurement
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 251
# Admin Produksi
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 252
# Admin Project
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 254
# Admin Project & Marketing Project
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 255
# Admin Project Site
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 256
# Admin Property
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 257
# Admin Proyek
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 258
# Admin Purchasing
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 259
# Admin Purchasing / Production Planning & Inventory Control
# UPDATE titles_raws SET first = 'A',   	nama_length = '58'     where id = 261
# Admin Purchasing Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 262
# Admin Registrasi Produk & Impor
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 263
# Admin Rekrutmen
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 264
# Admin Sales
# UPDATE titles_raws SET first = 'A',   	nama_length = '11'     where id = 265
# Admin Sales & Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 266
# Admin Sales Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 267
# Admin Sales Online
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 268
# Admin Sales Support
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 269
# Admin SAP
# UPDATE titles_raws SET first = 'A',   	nama_length = '9'     where id = 270
# Admin Sekretaris
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 271
# Admin Senior
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 272
# Admin Settlement
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 273
# Admin Social Media Content Creator Tiktok & Talent Host Livestreamer
# UPDATE titles_raws SET first = 'A',   	nama_length = '68'     where id = 274
# Admin Sosial Media
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 275
# Admin Sparepart
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 277
# Admin Spareparts
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 278
# Admin Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 279
# Admin Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '11'     where id = 280
# Admin Staff Finance Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 281
# Admin Support
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 282
# Admin Support Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 283
# Admin Support Sipil
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 284
# Admin Tax
# UPDATE titles_raws SET first = 'A',   	nama_length = '9'     where id = 285
# Admin Teknisi
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 286
# Admin Telemarketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 287
# Admin Toko
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 288
# Admin Treasury
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 289
# Admin Umum
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 290
# Admin Verification Telephone
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 291
# Admin Warehouse
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 292
# Administrasi
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 293
# Administrasi & Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 294
# Administrasi & Customer Service
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 295
# Administrasi & Logistik
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 296
# Administrasi Customer Service Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '37'     where id = 297
# Administrasi Gudang
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 298
# Administrasi Gudang Material
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 299
# Administrasi Gudang Pusat
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 300
# Administrasi IT
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 301
# Administrasi K3
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 302
# Administrasi Kantor
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 303
# Administrasi Keuangan
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 304
# Administrasi Kontrak
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 305
# Administrasi Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 306
# Administrasi Operasional
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 307
# Administrasi Penjualan
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 308
# Administrasi Produksi
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 309
# Administrasi Proyek
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 310
# Administrasi Purchasing
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 311
# Administrasi Rumah Sakit
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 312
# Administrasi Sales
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 313
# Administrasi Sekretaris
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 314
# Administrasi Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 315
# Administrasi Stock
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 316
# Administrasi Support
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 317
# Administrasi Teknik
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 318
# Administrasi Teknisi
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 319
# Administrasi Umum
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 320
# Administration
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 321
# Administration & Finance Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 322
# Administration Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 323
# Administration Head
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 324
# Administration Intern
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 325
# Administration of Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 326
# Administration Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 327
# Administrative Assistant
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 328
# Administrative Assistant To Chief Representative
# UPDATE titles_raws SET first = 'A',   	nama_length = '48'     where id = 329
# Administrative Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 330
# Administrative Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 331
# Administrator
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 332
# Administrator Contract
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 333
# Administrator Pemasaran
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 334
# Admission Coordinator
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 335
# Admissions & Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 336
# Advertisement Specialist Digital Marketing
# UPDATE titles_raws SET first = 'A',   	nama_length = '42'     where id = 337
# Advertising & Promotion Property
# UPDATE titles_raws SET first = 'A',   	nama_length = '32'     where id = 338
# Advertising Lead
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 339
# Advisory Associate
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 340
# Advocate
# UPDATE titles_raws SET first = 'A',   	nama_length = '8'     where id = 341
# Aesthetic Dokter
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 342
# Aesthetics Dokter
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 343
# After Sales & Technical Support
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 344
# After Sales Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 345
# After Sales Service / Field Engineer
# UPDATE titles_raws SET first = 'A',   	nama_length = '36'     where id = 346
# Aftersales Promotion
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 347
# Agency Development Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 348
# Agency Marketing Support Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '32'     where id = 349
# Agent Desk Collection
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 350
# Agent Property
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 351
# Agricultural Advisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 352
# Agricultural Technical Lead
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 353
# Agriculture Engineer
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 354
# Agronomy Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 355
# Ahli Bubut / Tukang Bubut Mesin
# UPDATE titles_raws SET first = 'A',   	nama_length = '31'     where id = 356
# Ahli Gizi
# UPDATE titles_raws SET first = 'A',   	nama_length = '9'     where id = 357
# Ahli K3 Konstruksi
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 358
# Ai Operation
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 359
# Airport Office Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 360
# Ajudan Asisten Pimpinan
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 361
# Akademik & Program
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 362
# Akuntan
# UPDATE titles_raws SET first = 'A',   	nama_length = '7'     where id = 363
# Analis / Operator Instrumen Research and Development
# UPDATE titles_raws SET first = 'A',   	nama_length = '52'     where id = 364
# Analis Agronomi
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 365
# Analis Kimia
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 366
# Analis Kredit BPR
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 367
# Analis Laboratorium
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 368
# Analis Laboratorium Kimia
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 369
# Analisis Kredit
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 370
# Analyst Collection
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 371
# Analyst Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 372
# Analytical Development Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 373
# Android & Web Developer
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 374
# Android Developer
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 375
# Android Developer For Edc
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 376
# Android Developer Intern
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 377
# Android Developer Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 378
# Android Mobile Developer
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 379
# Android Programmer
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 380
# Angular Developer
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 381
# Angular Support Engineer
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 382
# Animal Health
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 383
# Animator
# UPDATE titles_raws SET first = 'A',   	nama_length = '8'     where id = 384
# Animator 2D & Motion Graphic
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 385
# Annual Report Writer
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 386
# Anti-fraud Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 387
# Anti-fraud Process & Qa Junior Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '41'     where id = 388
# Anti-fraud Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 389
# Ap Finance
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 390
# Apical Engineer Trainee
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 391
# Apotek Partnership Associate
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 392
# Apoteker
# UPDATE titles_raws SET first = 'A',   	nama_length = '8'     where id = 393
# Apoteker Telemedicine
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 394
# App Operations Assistant Indonesia
# UPDATE titles_raws SET first = 'A',   	nama_length = '34'     where id = 395
# Application Consultant
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 396
# Application Development
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 397
# Application Engineer
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 398
# Application Project Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 399
# Application Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 400
# Application Specialist Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 401
# Application Support
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 402
# Application Support Analyst
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 403
# Application Support Cum Developer
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 404
# Application Support Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 405
# Application System Architecturee Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '40'     where id = 406
# Application Systems Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 407
# Applied Art & Fine Art Teacher / Coach
# UPDATE titles_raws SET first = 'A',   	nama_length = '38'     where id = 408
# Appraisal Support
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 409
# Apu Ppt Monitoring & Reporting Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '36'     where id = 410
# Apu Ppt Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 411
# Ar Admin
# UPDATE titles_raws SET first = 'A',   	nama_length = '8'     where id = 412
# Ar Cinema Validation & Head Office Reconciliation Support Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '63'     where id = 413
# Ar Collection
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 414
# Ar Follow Up Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 415
# Ar Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '8'     where id = 416
# Architect
# UPDATE titles_raws SET first = 'A',   	nama_length = '9'     where id = 418
# Architect For Building Management
# UPDATE titles_raws SET first = 'A',   	nama_length = '33'     where id = 419
# Architectureal Drafter
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 420
# Architect
# UPDATE titles_raws SET first = 'A',   	nama_length = '9'     where id = 421
# Architect Desain Interior
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 422
# Art & Graphics Designer
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 423
# Art Designer
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 424
# Art Director
# UPDATE titles_raws SET first = 'A',   	nama_length = '12'     where id = 425
# Art Teacher
# UPDATE titles_raws SET first = 'A',   	nama_length = '11'     where id = 426
# Asessment Engineer, Utilities / Kiln
# UPDATE titles_raws SET first = 'A',   	nama_length = '36'     where id = 427
# Assistant Manager Warehouse
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 428
# Asistant Manager Finance Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '35'     where id = 429
# Asistant Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 430
# Asisten Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 431
# Asisten Agronomi
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 432
# Asisten Apoteker
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 433
# Asisten Bengkel
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 434
# Asisten Dokter
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 435
# Asisten Ehs
# UPDATE titles_raws SET first = 'A',   	nama_length = '11'     where id = 436
# Asisten Elektrik
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 437
# Asisten Gm
# UPDATE titles_raws SET first = 'A',   	nama_length = '10'     where id = 438
# Asisten Instruktur Konsultan Programming
# UPDATE titles_raws SET first = 'A',   	nama_length = '40'     where id = 439
# Asisten Kebun
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 440
# Asisten Kebun Karet
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 441
# Asisten Kebun Kelapa Sawit
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 442
# Asisten Kepala
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 443
# Asisten Lapangan
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 444
# Asisten Maintenance Pabrik Kelapa Sawit
# UPDATE titles_raws SET first = 'A',   	nama_length = '39'     where id = 445
# Asisten Manager Human Resources Development
# UPDATE titles_raws SET first = 'A',   	nama_length = '43'     where id = 446
# Asisten Manager Operation & Maintenance FTTH
# UPDATE titles_raws SET first = 'A',   	nama_length = '44'     where id = 447
# Asisten Manager Produksi
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 448
# Asisten Manager Purchasing
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 449
# Asisten Manajer Editorial Buku
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 450
# Asisten Manajer Hukum
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 451
# Asisten Mechanic
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 452
# Asisten Notaris
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 453
# Asisten Pribadi
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 454
# Asisten Quality Assurance
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 455
# Asisten Quality Control Agronomi
# UPDATE titles_raws SET first = 'A',   	nama_length = '32'     where id = 456
# Asisten Sales Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 457
# Asisten Sipil
# UPDATE titles_raws SET first = 'A',   	nama_length = '13'     where id = 458
# Asisten Surveyor Gis
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 459
# Asisten Teknik Kebun
# UPDATE titles_raws SET first = 'A',   	nama_length = '20'     where id = 460
# Asisten Teknisi Pendingin
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 461
# Asisten Traksi
# UPDATE titles_raws SET first = 'A',   	nama_length = '14'     where id = 462
# Asisten Transport
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 463
# Assistant Manager Hse
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 464
# Assistant Manager Pga
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 465
# Asp .Net Programmer
# UPDATE titles_raws SET first = 'A',   	nama_length = '19'     where id = 466
# Assembling Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 467
# Assembly Shop Specialist
# UPDATE titles_raws SET first = 'A',   	nama_length = '24'     where id = 468
# Assessment & Development Officer
# UPDATE titles_raws SET first = 'A',   	nama_length = '32'     where id = 469
# Assessment Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '18'     where id = 470
# Assessment Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '16'     where id = 471
# Assessor
# UPDATE titles_raws SET first = 'A',   	nama_length = '8'     where id = 472
# Asset Liquidity Management
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 473
# Asset Management Senior Supervisor
# UPDATE titles_raws SET first = 'A',   	nama_length = '34'     where id = 474
# Asset Management Staff
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 475
# Asset Recovery Collection
# UPDATE titles_raws SET first = 'A',   	nama_length = '25'     where id = 476
# Assistant Gudang & Logistik
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 477
# Assistant Leader Store
# UPDATE titles_raws SET first = 'A',   	nama_length = '22'     where id = 478
# Assistant Manager Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 479
# Assistant Manager of Polyester
# UPDATE titles_raws SET first = 'A',   	nama_length = '30'     where id = 480
# Assistant Manager Risk Management & Compliance
# UPDATE titles_raws SET first = 'A',   	nama_length = '46'     where id = 481
# Assistant To Director
# UPDATE titles_raws SET first = 'A',   	nama_length = '21'     where id = 482
# Assistant President Director
# UPDATE titles_raws SET first = 'A',   	nama_length = '28'     where id = 483
# Assistant Product Owner
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 484
# Assistant Admin Accounting
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 485
# Assistant Auditor
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 486
# Assistant Brand
# UPDATE titles_raws SET first = 'A',   	nama_length = '15'     where id = 487
# Assistant Brand Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '23'     where id = 488
# Assistant Business Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 489
# Assistant Category Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '26'     where id = 490
# Assistant Chemist
# UPDATE titles_raws SET first = 'A',   	nama_length = '17'     where id = 491
# Assistant Chief Engineering
# UPDATE titles_raws SET first = 'A',   	nama_length = '27'     where id = 492
# Assistant Communications Manager
# UPDATE titles_raws SET first = 'A',   	nama_length = '32'     where id = 493
# Assistant Controller
# ...
# User Acquisition Staff
# UPDATE titles_raws SET first = 'U',   	nama_length = '22'     where id = 6931
# User Research
# UPDATE titles_raws SET first = 'U',   	nama_length = '13'     where id = 6932
# Utility & Environmental Manager
# UPDATE titles_raws SET first = 'U',   	nama_length = '31'     where id = 6933
# Utility Foreman
# UPDATE titles_raws SET first = 'U',   	nama_length = '15'     where id = 6934
# Utility Manager
# UPDATE titles_raws SET first = 'U',   	nama_length = '15'     where id = 6935
# Utility Operator
# UPDATE titles_raws SET first = 'U',   	nama_length = '16'     where id = 6936
# Utility Staff
# UPDATE titles_raws SET first = 'U',   	nama_length = '13'     where id = 6937
# Utility Supervisor
# UPDATE titles_raws SET first = 'U',   	nama_length = '18'     where id = 6938
# Ux / Ui Designer
# UPDATE titles_raws SET first = 'U',   	nama_length = '16'     where id = 6939
# Ux / Ui Officer
# UPDATE titles_raws SET first = 'U',   	nama_length = '15'     where id = 6940
# Ux Design Manager
# UPDATE titles_raws SET first = 'U',   	nama_length = '17'     where id = 6941
# Ux Designer
# UPDATE titles_raws SET first = 'U',   	nama_length = '11'     where id = 6942
# Ux Quality Assurance
# UPDATE titles_raws SET first = 'U',   	nama_length = '20'     where id = 6943
# Ux Researcher
# UPDATE titles_raws SET first = 'U',   	nama_length = '13'     where id = 6944
# Ux Researcher Senior
# UPDATE titles_raws SET first = 'U',   	nama_length = '20'     where id = 6945
# Ux Writer
# UPDATE titles_raws SET first = 'U',   	nama_length = '9'     where id = 6946
# Validasi Qualification Analyst
# UPDATE titles_raws SET first = 'V',   	nama_length = '30'     where id = 6947
# Validation Transaction Associate
# UPDATE titles_raws SET first = 'V',   	nama_length = '32'     where id = 6948
# Vehicle Logistic Operator
# UPDATE titles_raws SET first = 'V',   	nama_length = '25'     where id = 6949
# Vendor Acquisition Staff
# UPDATE titles_raws SET first = 'V',   	nama_length = '24'     where id = 6950
# Vendor Management Analyst
# UPDATE titles_raws SET first = 'V',   	nama_length = '25'     where id = 6951
# Vendor Management Staff
# UPDATE titles_raws SET first = 'V',   	nama_length = '23'     where id = 6952
# Vendor Qa Senior Staff
# UPDATE titles_raws SET first = 'V',   	nama_length = '22'     where id = 6953
# Vessel Insurance Staff
# UPDATE titles_raws SET first = 'V',   	nama_length = '22'     where id = 6954
# Vessel Monitoring Group Leader
# UPDATE titles_raws SET first = 'V',   	nama_length = '30'     where id = 6955
# Vessel Operation & Logistic Staff
# UPDATE titles_raws SET first = 'V',   	nama_length = '33'     where id = 6956
# Veterinary
# UPDATE titles_raws SET first = 'V',   	nama_length = '10'     where id = 6957
# Video Animator
# UPDATE titles_raws SET first = 'V',   	nama_length = '14'     where id = 6958
# Video Content Creator
# UPDATE titles_raws SET first = 'V',   	nama_length = '21'     where id = 6959
# Video Creator
# UPDATE titles_raws SET first = 'V',   	nama_length = '13'     where id = 6960
# Video Editor
# UPDATE titles_raws SET first = 'V',   	nama_length = '12'     where id = 6961
# Video Editor & Content Creator
# UPDATE titles_raws SET first = 'V',   	nama_length = '30'     where id = 6962
# Video Editor & Design Graphis
# UPDATE titles_raws SET first = 'V',   	nama_length = '29'     where id = 6963
# Video Editor & Graphic Designer
# UPDATE titles_raws SET first = 'V',   	nama_length = '31'     where id = 6964
# Video Editor & Videografer
# UPDATE titles_raws SET first = 'V',   	nama_length = '26'     where id = 6965
# Video Editor Intern
# UPDATE titles_raws SET first = 'V',   	nama_length = '19'     where id = 6966
# Video Editor Specialist
# UPDATE titles_raws SET first = 'V',   	nama_length = '23'     where id = 6967
# Video Editor Staff
# UPDATE titles_raws SET first = 'V',   	nama_length = '18'     where id = 6968
# Videografer
# UPDATE titles_raws SET first = 'V',   	nama_length = '11'     where id = 6969
# Videographer
# UPDATE titles_raws SET first = 'V',   	nama_length = '12'     where id = 6970
# Videographer / Photographer
# UPDATE titles_raws SET first = 'V',   	nama_length = '27'     where id = 6971
# Videographer / Video Editor
# UPDATE titles_raws SET first = 'V',   	nama_length = '27'     where id = 6972
# Videographer & Editor
# UPDATE titles_raws SET first = 'V',   	nama_length = '21'     where id = 6973
# Videographer & Photographer
# UPDATE titles_raws SET first = 'V',   	nama_length = '27'     where id = 6974
# Videographer & Photographer Staff
# UPDATE titles_raws SET first = 'V',   	nama_length = '33'     where id = 6975
# Videographer Officer
# UPDATE titles_raws SET first = 'V',   	nama_length = '20'     where id = 6976
# Videographer Photographer
# UPDATE titles_raws SET first = 'V',   	nama_length = '25'     where id = 6977
# Videographer Senior Officer
# UPDATE titles_raws SET first = 'V',   	nama_length = '27'     where id = 6978
# Videographer Tiktok
# UPDATE titles_raws SET first = 'V',   	nama_length = '19'     where id = 6979
# Vip Service & Product Development Manager
# UPDATE titles_raws SET first = 'V',   	nama_length = '41'     where id = 6980
# Visual & Graphic Design
# UPDATE titles_raws SET first = 'V',   	nama_length = '23'     where id = 6981
# Visual Art & Design Teacher
# UPDATE titles_raws SET first = 'V',   	nama_length = '27'     where id = 6982
# Visual Comunication Designer
# UPDATE titles_raws SET first = 'V',   	nama_length = '28'     where id = 6983
# Visual Merchandiser
# UPDATE titles_raws SET first = 'V',   	nama_length = '19'     where id = 6984
# Visual Merchandiser Officer
# UPDATE titles_raws SET first = 'V',   	nama_length = '27'     where id = 6985
# Visual Merchandising Officer
# UPDATE titles_raws SET first = 'V',   	nama_length = '28'     where id = 6986
# Vp Marketing & Customer Experience
# UPDATE titles_raws SET first = 'V',   	nama_length = '34'     where id = 6987
# Vp of Sales
# UPDATE titles_raws SET first = 'V',   	nama_length = '11'     where id = 6988
# Vp Operation
# UPDATE titles_raws SET first = 'V',   	nama_length = '12'     where id = 6989
# Vulnerability Assessment
# UPDATE titles_raws SET first = 'V',   	nama_length = '24'     where id = 6990
# Waitress
# UPDATE titles_raws SET first = 'W',   	nama_length = '8'     where id = 6995
# Waitress Cashier Barista
# UPDATE titles_raws SET first = 'W',   	nama_length = '24'     where id = 6999
# Waitress Helper
# UPDATE titles_raws SET first = 'W',   	nama_length = '15'     where id = 7000
# Waitress Restoran & Bar
# UPDATE titles_raws SET first = 'W',   	nama_length = '23'     where id = 7001
# Waitress Waitress Server Barista Bar
# UPDATE titles_raws SET first = 'W',   	nama_length = '36'     where id = 7002
# Wakil Kepala Gudang
# UPDATE titles_raws SET first = 'W',   	nama_length = '19'     where id = 7004
# Wakil Kepala Teknik
# UPDATE titles_raws SET first = 'W',   	nama_length = '19'     where id = 7005
# Wakil Penjaminan Emisi Efek & Wakil Perantara Pedagang Efek Ojk
# UPDATE titles_raws SET first = 'W',   	nama_length = '63'     where id = 7006
# Wali Asrama
# UPDATE titles_raws SET first = 'W',   	nama_length = '11'     where id = 7007
# Warehouse & Delivery Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '31'     where id = 7009
# Warehouse & Distribution
# UPDATE titles_raws SET first = 'W',   	nama_length = '24'     where id = 7010
# Warehouse & Fulfillment Ops
# UPDATE titles_raws SET first = 'W',   	nama_length = '27'     where id = 7011
# Warehouse & Inventory Controller
# UPDATE titles_raws SET first = 'W',   	nama_length = '32'     where id = 7012
# Warehouse & Logistic Manager
# UPDATE titles_raws SET first = 'W',   	nama_length = '28'     where id = 7013
# Warehouse & Logistic Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '31'     where id = 7014
# Warehouse & Transportation Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '37'     where id = 7015
# Warehouse Admin
# UPDATE titles_raws SET first = 'W',   	nama_length = '15'     where id = 7016
# Warehouse Admin Staff
# UPDATE titles_raws SET first = 'W',   	nama_length = '21'     where id = 7017
# Warehouse Analyst
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7018
# Staff Gudang
# UPDATE titles_raws SET first = 'S',   	nama_length = '12'     where id = 7019
# Warehouse Associate Manager
# UPDATE titles_raws SET first = 'W',   	nama_length = '27'     where id = 7020
# Warehouse Checker
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7021
# Warehouse Crew
# UPDATE titles_raws SET first = 'W',   	nama_length = '14'     where id = 7022
# Warehouse Executive
# UPDATE titles_raws SET first = 'W',   	nama_length = '19'     where id = 7023
# Warehouse Foreman
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7024
# Warehouse Head
# UPDATE titles_raws SET first = 'W',   	nama_length = '14'     where id = 7025
# Warehouse Indoor Staff
# UPDATE titles_raws SET first = 'W',   	nama_length = '22'     where id = 7026
# Warehouse Inventory Control
# UPDATE titles_raws SET first = 'W',   	nama_length = '27'     where id = 7027
# Warehouse Leader
# UPDATE titles_raws SET first = 'W',   	nama_length = '16'     where id = 7028
# Warehouse Logistics Staff
# UPDATE titles_raws SET first = 'W',   	nama_length = '25'     where id = 7029
# Warehouse Manager
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7030
# Warehouse Material Auditor
# UPDATE titles_raws SET first = 'W',   	nama_length = '26'     where id = 7031
# Warehouse Officer
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7032
# Warehouse Officer / Petugas Gudang
# UPDATE titles_raws SET first = 'W',   	nama_length = '34'     where id = 7033
# Warehouse Officer Cum Translator
# UPDATE titles_raws SET first = 'W',   	nama_length = '32'     where id = 7034
# Warehouse Operator
# UPDATE titles_raws SET first = 'W',   	nama_length = '18'     where id = 7035
# Warehouse Production Planning & Inventory Control
# UPDATE titles_raws SET first = 'W',   	nama_length = '49'     where id = 7036
# Warehouse Staff
# UPDATE titles_raws SET first = 'W',   	nama_length = '15'     where id = 7037
# Warehouse Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '20'     where id = 7038
# Warehouse Supervisor & Logistics
# UPDATE titles_raws SET first = 'W',   	nama_length = '32'     where id = 7039
# Warehouse Supervisor Power Distribution & Renewable Energy
# UPDATE titles_raws SET first = 'W',   	nama_length = '58'     where id = 7040
# Warehouse Technician
# UPDATE titles_raws SET first = 'W',   	nama_length = '20'     where id = 7041
# Warehouse Training Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '29'     where id = 7042
# Warehouse Weight Checker
# UPDATE titles_raws SET first = 'W',   	nama_length = '24'     where id = 7043
# Wartawan Harian
# UPDATE titles_raws SET first = 'W',   	nama_length = '15'     where id = 7044
# Waste Water Treatment Plant Manager
# UPDATE titles_raws SET first = 'W',   	nama_length = '35'     where id = 7045
# Water Sports / Lifeguard
# UPDATE titles_raws SET first = 'W',   	nama_length = '24'     where id = 7046
# Water Treatment Manager
# UPDATE titles_raws SET first = 'W',   	nama_length = '23'     where id = 7047
# Web / Mobile Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '22'     where id = 7048
# Web & Android Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '23'     where id = 7049
# Web & Api Programmer
# UPDATE titles_raws SET first = 'W',   	nama_length = '20'     where id = 7050
# Web & Mobile Development Specialist
# UPDATE titles_raws SET first = 'W',   	nama_length = '35'     where id = 7051
# Web Administrator
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7053
# Web Designer
# UPDATE titles_raws SET first = 'W',   	nama_length = '12'     where id = 7054
# Web Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '13'     where id = 7055
# Web Developer & Seo Specialist
# UPDATE titles_raws SET first = 'W',   	nama_length = '30'     where id = 7056
# Web Developer Intern
# UPDATE titles_raws SET first = 'W',   	nama_length = '20'     where id = 7057
# Web Development Specialist
# UPDATE titles_raws SET first = 'W',   	nama_length = '26'     where id = 7058
# Web Engineer
# UPDATE titles_raws SET first = 'W',   	nama_length = '12'     where id = 7059
# Web Front End Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '23'     where id = 7060
# Web Programmer
# UPDATE titles_raws SET first = 'W',   	nama_length = '14'     where id = 7061
# Web Programmer Specialist
# UPDATE titles_raws SET first = 'W',   	nama_length = '25'     where id = 7062
# Web Quality Assurance
# UPDATE titles_raws SET first = 'W',   	nama_length = '21'     where id = 7063
# Webapp Developer Intern
# UPDATE titles_raws SET first = 'W',   	nama_length = '23'     where id = 7064
# Webmaster
# UPDATE titles_raws SET first = 'W',   	nama_length = '9'     where id = 7065
# Webmethods Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '20'     where id = 7066
# Website Commercial Operation Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '39'     where id = 7067
# Website Design & Administrator
# UPDATE titles_raws SET first = 'W',   	nama_length = '30'     where id = 7068
# Website Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7069
# Website Front End Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '27'     where id = 7070
# Website Technical Consultant
# UPDATE titles_raws SET first = 'W',   	nama_length = '28'     where id = 7071
# Webtoon Korean Translator
# UPDATE titles_raws SET first = 'W',   	nama_length = '25'     where id = 7072
# Webtoon Line Artist
# UPDATE titles_raws SET first = 'W',   	nama_length = '19'     where id = 7073
# Webtoon Typesetter
# UPDATE titles_raws SET first = 'W',   	nama_length = '18'     where id = 7074
# Wedding Sales
# UPDATE titles_raws SET first = 'W',   	nama_length = '13'     where id = 7075
# Welder
# UPDATE titles_raws SET first = 'W',   	nama_length = '6'     where id = 7076
# Welder Cpvc / Pvc
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7077
# Welding Inspector
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7078
# Well Integrity / Valve Maintenance Engineer
# UPDATE titles_raws SET first = 'W',   	nama_length = '43'     where id = 7079
# Wellness Business Development Staff
# UPDATE titles_raws SET first = 'W',   	nama_length = '35'     where id = 7080
# Wellness Programmer
# UPDATE titles_raws SET first = 'W',   	nama_length = '19'     where id = 7081
# Whatsapp Operator
# UPDATE titles_raws SET first = 'W',   	nama_length = '17'     where id = 7082
# Wine Sommelier
# UPDATE titles_raws SET first = 'W',   	nama_length = '14'     where id = 7083
# Wireless O&M Engineer
# UPDATE titles_raws SET first = 'W',   	nama_length = '21'     where id = 7084
# Wood Handling Plant Expert
# UPDATE titles_raws SET first = 'W',   	nama_length = '26'     where id = 7085
# Wordpress Developer
# UPDATE titles_raws SET first = 'W',   	nama_length = '19'     where id = 7086
# Wordpress Engineer
# UPDATE titles_raws SET first = 'W',   	nama_length = '18'     where id = 7087
# Working Permit Specialist
# UPDATE titles_raws SET first = 'W',   	nama_length = '25'     where id = 7088
# Workshop Head
# UPDATE titles_raws SET first = 'W',   	nama_length = '13'     where id = 7089
# Workshop Manager
# UPDATE titles_raws SET first = 'W',   	nama_length = '16'     where id = 7090
# Workshop Production Manager
# UPDATE titles_raws SET first = 'W',   	nama_length = '27'     where id = 7092
# Workshop Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '19'     where id = 7093
# Workshophead
# UPDATE titles_raws SET first = 'W',   	nama_length = '12'     where id = 7094
# Wwtp Supervisor
# UPDATE titles_raws SET first = 'W',   	nama_length = '15'     where id = 7095
# Youtube & Tiktok Content Writer & Idea Maker
# UPDATE titles_raws SET first = 'Y',   	nama_length = '44'     where id = 7096
# Youtube Channel Specialist
# UPDATE titles_raws SET first = 'Y',   	nama_length = '26'     where id = 7097
# Youtube Content Creator
# UPDATE titles_raws SET first = 'Y',   	nama_length = '23'     where id = 7098
# done : 7018 row(s)
