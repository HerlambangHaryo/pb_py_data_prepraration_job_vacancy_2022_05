# %%
# Connect to DB

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')


# set query 1
select = ' * '
fromdb = 'titles_raws'
where = ' '
group = ' '
# Out:
# connect

# %%
# repairing tittle

where = '  '
orderby = ' order by nama ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0]) 
    word = x[1]  
    
    print(word)   
    
    queryy = "Select nama From titles Where nama like '"+word+"' "
    print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()

    queryy_len = len(myresultc)
    print(queryy_len)

    if(queryy_len == 0):        
        queryx = "INSERT INTO titles (nama) VALUES ('"+word+"')"
        mycursor.execute(queryx)
        mydb.commit()   
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# .Net Core Developer
# Select nama From titles Where nama like '.Net Core Developer'
# 0
# .Net Developer
# Select nama From titles Where nama like '.Net Developer'
# 0
# .Net Developer
# Select nama From titles Where nama like '.Net Developer'
# 1
# .Net Engineer
# Select nama From titles Where nama like '.Net Engineer'
# 0
# .Net Programmer
# Select nama From titles Where nama like '.Net Programmer'
# 0
# .Net Revenue Management Analyst
# Select nama From titles Where nama like '.Net Revenue Management Analyst'
# 0
# 2D / 3D Designer
# Select nama From titles Where nama like '2D / 3D Designer'
# 0
# 3D Artist
# Select nama From titles Where nama like '3D Artist'
# 0
# 3D Artist / Modeling For GAme
# Select nama From titles Where nama like '3D Artist / Modeling For GAme'
# 0
# 3D Artist Staff
# Select nama From titles Where nama like '3D Artist Staff'
# 0
# 3D Designer
# Select nama From titles Where nama like '3D Designer'
# 0
# 3D Designer Interior
# Select nama From titles Where nama like '3D Designer Interior'
# 0
# 3D Modeller Arsitektur
# Select nama From titles Where nama like '3D Modeller Arsitektur'
# 0
# 3D Visualizer
# Select nama From titles Where nama like '3D Visualizer'
# 0
# Abaper
# Select nama From titles Where nama like 'Abaper'
# 0
# Academic Specialist Matematika & Fisika
# Select nama From titles Where nama like 'Academic Specialist Matematika & Fisika'
# 0
# Academics Coordinator
# Select nama From titles Where nama like 'Academics Coordinator'
# 0
# Access Point Engineering & Development
# Select nama From titles Where nama like 'Access Point Engineering & Development'
# 0
# Accident & Health Flow Underwriter
# Select nama From titles Where nama like 'Accident & Health Flow Underwriter'
# 0
# Account / Sales Leader
# Select nama From titles Where nama like 'Account / Sales Leader'
# 0
# Account Assistant
# Select nama From titles Where nama like 'Account Assistant'
# 0
# Account Director
# Select nama From titles Where nama like 'Account Director'
# 0
# Account Executive
# Select nama From titles Where nama like 'Account Executive'
# 0
# Account Executive Associate
# Select nama From titles Where nama like 'Account Executive Associate'
# 0
# Account Executive Audio Visual
# Select nama From titles Where nama like 'Account Executive Audio Visual'
# 0
# Account Executive Corporate Banking
# Select nama From titles Where nama like 'Account Executive Corporate Banking'
# 0
# Account Executive Creative Agency GAram
# Select nama From titles Where nama like 'Account Executive Creative Agency GAram'
# 0
# Account Executive Enterprise
# Select nama From titles Where nama like 'Account Executive Enterprise'
# 0
# Account Executive Erp
# Select nama From titles Where nama like 'Account Executive Erp'
# 0
# Account Executive For Interior Design
# Select nama From titles Where nama like 'Account Executive For Interior Design'
# 0
# Account Executive For Pharmacy Ingredients Business
# Select nama From titles Where nama like 'Account Executive For Pharmacy Ingredients Business'
# 0
# Account Executive Marketing
# Select nama From titles Where nama like 'Account Executive Marketing'
# 0
# Account Executive Payment Switching
# Select nama From titles Where nama like 'Account Executive Payment Switching'
# 0
# Account Manager
# Select nama From titles Where nama like 'Account Manager'
# 0
# Account Manager & Sales Manager
# Select nama From titles Where nama like 'Account Manager & Sales Manager'
# 0
# Account Manager Cbn Cloud
# Select nama From titles Where nama like 'Account Manager Cbn Cloud'
# 0
# Account Manager Corporate
# Select nama From titles Where nama like 'Account Manager Corporate'
# 0
# Account Manager For Fsi
# Select nama From titles Where nama like 'Account Manager For Fsi'
# 0
# Account Officer
# Select nama From titles Where nama like 'Account Officer'
# 0
# Account Officer, Remedial & Analis Kredit Perbankan
# Select nama From titles Where nama like 'Account Officer, Remedial & Analis Kredit Perbankan'
# 0
# Account Payable
# Select nama From titles Where nama like 'Account Payable'
# 0
# Account Payable & Account Receivable Staff
# Select nama From titles Where nama like 'Account Payable & Account Receivable Staff'
# 0
# Account Payable Analyst
# Select nama From titles Where nama like 'Account Payable Analyst'
# 0
# Account Payable Associate
# Select nama From titles Where nama like 'Account Payable Associate'
# 0
# Account Payable Group Leader
# Select nama From titles Where nama like 'Account Payable Group Leader'
# 0
# Account Payable Officer
# Select nama From titles Where nama like 'Account Payable Officer'
# 0
# Account Payable Specialist
# Select nama From titles Where nama like 'Account Payable Specialist'
# 0
# Account Payable Staff
# Select nama From titles Where nama like 'Account Payable Staff'
# 0
# Account Payable Supervisor
# Select nama From titles Where nama like 'Account Payable Supervisor'
# 0
# Account Receivable
# Select nama From titles Where nama like 'Account Receivable'
# 0
# Account Receivable & Billing Analyst
# Select nama From titles Where nama like 'Account Receivable & Billing Analyst'
# 0
# Account Receivable Admin
# Select nama From titles Where nama like 'Account Receivable Admin'
# 0
# Account Receivable Control
# Select nama From titles Where nama like 'Account Receivable Control'
# 0
# Account Receivable Officer
# Select nama From titles Where nama like 'Account Receivable Officer'
# 0
# Account Receivable Section Head
# Select nama From titles Where nama like 'Account Receivable Section Head'
# 0
# Account Receivable Staff
# Select nama From titles Where nama like 'Account Receivable Staff'
# 0
# Account Receivable Supervisor
# Select nama From titles Where nama like 'Account Receivable Supervisor'
# 0
# Accountant
# Select nama From titles Where nama like 'Accountant'
# 0
# Accountant / HRd
# Select nama From titles Where nama like 'Accountant / HRd'
# 0
# Accountant Executive
# Select nama From titles Where nama like 'Accountant Executive'
# 0
# Accountant For Construction Business
# Select nama From titles Where nama like 'Accountant For Construction Business'
# 0
# Accountant Supervisor
# Select nama From titles Where nama like 'Accountant Supervisor'
# 0
# Accountant, Account Officer, Tax Consultant
# Select nama From titles Where nama like 'Accountant, Account Officer, Tax Consultant'
# 0
# Accounting
# Select nama From titles Where nama like 'Accounting'
# 0
# Accounting / Finance Supervisor
# Select nama From titles Where nama like 'Accounting / Finance Supervisor'
# 0
# Accounting / Perpajakan
# Select nama From titles Where nama like 'Accounting / Perpajakan'
# 0
# Accounting & Administration Staff
# Select nama From titles Where nama like 'Accounting & Administration Staff'
# 0
# Accounting & Budget Staff
# Select nama From titles Where nama like 'Accounting & Budget Staff'
# 0
# Accounting & Finance
# Select nama From titles Where nama like 'Accounting & Finance'
# 0
# Accounting & Finance Head
# Select nama From titles Where nama like 'Accounting & Finance Head'
# 0
# Accounting & Finance Manager
# Select nama From titles Where nama like 'Accounting & Finance Manager'
# 0
# Accounting & Finance Officer
# Select nama From titles Where nama like 'Accounting & Finance Officer'
# 0
# Accounting & Finance Staff
# Select nama From titles Where nama like 'Accounting & Finance Staff'
# 0
# Accounting & Finance Supervisor
# Select nama From titles Where nama like 'Accounting & Finance Supervisor'
# 0
# Accounting & Finance Supervisor
# Select nama From titles Where nama like 'Accounting & Finance Supervisor'
# 1
# Accounting & Finance Supervisor / Coordinator
# Select nama From titles Where nama like 'Accounting & Finance Supervisor / Coordinator'
# 0
# Accounting & General Admin
# Select nama From titles Where nama like 'Accounting & General Admin'
# 0
# Accounting & Reconciliation Staff
# Select nama From titles Where nama like 'Accounting & Reconciliation Staff'
# 0
# Accounting & Regulatory Reporting Officer
# Select nama From titles Where nama like 'Accounting & Regulatory Reporting Officer'
# 0
# Accounting & Reporting Manager
# Select nama From titles Where nama like 'Accounting & Reporting Manager'
# 0
# Accounting & Tax
# Select nama From titles Where nama like 'Accounting & Tax'
# 0
# Accounting & Tax Asistant Manager
# Select nama From titles Where nama like 'Accounting & Tax Asistant Manager'
# 0
# Accounting & Tax Assistant Manager
# Select nama From titles Where nama like 'Accounting & Tax Assistant Manager'
# 0
# Accounting & Tax Consultant Staff
# Select nama From titles Where nama like 'Accounting & Tax Consultant Staff'
# 0
# Accounting & Tax Leader
# Select nama From titles Where nama like 'Accounting & Tax Leader'
# 0
# Accounting & Tax Manager
# Select nama From titles Where nama like 'Accounting & Tax Manager'
# 0
# Accounting & Tax Officer
# Select nama From titles Where nama like 'Accounting & Tax Officer'
# 0
# Accounting & Tax Senior Staff
# Select nama From titles Where nama like 'Accounting & Tax Senior Staff'
# 0
# Accounting & Tax Staf
# Select nama From titles Where nama like 'Accounting & Tax Staf'
# 0
# Accounting & Tax Staff
# Select nama From titles Where nama like 'Accounting & Tax Staff'
# 0
# Accounting & Tax Supervisor
# Select nama From titles Where nama like 'Accounting & Tax Supervisor'
# 0
# Accounting Account Receivable Supervisor
# Select nama From titles Where nama like 'Accounting Account Receivable Supervisor'
# 0
# Accounting Admin
# Select nama From titles Where nama like 'Accounting Admin'
# 0
# Accounting Administator
# Select nama From titles Where nama like 'Accounting Administator'
# 0
# Accounting Analyst
# Select nama From titles Where nama like 'Accounting Analyst'
# 0
# Accounting Ass Manager
# Select nama From titles Where nama like 'Accounting Ass Manager'
# 0
# Accounting Asset & Tax Officer
# Select nama From titles Where nama like 'Accounting Asset & Tax Officer'
# 0
# Accounting Assistant
# Select nama From titles Where nama like 'Accounting Assistant'
# 0
# Accounting Assistant Manager
# Select nama From titles Where nama like 'Accounting Assistant Manager'
# 0
# Accounting Audit Supervisor
# Select nama From titles Where nama like 'Accounting Audit Supervisor'
# 0
# Accounting Budgeting Manager Mandarin
# Select nama From titles Where nama like 'Accounting Budgeting Manager Mandarin'
# 0
# Accounting Claim
# Select nama From titles Where nama like 'Accounting Claim'
# 0
# Accounting Consultant
# Select nama From titles Where nama like 'Accounting Consultant'
# 0
# Accounting Executive
# Select nama From titles Where nama like 'Accounting Executive'
# 0
# Accounting Executive Mandarin Speaking
# Select nama From titles Where nama like 'Accounting Executive Mandarin Speaking'
# 0
# Accounting Finance
# Select nama From titles Where nama like 'Accounting Finance'
# 0
# Accounting Finance & Tax Department Head
# Select nama From titles Where nama like 'Accounting Finance & Tax Department Head'
# 0
# Accounting Finance Officer
# Select nama From titles Where nama like 'Accounting Finance Officer'
# 0
# Accounting Finance Site
# Select nama From titles Where nama like 'Accounting Finance Site'
# 0
# Accounting Finance Staff
# Select nama From titles Where nama like 'Accounting Finance Staff'
# 0
# Accounting Finance Supervisor
# Select nama From titles Where nama like 'Accounting Finance Supervisor'
# 0
# Accounting Head
# Select nama From titles Where nama like 'Accounting Head'
# 0
# Accounting Inventory
# Select nama From titles Where nama like 'Accounting Inventory'
# 0
# Accounting Junior Manager
# Select nama From titles Where nama like 'Accounting Junior Manager'
# 0
# Accounting Junior Staff
# Select nama From titles Where nama like 'Accounting Junior Staff'
# 0
# Accounting Manager
# Select nama From titles Where nama like 'Accounting Manager'
# 0
# Accounting Manager Freight Forwarding
# Select nama From titles Where nama like 'Accounting Manager Freight Forwarding'
# 0
# Accounting Officer
# Select nama From titles Where nama like 'Accounting Officer'
# 0
# Accounting Officer Leader
# Select nama From titles Where nama like 'Accounting Officer Leader'
# 0
# Accounting Officer Trucking Company
# Select nama From titles Where nama like 'Accounting Officer Trucking Company'
# 0
# Accounting Project
# Select nama From titles Where nama like 'Accounting Project'
# 0
# Accounting Reporting Supervisor
# Select nama From titles Where nama like 'Accounting Reporting Supervisor'
# 0
# Accounting Revenue & Refund Flight Staff
# Select nama From titles Where nama like 'Accounting Revenue & Refund Flight Staff'
# 0
# Accounting Section Head
# Select nama From titles Where nama like 'Accounting Section Head'
# 0
# Accounting Senior Associate
# Select nama From titles Where nama like 'Accounting Senior Associate'
# 0
# Accounting Senior Manager
# Select nama From titles Where nama like 'Accounting Senior Manager'
# 0
# Accounting Senior Supervisor
# Select nama From titles Where nama like 'Accounting Senior Supervisor'
# 0
# Accounting Specialist
# Select nama From titles Where nama like 'Accounting Specialist'
# 0
# Accounting Staff
# Select nama From titles Where nama like 'Accounting Staff'
# 0
# Accounting Staff & Tax Staff
# Select nama From titles Where nama like 'Accounting Staff & Tax Staff'
# 0
# Accounting Staff Fresh Graduate
# Select nama From titles Where nama like 'Accounting Staff Fresh Graduate'
# 0
# Accounting Supervisor
# Select nama From titles Where nama like 'Accounting Supervisor'
# 0
# Accounting Tax
# Select nama From titles Where nama like 'Accounting Tax'
# 0
# Accounting Tax Manager
# Select nama From titles Where nama like 'Accounting Tax Manager'
# 0
# Accounting Tax Senior
# Select nama From titles Where nama like 'Accounting Tax Senior'
# 0
# Accounting Tax Senior Staff
# Select nama From titles Where nama like 'Accounting Tax Senior Staff'
# 0
# Accounting Tax Staff
# Select nama From titles Where nama like 'Accounting Tax Staff'
# 0
# Accounting Tax Supervisor
# Select nama From titles Where nama like 'Accounting Tax Supervisor'
# 0
# Accounting, Admin Kredit & Account Officer
# Select nama From titles Where nama like 'Accounting, Admin Kredit & Account Officer'
# 0
# Accounting, Costing & Inventory
# Select nama From titles Where nama like 'Accounting, Costing & Inventory'
# 0
# Accounting, Finance & Tax Staff
# Select nama From titles Where nama like 'Accounting, Finance & Tax Staff'
# 0
# Accounting, Tax & Finance Supervisor
# Select nama From titles Where nama like 'Accounting, Tax & Finance Supervisor'
# 0
# Accounts & Tax Executive
# Select nama From titles Where nama like 'Accounts & Tax Executive'
# 0
# Accounts Admin
# Select nama From titles Where nama like 'Accounts Admin'
# 0
# Accounts Assistant
# Select nama From titles Where nama like 'Accounts Assistant'
# 0
# Accounts Executive
# Select nama From titles Where nama like 'Accounts Executive'
# 0
# Accounts Officer
# Select nama From titles Where nama like 'Accounts Officer'
# 0
# Accouting & Tax Staff
# Select nama From titles Where nama like 'Accouting & Tax Staff'
# 0
# Accreditation Staff
# Select nama From titles Where nama like 'Accreditation Staff'
# 0
# Acount Executive Sales Marketing Mini Market & Corporate Retailer
# Select nama From titles Where nama like 'Acount Executive Sales Marketing Mini Market & Corporate Retailer'
# 0
# Acquiring Operation Engineer
# Select nama From titles Where nama like 'Acquiring Operation Engineer'
# 0
# Acquisition Supervisor
# Select nama From titles Where nama like 'Acquisition Supervisor'
# 0
# Activation Supervisor
# Select nama From titles Where nama like 'Activation Supervisor'
# 0
# Actuarial Internship
# Select nama From titles Where nama like 'Actuarial Internship'
# 0
# Actuary Assistant Manager
# Select nama From titles Where nama like 'Actuary Assistant Manager'
# 0
# Actuary Staff
# Select nama From titles Where nama like 'Actuary Staff'
# 0
# Ad Ops Vcbl
# Select nama From titles Where nama like 'Ad Ops Vcbl'
# 0
# Admin
# Select nama From titles Where nama like 'Admin'
# 0
# Admin & Accounting Staff
# Select nama From titles Where nama like 'Admin & Accounting Staff'
# 0
# Admin & Acounting
# Select nama From titles Where nama like 'Admin & Acounting'
# 0
# Admin & Cashier
# Select nama From titles Where nama like 'Admin & Cashier'
# 0
# Admin & Customer Service Executive
# Select nama From titles Where nama like 'Admin & Customer Service Executive'
# 0
# Admin & Finance
# Select nama From titles Where nama like 'Admin & Finance'
# 0
# Admin & Sales Counter Kudus
# Select nama From titles Where nama like 'Admin & Sales Counter Kudus'
# 0
# Admin & Sekretaris
# Select nama From titles Where nama like 'Admin & Sekretaris'
# 0
# Admin Account
# Select nama From titles Where nama like 'Admin Account'
# 0
# Admin Account Auction Staff
# Select nama From titles Where nama like 'Admin Account Auction Staff'
# 0
# Admin Account Receivable
# Select nama From titles Where nama like 'Admin Account Receivable'
# 0
# Admin Account Receivable Officer
# Select nama From titles Where nama like 'Admin Account Receivable Officer'
# 0
# Admin Accounting
# Select nama From titles Where nama like 'Admin Accounting'
# 0
# Admin Analyst
# Select nama From titles Where nama like 'Admin Analyst'
# 0
# Admin Assistant
# Select nama From titles Where nama like 'Admin Assistant'
# 0
# Admin Auditor
# Select nama From titles Where nama like 'Admin Auditor'
# 0
# Admin Bahasa Mandarin
# Select nama From titles Where nama like 'Admin Bahasa Mandarin'
# 0
# Admin Brand Marketing
# Select nama From titles Where nama like 'Admin Brand Marketing'
# 0
# Admin Cathlab
# Select nama From titles Where nama like 'Admin Cathlab'
# 0
# Admin Cdgr
# Select nama From titles Where nama like 'Admin Cdgr'
# 0
# Admin Collection
# Select nama From titles Where nama like 'Admin Collection'
# 0
# Admin Cum Kasir
# Select nama From titles Where nama like 'Admin Cum Kasir'
# 0
# Admin Cum Receptionist
# Select nama From titles Where nama like 'Admin Cum Receptionist'
# 0
# Admin Customer Service Sea Freight Export
# Select nama From titles Where nama like 'Admin Customer Service Sea Freight Export'
# 0
# Admin Data
# Select nama From titles Where nama like 'Admin Data'
# 0
# Admin Data Analyst
# Select nama From titles Where nama like 'Admin Data Analyst'
# 0
# Admin Data Entry
# Select nama From titles Where nama like 'Admin Data Entry'
# 0
# Admin Dispatch
# Select nama From titles Where nama like 'Admin Dispatch'
# 0
# Admin Divisi Market
# Select nama From titles Where nama like 'Admin Divisi Market'
# 0
# Admin Ecommerce
# Select nama From titles Where nama like 'Admin Ecommerce'
# 0
# Admin Ecommerce / Ecommerce Manager
# Select nama From titles Where nama like 'Admin Ecommerce / Ecommerce Manager'
# 0
# Admin Executive Anodizing Department
# Select nama From titles Where nama like 'Admin Executive Anodizing Department'
# 0
# Admin Finance
# Select nama From titles Where nama like 'Admin Finance'
# 0
# Admin Finance & Accounting
# Select nama From titles Where nama like 'Admin Finance & Accounting'
# 0
# Admin Finance Accounting
# Select nama From titles Where nama like 'Admin Finance Accounting'
# 0
# Admin Finance, Accounting & Tax
# Select nama From titles Where nama like 'Admin Finance, Accounting & Tax'
# 0
# Admin Finish Goods & Delivery
# Select nama From titles Where nama like 'Admin Finish Goods & Delivery'
# 0
# Admin Freelance
# Select nama From titles Where nama like 'Admin Freelance'
# 0
# Admin Gudang
# Select nama From titles Where nama like 'Admin Gudang'
# 0
# Admin Gudang Farmasi
# Select nama From titles Where nama like 'Admin Gudang Farmasi'
# 0
# Admin Head Accounting
# Select nama From titles Where nama like 'Admin Head Accounting'
# 0
# Admin HR
# Select nama From titles Where nama like 'Admin HR'
# 0
# Admin HR Generalist
# Select nama From titles Where nama like 'Admin HR Generalist'
# 0
# Admin HRd
# Select nama From titles Where nama like 'Admin HRd'
# 0
# Admin HRd GA
# Select nama From titles Where nama like 'Admin HRd GA'
# 0
# Admin Import
# Select nama From titles Where nama like 'Admin Import'
# 0
# Admin Import Staff
# Select nama From titles Where nama like 'Admin Import Staff'
# 0
# Admin Internal Marketing
# Select nama From titles Where nama like 'Admin Internal Marketing'
# 0
# Admin Internship
# Select nama From titles Where nama like 'Admin Internship'
# 0
# Admin Inventory
# Select nama From titles Where nama like 'Admin Inventory'
# 0
# Admin Inventory Control
# Select nama From titles Where nama like 'Admin Inventory Control'
# 0
# Admin Invoice
# Select nama From titles Where nama like 'Admin Invoice'
# 0
# Admin Invoice Staff
# Select nama From titles Where nama like 'Admin Invoice Staff'
# 0
# Admin Invoicing
# Select nama From titles Where nama like 'Admin Invoicing'
# 0
# Admin Kantor
# Select nama From titles Where nama like 'Admin Kantor'
# 0
# Admin Kantor / Online / Gudang
# Select nama From titles Where nama like 'Admin Kantor / Online / Gudang'
# 0
# Admin Kasir
# Select nama From titles Where nama like 'Admin Kasir'
# 0
# Admin Kepabeanan
# Select nama From titles Where nama like 'Admin Kepabeanan'
# 0
# Admin Keuangan
# Select nama From titles Where nama like 'Admin Keuangan'
# 0
# Admin Lab
# Select nama From titles Where nama like 'Admin Lab'
# 0
# Admin Last Mile / Linehaul
# Select nama From titles Where nama like 'Admin Last Mile / Linehaul'
# 0
# Admin Live Streaming
# Select nama From titles Where nama like 'Admin Live Streaming'
# 0
# Admin Logistik
# Select nama From titles Where nama like 'Admin Logistik'
# 0
# Admin Mandarin
# Select nama From titles Where nama like 'Admin Mandarin'
# 0
# Admin Mandarin Staff
# Select nama From titles Where nama like 'Admin Mandarin Staff'
# 0
# Admin Marine
# Select nama From titles Where nama like 'Admin Marine'
# 0
# Admin Marketing
# Select nama From titles Where nama like 'Admin Marketing'
# 0
# Admin Marketing Online Marketplace
# Select nama From titles Where nama like 'Admin Marketing Online Marketplace'
# 0
# Admin Marketing Support
# Select nama From titles Where nama like 'Admin Marketing Support'
# 0
# Admin Marketplace
# Select nama From titles Where nama like 'Admin Marketplace'
# 0
# Admin Material Control Ftth
# Select nama From titles Where nama like 'Admin Material Control Ftth'
# 0
# Admin Media Online
# Select nama From titles Where nama like 'Admin Media Online'
# 0
# Admin Media Sosial & Online Promotion
# Select nama From titles Where nama like 'Admin Media Sosial & Online Promotion'
# 0
# Admin Merchandiser
# Select nama From titles Where nama like 'Admin Merchandiser'
# 0
# Admin Mine Engineer
# Select nama From titles Where nama like 'Admin Mine Engineer'
# 0
# Admin Online
# Select nama From titles Where nama like 'Admin Online'
# 0
# Admin Online & Retail
# Select nama From titles Where nama like 'Admin Online & Retail'
# 0
# Admin Online & Staff Toko
# Select nama From titles Where nama like 'Admin Online & Staff Toko'
# 0
# Admin Online Marketplace
# Select nama From titles Where nama like 'Admin Online Marketplace'
# 0
# Admin Online Shop
# Select nama From titles Where nama like 'Admin Online Shop'
# 0
# Admin Online Shop & Live Streaming
# Select nama From titles Where nama like 'Admin Online Shop & Live Streaming'
# 0
# Admin Online Store
# Select nama From titles Where nama like 'Admin Online Store'
# 0
# Admin Operasional
# Select nama From titles Where nama like 'Admin Operasional'
# 0
# Admin Operation Staff
# Select nama From titles Where nama like 'Admin Operation Staff'
# 0
# Admin Operational Staff
# Select nama From titles Where nama like 'Admin Operational Staff'
# 0
# Admin Outlet
# Select nama From titles Where nama like 'Admin Outlet'
# 0
# Admin Pabrik
# Select nama From titles Where nama like 'Admin Pabrik'
# 0
# Admin Pembelian
# Select nama From titles Where nama like 'Admin Pembelian'
# 0
# Admin Pembelian / Purchasing
# Select nama From titles Where nama like 'Admin Pembelian / Purchasing'
# 0
# Admin Penjualan
# Select nama From titles Where nama like 'Admin Penjualan'
# 0
# Admin Penjualan / Karyawan Gudang Umum
# Select nama From titles Where nama like 'Admin Penjualan / Karyawan Gudang Umum'
# 0
# Admin Penjualan & Pembelian Export Import
# Select nama From titles Where nama like 'Admin Penjualan & Pembelian Export Import'
# 0
# Admin Perusahaan
# Select nama From titles Where nama like 'Admin Perusahaan'
# 0
# Admin Piutang
# Select nama From titles Where nama like 'Admin Piutang'
# 0
# Admin Ppic
# Select nama From titles Where nama like 'Admin Ppic'
# 0
# Admin Procurement
# Select nama From titles Where nama like 'Admin Procurement'
# 0
# Admin Produksi
# Select nama From titles Where nama like 'Admin Produksi'
# 0
# Admin Produksi Peternakan Ayam
# Select nama From titles Where nama like 'Admin Produksi Peternakan Ayam'
# 0
# Admin Project
# Select nama From titles Where nama like 'Admin Project'
# 0
# Admin Project & Marketing Project
# Select nama From titles Where nama like 'Admin Project & Marketing Project'
# 0
# Admin Project Site
# Select nama From titles Where nama like 'Admin Project Site'
# 0
# Admin Property
# Select nama From titles Where nama like 'Admin Property'
# 0
# Admin Proyek
# Select nama From titles Where nama like 'Admin Proyek'
# 0
# Admin Purchasing
# Select nama From titles Where nama like 'Admin Purchasing'
# 0
# Admin Purchasing / Export Import
# Select nama From titles Where nama like 'Admin Purchasing / Export Import'
# 0
# Admin Purchasing / Ppic
# Select nama From titles Where nama like 'Admin Purchasing / Ppic'
# 0
# Admin Purchasing Staff
# Select nama From titles Where nama like 'Admin Purchasing Staff'
# 0
# Admin Registrasi Produk & Impor
# Select nama From titles Where nama like 'Admin Registrasi Produk & Impor'
# 0
# Admin Rekrutmen
# Select nama From titles Where nama like 'Admin Rekrutmen'
# 0
# Admin Sales
# Select nama From titles Where nama like 'Admin Sales'
# 0
# Admin Sales & Marketing
# Select nama From titles Where nama like 'Admin Sales & Marketing'
# 0
# Admin Sales Marketing
# Select nama From titles Where nama like 'Admin Sales Marketing'
# 0
# Admin Sales Online
# Select nama From titles Where nama like 'Admin Sales Online'
# 0
# Admin Sales Support
# Select nama From titles Where nama like 'Admin Sales Support'
# 0
# Admin Sap
# Select nama From titles Where nama like 'Admin Sap'
# 0
# Admin Sekretaris
# Select nama From titles Where nama like 'Admin Sekretaris'
# 0
# Admin Senior
# Select nama From titles Where nama like 'Admin Senior'
# 0
# Admin Settlement
# Select nama From titles Where nama like 'Admin Settlement'
# 0
# Admin Social Media Content Creator Tiktok & Talent Host Livestreamer
# Select nama From titles Where nama like 'Admin Social Media Content Creator Tiktok & Talent Host Livestreamer'
# 0
# Admin Sosial Media
# Select nama From titles Where nama like 'Admin Sosial Media'
# 0
# Admin Spare Part
# Select nama From titles Where nama like 'Admin Spare Part'
# 0
# Admin Sparepart
# Select nama From titles Where nama like 'Admin Sparepart'
# 0
# Admin Spareparts
# Select nama From titles Where nama like 'Admin Spareparts'
# 0
# Admin Specialist
# Select nama From titles Where nama like 'Admin Specialist'
# 0
# Admin Staff
# Select nama From titles Where nama like 'Admin Staff'
# 0
# Admin Staff Finance Accounting
# Select nama From titles Where nama like 'Admin Staff Finance Accounting'
# 0
# Admin Support
# Select nama From titles Where nama like 'Admin Support'
# 0
# Admin Support Marketing
# Select nama From titles Where nama like 'Admin Support Marketing'
# 0
# Admin Support Sipil
# Select nama From titles Where nama like 'Admin Support Sipil'
# 0
# Admin Tax
# Select nama From titles Where nama like 'Admin Tax'
# 0
# Admin Teknisi
# Select nama From titles Where nama like 'Admin Teknisi'
# 0
# Admin Telemarketing
# Select nama From titles Where nama like 'Admin Telemarketing'
# 0
# Admin Toko Bahan Kue
# Select nama From titles Where nama like 'Admin Toko Bahan Kue'
# 0
# Admin Treasury
# Select nama From titles Where nama like 'Admin Treasury'
# 0
# Admin Umum
# Select nama From titles Where nama like 'Admin Umum'
# 0
# Admin Verification Telephone
# Select nama From titles Where nama like 'Admin Verification Telephone'
# 0
# Admin Warehouse
# Select nama From titles Where nama like 'Admin Warehouse'
# 0
# Administrasi
# Select nama From titles Where nama like 'Administrasi'
# 0
# Administrasi & Accounting
# Select nama From titles Where nama like 'Administrasi & Accounting'
# 0
# Administrasi & Customer Service
# Select nama From titles Where nama like 'Administrasi & Customer Service'
# 0
# Administrasi & Logistik
# Select nama From titles Where nama like 'Administrasi & Logistik'
# 0
# Administrasi Customer Service Officer
# Select nama From titles Where nama like 'Administrasi Customer Service Officer'
# 0
# Administrasi Gudang
# Select nama From titles Where nama like 'Administrasi Gudang'
# 0
# Administrasi Gudang Material
# Select nama From titles Where nama like 'Administrasi Gudang Material'
# 0
# Administrasi Gudang Pusat
# Select nama From titles Where nama like 'Administrasi Gudang Pusat'
# 0
# Administrasi It
# Select nama From titles Where nama like 'Administrasi It'
# 0
# Administrasi K3
# Select nama From titles Where nama like 'Administrasi K3'
# 0
# Administrasi Kantor
# Select nama From titles Where nama like 'Administrasi Kantor'
# 0
# Administrasi Keuangan
# Select nama From titles Where nama like 'Administrasi Keuangan'
# 0
# Administrasi Kontrak
# Select nama From titles Where nama like 'Administrasi Kontrak'
# 0
# Administrasi Marketing
# Select nama From titles Where nama like 'Administrasi Marketing'
# 0
# Administrasi Operasional
# Select nama From titles Where nama like 'Administrasi Operasional'
# 0
# Administrasi Penjualan
# Select nama From titles Where nama like 'Administrasi Penjualan'
# 0
# Administrasi Produksi Pabrik Plastik
# Select nama From titles Where nama like 'Administrasi Produksi Pabrik Plastik'
# 0
# Administrasi Proyek
# Select nama From titles Where nama like 'Administrasi Proyek'
# 0
# Administrasi Purchasing
# Select nama From titles Where nama like 'Administrasi Purchasing'
# 0
# Administrasi Rumah Sakit
# Select nama From titles Where nama like 'Administrasi Rumah Sakit'
# 0
# Administrasi Sales
# Select nama From titles Where nama like 'Administrasi Sales'
# 0
# Administrasi Sekretaris
# Select nama From titles Where nama like 'Administrasi Sekretaris'
# 0
# Administrasi Staff
# Select nama From titles Where nama like 'Administrasi Staff'
# 0
# Administrasi Stock
# Select nama From titles Where nama like 'Administrasi Stock'
# 0
# Administrasi Support
# Select nama From titles Where nama like 'Administrasi Support'
# 0
# Administrasi Teknik
# Select nama From titles Where nama like 'Administrasi Teknik'
# 0
# Administrasi Teknisi
# Select nama From titles Where nama like 'Administrasi Teknisi'
# 0
# Administrasi Umum
# Select nama From titles Where nama like 'Administrasi Umum'
# 0
# Administration
# Select nama From titles Where nama like 'Administration'
# 0
# Administration & Finance Staff
# Select nama From titles Where nama like 'Administration & Finance Staff'
# 0
# Administration Accounting
# Select nama From titles Where nama like 'Administration Accounting'
# 0
# Administration Head
# Select nama From titles Where nama like 'Administration Head'
# 0
# Administration Internship
# Select nama From titles Where nama like 'Administration Internship'
# 0
# Administration Of Marketing
# Select nama From titles Where nama like 'Administration Of Marketing'
# 0
# Administration Staff
# Select nama From titles Where nama like 'Administration Staff'
# 0
# Administrative Assistant
# Select nama From titles Where nama like 'Administrative Assistant'
# 0
# Administrative Assistant To Chief Representative
# Select nama From titles Where nama like 'Administrative Assistant To Chief Representative'
# 0
# Administrative Manager
# Select nama From titles Where nama like 'Administrative Manager'
# 0
# Administrative Officer
# Select nama From titles Where nama like 'Administrative Officer'
# 0
# Administrator
# Select nama From titles Where nama like 'Administrator'
# 0
# Administrator Contract
# Select nama From titles Where nama like 'Administrator Contract'
# 0
# Administrator Pemasaran
# Select nama From titles Where nama like 'Administrator Pemasaran'
# 0
# Admission Coordinator
# Select nama From titles Where nama like 'Admission Coordinator'
# 0
# Admissions & Marketing
# Select nama From titles Where nama like 'Admissions & Marketing'
# 0
# Advertisement Specialist Digital Marketing
# Select nama From titles Where nama like 'Advertisement Specialist Digital Marketing'
# 0
# Advertising & Promotion Property
# Select nama From titles Where nama like 'Advertising & Promotion Property'
# 0
# Advertising Lead
# Select nama From titles Where nama like 'Advertising Lead'
# 0
# Advisory Associate
# Select nama From titles Where nama like 'Advisory Associate'
# 0
# Advocate
# Select nama From titles Where nama like 'Advocate'
# 0
# Aesthetic Dokter
# Select nama From titles Where nama like 'Aesthetic Dokter'
# 0
# Aesthetics Dokter
# Select nama From titles Where nama like 'Aesthetics Dokter'
# 0
# After Sales & Technical Support
# Select nama From titles Where nama like 'After Sales & Technical Support'
# 0
# After Sales Manager
# Select nama From titles Where nama like 'After Sales Manager'
# 0
# After Sales Service / Field Engineer
# Select nama From titles Where nama like 'After Sales Service / Field Engineer'
# 0
# Aftersales Promotion
# Select nama From titles Where nama like 'Aftersales Promotion'
# 0
# Agency Development Manager
# Select nama From titles Where nama like 'Agency Development Manager'
# 0
# Agency Marketing Support Manager
# Select nama From titles Where nama like 'Agency Marketing Support Manager'
# 0
# Agent Desk Collection
# Select nama From titles Where nama like 'Agent Desk Collection'
# 0
# Agent Property
# Select nama From titles Where nama like 'Agent Property'
# 0
# Agricultural Advisor
# Select nama From titles Where nama like 'Agricultural Advisor'
# 0
# Agricultural Technical Lead
# Select nama From titles Where nama like 'Agricultural Technical Lead'
# 0
# Agriculture Engineer
# Select nama From titles Where nama like 'Agriculture Engineer'
# 0
# Agronomy Officer
# Select nama From titles Where nama like 'Agronomy Officer'
# 0
# Ahli Bubut / Tukang Bubut Mesin
# Select nama From titles Where nama like 'Ahli Bubut / Tukang Bubut Mesin'
# 0
# Ahli Gizi
# Select nama From titles Where nama like 'Ahli Gizi'
# 0
# Ahli K3 Konstruksi
# Select nama From titles Where nama like 'Ahli K3 Konstruksi'
# 0
# Ai Operation
# Select nama From titles Where nama like 'Ai Operation'
# 0
# Airport Office Manager
# Select nama From titles Where nama like 'Airport Office Manager'
# 0
# Ajudan Asisten Pimpinan
# Select nama From titles Where nama like 'Ajudan Asisten Pimpinan'
# 0
# Akademik & Program
# Select nama From titles Where nama like 'Akademik & Program'
# 0
# Akuntan
# Select nama From titles Where nama like 'Akuntan'
# 0
# Analis / Operator Instrumen R&D
# Select nama From titles Where nama like 'Analis / Operator Instrumen R&D'
# 0
# Analis Agronomi
# Select nama From titles Where nama like 'Analis Agronomi'
# 0
# Analis Kimia
# Select nama From titles Where nama like 'Analis Kimia'
# 0
# Analis Kredit Bpr
# Select nama From titles Where nama like 'Analis Kredit Bpr'
# 0
# Analis Laboratorium
# Select nama From titles Where nama like 'Analis Laboratorium'
# 0
# Analis Laboratorium Kimia
# Select nama From titles Where nama like 'Analis Laboratorium Kimia'
# 0
# Analisis Kredit
# Select nama From titles Where nama like 'Analisis Kredit'
# 0
# Analyst Collection
# Select nama From titles Where nama like 'Analyst Collection'
# 0
# Analyst Staff
# Select nama From titles Where nama like 'Analyst Staff'
# 0
# Analytical Development Analyst
# Select nama From titles Where nama like 'Analytical Development Analyst'
# 0
# Android & Web Developer
# Select nama From titles Where nama like 'Android & Web Developer'
# 0
# Android Developer
# Select nama From titles Where nama like 'Android Developer'
# 0
# Android Developer For Edc
# Select nama From titles Where nama like 'Android Developer For Edc'
# 0
# Android Developer Internship
# Select nama From titles Where nama like 'Android Developer Internship '
# 0
# Android Developer Staff
# Select nama From titles Where nama like 'Android Developer Staff'
# 0
# Android Mobile Developer
# Select nama From titles Where nama like 'Android Mobile Developer'
# 0
# Android Programmer
# Select nama From titles Where nama like 'Android Programmer'
# 0
# Angular Developer
# Select nama From titles Where nama like 'Angular Developer'
# 0
# Angular Support Engineer
# Select nama From titles Where nama like 'Angular Support Engineer'
# 0
# Animal Health
# Select nama From titles Where nama like 'Animal Health'
# 0
# Animator
# Select nama From titles Where nama like 'Animator'
# 0
# Animator 2D & Motion Graphic
# Select nama From titles Where nama like 'Animator 2D & Motion Graphic'
# 0
# Annual Report Writer
# Select nama From titles Where nama like 'Annual Report Writer'
# 0
# Anti Fraud Analyst
# Select nama From titles Where nama like 'Anti Fraud Analyst'
# 0
# Anti Fraud Process & Qa Junior Specialist
# Select nama From titles Where nama like 'Anti Fraud Process & Qa Junior Specialist'
# 0
# Anti Fraud Specialist
# Select nama From titles Where nama like 'Anti Fraud Specialist'
# 0
# Ap Finance
# Select nama From titles Where nama like 'Ap Finance'
# 0
# Apical Engineer Trainee
# Select nama From titles Where nama like 'Apical Engineer Trainee'
# 0
# Apotek Partnership Associate
# Select nama From titles Where nama like 'Apotek Partnership Associate'
# 0
# Apoteker
# Select nama From titles Where nama like 'Apoteker'
# 0
# Apoteker Telemedicine
# Select nama From titles Where nama like 'Apoteker Telemedicine'
# 0
# App Operations Assistant Indonesia
# Select nama From titles Where nama like 'App Operations Assistant Indonesia'
# 0
# Application Consultant
# Select nama From titles Where nama like 'Application Consultant'
# 0
# Application Development
# Select nama From titles Where nama like 'Application Development'
# 0
# Application Engineer
# Select nama From titles Where nama like 'Application Engineer'
# 0
# Application Project Manager
# Select nama From titles Where nama like 'Application Project Manager'
# 0
# Application Specialist
# Select nama From titles Where nama like 'Application Specialist'
# 0
# Application Specialist Staff
# Select nama From titles Where nama like 'Application Specialist Staff'
# 0
# Application Support
# Select nama From titles Where nama like 'Application Support'
# 0
# Application Support Analyst
# Select nama From titles Where nama like 'Application Support Analyst'
# 0
# Application Support Cum Developer
# Select nama From titles Where nama like 'Application Support Cum Developer'
# 0
# Application Support Specialist
# Select nama From titles Where nama like 'Application Support Specialist'
# 0
# Application System Architecture Manager
# Select nama From titles Where nama like 'Application System Architecture Manager'
# 0
# Application Systems Manager
# Select nama From titles Where nama like 'Application Systems Manager'
# 0
# Applied Art & Fine Art Teacher / Coach
# Select nama From titles Where nama like 'Applied Art & Fine Art Teacher / Coach'
# 0
# Appraisal Support
# Select nama From titles Where nama like 'Appraisal Support'
# 0
# Apu Ppt Monitoring & Reporting Staff
# Select nama From titles Where nama like 'Apu Ppt Monitoring & Reporting Staff'
# 0
# Apu Ppt Specialist
# Select nama From titles Where nama like 'Apu Ppt Specialist'
# 0
# Ar Admin
# Select nama From titles Where nama like 'Ar Admin'
# 0
# Ar Cinema Validation & Head Office Reconciliation Support Staff
# Select nama From titles Where nama like 'Ar Cinema Validation & Head Office Reconciliation Support Staff'
# 0
# Ar Collection
# Select nama From titles Where nama like 'Ar Collection'
# 0
# Ar Follow Up Staff
# Select nama From titles Where nama like 'Ar Follow Up Staff'
# 0
# Ar Staff
# Select nama From titles Where nama like 'Ar Staff'
# 0
# Architect
# Select nama From titles Where nama like 'Architect '
# 0
# Architect
# Select nama From titles Where nama like 'Architect'
# 0
# Architect For Building Management
# Select nama From titles Where nama like 'Architect For Building Management'
# 0
# Architectural Drafter
# Select nama From titles Where nama like 'Architectural Drafter'
# 0
# Arsitek
# Select nama From titles Where nama like 'Arsitek'
# 0
# Arsitek Desain Interior
# Select nama From titles Where nama like 'Arsitek Desain Interior'
# 0
# Art & Graphics Designer
# Select nama From titles Where nama like 'Art & Graphics Designer'
# 0
# Art Designer
# Select nama From titles Where nama like 'Art Designer'
# 0
# Art Director
# Select nama From titles Where nama like 'Art Director'
# 0
# Art Teacher
# Select nama From titles Where nama like 'Art Teacher'
# 0
# Asessment Engineer, Utilities / Kiln
# Select nama From titles Where nama like 'Asessment Engineer, Utilities / Kiln'
# 0
# Asisstant Manager Warehouse
# Select nama From titles Where nama like 'Asisstant Manager Warehouse'
# 0
# Asistant Manager Finance Accounting
# Select nama From titles Where nama like 'Asistant Manager Finance Accounting'
# 0
# Asistant Supervisor
# Select nama From titles Where nama like 'Asistant Supervisor'
# 0
# Asisten Accounting
# Select nama From titles Where nama like 'Asisten Accounting'
# 0
# Asisten Agronomi
# Select nama From titles Where nama like 'Asisten Agronomi'
# 0
# Asisten Apoteker
# Select nama From titles Where nama like 'Asisten Apoteker'
# 0
# Asisten Bengkel
# Select nama From titles Where nama like 'Asisten Bengkel'
# 0
# Asisten Dokter
# Select nama From titles Where nama like 'Asisten Dokter'
# 0
# Asisten Ehs
# Select nama From titles Where nama like 'Asisten Ehs'
# 0
# Asisten Elektrik
# Select nama From titles Where nama like 'Asisten Elektrik'
# 0
# Asisten Gm
# Select nama From titles Where nama like 'Asisten Gm'
# 0
# Asisten Instruktur Konsultan Programming
# Select nama From titles Where nama like 'Asisten Instruktur Konsultan Programming'
# 0
# Asisten Kebun
# Select nama From titles Where nama like 'Asisten Kebun'
# 0
# Asisten Kebun Karet
# Select nama From titles Where nama like 'Asisten Kebun Karet'
# 0
# Asisten Kebun Kelapa Sawit
# Select nama From titles Where nama like 'Asisten Kebun Kelapa Sawit'
# 0
# Asisten Kepala
# Select nama From titles Where nama like 'Asisten Kepala'
# 0
# Asisten Lapangan
# Select nama From titles Where nama like 'Asisten Lapangan'
# 0
# Asisten Maintenance Pabrik Kelapa Sawit
# Select nama From titles Where nama like 'Asisten Maintenance Pabrik Kelapa Sawit'
# 0
# Asisten Manager HRd
# Select nama From titles Where nama like 'Asisten Manager HRd'
# 0
# Asisten Manager Operation & Maintenance Ftth
# Select nama From titles Where nama like 'Asisten Manager Operation & Maintenance Ftth'
# 0
# Asisten Manager Produksi
# Select nama From titles Where nama like 'Asisten Manager Produksi'
# 0
# Asisten Manager Purchasing
# Select nama From titles Where nama like 'Asisten Manager Purchasing'
# 0
# Asisten Manajer Editorial Buku
# Select nama From titles Where nama like 'Asisten Manajer Editorial Buku'
# 0
# Asisten Manajer Hukum
# Select nama From titles Where nama like 'Asisten Manajer Hukum'
# 0
# Asisten Mechanic
# Select nama From titles Where nama like 'Asisten Mechanic'
# 0
# Asisten Notaris
# Select nama From titles Where nama like 'Asisten Notaris'
# 0
# Asisten Pribadi
# Select nama From titles Where nama like 'Asisten Pribadi'
# 0
# Asisten Quality Assurance
# Select nama From titles Where nama like 'Asisten Quality Assurance'
# 0
# Asisten Quality Control Agronomi
# Select nama From titles Where nama like 'Asisten Quality Control Agronomi'
# 0
# Asisten Sales Manager
# Select nama From titles Where nama like 'Asisten Sales Manager'
# 0
# Asisten Sipil
# Select nama From titles Where nama like 'Asisten Sipil'
# 0
# Asisten Surveyor Gis
# Select nama From titles Where nama like 'Asisten Surveyor Gis'
# 0
# Asisten Teknik Kebun
# Select nama From titles Where nama like 'Asisten Teknik Kebun'
# 0
# Asisten Teknisi Pendingin
# Select nama From titles Where nama like 'Asisten Teknisi Pendingin'
# 0
# Asisten Traksi
# Select nama From titles Where nama like 'Asisten Traksi'
# 0
# Asisten Transport
# Select nama From titles Where nama like 'Asisten Transport'
# 0
# Asmen Hse
# Select nama From titles Where nama like 'Asmen Hse'
# 0
# Asmen Pga
# Select nama From titles Where nama like 'Asmen Pga'
# 0
# Asp..Net Programmer
# Select nama From titles Where nama like 'Asp..Net Programmer'
# 0
# Assembling Staff
# Select nama From titles Where nama like 'Assembling Staff'
# 0
# Assembly Shop Specialist
# Select nama From titles Where nama like 'Assembly Shop Specialist'
# 0
# Assessment & Development Officer
# Select nama From titles Where nama like 'Assessment & Development Officer'
# 0
# Assessment Manager
# Select nama From titles Where nama like 'Assessment Manager'
# 0
# Assessment Staff
# Select nama From titles Where nama like 'Assessment Staff'
# 0
# Assessor
# Select nama From titles Where nama like 'Assessor'
# 0
# Asset Liquidity Management
# Select nama From titles Where nama like 'Asset Liquidity Management'
# 0
# Asset Management Senior Supervisor
# Select nama From titles Where nama like 'Asset Management Senior Supervisor'
# 0
# Asset Management Staff
# Select nama From titles Where nama like 'Asset Management Staff'
# 0
# Asset Recovery Collection
# Select nama From titles Where nama like 'Asset Recovery Collection'
# 0
# Assisstant Gudang & Logistik
# Select nama From titles Where nama like 'Assisstant Gudang & Logistik'
# 0
# Assisstant Leader Store
# Select nama From titles Where nama like 'Assisstant Leader Store'
# 0
# Assisstant Manager Accounting
# Select nama From titles Where nama like 'Assisstant Manager Accounting'
# 0
# Assisstant Manager Of Polyester
# Select nama From titles Where nama like 'Assisstant Manager Of Polyester'
# 0
# Assisstant Manager Risk Management & Compliance
# Select nama From titles Where nama like 'Assisstant Manager Risk Management & Compliance'
# 0
# Assisstant To Director
# Select nama From titles Where nama like 'Assisstant To Director'
# 0
# Assistance President Director
# Select nama From titles Where nama like 'Assistance President Director'
# 0
# Assistance Product Owner
# Select nama From titles Where nama like 'Assistance Product Owner'
# 0
# Assistant Admin Accounting
# Select nama From titles Where nama like 'Assistant Admin Accounting'
# 0
# Assistant Auditor
# Select nama From titles Where nama like 'Assistant Auditor'
# 0
# Assistant Brand
# Select nama From titles Where nama like 'Assistant Brand'
# 0
# Assistant Brand Manager
# Select nama From titles Where nama like 'Assistant Brand Manager'
# 0
# Assistant Business Manager
# Select nama From titles Where nama like 'Assistant Business Manager'
# 0
# Assistant Category Manager
# Select nama From titles Where nama like 'Assistant Category Manager'
# 0
# Assistant Chemist
# Select nama From titles Where nama like 'Assistant Chemist'
# 0
# Assistant Chief Engineering
# Select nama From titles Where nama like 'Assistant Chief Engineering'
# 0
# Assistant Communications Manager
# Select nama From titles Where nama like 'Assistant Communications Manager'
# 0
# Assistant Controller
# Select nama From titles Where nama like 'Assistant Controller'
# 0
# Assistant Crm Manager
# Select nama From titles Where nama like 'Assistant Crm Manager'
# 0
# Assistant Cutting
# Select nama From titles Where nama like 'Assistant Cutting'
# 0
# Assistant Director
# Select nama From titles Where nama like 'Assistant Director'
# 0
# Assistant Financial Controller
# Select nama From titles Where nama like 'Assistant Financial Controller'
# 0
# Assistant General Manager
# Select nama From titles Where nama like 'Assistant General Manager'
# 0
# Assistant Head Store
# Select nama From titles Where nama like 'Assistant Head Store'
# 0
# Assistant HR Generalist
# Select nama From titles Where nama like 'Assistant HR Generalist'
# 0
# Assistant Human Resource Manager
# Select nama From titles Where nama like 'Assistant Human Resource Manager'
# 0
# Assistant Industrial Relation Manager
# Select nama From titles Where nama like 'Assistant Industrial Relation Manager'
# 0
# Assistant Logistics Sales Manager
# Select nama From titles Where nama like 'Assistant Logistics Sales Manager'
# 0
# Assistant Maintenance Manager
# Select nama From titles Where nama like 'Assistant Maintenance Manager'
# 0
# Assistant Management Accounting & Finance
# Select nama From titles Where nama like 'Assistant Management Accounting & Finance'
# 0
# Assistant Manager
# Select nama From titles Where nama like 'Assistant Manager'
# 0
# Assistant Manager / Supervisor Purchasing
# Select nama From titles Where nama like 'Assistant Manager / Supervisor Purchasing'
# 0
# Assistant Manager Accounting & Tax
# Select nama From titles Where nama like 'Assistant Manager Accounting & Tax'
# 0
# Assistant Manager Ar Collection & Claim
# Select nama From titles Where nama like 'Assistant Manager Ar Collection & Claim'
# 0
# Assistant Manager Care Quality Control
# Select nama From titles Where nama like 'Assistant Manager Care Quality Control'
# 0
# Assistant Manager Corporate Sales Employee Benefit
# Select nama From titles Where nama like 'Assistant Manager Corporate Sales Employee Benefit'
# 0
# Assistant Manager Cost Accounting
# Select nama From titles Where nama like 'Assistant Manager Cost Accounting'
# 0
# Assistant Manager Ecommerce
# Select nama From titles Where nama like 'Assistant Manager Ecommerce'
# 0
# Assistant Manager Environmental Management
# Select nama From titles Where nama like 'Assistant Manager Environmental Management'
# 0
# Assistant Manager Finance
# Select nama From titles Where nama like 'Assistant Manager Finance'
# 0
# Assistant Manager Finance Accounting & Tax
# Select nama From titles Where nama like 'Assistant Manager Finance Accounting & Tax'
# 0
# Assistant Manager HR
# ...
# Select nama From titles Where nama like 'Universal Banker Service'
# 0
# University Counselor
# Select nama From titles Where nama like 'University Counselor'
# 0
# Unreal GAme Developer
# Select nama From titles Where nama like 'Unreal GAme Developer'
# 0
# Urgently Needed : Marketing Manager
# Select nama From titles Where nama like 'Urgently Needed : Marketing Manager'
# 0
# User Acquisition Intern
# Select nama From titles Where nama like 'User Acquisition Intern'
# 0
# User Acquisition Specialist
# Select nama From titles Where nama like 'User Acquisition Specialist'
# 0
# User Acquisition Staff
# Select nama From titles Where nama like 'User Acquisition Staff'
# 0
# User Research
# Select nama From titles Where nama like 'User Research'
# 0
# Utility & Environmental Manager
# Select nama From titles Where nama like 'Utility & Environmental Manager'
# 0
# Utility Foreman
# Select nama From titles Where nama like 'Utility Foreman'
# 0
# Utility Manager
# Select nama From titles Where nama like 'Utility Manager'
# 0
# Utility Operator
# Select nama From titles Where nama like 'Utility Operator'
# 0
# Utility Staff
# Select nama From titles Where nama like 'Utility Staff'
# 0
# Utility Supervisor
# Select nama From titles Where nama like 'Utility Supervisor'
# 0
# Ux / Ui Designer
# Select nama From titles Where nama like 'Ux / Ui Designer'
# 0
# Ux / Ui Officer
# Select nama From titles Where nama like 'Ux / Ui Officer'
# 0
# Ux Design Manager
# Select nama From titles Where nama like 'Ux Design Manager'
# 0
# Ux Designer
# Select nama From titles Where nama like 'Ux Designer'
# 0
# Ux Quality Assurance
# Select nama From titles Where nama like 'Ux Quality Assurance'
# 0
# Ux Researcher
# Select nama From titles Where nama like 'Ux Researcher'
# 0
# Ux Researcher Senior
# Select nama From titles Where nama like 'Ux Researcher Senior'
# 0
# Ux Writer
# Select nama From titles Where nama like 'Ux Writer'
# 0
# Validasi Qualification Analyst
# Select nama From titles Where nama like 'Validasi Qualification Analyst'
# 0
# Validation Transaction Associate
# Select nama From titles Where nama like 'Validation Transaction Associate'
# 0
# Vehicle Logistic Operator
# Select nama From titles Where nama like 'Vehicle Logistic Operator'
# 0
# Vendor Acquisition Staff
# Select nama From titles Where nama like 'Vendor Acquisition Staff'
# 0
# Vendor Management Analyst
# Select nama From titles Where nama like 'Vendor Management Analyst'
# 0
# Vendor Management Staff
# Select nama From titles Where nama like 'Vendor Management Staff'
# 0
# Vendor Qa Senior Staff
# Select nama From titles Where nama like 'Vendor Qa Senior Staff'
# 0
# Vessel Insurance Staff
# Select nama From titles Where nama like 'Vessel Insurance Staff'
# 0
# Vessel Monitoring Group Leader
# Select nama From titles Where nama like 'Vessel Monitoring Group Leader'
# 0
# Vessel Operation & Logistic Staff
# Select nama From titles Where nama like 'Vessel Operation & Logistic Staff'
# 0
# Veterinary
# Select nama From titles Where nama like 'Veterinary'
# 0
# Video Animator
# Select nama From titles Where nama like 'Video Animator'
# 0
# Video Content Creator
# Select nama From titles Where nama like 'Video Content Creator'
# 0
# Video Creator
# Select nama From titles Where nama like 'Video Creator'
# 0
# Video Editor
# Select nama From titles Where nama like 'Video Editor'
# 0
# Video Editor & Content Creator
# Select nama From titles Where nama like 'Video Editor & Content Creator'
# 0
# Video Editor & Design Graphis
# Select nama From titles Where nama like 'Video Editor & Design Graphis'
# 0
# Video Editor & Graphic Designer
# Select nama From titles Where nama like 'Video Editor & Graphic Designer'
# 0
# Video Editor & Videografer
# Select nama From titles Where nama like 'Video Editor & Videografer'
# 0
# Video Editor Intern
# Select nama From titles Where nama like 'Video Editor Intern'
# 0
# Video Editor Specialist
# Select nama From titles Where nama like 'Video Editor Specialist'
# 0
# Video Editor Staff
# Select nama From titles Where nama like 'Video Editor Staff'
# 0
# Videografer
# Select nama From titles Where nama like 'Videografer'
# 0
# Videographer
# Select nama From titles Where nama like 'Videographer'
# 0
# Videographer / Photographer
# Select nama From titles Where nama like 'Videographer / Photographer'
# 0
# Videographer / Video Editor
# Select nama From titles Where nama like 'Videographer / Video Editor'
# 0
# Videographer & Editor
# Select nama From titles Where nama like 'Videographer & Editor'
# 0
# Videographer & Photographer
# Select nama From titles Where nama like 'Videographer & Photographer'
# 0
# Videographer & Photographer Staff
# Select nama From titles Where nama like 'Videographer & Photographer Staff'
# 0
# Videographer Officer
# Select nama From titles Where nama like 'Videographer Officer'
# 0
# Videographer Photographer
# Select nama From titles Where nama like 'Videographer Photographer'
# 0
# Videographer Senior Officer
# Select nama From titles Where nama like 'Videographer Senior Officer'
# 0
# Videographer Tiktok
# Select nama From titles Where nama like 'Videographer Tiktok'
# 0
# Vip Service & Product Development Manager
# Select nama From titles Where nama like 'Vip Service & Product Development Manager'
# 0
# Visual & Graphic Design
# Select nama From titles Where nama like 'Visual & Graphic Design'
# 0
# Visual Art & Design Teacher
# Select nama From titles Where nama like 'Visual Art & Design Teacher'
# 0
# Visual Comunication Designer
# Select nama From titles Where nama like 'Visual Comunication Designer'
# 0
# Visual Merchandiser
# Select nama From titles Where nama like 'Visual Merchandiser'
# 0
# Visual Merchandiser Officer
# Select nama From titles Where nama like 'Visual Merchandiser Officer'
# 0
# Visual Merchandising Officer
# Select nama From titles Where nama like 'Visual Merchandising Officer'
# 0
# Vp Marketing & Customer Experience
# Select nama From titles Where nama like 'Vp Marketing & Customer Experience'
# 0
# Vp Of Sales
# Select nama From titles Where nama like 'Vp Of Sales'
# 0
# Vp Operation
# Select nama From titles Where nama like 'Vp Operation'
# 0
# Vulnerability Assessment
# Select nama From titles Where nama like 'Vulnerability Assessment'
# 0
# Waiter
# Select nama From titles Where nama like 'Waiter'
# 0
# Waiters
# Select nama From titles Where nama like 'Waiters'
# 0
# Waiters / Pramusaji Katering
# Select nama From titles Where nama like 'Waiters / Pramusaji Katering'
# 0
# Waitres
# Select nama From titles Where nama like 'Waitres'
# 0
# Waitress
# Select nama From titles Where nama like 'Waitress'
# 0
# Waitress / Barista
# Select nama From titles Where nama like 'Waitress / Barista'
# 0
# Waitress / Waitress
# Select nama From titles Where nama like 'Waitress / Waitress'
# 0
# Waitress & Waitress
# Select nama From titles Where nama like 'Waitress & Waitress'
# 0
# Waitress Cashier Barista
# Select nama From titles Where nama like 'Waitress Cashier Barista'
# 0
# Waitress Helper
# Select nama From titles Where nama like 'Waitress Helper'
# 0
# Waitress Restoran & Bar
# Select nama From titles Where nama like 'Waitress Restoran & Bar'
# 0
# Waitress Waitress Server Barista Bar
# Select nama From titles Where nama like 'Waitress Waitress Server Barista Bar'
# 0
# Waitress&Kasir
# Select nama From titles Where nama like 'Waitress&Kasir'
# 0
# Wakil Kepala Gudang
# Select nama From titles Where nama like 'Wakil Kepala Gudang'
# 0
# Wakil Kepala Teknik
# Select nama From titles Where nama like 'Wakil Kepala Teknik'
# 0
# Wakil Penjaminan Emisi Efek & Wakil Perantara Pedagang Efek Ojk
# Select nama From titles Where nama like 'Wakil Penjaminan Emisi Efek & Wakil Perantara Pedagang Efek Ojk'
# 0
# Wali Asrama Atau Pembina Asrama
# Select nama From titles Where nama like 'Wali Asrama Atau Pembina Asrama'
# 0
# Warehouse
# Select nama From titles Where nama like 'Warehouse'
# 0
# Warehouse & Delivery Supervisor
# Select nama From titles Where nama like 'Warehouse & Delivery Supervisor'
# 0
# Warehouse & Distribution
# Select nama From titles Where nama like 'Warehouse & Distribution'
# 0
# Warehouse & Fulfillment Ops
# Select nama From titles Where nama like 'Warehouse & Fulfillment Ops'
# 0
# Warehouse & Inventory Controller
# Select nama From titles Where nama like 'Warehouse & Inventory Controller'
# 0
# Warehouse & Logistic Manager
# Select nama From titles Where nama like 'Warehouse & Logistic Manager'
# 0
# Warehouse & Logistic Supervisor
# Select nama From titles Where nama like 'Warehouse & Logistic Supervisor'
# 0
# Warehouse & Transportation Supervisor
# Select nama From titles Where nama like 'Warehouse & Transportation Supervisor'
# 0
# Warehouse Admin
# Select nama From titles Where nama like 'Warehouse Admin'
# 0
# Warehouse Admin Staff
# Select nama From titles Where nama like 'Warehouse Admin Staff'
# 0
# Warehouse Analyst
# Select nama From titles Where nama like 'Warehouse Analyst'
# 0
# Warehouse Associate / Staff Gudang
# Select nama From titles Where nama like 'Warehouse Associate / Staff Gudang'
# 0
# Warehouse Associate Manager
# Select nama From titles Where nama like 'Warehouse Associate Manager'
# 0
# Warehouse Checker
# Select nama From titles Where nama like 'Warehouse Checker'
# 0
# Warehouse Crew
# Select nama From titles Where nama like 'Warehouse Crew'
# 0
# Warehouse Executive
# Select nama From titles Where nama like 'Warehouse Executive'
# 0
# Warehouse Foreman
# Select nama From titles Where nama like 'Warehouse Foreman'
# 0
# Warehouse Head
# Select nama From titles Where nama like 'Warehouse Head'
# 0
# Warehouse Indoor Staff
# Select nama From titles Where nama like 'Warehouse Indoor Staff'
# 0
# Warehouse Inventory Control
# Select nama From titles Where nama like 'Warehouse Inventory Control'
# 0
# Warehouse Leader
# Select nama From titles Where nama like 'Warehouse Leader'
# 0
# Warehouse Logistics Staff
# Select nama From titles Where nama like 'Warehouse Logistics Staff'
# 0
# Warehouse Manager
# Select nama From titles Where nama like 'Warehouse Manager'
# 0
# Warehouse Material Auditor
# Select nama From titles Where nama like 'Warehouse Material Auditor'
# 0
# Warehouse Officer
# Select nama From titles Where nama like 'Warehouse Officer'
# 0
# Warehouse Officer / Petugas Gudang
# Select nama From titles Where nama like 'Warehouse Officer / Petugas Gudang'
# 0
# Warehouse Officer Cum Translator
# Select nama From titles Where nama like 'Warehouse Officer Cum Translator'
# 0
# Warehouse Operator
# Select nama From titles Where nama like 'Warehouse Operator'
# 0
# Warehouse Ppic
# Select nama From titles Where nama like 'Warehouse Ppic'
# 0
# Warehouse Staff
# Select nama From titles Where nama like 'Warehouse Staff'
# 0
# Warehouse Supervisor
# Select nama From titles Where nama like 'Warehouse Supervisor'
# 0
# Warehouse Supervisor & Logistics
# Select nama From titles Where nama like 'Warehouse Supervisor & Logistics'
# 0
# Warehouse Supervisor Power Distribution & Renewable Energy
# Select nama From titles Where nama like 'Warehouse Supervisor Power Distribution & Renewable Energy'
# 0
# Warehouse Technician
# Select nama From titles Where nama like 'Warehouse Technician'
# 0
# Warehouse Training Supervisor
# Select nama From titles Where nama like 'Warehouse Training Supervisor'
# 0
# Warehouse Weight Checker
# Select nama From titles Where nama like 'Warehouse Weight Checker'
# 0
# Wartawan Harian Kompas
# Select nama From titles Where nama like 'Wartawan Harian Kompas'
# 0
# Waste Water Treatment Plant Manager
# Select nama From titles Where nama like 'Waste Water Treatment Plant Manager'
# 0
# Water Sports / Lifeguard
# Select nama From titles Where nama like 'Water Sports / Lifeguard'
# 0
# Water Treatment Manager
# Select nama From titles Where nama like 'Water Treatment Manager'
# 0
# Web / Mobile Developer
# Select nama From titles Where nama like 'Web / Mobile Developer'
# 0
# Web & Android Developer
# Select nama From titles Where nama like 'Web & Android Developer'
# 0
# Web & Api Programmer
# Select nama From titles Where nama like 'Web & Api Programmer'
# 0
# Web & Mobile Development Specialist
# Select nama From titles Where nama like 'Web & Mobile Development Specialist'
# 0
# Web Administrator / Admin Online
# Select nama From titles Where nama like 'Web Administrator / Admin Online'
# 0
# Web Adminstrator / Admin Online
# Select nama From titles Where nama like 'Web Adminstrator / Admin Online'
# 0
# Web Designer
# Select nama From titles Where nama like 'Web Designer'
# 0
# Web Developer
# Select nama From titles Where nama like 'Web Developer'
# 0
# Web Developer & Seo Specialist
# Select nama From titles Where nama like 'Web Developer & Seo Specialist'
# 0
# Web Developer Intern
# Select nama From titles Where nama like 'Web Developer Intern'
# 0
# Web Development Specialist
# Select nama From titles Where nama like 'Web Development Specialist'
# 0
# Web Engineer
# Select nama From titles Where nama like 'Web Engineer'
# 0
# Web Front End Developer
# Select nama From titles Where nama like 'Web Front End Developer'
# 0
# Web Programmer
# Select nama From titles Where nama like 'Web Programmer'
# 0
# Web Programmer Specialist
# Select nama From titles Where nama like 'Web Programmer Specialist'
# 0
# Web Quality Assurance
# Select nama From titles Where nama like 'Web Quality Assurance'
# 0
# Webapp Developer Internship
# Select nama From titles Where nama like 'Webapp Developer Internship'
# 0
# Webmaster
# Select nama From titles Where nama like 'Webmaster'
# 0
# Webmethods Developer
# Select nama From titles Where nama like 'Webmethods Developer'
# 0
# Website Commercial Operation Supervisor
# Select nama From titles Where nama like 'Website Commercial Operation Supervisor'
# 0
# Website Design & Administrator
# Select nama From titles Where nama like 'Website Design & Administrator'
# 0
# Website Developer
# Select nama From titles Where nama like 'Website Developer'
# 0
# Website Front End Developer
# Select nama From titles Where nama like 'Website Front End Developer'
# 0
# Website Technical Consultant
# Select nama From titles Where nama like 'Website Technical Consultant'
# 0
# Webtoon Korean Translator
# Select nama From titles Where nama like 'Webtoon Korean Translator'
# 0
# Webtoon Line Artist
# Select nama From titles Where nama like 'Webtoon Line Artist'
# 0
# Webtoon Typesetter
# Select nama From titles Where nama like 'Webtoon Typesetter'
# 0
# Wedding Sales
# Select nama From titles Where nama like 'Wedding Sales'
# 0
# Welder
# Select nama From titles Where nama like 'Welder'
# 0
# Welder Cpvc / Pvc
# Select nama From titles Where nama like 'Welder Cpvc / Pvc'
# 0
# Welding Inspector
# Select nama From titles Where nama like 'Welding Inspector'
# 0
# Well Integrity / Valve Maintenance Engineer
# Select nama From titles Where nama like 'Well Integrity / Valve Maintenance Engineer'
# 0
# Wellness Business Development Staff
# Select nama From titles Where nama like 'Wellness Business Development Staff'
# 0
# Wellness Programmer
# Select nama From titles Where nama like 'Wellness Programmer'
# 0
# Whatsapp Operator
# Select nama From titles Where nama like 'Whatsapp Operator'
# 0
# Wine Sommelier
# Select nama From titles Where nama like 'Wine Sommelier'
# 0
# Wireless O&M Engineer
# Select nama From titles Where nama like 'Wireless O&M Engineer'
# 0
# Wood Handling Plant Expert
# Select nama From titles Where nama like 'Wood Handling Plant Expert'
# 0
# Wordpress Developer
# Select nama From titles Where nama like 'Wordpress Developer'
# 0
# Wordpress Engineer
# Select nama From titles Where nama like 'Wordpress Engineer'
# 0
# Working Permit Specialist
# Select nama From titles Where nama like 'Working Permit Specialist'
# 0
# Workshop Head
# Select nama From titles Where nama like 'Workshop Head'
# 0
# Workshop Manager
# Select nama From titles Where nama like 'Workshop Manager'
# 0
# Workshop Manager / Kepala Bengkel
# Select nama From titles Where nama like 'Workshop Manager / Kepala Bengkel'
# 0
# Workshop Production Manager
# Select nama From titles Where nama like 'Workshop Production Manager'
# 0
# Workshop Supervisor
# Select nama From titles Where nama like 'Workshop Supervisor'
# 0
# Workshophead
# Select nama From titles Where nama like 'Workshophead'
# 0
# Wwtp Supervisor
# Select nama From titles Where nama like 'Wwtp Supervisor'
# 0
# Youtube & Tiktok Content Writer & Idea Maker
# Select nama From titles Where nama like 'Youtube & Tiktok Content Writer & Idea Maker'
# 0
# Youtube Channel Specialist
# Select nama From titles Where nama like 'Youtube Channel Specialist'
# 0
# Youtube Content Creator
# Select nama From titles Where nama like 'Youtube Content Creator'
# 0
# done : 7105 row(s)
