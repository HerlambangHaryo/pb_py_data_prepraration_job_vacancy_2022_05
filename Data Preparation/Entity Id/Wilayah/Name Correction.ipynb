# %%
# Connect to DB
import datetime
datenow = datetime.datetime.now()

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
print(datenow)
# Out:
# connect
# 2022-06-12 18:29:41.920374

# %%
# set query 1
select = ' id, placement '
fromdb = 'jobstreet_raws_v2' 
where = ' group by placement ASC '
orderby = '  order by placement ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)   
    
    queryy = "Select id, nama From provinsis Where nama like '"+nama+"'  " 
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()
    
    counter = 1 
    for y in myresultc:   
        wilayah_id = str(y[0]) 
        word = y[1]   
        
        print(" ======================================> " + str(counter) + " / " + word)
        counter += 1
        
#         placement_provinsi_id 
    
        queryy = "UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '"+wilayah_id+"'  where placement like '"+nama+"' "
        print(queryy)
        mycursor.execute(queryy)
        mydb.commit()   
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# SELECT  id, placement  FROM `jobstreet_raws_v2`  group by placement ASC   order by placement ASC
# We start and please wait ...
# Aceh
#  ======================================> 1 / Aceh
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '1'  where placement like 'Aceh'
# Ambon
# Asahan Kisaran
# Badung
# Bali
#  ======================================> 1 / Bali
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '17'  where placement like 'Bali'
# Balikpapan
# Bandar Lampung
# Bandung
# Bangka
# Bangka Belitung
# Banjar
# Banjarbaru
# Banjarmasin
# Banjarnegara
# Banten
#  ======================================> 1 / Banten
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '16'  where placement like 'Banten'
# Bantul
# Banyuwangi
# Barito Timur
# Barito Utara
# Batam
# Bayan Lepas
# Bekasi
# Belitung
# Bengkulu
#  ======================================> 1 / Bengkulu
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '7'  where placement like 'Bengkulu'
# Bima
# Binjai
# ...

# %%
# set query 1
select = ' id, placement '
fromdb = 'jobstreet_raws_v2' 
where = ' group by placement ASC '
orderby = '  order by placement ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)   
    
    queryy = "Select id, nama From provinsis Where nama like '%"+nama+"%'  " 
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()
    
    counter = 1 
    for y in myresultc:   
        wilayah_id = str(y[0]) 
        word = y[1]   
        
        print(" ======================================> " + str(counter) + " / " + word)
        counter += 1
        
#         placement_provinsi_id 
    
        queryy = "UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '"+wilayah_id+"'  where placement like '"+nama+"' "
        print(queryy)
#         mycursor.execute(queryy)
#         mydb.commit()   
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# SELECT  id, placement  FROM `jobstreet_raws_v2`  group by placement ASC   order by placement ASC
# We start and please wait ...
# Aceh
#  ======================================> 1 / Aceh
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '1'  where placement like 'Aceh'
# Ambon
# Asahan Kisaran
# Badung
# Bali
#  ======================================> 1 / Bali
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '17'  where placement like 'Bali'
# Balikpapan
# Bandar Lampung
# Bandung
# Bangka
#  ======================================> 1 / Kepulauan Bangka Belitung
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '9'  where placement like 'Bangka'
# Bangka Belitung
#  ======================================> 1 / Kepulauan Bangka Belitung
# UPDATE jobstreet_raws_v2 SET placement_provinsi_id = '9'  where placement like 'Bangka Belitung'
# Banjar
# Banjarbaru
# Banjarmasin
# Banjarnegara
# Banten
#  ======================================> 1 / Banten
# ...

# %%
# set query 1
select = ' id, placement '
fromdb = 'jobstreet_raws_v2' 
where = ' where placement_provinsi_id is not null'
groupby = ' group by placement ASC '
orderby = '  order by placement ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + groupby +  orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)   
    
    queryy = "Select id, nama From kotas Where nama like '"+nama+"'  "
#     print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()
    
    counter = 1
    
    for y in myresultc:   
        wilayah_id = str(y[0]) 
        word = y[1]   
        
        print(" ======================================> " + str(counter) + " / " + word)
        counter += 1
        
#         placement_provinsi_id 
    
        queryy = "UPDATE jobstreet_raws_v2 SET placement_kota_id = '"+wilayah_id+"'  where placement like '"+nama+"' "
        print(queryy)
#         mycursor.execute(queryy)
#         mydb.commit()   
    
    
    
print('done : ' + str(len(myresult)) + ' row(s)')

# %%
# set query 1
select = ' id, placement '
fromdb = 'jobstreet_raws_v2' 
where = ' group by placement ASC '
orderby = '  order by placement ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)   
    
    queryy = "Select id, nama From kecamatans Where nama like '%"+nama+"%'  "
#     print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()
    
    counter = 1
    
    for y in myresultc:   
        job_vacancy_id = str(y[0]) 
        word = y[1]   
        
        print(" ======================================> " + str(counter) + " / " + word)
        counter += 1
    
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# SELECT  id, placement  FROM `jobstreet_raws_v2`  group by placement ASC   order by placement ASC
# We start and please wait ...
# Aceh
#  ======================================> 1 / Pulo Aceh
# Ambon
#  ======================================> 1 / Sambong
#  ======================================> 2 / Jambon
#  ======================================> 3 / Prambon
#  ======================================> 4 / Prambon
#  ======================================> 5 / Ngambon
#  ======================================> 6 / Teluk Ambon
#  ======================================> 7 / Kamboneri
# Asahan Kisaran
# Badung
# Bali
#  ======================================> 1 / Balige
#  ======================================> 2 / Koto Balingka
#  ======================================> 3 / Balik Bukit
#  ======================================> 4 / Rancabali
#  ======================================> 5 / Purbalingga
#  ======================================> 6 / Cibaliung
# ...

# %%
# set query 1
select = ' id, placement '
fromdb = 'jobstreet_raws_v2' 
where = ' group by placement ASC '
orderby = '  order by placement ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)   
    
    queryy = "Select id, nama From kelurahans Where nama like '%"+nama+"%'  "
#     print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()
    
    counter = 1
    
    for y in myresultc:   
        job_vacancy_id = str(y[0]) 
        word = y[1]   
        
        print(" ======================================> " + str(counter) + " / " + word)
        counter += 1
    
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# SELECT  id, placement  FROM `jobstreet_raws_v2`  group by placement ASC   order by placement ASC
# We start and please wait ...
# Aceh
#  ======================================> 1 / Seuneubok  Aceh
#  ======================================> 2 / Gampong Aceh
#  ======================================> 3 / Keude Aceh
#  ======================================> 4 / Seuneubok Aceh
#  ======================================> 5 / Seuneubok  Aceh
#  ======================================> 6 / Seuneubok  Aceh Baro
#  ======================================> 7 / Pasar Aceh
#  ======================================> 8 / Pasi Aceh
#  ======================================> 9 / Pasi Aceh. Tunong
#  ======================================> 10 / Pasi Aceh Baroh
#  ======================================> 11 / Saree Aceh
#  ======================================> 12 / Tumpok Aceh
#  ======================================> 13 / Seuneubok Aceh
#  ======================================> 14 / Selok Aceh
# ...
