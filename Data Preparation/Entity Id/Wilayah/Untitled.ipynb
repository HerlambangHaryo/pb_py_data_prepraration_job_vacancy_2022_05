# %%
# Connect to DB
import datetime
datenow = datetime.datetime.now()

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
print(datenow)
# Out:
# connect
# 2022-06-12 21:56:05.369699

# %%
# set query 1
select = ' id, placement '
fromdb = 'jobstreet_raws_v2' 
where = ' where placement_provinsi_id is null and placement_kota_id is null'
groupby = ' group by placement ASC '
orderby = '  order by placement ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + groupby +  orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)   
    
    queryy = "Select id, nama, kota_id From kecamatans Where nama like '"+nama+"'  "
#     print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()
    
    counter = 1
    
    for y in myresultc:   
        wilayah_id = str(y[0]) 
        word = y[1]   
        kota_id = str(y[2]) 
        
#         print(" ======================================> " + str(counter) + " / " + word)
        
#         placement_provinsi_id 
        if(len(myresultc) == 1):
            print(" ======================================> " + str(counter) + " / " + word)
            queryy = "UPDATE jobstreet_raws_v2 SET placement_kota_id = '"+wilayah_id+"' , placement_kota_id = '"+kota_id+"'         where placement like '"+nama+"' "
    #         print(queryy)
#             mycursor.execute(queryy)
#             mydb.commit()   
        counter += 1
    
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# SELECT  id, placement  FROM `jobstreet_raws_v2`  where placement_provinsi_id is null and placement_kota_id is null group by placement ASC   order by placement ASC
# We start and please wait ...
# Asahan Kisaran
# Bandung
# Bangka Belitung
# Banjar
# Bayan Lepas
# Bekasi
# Bima
# Blitar
# Bogor
# Cambodia
# Cibinong
# Cikarang
# Cikupa
#  ======================================> 1 / Cikupa
# Cileungsi
#  ======================================> 1 / Cileungsi
# Cirebon
# Citeureup
#  ======================================> 1 / Citeureup
# Cyberjaya
# Flores Timur Larantuka
# Gunung Kidul
# Halmahera
# Hong Kong
# Jakarta Barat
# Jakarta Pusat
# Jakarta Raya
# Jakarta Selatan
# Jakarta Timur
# Jakarta Utara
# Jayapura
#  ======================================> 1 / Jayapura
# Jember
# Jepara
#  ======================================> 1 / Jepara
# Karangasem
#  ======================================> 1 / Karangasem
# Karawang
# Kediri
# Kendari
#  ======================================> 1 / Kendari
# Ketapang
# Klaten
# Klungkung
#  ======================================> 1 / Klungkung
# Kota Banda Aceh
# Kotabaru
# Kotawaringin Barat
# Kotawaringin Timur
# Kuala Lumpur
# Kudus
# Kulon Progo
# Kupang
# Kuta
#  ======================================> 1 / Kuta
# Kutai Barat
# Kutai Kartanegara
# Kutai Timur
# Lhokseumawe
# Lombok
# Madiun
#  ======================================> 1 / Madiun
# Madura
# Magelang
# Mahakam Ulu
# Makassar
#  ======================================> 1 / Makassar
# Makati City
# Malang
# Malinau
# Maluku Barat
# Mamuju
#  ======================================> 1 / Mamuju
# Manado
# Manila City
# Manokwari
# Maros
# Mataram
#  ======================================> 1 / Mataram
# Medan
# Melawi
# Merauke
#  ======================================> 1 / Merauke
# Minahasa
# Mojokerto
# Muara Enim
#  ======================================> 1 / Muara Enim
# National Capital Reg
# Nunukan
#  ======================================> 1 / Nunukan
# Padang
#  ======================================> 1 / Padang
# Padang Sidempuan
# Palangkaraya
# Palembang
# Palopo
# Palu
# Pandeglang
#  ======================================> 1 / Pandeglang
# Pangkal Pinang
# Pare-Pare
# Paser
# Pasuruan
# Pekalongan
#  ======================================> 1 / Pekalongan
# Pekanbaru
# Pemalang
#  ======================================> 1 / Pemalang
# Pematangsiantar
# Penajam Paser Utara
# Petaling Jaya
# Pontianak
# Poso
# Prabumulih
# Probolinggo
# Purbalingga
#  ======================================> 1 / Purbalingga
# Purwakarta
# Purwokerto
# Purworejo
# Salatiga
#  ======================================> 1 / Salatiga
# Samarinda
# Sambas
#  ======================================> 1 / Sambas
# Semarang
# Seminyak
# Serang
#  ======================================> 1 / Serang
# Seruyan
# Sibolga
# Sidoarjo
#  ======================================> 1 / Sidoarjo
# Singkawang
# Sintang
#  ======================================> 1 / Sintang
# Sleman
#  ======================================> 1 / Sleman
# Sorong
# Sukabumi
# Sumbawa
#  ======================================> 1 / Sumbawa
# Surabaya
# Surakarta
# Tabalong
# Taiwan
# Tanah Laut
# Tangerang
#  ======================================> 1 / Tangerang
# Tanjung Pinang
# Tapanuli
# Tapin
# Tarakan
# Tasikmalaya
# Tegal
# Ternate
# Timika
# Timor-Leste
# Tuban
#  ======================================> 1 / Tuban
# Ubud
#  ======================================> 1 / Ubud
# Ungaran
# Wonogiri
# Yogyakarta
# done : 134 row(s)
