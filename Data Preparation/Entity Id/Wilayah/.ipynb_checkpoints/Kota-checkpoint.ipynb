# %%
# Connect to DB
import datetime
datenow = datetime.datetime.now()

host="localhost"
user="root"

# host="192.168.100.3"
# user="rootx"

import mysql.connector
mydb = mysql.connector.connect(
    host=host,
    user=user,
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')
print(datenow)
# Out:
# connect
# 2022-06-12 21:29:08.371120

# %%
# set query 1
select = ' id, placement '
fromdb = 'jobstreet_raws_v2' 
where = ' where placement_provinsi_id is null'
groupby = ' group by placement ASC '
orderby = '  order by placement ASC '

query_1 = "SELECT " + select + " FROM `" + fromdb + "` " + where + groupby +  orderby 
print(query_1)
# query 1
mycursor = mydb.cursor()
mycursor.execute(query_1)
myresult = mycursor.fetchall()

print('We start and please wait ...')

# loop query 1
for x in myresult:  
    id_benefit = str(x[0]) 
    nama = x[1]   
    
    print(nama)   
    
    queryy = "Select id, nama, provinsi_id From kotas Where nama like '"+nama+"'  "
#     print(queryy)
    mycursor.execute(queryy)
    myresultc = mycursor.fetchall()
    
    counter = 1
    
    for y in myresultc:   
        wilayah_id = str(y[0]) 
        word = y[1]   
        provinsi_id = str(y[2]) 
        
#         print(" ======================================> " + str(counter) + " / " + word)
        
#         placement_provinsi_id 
        if(len(myresultc) == 1):
            print(" ======================================> " + str(counter) + " / " + word)
            queryy = "UPDATE jobstreet_raws_v2 SET placement_kota_id = '"+wilayah_id+"' , placement_provinsi_id = '"+provinsi_id+"'         where placement like '"+nama+"' "
    #         print(queryy)
            mycursor.execute(queryy)
            mydb.commit()   
        counter += 1
    
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# SELECT  id, placement  FROM `jobstreet_raws_v2`  where placement_provinsi_id is null group by placement ASC   order by placement ASC
# We start and please wait ...
# Ambon
#  ======================================> 1 / Ambon
# Asahan Kisaran
# Badung
#  ======================================> 1 / Badung
# Balikpapan
#  ======================================> 1 / Balikpapan
# Bandar Lampung
#  ======================================> 1 / Bandar Lampung
# Bandung
# Bangka
#  ======================================> 1 / Bangka
# Bangka Belitung
# Banjar
# Banjarbaru
#  ======================================> 1 / Banjarbaru
# Banjarmasin
#  ======================================> 1 / Banjarmasin
# Banjarnegara
#  ======================================> 1 / Banjarnegara
# Bantul
#  ======================================> 1 / Bantul
# Banyuwangi
#  ======================================> 1 / Banyuwangi
# Barito Timur
#  ======================================> 1 / Barito Timur
# Barito Utara
#  ======================================> 1 / Barito Utara
# Batam
#  ======================================> 1 / Batam
# Bayan Lepas
# Bekasi
# Belitung
#  ======================================> 1 / Belitung
# Bima
# Binjai
#  ======================================> 1 / Binjai
# Bintan
#  ======================================> 1 / Bintan
# Bitung
#  ======================================> 1 / Bitung
# Blitar
# Bogor
# Bontang
#  ======================================> 1 / Bontang
# Brebes
#  ======================================> 1 / Brebes
# Bukittinggi
#  ======================================> 1 / Bukittinggi
# Bulungan
#  ======================================> 1 / Bulungan
# Buton
#  ======================================> 1 / Buton
# Cambodia
# Cianjur
#  ======================================> 1 / Cianjur
# Cibinong
# Cikarang
# Cikupa
# Cilacap
#  ======================================> 1 / Cilacap
# Cilegon
#  ======================================> 1 / Cilegon
# Cileungsi
# Cimahi
#  ======================================> 1 / Cimahi
# Cirebon
# Citeureup
# Cyberjaya
# Demak
#  ======================================> 1 / Demak
# Denpasar
#  ======================================> 1 / Denpasar
# Depok
#  ======================================> 1 / Depok
# Dumai
#  ======================================> 1 / Dumai
# Ende
#  ======================================> 1 / Ende
