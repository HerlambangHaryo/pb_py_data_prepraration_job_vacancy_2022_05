# %%
# Connect to DB

import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')

entity = 'industry'

# set query 1
select = ' id, created_at, ' + entity
fromdb = 'jobstreet_raws'
where = ' '
group = ' '
# Out:
# connect

# %%
# check distinct
group = ' Group By ' +  entity
orderby = ' Order By ' + entity + ' ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0])
    created_at = x[1]  
    word = x[2]    
    print(word) 
    
#     queryx = "insert into industries (nama) values ('"+word+"')  "  
#     print(queryx)
#     mycursor.execute(queryx)
#     mydb.commit()    
     
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# insert into industries (nama) values ('Agrikultural / Perkebunan / Peternakan Unggas / Perikanan')
# Akunting  /  Audit  /  Layanan Pajak
# insert into industries (nama) values ('Akunting  /  Audit  /  Layanan Pajak')
# Asuransi
# insert into industries (nama) values ('Asuransi')
# Automobil / Mesin Tambahan Automotif / Kendaraan
# insert into industries (nama) values ('Automobil / Mesin Tambahan Automotif / Kendaraan')
# Bahan Kimia / Pupuk / Pestisida
# insert into industries (nama) values ('Bahan Kimia / Pupuk / Pestisida')
# BioTeknologi / Farmasi / Riset klinik
# insert into industries (nama) values ('BioTeknologi / Farmasi / Riset klinik')
# Call Center / IT-Enabled Services / BPO
# insert into industries (nama) values ('Call Center / IT-Enabled Services / BPO')
# Elektrikal & Elektronik
# insert into industries (nama) values ('Elektrikal & Elektronik')
# Hiburan / Media
# insert into industries (nama) values ('Hiburan / Media')
# Hotel / Pariwisata
# insert into industries (nama) values ('Hotel / Pariwisata')
# Hukum / Legal
# insert into industries (nama) values ('Hukum / Legal')
# Ilmu Pengetahuan & Teknologi
# insert into industries (nama) values ('Ilmu Pengetahuan & Teknologi')
# Industri Berat / Mesin / Peralatan
# insert into industries (nama) values ('Industri Berat / Mesin / Peralatan')
# Jual Beli Saham / Sekuritas
# insert into industries (nama) values ('Jual Beli Saham / Sekuritas')
# Jurnalisme
# insert into industries (nama) values ('Jurnalisme')
# Kayu / Fiber / Kertas
# insert into industries (nama) values ('Kayu / Fiber / Kertas')
# Keamanan / Penegak hukum
# insert into industries (nama) values ('Keamanan / Penegak hukum')
# Kelautan / Aquakultur
# insert into industries (nama) values ('Kelautan / Aquakultur')
# Kesehatan / Medis
# insert into industries (nama) values ('Kesehatan / Medis')
# Komputer / Teknik Informatika (Perangkat Keras)
# insert into industries (nama) values ('Komputer / Teknik Informatika (Perangkat Keras)')
# Komputer / Teknik Informatika (Perangkat Lunak)
# insert into industries (nama) values ('Komputer / Teknik Informatika (Perangkat Lunak)')
# Konstruksi / Bangunan / Teknik
# insert into industries (nama) values ('Konstruksi / Bangunan / Teknik')
# Konsultasi (Bisnis & Manajemen)
# insert into industries (nama) values ('Konsultasi (Bisnis & Manajemen)')
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# insert into industries (nama) values ('Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)')
# Lainnya
# insert into industries (nama) values ('Lainnya')
# Layanan Umum / Tenaga Penggerak
# insert into industries (nama) values ('Layanan Umum / Tenaga Penggerak')
# Lingkungan / Kesehatan / Keamanan
# insert into industries (nama) values ('Lingkungan / Kesehatan / Keamanan')
# Luar Angkasa / Aviasi / Pesawat Terbang
# insert into industries (nama) values ('Luar Angkasa / Aviasi / Pesawat Terbang')
# Makanan & Minuman / Katering / Restoran
# insert into industries (nama) values ('Makanan & Minuman / Katering / Restoran')
# Manajemen / Konsulting HR
# insert into industries (nama) values ('Manajemen / Konsulting HR')
# Manufaktur / Produksi
# insert into industries (nama) values ('Manufaktur / Produksi')
# Minyak / Gas / Petroleum
# insert into industries (nama) values ('Minyak / Gas / Petroleum')
# Olahraga
# insert into industries (nama) values ('Olahraga')
# Organisasi Nirlaba / Pelayanan Sosial / LSM
# insert into industries (nama) values ('Organisasi Nirlaba / Pelayanan Sosial / LSM')
# Pakaian
# insert into industries (nama) values ('Pakaian')
# Pameran / Manajemen acara / PIKP
# insert into industries (nama) values ('Pameran / Manajemen acara / PIKP')
# Pelayanan Arsitek / Desain Interior
# insert into industries (nama) values ('Pelayanan Arsitek / Desain Interior')
# Pelayanan Perbaikan & Pemeliharaan
# insert into industries (nama) values ('Pelayanan Perbaikan & Pemeliharaan')
# Pemerintahan / Pertahanan
# insert into industries (nama) values ('Pemerintahan / Pertahanan')
# Pendidikan
# insert into industries (nama) values ('Pendidikan')
# Perawatan / Kecantikan / Fitnes
# insert into industries (nama) values ('Perawatan / Kecantikan / Fitnes')
# Perbankan / Pelayanan Keuangan
# insert into industries (nama) values ('Perbankan / Pelayanan Keuangan')
# Percetakan / Penerbitan
# insert into industries (nama) values ('Percetakan / Penerbitan')
# Periklanan / Marketing / Promosi / Hubungan Masyarakat
# insert into industries (nama) values ('Periklanan / Marketing / Promosi / Hubungan Masyarakat')
# Permata / Perhiasan
# insert into industries (nama) values ('Permata / Perhiasan')
# Pertambangan
# insert into industries (nama) values ('Pertambangan')
# Polymer / Plastik / Karet / Ban
# insert into industries (nama) values ('Polymer / Plastik / Karet / Ban')
# Produk Konsumen / Barang konsumen yang bergerak cepat
# insert into industries (nama) values ('Produk Konsumen / Barang konsumen yang bergerak cepat')
# Properti / Real Estate
# insert into industries (nama) values ('Properti / Real Estate')
# R&D
# insert into industries (nama) values ('R&D')
# Retail / Merchandise
# insert into industries (nama) values ('Retail / Merchandise')
# Seni / Desain / Fashion
# insert into industries (nama) values ('Seni / Desain / Fashion')
# Tekstil / Garment
# insert into industries (nama) values ('Tekstil / Garment')
# Telekomunikasi
# insert into industries (nama) values ('Telekomunikasi')
# Tembakau
# insert into industries (nama) values ('Tembakau')
# Transportasi / Logistik
# insert into industries (nama) values ('Transportasi / Logistik')
# Travel / Pariwisata
# insert into industries (nama) values ('Travel / Pariwisata')
# Umum & Grosir
# insert into industries (nama) values ('Umum & Grosir')
# done : 58 row(s)

# %%
group = ' '

# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group  )
myresult = mycursor.fetchall()
  
# set query 2
select_v2 = ' id, nama '
fromdb_v2 = 'industries'
where_v2 = ' where nama like ' 

# loop query 1
for x in myresult:  
    idx = str(x[0])
    created_at = x[1]  
    word = x[2]    
    print(word)
    
    query = "SELECT " + select_v2 + " FROM `" + fromdb_v2 + "` " + where_v2 + "'%" + word + "%'"
     
    mycursor2 = mydb.cursor()
    mycursor2.execute(query)
    myresult2 = mycursor2.fetchall()
    
    for y in myresult2:   
        idy = str(y[0])
         
        queryx = "UPDATE jobstreet_raws_v2 SET "+entity+" = '"+idy+"'   " 
        wherex = "  where id = '" + idx + "'"  
        print(queryx + wherex)
        mycursor.execute(queryx + wherex)
        mydb.commit()    
         
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '1'
# Hiburan / Media
# UPDATE jobstreet_raws_v2 SET industry = '9'     where id = '2'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '3'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '4'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '5'
# Kayu / Fiber / Kertas
# UPDATE jobstreet_raws_v2 SET industry = '16'     where id = '6'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '7'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '8'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '9'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '10'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '11'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '12'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '13'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '14'
# Hiburan / Media
# UPDATE jobstreet_raws_v2 SET industry = '9'     where id = '15'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '16'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '17'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '18'
# Kayu / Fiber / Kertas
# UPDATE jobstreet_raws_v2 SET industry = '16'     where id = '19'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '20'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '21'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '22'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '23'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '24'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '25'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '26'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '27'
# Komputer / Teknik Informatika (Perangkat Keras)
# UPDATE jobstreet_raws_v2 SET industry = '20'     where id = '28'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '29'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '30'
# Komputer / Teknik Informatika (Perangkat Keras)
# UPDATE jobstreet_raws_v2 SET industry = '20'     where id = '31'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '32'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '33'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '34'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '35'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '36'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '37'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '38'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '39'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '40'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '41'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '42'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '43'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '44'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '45'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '46'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '47'
# BioTeknologi / Farmasi / Riset klinik
# UPDATE jobstreet_raws_v2 SET industry = '6'     where id = '48'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '49'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '50'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '51'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '52'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '53'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '54'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '55'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '56'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '57'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '58'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '59'
# Tekstil / Garment
# UPDATE jobstreet_raws_v2 SET industry = '53'     where id = '60'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '61'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '62'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '63'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '64'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '65'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '66'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '67'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '68'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '69'
# BioTeknologi / Farmasi / Riset klinik
# UPDATE jobstreet_raws_v2 SET industry = '6'     where id = '70'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '71'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '72'
# Tekstil / Garment
# UPDATE jobstreet_raws_v2 SET industry = '53'     where id = '73'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '74'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '75'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '76'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '77'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '78'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '79'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '80'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '81'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '82'
# Minyak / Gas / Petroleum
# UPDATE jobstreet_raws_v2 SET industry = '32'     where id = '83'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '84'
# Tekstil / Garment
# UPDATE jobstreet_raws_v2 SET industry = '53'     where id = '85'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '86'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '87'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '88'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '89'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '90'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '91'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '92'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '93'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '94'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '95'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '96'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '97'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '98'
# BioTeknologi / Farmasi / Riset klinik
# UPDATE jobstreet_raws_v2 SET industry = '6'     where id = '99'
# Minyak / Gas / Petroleum
# UPDATE jobstreet_raws_v2 SET industry = '32'     where id = '100'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '101'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '102'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '103'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '104'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '105'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '106'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '107'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '108'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '109'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '110'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '111'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '112'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '113'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '114'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '115'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '116'
# Bahan Kimia / Pupuk / Pestisida
# UPDATE jobstreet_raws_v2 SET industry = '5'     where id = '117'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '118'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '119'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '120'
# Pameran / Manajemen acara / PIKP
# UPDATE jobstreet_raws_v2 SET industry = '36'     where id = '121'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '122'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '123'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '124'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '125'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '126'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '127'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '128'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '129'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '130'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '131'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '132'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '133'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '134'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '135'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '136'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '137'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '138'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '139'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '140'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '141'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '142'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '143'
# Seni / Desain / Fashion
# UPDATE jobstreet_raws_v2 SET industry = '52'     where id = '144'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '145'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '146'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '147'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '148'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '149'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '150'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '151'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '152'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '153'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '154'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '155'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '156'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '157'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '158'
# Hiburan / Media
# UPDATE jobstreet_raws_v2 SET industry = '9'     where id = '159'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '160'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '161'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '162'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '163'
# Pelayanan Arsitek / Desain Interior
# UPDATE jobstreet_raws_v2 SET industry = '37'     where id = '164'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '165'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '166'
# Lingkungan / Kesehatan / Keamanan
# UPDATE jobstreet_raws_v2 SET industry = '27'     where id = '167'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '168'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '169'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '170'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '171'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '172'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '173'
# Minyak / Gas / Petroleum
# UPDATE jobstreet_raws_v2 SET industry = '32'     where id = '174'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '175'
# Kelautan / Aquakultur
# UPDATE jobstreet_raws_v2 SET industry = '18'     where id = '176'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '177'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '178'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '179'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '180'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '181'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '182'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '183'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '184'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '185'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '186'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '187'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '188'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '189'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '190'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '191'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '192'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '193'
# Percetakan / Penerbitan
# UPDATE jobstreet_raws_v2 SET industry = '43'     where id = '194'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '195'
# Layanan Umum / Tenaga Penggerak
# UPDATE jobstreet_raws_v2 SET industry = '26'     where id = '196'
# Luar Angkasa / Aviasi / Pesawat Terbang
# UPDATE jobstreet_raws_v2 SET industry = '28'     where id = '197'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '198'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '199'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '200'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '201'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '202'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '203'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '204'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '205'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '206'
# Luar Angkasa / Aviasi / Pesawat Terbang
# UPDATE jobstreet_raws_v2 SET industry = '28'     where id = '207'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '208'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '209'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '210'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '211'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '212'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '213'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '214'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '215'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '216'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '217'
# Call Center / IT-Enabled Services / BPO
# UPDATE jobstreet_raws_v2 SET industry = '7'     where id = '218'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '219'
# Komputer / Teknik Informatika (Perangkat Keras)
# UPDATE jobstreet_raws_v2 SET industry = '20'     where id = '220'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '221'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '222'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '223'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '224'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '225'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '226'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '227'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '228'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '229'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '230'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '231'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '232'
# Komputer / Teknik Informatika (Perangkat Keras)
# UPDATE jobstreet_raws_v2 SET industry = '20'     where id = '233'
# Perawatan / Kecantikan / Fitnes
# UPDATE jobstreet_raws_v2 SET industry = '41'     where id = '234'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '235'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '236'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '237'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '238'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '239'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '240'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '241'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '242'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '243'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '244'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '245'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '246'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '247'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '248'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '249'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '250'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '251'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '252'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '253'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '254'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '255'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '256'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '257'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '258'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '259'
# Hotel / Pariwisata
# UPDATE jobstreet_raws_v2 SET industry = '10'     where id = '260'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '261'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '262'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '263'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '264'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '265'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '266'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '267'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '268'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '269'
# Minyak / Gas / Petroleum
# UPDATE jobstreet_raws_v2 SET industry = '32'     where id = '270'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '271'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '272'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '273'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '274'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '275'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '276'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '277'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '278'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '279'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '280'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '281'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '282'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '283'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '284'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '285'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '286'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '287'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '288'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '289'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '290'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '291'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '292'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '293'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '294'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '295'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '296'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '297'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '298'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '299'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '300'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '301'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '302'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '303'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '304'
# Bahan Kimia / Pupuk / Pestisida
# UPDATE jobstreet_raws_v2 SET industry = '5'     where id = '305'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '306'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '307'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '308'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '309'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '310'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '311'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '312'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '313'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '314'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '315'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '316'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '317'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '318'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '319'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '320'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '321'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '322'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '323'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '324'
# Bahan Kimia / Pupuk / Pestisida
# UPDATE jobstreet_raws_v2 SET industry = '5'     where id = '325'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '326'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '327'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '328'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '329'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '330'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '331'
# Akunting  /  Audit  /  Layanan Pajak
# UPDATE jobstreet_raws_v2 SET industry = '2'     where id = '332'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '333'
# Bahan Kimia / Pupuk / Pestisida
# UPDATE jobstreet_raws_v2 SET industry = '5'     where id = '334'
# Komputer / Teknik Informatika (Perangkat Keras)
# UPDATE jobstreet_raws_v2 SET industry = '20'     where id = '335'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '336'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '337'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '338'
# Seni / Desain / Fashion
# UPDATE jobstreet_raws_v2 SET industry = '52'     where id = '339'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '340'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '341'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '342'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '343'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '344'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '345'
# Perawatan / Kecantikan / Fitnes
# UPDATE jobstreet_raws_v2 SET industry = '41'     where id = '346'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '347'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '348'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '349'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '350'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '351'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '352'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '353'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '354'
# Akunting  /  Audit  /  Layanan Pajak
# UPDATE jobstreet_raws_v2 SET industry = '2'     where id = '355'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '356'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '357'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '358'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '359'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '360'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '361'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '362'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '363'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '364'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '365'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '366'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '367'
# Polymer / Plastik / Karet / Ban
# UPDATE jobstreet_raws_v2 SET industry = '47'     where id = '368'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '369'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '370'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '371'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '372'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '373'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '374'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '375'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '376'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '377'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '378'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '379'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '380'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '381'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '382'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '383'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '384'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '385'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '386'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '387'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '388'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '389'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '390'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '391'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '392'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '393'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '394'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '395'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '396'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '397'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '398'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '399'
# Minyak / Gas / Petroleum
# UPDATE jobstreet_raws_v2 SET industry = '32'     where id = '400'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '401'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '402'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '403'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '404'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '405'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '406'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '407'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '408'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '409'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '410'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '411'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '412'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '413'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '414'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '415'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '416'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '417'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '418'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '419'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '420'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '421'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '422'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '423'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '424'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '425'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '426'
# Perawatan / Kecantikan / Fitnes
# UPDATE jobstreet_raws_v2 SET industry = '41'     where id = '427'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '428'
# Pakaian
# UPDATE jobstreet_raws_v2 SET industry = '35'     where id = '429'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '430'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '431'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '432'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '433'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '434'
# Periklanan / Marketing / Promosi / Hubungan Masyarakat
# UPDATE jobstreet_raws_v2 SET industry = '44'     where id = '435'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '436'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '437'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '438'
# BioTeknologi / Farmasi / Riset klinik
# UPDATE jobstreet_raws_v2 SET industry = '6'     where id = '439'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '440'
# Kayu / Fiber / Kertas
# UPDATE jobstreet_raws_v2 SET industry = '16'     where id = '441'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '442'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '443'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '444'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '445'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '446'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '447'
# Hiburan / Media
# UPDATE jobstreet_raws_v2 SET industry = '9'     where id = '448'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '449'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '450'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '451'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '452'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '453'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '454'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '455'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '456'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '457'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '458'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '459'
# Perawatan / Kecantikan / Fitnes
# UPDATE jobstreet_raws_v2 SET industry = '41'     where id = '460'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '461'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '462'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '463'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '464'
# Konsultasi (Bisnis & Manajemen)
# UPDATE jobstreet_raws_v2 SET industry = '23'     where id = '465'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '466'
# Polymer / Plastik / Karet / Ban
# UPDATE jobstreet_raws_v2 SET industry = '47'     where id = '467'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '468'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '469'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '470'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '471'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '472'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '473'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '474'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '475'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '476'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '477'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '478'
# BioTeknologi / Farmasi / Riset klinik
# UPDATE jobstreet_raws_v2 SET industry = '6'     where id = '479'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '480'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '481'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '482'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '483'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '484'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '485'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '486'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '487'
# Periklanan / Marketing / Promosi / Hubungan Masyarakat
# UPDATE jobstreet_raws_v2 SET industry = '44'     where id = '488'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '489'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '490'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '491'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '492'
# Perawatan / Kecantikan / Fitnes
# UPDATE jobstreet_raws_v2 SET industry = '41'     where id = '493'
# Akunting  /  Audit  /  Layanan Pajak
# UPDATE jobstreet_raws_v2 SET industry = '2'     where id = '494'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '495'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '496'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '497'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '498'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '499'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '500'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '501'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '502'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '503'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '504'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '505'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '506'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '507'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '508'
# Makanan & Minuman / Katering / Restoran
# ...
# UPDATE jobstreet_raws_v2 SET industry = '2'     where id = '20444'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20445'
# Kayu / Fiber / Kertas
# UPDATE jobstreet_raws_v2 SET industry = '16'     where id = '20446'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '20447'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20448'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20449'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '20450'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '20451'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20452'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '20453'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '20454'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20455'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20456'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20457'
# Tekstil / Garment
# UPDATE jobstreet_raws_v2 SET industry = '53'     where id = '20458'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20459'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '20460'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20461'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20462'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20463'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '20464'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20465'
# Hotel / Pariwisata
# UPDATE jobstreet_raws_v2 SET industry = '10'     where id = '20466'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20467'
# Layanan Umum / Tenaga Penggerak
# UPDATE jobstreet_raws_v2 SET industry = '26'     where id = '20468'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20469'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20470'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20471'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '20472'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20473'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '20474'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20475'
# Hiburan / Media
# UPDATE jobstreet_raws_v2 SET industry = '9'     where id = '20476'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20477'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '20478'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '20479'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '20480'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '20481'
# Pelayanan Arsitek / Desain Interior
# UPDATE jobstreet_raws_v2 SET industry = '37'     where id = '20482'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20483'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20484'
# Tekstil / Garment
# UPDATE jobstreet_raws_v2 SET industry = '53'     where id = '20485'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20486'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20487'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20488'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '20489'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '20490'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20491'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '20492'
# Akunting  /  Audit  /  Layanan Pajak
# UPDATE jobstreet_raws_v2 SET industry = '2'     where id = '20493'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20494'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '20495'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20496'
# Minyak / Gas / Petroleum
# UPDATE jobstreet_raws_v2 SET industry = '32'     where id = '20497'
# Pelayanan Perbaikan & Pemeliharaan
# UPDATE jobstreet_raws_v2 SET industry = '38'     where id = '20498'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20499'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20500'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '20501'
# Minyak / Gas / Petroleum
# UPDATE jobstreet_raws_v2 SET industry = '32'     where id = '20502'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20503'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '20504'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20505'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20506'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '20507'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20508'
# Hotel / Pariwisata
# UPDATE jobstreet_raws_v2 SET industry = '10'     where id = '20509'
# Hotel / Pariwisata
# UPDATE jobstreet_raws_v2 SET industry = '10'     where id = '20510'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '20511'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '20512'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '20513'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '20514'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20515'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20516'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20517'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20518'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20519'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '20520'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20521'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20522'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '20523'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '20524'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '20525'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '20526'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20527'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20528'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20529'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20530'
# Pendidikan
# UPDATE jobstreet_raws_v2 SET industry = '40'     where id = '20531'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '20532'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '20533'
# Tekstil / Garment
# UPDATE jobstreet_raws_v2 SET industry = '53'     where id = '20534'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20535'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '20536'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '20537'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20538'
# Konstruksi / Bangunan / Teknik
# UPDATE jobstreet_raws_v2 SET industry = '22'     where id = '20539'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20540'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '20541'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '20542'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '20543'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '20544'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '20545'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20546'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '20547'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '20548'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20549'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '20550'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20551'
# Perawatan / Kecantikan / Fitnes
# UPDATE jobstreet_raws_v2 SET industry = '41'     where id = '20552'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20553'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '20554'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '20555'
# BioTeknologi / Farmasi / Riset klinik
# UPDATE jobstreet_raws_v2 SET industry = '6'     where id = '20556'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '20557'
# Lainnya
# UPDATE jobstreet_raws_v2 SET industry = '25'     where id = '20558'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '20559'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '20560'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20561'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '20562'
# Agrikultural / Perkebunan / Peternakan Unggas / Perikanan
# UPDATE jobstreet_raws_v2 SET industry = '1'     where id = '20563'
# Elektrikal & Elektronik
# UPDATE jobstreet_raws_v2 SET industry = '8'     where id = '20564'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '20565'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20566'
# Pelayanan Perbaikan & Pemeliharaan
# UPDATE jobstreet_raws_v2 SET industry = '38'     where id = '20567'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '20568'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '20569'
# Bahan Kimia / Pupuk / Pestisida
# UPDATE jobstreet_raws_v2 SET industry = '5'     where id = '20570'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20571'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '20572'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '20573'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '20574'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20575'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20576'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20577'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20578'
# Konsultasi (IT, Ilmu Pengetahuan, Teknis & Teknikal)
# UPDATE jobstreet_raws_v2 SET industry = '24'     where id = '20579'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20580'
# Transportasi / Logistik
# UPDATE jobstreet_raws_v2 SET industry = '56'     where id = '20581'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20582'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20583'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20584'
# Komputer / Teknik Informatika (Perangkat Keras)
# UPDATE jobstreet_raws_v2 SET industry = '20'     where id = '20585'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '20586'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20587'
# Pelayanan Arsitek / Desain Interior
# UPDATE jobstreet_raws_v2 SET industry = '37'     where id = '20588'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '20589'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '20590'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '20591'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20592'
# Produk Konsumen / Barang konsumen yang bergerak cepat
# UPDATE jobstreet_raws_v2 SET industry = '48'     where id = '20593'
# Manajemen / Konsulting HR
# UPDATE jobstreet_raws_v2 SET industry = '30'     where id = '20594'
# Pertambangan
# UPDATE jobstreet_raws_v2 SET industry = '46'     where id = '20595'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20596'
# Komputer / Teknik Informatika (Perangkat Lunak)
# UPDATE jobstreet_raws_v2 SET industry = '21'     where id = '20597'
# Manufaktur / Produksi
# UPDATE jobstreet_raws_v2 SET industry = '31'     where id = '20598'
# Properti / Real Estate
# UPDATE jobstreet_raws_v2 SET industry = '49'     where id = '20599'
# Asuransi
# UPDATE jobstreet_raws_v2 SET industry = '3'     where id = '20600'
# Bahan Kimia / Pupuk / Pestisida
# UPDATE jobstreet_raws_v2 SET industry = '5'     where id = '20601'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20602'
# Automobil / Mesin Tambahan Automotif / Kendaraan
# UPDATE jobstreet_raws_v2 SET industry = '4'     where id = '20603'
# Umum & Grosir
# UPDATE jobstreet_raws_v2 SET industry = '58'     where id = '20604'
# Retail / Merchandise
# UPDATE jobstreet_raws_v2 SET industry = '51'     where id = '20605'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '20606'
# Industri Berat / Mesin / Peralatan
# UPDATE jobstreet_raws_v2 SET industry = '13'     where id = '20607'
# Perbankan / Pelayanan Keuangan
# UPDATE jobstreet_raws_v2 SET industry = '42'     where id = '20608'
# Makanan & Minuman / Katering / Restoran
# UPDATE jobstreet_raws_v2 SET industry = '29'     where id = '20609'
# Telekomunikasi
# UPDATE jobstreet_raws_v2 SET industry = '54'     where id = '20610'
# Kesehatan / Medis
# UPDATE jobstreet_raws_v2 SET industry = '19'     where id = '20611'
# done : 20611 row(s)
