# %%
# Connect to DB

import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)
mycursor = mydb.cursor()
print('connect')

entity = 'title'

# set query 1
select = ' id, created_at, ' + entity + ", company, city, placement, address"
fromdb = 'jobstreet_raws'
where = ' '
group = ' '
# Out:
# connect

# %%
# check distinct
group = ' Group By ' +  entity
orderby = ' Order By ' + entity + ' ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0])
    created_at = x[1]  
    company = x[3]  
    city = x[4]  
    placement = x[5]  
    
    word = x[2].replace("\\u002F", " / ")    
    words = word + " // " + company
    words = word
    print(words) 
     
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# .NET - Angular Developer
# .NET CORE Developer
# .NET Developer
# .Net Developer C# (Karawaci)
# .NET Developers
# .Net Programmer
# (Doctor) Medical Advisor
# (JV2107008) Account Officer - Sales - Makassar
# (JV2108004) Account Officer - Sales - Direct & Leasing
# (JV2108005) Account Officer - Sales - Manado
# (JV2110009) Account Officer - Sales - Medan
# (JV2112007) Account Officer  Sales - Lampung
# (JV2203001) Account Officer - Direct Sales jakarta
# (JV2203003) Account Officer - Sales - Jember
# (JV2204003) Account Officer - Sales - Malang
# (JV2204004) MV Claim Controller
# (JV2205001) Account Officer - Sales - Surabaya
# (JV2205002) Account Officer - Sales - Denpasar
# (JV2205005) Account Officer - Sales - Pontianak
# (JV2205008) Underwriter Marine Hull
# (JV2205009) Surveyor - Semarang
# (JV2205010) Treasury Staff- Jakarta (Temporary)
# (JV2205012) Account Officer - Sales - Bandung
# (Programmable Logic Controller) PLC Engineer  /  Specialist
# ...

# %%
# Penempatan

# check distinct
group = ' Group By ' +  entity
orderby = ' Order By ' + entity + ' ASC '
 
# query 1
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group + orderby )
myresult = mycursor.fetchall()

print('We start and please wait ...')
# loop query 1
for x in myresult:  
    idx = str(x[0])
    created_at = x[1]  
    company = x[3]  
    
    city = x[4]  
    placement = x[5]  
    address = x[6]
    
    word = x[2].replace("\\u002F", " / ")    
#     words = word + " // " + company
    words = word
    
    if("Penempatan" in word) :
#         print(words) 
        penempatan_1 = words.split("Penempatan")[1]
        
        penempatan_2 = penempatan_1.replace(")","")
        penempatan_3 = penempatan_2.replace(":","")
        penempatan_4 = penempatan_3.replace("di","") 
        penempatan_5 = penempatan_4.replace("(","")
        
        penempatan = penempatan_5.strip()
        
        if("," in penempatan):
            asv = ''
        elif("&" in penempatan):
            asv = ''
        elif("dan" in penempatan):
            asv = ''
        else:
            wordx = penempatan + " // " + city + " // " + placement + " // " + address
            print(wordx)
     
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# We start and please wait ...
# Surabaya // Surabaya // Surabaya // Jl. Margomulyo 63
# Purwakarta // Purwakarta // Purwakarta //
# Palembang // Sumatera Selatan // Sumatera Selatan // palembang
# Lampung // Bandar Lampung // Bandar Lampung // Tanjung Karang
# Samarinda // Samarinda // Samarinda //
# Solo // Surakarta // Surakarta //
# Kebun Kalbar // Kalimantan Barat // Kalimantan Barat //
# Nabire Papua Site // Papua // Papua // Nabire
# Kalimantan Tengah // Kotawaringin Timur // Kotawaringin Timur // Sampit
# Area Surabaya // Jawa Timur // Jawa Timur // Ahmad Yani, Wiyung, Kedungdoro, Sidoarjo
# Bali // Bali // Bali // Gatot Subroto, Bypass
# Samarinda // Samarinda // Samarinda //
# Bandung // Bandung // Bandung //
# Cilacap // Cilacap // Cilacap //
# NTT // Nusa Tenggara Timur // Nusa Tenggara Timur // Sumba Timur
# Surakarta // Surakarta // Surakarta // Jl. Raya Palur, Surakarta
# Mega Kuningan // Jakarta Selatan // Jakarta Selatan // The East Building, Mega Kuningan
# ...
