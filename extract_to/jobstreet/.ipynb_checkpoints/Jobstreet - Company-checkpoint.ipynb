# %%
# Connect DB

import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="pr_scraping_job_vacancy_indonesia_2022_04"
)

# %%
# make Company _id

select = ' city, count(8) '
fromdb = 'jobstreet_raws'
where = '  '
group = ' GROUP by city ' 
 
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group  )
myresult = mycursor.fetchall()

counter = 1

for x in myresult:  
    words = x[0]  + " //--------------------------------------- " + x[1]  
    print(words)
     
#     query = "UPDATE jobstreet_raws SET company_id = '" + str(counter)+"'   " 
#     where = "  where company LIKE '" + x[0] + "'" 
#     andwhere = "  and city LIKE '" + x[1] + "'" 
#     print(query + where + andwhere)
#     mycursor.execute(query + where + andwhere)
#     mydb.commit()  
    
#     counter += 1
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Invalid use of group function
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [5], in <cell line: 9>()
#       6 group = ' GROUP by' + select
#       8 mycursor = mydb.cursor()
# ...

# %%
# make Company _id

select = ' company, city '
fromdb = 'jobstreet_raws'
where = '  '
group = ' GROUP by' + select
 
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group  )
myresult = mycursor.fetchall()

counter = 1

for x in myresult:  
    words = x[0]  + " //--------------------------------------- " + x[1]  
    print(words)
     
#     query = "UPDATE jobstreet_raws SET company_id = '" + str(counter)+"'   " 
#     where = "  where company LIKE '" + x[0] + "'" 
#     andwhere = "  and city LIKE '" + x[1] + "'" 
#     print(query + where + andwhere)
#     mycursor.execute(query + where + andwhere)
#     mydb.commit()  
    
#     counter += 1
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# (EF) English First for Adults Indonesia //--------------------------------------- Jakarta Raya
# (EF) English First for Adults Indonesia //--------------------------------------- Surabaya
# 3.6.9. Group //--------------------------------------- Surabaya
# 3E ACCOUNTING PTE LTD //--------------------------------------- Jakarta Raya
# A for Effort //--------------------------------------- Jakarta Selatan
# A&W Restaurants Indonesia //--------------------------------------- Jakarta Utara
# A2B Outsourcing //--------------------------------------- Bali
# AAA Consulting Limited (Jakarta) //--------------------------------------- Jakarta Raya
# Abadi Jaya Guangzhou Kosmetik //--------------------------------------- Jakarta Raya
# Abadi Jaya Guangzhou Kosmetik //--------------------------------------- Jakarta Timur
# Abadi Jaya Guangzhou Kosmetik //--------------------------------------- Jawa Timur
# Abadi Jaya Guangzhou Kosmetik //--------------------------------------- Tangerang
# ...

# %%
# make Company _id

select = ' company, city '
fromdb = 'jobstreet_raws'
where = '  '
group = ' GROUP by' + select
 
mycursor = mydb.cursor()
mycursor.execute("SELECT " + select + " FROM `" + fromdb + "` " + where + group  )
myresult = mycursor.fetchall()

counter = 1

for x in myresult:  
    words = x[0]  
    print(words)
     
    query = "UPDATE jobstreet_raws SET company_id = '" + str(counter)+"'   " 
    where = "  where company LIKE '" + x[0] + "'" 
    andwhere = "  and city LIKE '" + x[1] + "'" 
    print(query + where + andwhere)
    mycursor.execute(query + where + andwhere)
    mydb.commit()  
    
    counter += 1
    
    
print('done : ' + str(len(myresult)) + ' row(s)')
# Out:
# (EF) English First for Adults Indonesia
# UPDATE jobstreet_raws SET company_id = '1'     where company LIKE '(EF) English First for Adults Indonesia'  and city LIKE 'Jakarta Raya'
# (EF) English First for Adults Indonesia
# UPDATE jobstreet_raws SET company_id = '2'     where company LIKE '(EF) English First for Adults Indonesia'  and city LIKE 'Surabaya'
# 3.6.9. Group
# UPDATE jobstreet_raws SET company_id = '3'     where company LIKE '3.6.9. Group'  and city LIKE 'Surabaya'
# 3E ACCOUNTING PTE LTD
# UPDATE jobstreet_raws SET company_id = '4'     where company LIKE '3E ACCOUNTING PTE LTD'  and city LIKE 'Jakarta Raya'
# A for Effort
# UPDATE jobstreet_raws SET company_id = '5'     where company LIKE 'A for Effort'  and city LIKE 'Jakarta Selatan'
# A&W Restaurants Indonesia
# UPDATE jobstreet_raws SET company_id = '6'     where company LIKE 'A&W Restaurants Indonesia'  and city LIKE 'Jakarta Utara'
# A2B Outsourcing
# ...
